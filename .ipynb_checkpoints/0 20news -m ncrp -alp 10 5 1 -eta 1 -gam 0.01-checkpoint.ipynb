# %%
# %%javascript
# IPython.notebook.kernel.execute('nb_name = "' + IPython.notebook.notebook_name + '"')

# %%
# %load_ext autoreload
# %autoreload
from IPython.display import clear_output

import os
import pdb
import _pickle as cPickle
import time
import subprocess
import glob

import random
import numpy as np
import pandas as pd
import tensorflow as tf

from collections import defaultdict, Counter
from ncrp import Topic, Doc, init, sample, get_perplexity, get_topic_specialization, get_hierarchical_affinities, get_freq_tokens_ncrp, get_docs
from configure import get_config

# %% [markdown]
# # load config & data

# %%
config = get_config(nb_name)
np.random.seed(config.seed)
random.seed(config.seed)

# %%
instances_train, instances_dev, instances_test, word_to_idx, idx_to_word, bow_idxs = cPickle.load(open(config.path_data,'rb'))

# %%
config.n_doc = len(instances_train)
config.n_vocab = len(bow_idxs)
config.n_doc, config.n_vocab
# Out:
# (31943, 1035)

# %% [markdown]
# # run

# %% [markdown]
# ## initialize log

# %%
checkpoint = []
ppl_min = np.inf
epoch = 0

cmd_rm = 'rm -r %s' % config.dir_model
res = subprocess.call(cmd_rm.split())
cmd_mk = 'mkdir %s' % config.dir_model
res = subprocess.call(cmd_mk.split())

log_df = pd.DataFrame(columns=pd.MultiIndex.from_tuples(
                    list(zip(*[['','','','TRAIN:','VALID:','TEST:','SPEC:', '', '', 'HIER:', ''],
                            ['Time','Ep','Ct','PPL','PPL', 'PPL','1', '2', '3', 'CHILD', 'OTHER']]))))

def update_checkpoint(config, checkpoint, epoch):
    checkpoint.append(config.path_model + '-%i' % epoch)
    if len(checkpoint) > config.max_to_keep:
        path_model = checkpoint.pop(0)
        for p in glob.glob(path_model):
            os.remove(p)
    cPickle.dump(checkpoint, open(config.path_checkpoint, 'wb'))

# %% [markdown]
# ## initialize data

# %%
topic_root = Topic(idx='0', sibling_idx=0, parent=None, depth=0, config=config)
train_docs = get_docs(instances_train, config)
dev_docs = get_docs(instances_dev, config)
test_docs = get_docs(instances_test, config)
init(train_docs, dev_docs, test_docs, topic_root)
# Out:
# 0 10000 20000 30000 0 0

# %% [markdown]
# ## run

# %%
time_start = time.time()
while epoch < config.n_epochs:
    sample(train_docs, dev_docs, test_docs, topic_root)
    ppl_train = get_perplexity(train_docs, topic_root)
    ppl_dev = get_perplexity(dev_docs, topic_root)
    
    if ppl_dev < ppl_min:
        ppl_min = ppl_dev
        ppl_test = get_perplexity(test_docs, topic_root)
        cPickle.dump([test_docs, topic_root], open(config.path_model + '-%i'%epoch, 'wb'))
        update_checkpoint(config, checkpoint, epoch)
        
    depth_spec = get_topic_specialization(test_docs, topic_root)
    hierarchical_affinities = get_hierarchical_affinities(topic_root)
    
    clear_output()
    time_log = int(time.time() - time_start)
    time_start = time.time()
    log_series = pd.Series([time_log, epoch, 0, \
            '%.0f'%ppl_train, '%.0f'%ppl_dev, '%.0f'%ppl_test, \
            '%.2f'%depth_spec[1], '%.2f'%depth_spec[2], '%.2f'%depth_spec[3], \
            '%.2f'%hierarchical_affinities[0], '%.2f'%hierarchical_affinities[1]],
            index=log_df.columns)
    log_df.loc[epoch] = log_series    
    display(log_df)
    get_freq_tokens_ncrp(topic_root, idx_to_word, bow_idxs)
    
    cPickle.dump(log_df, open(config.path_log, 'wb'))
    epoch += 1
# Out:
#              TRAIN: VALID: TEST: SPEC:             HIER:
#   Time Ep Ct    PPL    PPL   PPL   PPL     1     2     3 CHILD
# 0  199  0  0    367    349   348  0.09  0.50  0.64  0.47  0.34
# 1  242  1  0    328    320   322  0.10  0.53  0.66  0.44  0.29
# 2  266  2  0    317    315   312  0.10  0.52  0.67  0.46  0.29
# 3  286  3  0    306    305   304  0.10  0.54  0.65  0.44  0.29
# 4  339  4  0    291    293   288  0.11  0.56  0.66  0.40  0.28
# 5  360  5  0    288    292   286  0.11  0.55  0.66  0.35  0.25
# 6  371  6  0    290    296   286  0.12  0.56  0.65  0.35  0.25
# 7  416  7  0    286    287   287  0.12  0.57  0.64  0.35  0.26
# 8  442  8  0    280    281   279  0.12  0.57  0.63  0.34  0.25
# 9  458  9  0    279    282   279  0.12  0.58  0.62  0.36  0.28
#  0 31943 273619.0 ! nice bought price quality love made 'm put recommend
#    0-1 1810 12189.0 ! love color cover mac perfectly perfect recommend pro sleeve
#      0-1-2 151 124.0 needed fix shape con fabric works snug bonus cushion quickly
#      0-1-4 308 234.0 mbp memory weak sony bulk hard card kuzy vaio dell
#      0-1-5 1351 1211.0 smell keyboard cover highly protector chromebook picture typing chemical angle
#    0-2 708 6143.0 travel carry work security airport easy compartments trip business pockets
#      0-2-1 117 113.0 netbook carry accommodate home handles change numerous found phone papers
#      0-2-2 534 522.0 dvd security player asked airport office tsa plane compartment shoulder
#      0-2-3 57 56.0 glad priced devices rolling essentials highly option purpose amount excellent
#    0-3 718 6845.0 pocket power netbook mouse cord room small charger carry acer
#      0-3-2 612 597.0 dvd player external portable accessories store usb drive size power
#      0-3-3 102 82.0 cables choice zip handles pouches slots vaio unlike ground helpful
#      0-3-4 4 9.0 road carried office son airplane important sold seat samsung finish
#    0-4 723 6637.0 bottom cover top months corners cracked speck piece plastic part
#      0-4-1 681 667.0 rubber annoying front keys hold month piece base pads keyboard
#      0-4-3 42 44.0 usage part adds positive trouble foam easily portion space makes
#    0-5 1767 13218.0 ! love carry & room perfect ; pockets ipad plenty
#      0-5-2 471 858.0 ; & work bring daughter bill large briefcase files tsa
#      0-5-3 557 417.0 business perfect office travel purse recommended roll beautiful lightweight wonderful
#      0-5-4 190 611.0 ; & holds roller player description travel retina / ?
#      0-5-5 549 620.0 player dvd camera lens portable comfortable canon carrier plenty room
#    0-6 2474 18634.0 ! cover color pro mac apple keyboard $ ordered ...
#      0-6-1 147 140.0 mine expensive plug review test concern wont honestly parts fingerprints
#      0-6-2 182 249.0 return item customer refund send correct hassle contacted wrong packaging
#      0-6-3 525 599.0 cover keyboard skin ipearl protector mcover free keys typing mouse
#      0-6-4 1620 1913.0 keyboard cover protector return item customer screen cases type retina
#    0-7 337 2603.0 cards sd memory card slots small plastic camera pockets sleeves
#      0-7-1 228 157.0 replaced usb larger lose feature thinking stay run slot storage
#      0-7-2 109 124.0 dvd player sony searching phone christmas shipped needed foam car
#    0-8 502 4509.0 broke zipper months quality strap year straps years return shoulder
#      0-8-1 42 43.0 desk papers quality cheaply lack kinda edge sort junk ended
#      0-8-2 45 47.0 damaged money backpacks worked zips waste month big making solution
#      0-8-3 415 381.0 break main amazon wheels stuck tabs office end entire customer
#    0-9 2112 16449.0 cover color ! love mac apple pro keyboard bottom hard
#      0-9-2 141 108.0 live aluminum regular model top stand note neat nicely crack
#      0-9-3 292 995.0 & ; corner model comfort sound piece portion returned air
#      0-9-4 394 1289.0 keyboard cover keys screen protector ; & type typing key
#      0-9-5 1259 1412.0 keyboard cover ; keys mbp show angle finish feet remove
#      0-9-6 26 25.0 unibody card perfect flexible kids specifically received amazing star accessory
#    0-10 630 6493.0 pocket pockets small water books bottle carry compartment front side
#      0-10-1 60 64.0 pencils safe lost surprise part paper pads downside stuff gray
#      0-10-2 282 302.0 cell flap reason weight documents metal professional downside doesnt waste
#      0-10-3 273 329.0 rain binder lunch plan gear ipad business empty lug compartments
#      0-10-4 15 16.0 books clip deep interior exterior sides bill portion thicker folder
#    0-11 1430 10111.0 sleeve inch pocket pro tight zipper netbook snug small extra
#      0-11-1 42 36.0 portion computers bulky sizes happier design ac texture charging big
#      0-11-2 3 2.0 protects briefcase zips flap finger fingerprints finish fitting fix flash
#      0-11-3 595 620.0 inches smell inch dimensions drive description screen chemical bigger player
#      0-11-4 304 1193.0 & ; smell barely dimensions wide description similar lenovo sized
#      0-11-5 267 421.0 ; retina & pro late display model expecting snuggly mbp
#      0-11-6 168 172.0 logic ac imagine time aspire item corners completely ordered ca
#      0-11-7 51 63.0 prevent foam series deep damage touch similar pads friends computers
#    0-12 460 4601.0 strap zipper handle months broke shoulder straps zippers started weeks
#      0-12-1 3 17.0 version floor offer clear ago spend thinner leaving section plane
#      0-12-2 34 20.0 trip purchasing flimsy adding plenty weekend check office plan side
#      0-12-3 413 376.0 smell closed times constantly month week binder metal days noticed
#      0-12-4 10 16.0 binder layer long crack slides downside warranty week ; lunch
#    0-13 907 8593.0 camera lenses carry pack room straps pockets plenty gear accessories
#      0-13-1 340 400.0 documents fall cables store pack plenty future fairly business swiss
#      0-13-2 371 935.0 camera canon lenses lens tripod body flash equipment battery attached
#      0-13-3 196 614.0 lens camera canon flash battery lenses batteries cards attached memory
#    0-14 1587 13230.0 cover bottom top plastic scratches hard keyboard apple mac color
#      0-14-1 230 699.0 keyboard protector screen cover keys key typing type included ended
#      0-14-2 324 390.0 bad keyboard dirty drop smell hands weeks serves keys cover
#      0-14-3 591 729.0 ports hole pros mcover touch cons edges : access left
#      0-14-4 442 425.0 mbp piece retina sit immediately order protecting display perfect portion
#    0-15 817 7101.0 carry back books heavy pack pockets straps stuff school work
#      0-15-1 70 81.0 dvd seat player pretty storage purchased attach basis tough bad
#      0-15-2 35 36.0 absolutely headphones tablet sizes make squeeze wear normal realize cushioned
#      0-15-3 628 587.0 stuff problem needed walk worn day car home files comfortably
#      0-15-4 76 88.0 bottle books brand husband supplies college fact avoid average important
#      0-15-5 8 5.0 friends cute pick compact makes zips fitting fine finger fingerprints
#    0-16 1576 14667.0 room pockets carry pocket plenty power strap mouse books shoulder
#      0-16-1 9 6.0 college hand barely replacement professional simply flap fix fitting find
#      0-16-2 345 337.0 dvd player portable sony vaio absolutely plenty usb carrier alot
#      0-16-3 2 0.0 zips fast floor flimsy flexible flaw flat flash flap fix
#      0-16-4 35 21.0 areas long home holds addition electronics sold bill stand owned
#      0-16-5 819 906.0 & ; pros ipad slim large cords tote folders extra
#      0-16-6 99 79.0 ipad box keys ipod needed ! slots pros fairly smaller
#      0-16-7 232 282.0 & ; rugged medium adapter internal compartment full documents constructed
#      0-16-8 35 35.0 size sewn easily wear tablet spacious kinda christmas organization ordered
#    0-17 5371 34306.0 ! 've zipper strap handle leather pockets years amazon sleeve
#      0-17-1 479 1006.0 smell strong smells odor chemical bad terrible return sleeve days
#      0-17-2 618 1578.0 & ; return item refund dimensions seller description amazon shipping
#      0-17-3 2148 2670.0 christmas orange loves gear books loved durable 've box day
#      0-17-4 1173 1738.0 & ; bags stitching nylon model fine make velcro decided
#      0-17-5 916 1177.0 ipad found item searching class zippers bigger ... real pleased
#      0-17-6 37 51.0 packaging awesome build ample set cracked mentioned helps heavier entire
#    0-18 2417 17967.0 sleeve protection air protect inside zipper padding neoprene pro soft
#      0-18-1 1118 1402.0 ipad smell mbp retina display chemical & zipper ; strong
#      0-18-2 299 716.0 & ; mbp late retina made acer pro sharp inexpensive
#      0-18-3 1000 980.0 scratches offer hp -inch stretch thicker asus dell blue form
#    0-19 1207 8300.0 mouse netbook power : -- usb cord drive works hard
#      0-19-1 281 1289.0 drive usb cable external port card hard ports dvd plug
#      0-19-2 518 928.0 smell screen protector keyboard strong cover mouse keys gave ;
#      0-19-3 407 522.0 dvd player mini unibody canon stick stores airport average buy
#      0-19-4 1 1.0 + zips fix fine finger fingerprints finish fitting flap find
#    0-20 2112 20334.0 strap pockets shoulder pocket carry compartment - straps room padding
#      0-20-1 459 819.0 & ; player dvd carrying car zip seat board break
#      0-20-2 805 1399.0 ; & - cons pros area strap comfortable phone security
#      0-20-3 722 1069.0 cord ` power plane mp pen mouse sides cables traveling
#      0-20-4 126 222.0 giving corner canvas messenger makes walking wanted gadgets cards stylish
#    0-21 2207 15586.0 sleeve padding protection cover inside pockets ipad zipper pocket protect
#      0-21-1 616 1539.0 & ; smell dvd player strong logic closed stand odor
#      0-21-2 969 1604.0 pink canon foam ; keyboard cons inside cover cut pros
#      0-21-3 553 800.0 ipad rubber add retina complaint prevent rest lined iphone wonderful
#      0-21-4 69 113.0 chromebook spacious trust dirt key pouches concerned slides made ton
#    0-22 71 487.0 smell odor left red samsung corner chemical ` kind slightly
#      0-22-1 71 207.0 smell & chemical feet days guess strong player parts smells
# 0 10000 20000 30000 0 0
