# %%
# %load_ext autoreload
# %autoreload
from IPython.display import clear_output

import os
import sys
import subprocess
import pdb
import time
import datetime
import math
import random
import _pickle as cPickle
from collections import defaultdict

from six.moves import zip_longest
import numpy as np

import tensorflow as tf
from tensorflow import distributions as tfd
from tensorflow.keras.preprocessing.sequence import pad_sequences

from data_structure import get_batches
from components import tf_log, sample_latents, compute_kl_loss, dynamic_rnn, dynamic_bi_rnn
from topic_model import TopicModel

from topic_beam_search_decoder import BeamSearchDecoder

# %%
PAD = '<pad>' # This has a vocab id, which is used to pad the encoder input, decoder input and target sequence
UNK = '<unk>' # This has a vocab id, which is used to represent out-of-vocabulary words
BOS = '<p>' # This has a vocab id, which is used at the beginning of every decoder input sequence
EOS = '</p>' # This has a vocab id, which is used at the end of untruncated target sequences

# %% [markdown]
# # load data & set config

# %%
def del_all_flags(FLAGS):
    flags_dict = FLAGS._flags()    
    keys_list = [keys for keys in flags_dict]    
    for keys in keys_list:
        FLAGS.__delattr__(keys)

del_all_flags(tf.flags.FLAGS)

flags = tf.app.flags

flags.DEFINE_string('gpu', '4', 'visible gpu')

flags.DEFINE_string('mode', 'train', 'set train or eval')

flags.DEFINE_string('data_path', 'data/apnews/instances.pkl', 'path of data')
flags.DEFINE_string('modeldir', 'model/tglm_vae_mean', 'directory of model')
flags.DEFINE_string('modelname', 'apnews', 'name of model')

flags.DEFINE_integer('epochs', 1000, 'epochs')
flags.DEFINE_integer('batch_size', 64, 'number of sentences in each batch')
flags.DEFINE_integer('log_period', 500, 'valid period')

flags.DEFINE_string('opt', 'Adagrad', 'optimizer')
flags.DEFINE_float('lr', 0.1, 'lr')
flags.DEFINE_float('reg', 1., 'regularization term')
flags.DEFINE_float('beta', 0.001, 'initial value of beta')
flags.DEFINE_float('grad_clip', 5., 'grad_clip')

flags.DEFINE_float('keep_prob', 0.8, 'dropout rate')
flags.DEFINE_float('word_keep_prob', 0.75, 'word dropout rate')

flags.DEFINE_integer('warmup', 2500, 'warmup period for KL')
flags.DEFINE_integer('warmup_topic', 0, 'warmup period for KL of topic')

flags.DEFINE_integer('beam_width', 2, 'beam_width')
flags.DEFINE_float('length_penalty_weight', 0.0, 'length_penalty_weight')

flags.DEFINE_integer('n_topic', 10, 'number of topic')
flags.DEFINE_integer('dim_hidden_bow', 256, 'dim of hidden bow')
flags.DEFINE_integer('dim_latent_bow', 32, 'dim of latent topic')
flags.DEFINE_integer('dim_emb', 256, 'dim_emb')
flags.DEFINE_integer('dim_hidden', 512, 'dim_hidden')
flags.DEFINE_integer('dim_hidden_topic', 512, 'dim_hidden_topic')
flags.DEFINE_integer('dim_latent', 32, 'dim_latent')
flags.DEFINE_bool('bidirectional', True, 'flg of bidirectional encoding')

# for evaluation
flags.DEFINE_string('refdir', 'ref', 'refdir')
flags.DEFINE_string('outdir', 'out', 'outdir')

flags.DEFINE_string('f', '', 'kernel')
flags.DEFINE_bool('logtostderr', True, 'kernel')
flags.DEFINE_bool('showprefixforinfo', False, '')
flags.DEFINE_bool('verbosity', False, '')
# flags.DEFINE_integer('stderrthreshold', 20, 'kernel')

config = flags.FLAGS

flags.DEFINE_string('modelpath', os.path.join(config.modeldir, config.modelname), 'path of model')

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = config.gpu

# %%
instances_train, instances_dev, instances_test, word_to_idx, idx_to_word, bow_idxs = cPickle.load(open(config.data_path,'rb'))

# %%
train_batches = get_batches(instances_train, config.batch_size)
dev_batches = get_batches(instances_dev, config.batch_size)
test_batches = get_batches(instances_test, config.batch_size)

# %%
flags.DEFINE_integer('PAD_IDX', word_to_idx[PAD], 'PAD_IDX')
flags.DEFINE_integer('UNK_IDX', word_to_idx[UNK], 'UNK_IDX')
flags.DEFINE_integer('BOS_IDX', word_to_idx[BOS], 'BOS_IDX')
flags.DEFINE_integer('EOS_IDX', word_to_idx[EOS], 'EOS_IDX')

flags.DEFINE_integer('n_vocab', len(word_to_idx), 'n_vocab')
flags.DEFINE_integer('dim_bow', len(bow_idxs), 'dim_bow')

maximum_iterations = max([max([instance.max_sent_l for instance in batch]) for ct, batch in dev_batches])
flags.DEFINE_integer('maximum_iterations', maximum_iterations, 'maximum_iterations')

# %% [markdown]
# # build language model

# %% [markdown]
# ## feed dict

# %%
tf.reset_default_graph()

t_variables = {}
t_variables['bow'] = tf.placeholder(tf.float32, [None, config.dim_bow], name='bow')
t_variables['input_token_idxs'] = tf.placeholder(tf.int32, [None, None], name='input_token_idxs')
t_variables['dec_input_idxs'] = tf.placeholder(tf.int32, [None, None], name='dec_input_idxs')
t_variables['dec_target_idxs'] = tf.placeholder(tf.int32, [None, None], name='dec_target_idxs')
t_variables['batch_l'] = tf.placeholder(tf.int32, name='batch_l')
t_variables['doc_l'] = tf.placeholder(tf.int32, [None], name='doc_l')
t_variables['sent_l'] = tf.placeholder(tf.int32, [None], name='sent_l')
t_variables['keep_prob'] = tf.placeholder(tf.float32, name='keep_prob')

# %%
def get_feed_dict(batch, mode='train', assertion=False):
    def token_dropout(sent_idxs):
        sent_idxs_dropout = np.asarray(sent_idxs)
        sent_idxs_dropout[np.random.rand(len(sent_idxs)) > config.word_keep_prob] = config.UNK_IDX
        return list(sent_idxs_dropout)

    bow = np.array([instance.bow for instance in batch]).astype(np.float32)
    
    doc_l = np.array([len(instance.token_idxs) for instance in batch])
    
    feed_input_token_idxs_list = [sent_idxs for instance in batch for sent_idxs in instance.token_idxs]
    feed_dec_input_idxs_list = [[config.BOS_IDX] + token_dropout(sent_idxs) for sent_idxs in feed_input_token_idxs_list]
    feed_dec_target_idxs_list = [sent_idxs + [config.EOS_IDX]  for sent_idxs in feed_input_token_idxs_list]
        
    sent_l = np.array([len(sent_idxs) for sent_idxs in feed_input_token_idxs_list], np.int32)
    batch_l = len(sent_l)
    
    feed_input_token_idxs = pad_sequences(feed_input_token_idxs_list, padding='post', value=config.PAD_IDX, dtype=np.int32)
    feed_dec_input_idxs = pad_sequences(feed_dec_input_idxs_list, padding='post', value=config.PAD_IDX, dtype=np.int32)
    feed_dec_target_idxs = pad_sequences(feed_dec_target_idxs_list, padding='post', value=config.PAD_IDX, dtype=np.int32)
    
    if assertion:
        index = 0
        for instance in batch:
            for line_idxs in instance.token_idxs:
                assert feed_input_token_idxs_list[index] == line_idxs
                index += 1
        assert feed_input_token_idxs.shape[1] == np.max(sent_l)
        assert feed_dec_input_idxs.shape[1] == np.max(sent_l) + 1
        assert feed_dec_target_idxs.shape[1] == np.max(sent_l) + 1
    
    keep_prob = config.keep_prob if mode == 'train' else 1.0

    feed_dict = {
                t_variables['bow']: bow, 
                t_variables['batch_l']: batch_l, t_variables['doc_l']: doc_l, t_variables['sent_l']: sent_l, 
                t_variables['input_token_idxs']: feed_input_token_idxs, t_variables['dec_input_idxs']: feed_dec_input_idxs, t_variables['dec_target_idxs']: feed_dec_target_idxs, 
                t_variables['keep_prob']: keep_prob
    }
    return  feed_dict

# %%
def debug_shape(variables):
    sample_batch = test_batches[0][1]
    feed_dict = get_feed_dict(sample_batch)
    _variables = sess.run(variables, feed_dict=feed_dict)
    for _variable, variable in zip(_variables, variables):
        if hasattr(variable, 'name'):
            print(variable.name, ':', _variable.shape)
        else:
            print(_variable.shape)

def debug_value(variables, return_value=False):
    sample_batch = test_batches[0][1]
    feed_dict = get_feed_dict(sample_batch)
    _variables = sess.run(variables, feed_dict=feed_dict)

    if return_value: 
        return _variables
    else:
        for _variable, variable in zip(_variables, variables):
            if hasattr(variable, 'name'):
                print(variable.name, ':', _variable)
            else:
                print(_variable)
                
def check_shape(variables):
    if 'sess' in globals(): raise
    sess = tf.Session()
    sess.run(tf.global_variables_initializer())
    
    sample_batch = test_batches[0][1]
    feed_dict = get_feed_dict(sample_batch)
    _variables = sess.run(variables, feed_dict=feed_dict)
    for _variable, variable in zip(_variables, variables):
        if hasattr(variable, 'name'):
            print(variable.name, ':', _variable.shape)
        else:
            print(_variable.shape)
            
    sess.close()
    
def check_value(variables):
    if 'sess' in globals(): raise
    sess = tf.Session()
    sess.run(tf.global_variables_initializer())
    
    sample_batch = test_batches[0][1]
    feed_dict = get_feed_dict(sample_batch)
    _variables = sess.run(variables, feed_dict=feed_dict)
    for _variable, variable in zip(_variables, variables):
        if hasattr(variable, 'name'):
            print(variable.name, ':', _variable)
        else:
            print(_variable.shape)
            
    sess.close()    
    
# sent_loss_kl_categ_tmp = tf.reduce_mean(tf.reduce_sum(tf.multiply(prob_topic_infer, tf_log(prob_topic_infer/prob_topic_sents)), 1))
# debug_value([sent_loss_kl_categ, sent_loss_kl_categ_tmp])
# sent_loss_kl_gauss_tmp = 0.5 * tf.reduce_sum(tf.exp(logvars_topic_infer-logvars_topic) + tf.square(means_topic - means_topic_infer) / tf.exp(logvars_topic) - 1 + (logvars_topic - logvars_topic_infer), -1)
# sent_loss_kl_gmm_tmp = tf.reduce_mean(tf.reduce_sum(tf.multiply(prob_topic_infer, sent_loss_kl_gauss_tmp), -1))
# debug_value([sent_loss_kl_gmm_tmp, sent_loss_kl_gmm])

# %% [markdown]
# ## topic model

# %%
# encode bow
with tf.variable_scope('topic/enc', reuse=False):
    hidden_bow_ = tf.layers.Dense(units=config.dim_hidden_bow, activation=tf.nn.relu, name='hidden_bow')(t_variables['bow'])
    hidden_bow = tf.layers.Dropout(t_variables['keep_prob'])(hidden_bow_)
    means_bow = tf.layers.Dense(units=config.dim_latent_bow, name='mean_bow')(hidden_bow)
    logvars_bow = tf.layers.Dense(units=config.dim_latent_bow, kernel_initializer=tf.constant_initializer(0), bias_initializer=tf.constant_initializer(0), name='logvar_topic')(hidden_bow)
    latents_bow = sample_latents(means_bow, logvars_bow) # sample latent vectors

    prob_topic = tf.layers.Dense(units=config.n_topic, activation=tf.nn.softmax, name='prob_topic')(latents_bow) # inference of topic probabilities

# decode bow
with tf.variable_scope('shared', reuse=False):
    embeddings = tf.get_variable('emb', [config.n_vocab, config.dim_emb], dtype=tf.float32, initializer=tf.contrib.layers.xavier_initializer()) # embeddings of vocab

bow_embeddings = tf.nn.embedding_lookup(embeddings, bow_idxs) # embeddings of each bow features

with tf.variable_scope('topic/dec', reuse=False):
    topic_embeddings = tf.get_variable('topic_emb', [config.n_topic, config.dim_emb], dtype=tf.float32, initializer=tf.contrib.layers.xavier_initializer()) # embeddings of topics

    topic_bow = tf.nn.softmax(tf.matmul(topic_embeddings, bow_embeddings, transpose_b=True), 1) # bow vectors for each topic
    logits_bow = tf_log(tf.matmul(prob_topic, topic_bow)) # predicted bow distribution

    # prior of each gaussian distribution (computed for each topic)
    hidden_topic = tf.layers.Dense(units=config.dim_hidden_topic, activation=tf.nn.relu, name='hidden_topic')(topic_bow)
    means_topic = tf.layers.Dense(units=config.dim_latent, name='mean_topic')(hidden_topic)
    logvars_topic = tf.layers.Dense(units=config.dim_latent, kernel_initializer=tf.constant_initializer(0), bias_initializer=tf.constant_initializer(0), name='logvar_topic')(hidden_topic)
    sigma_topic = tf.exp(0.5 * logvars_topic)
    gauss_topic = tfd.Normal(loc=means_topic, scale=sigma_topic)    
    
# define losses
topic_losses_recon = -tf.reduce_sum(tf.multiply(t_variables['bow'], logits_bow), 1)
topic_loss_recon = tf.reduce_mean(topic_losses_recon) # negative log likelihood of each words

topic_loss_kl = compute_kl_loss(means_bow, logvars_bow) # KL divergence b/w latent dist & gaussian std

means_topic_norm = means_topic / tf.norm(means_topic, axis=1, keepdims=True)
topic_dots = tf.clip_by_value(tf.matmul(means_topic_norm, tf.transpose(means_topic_norm)), -1., 1.)
topic_loss_reg = tf.reduce_mean(tf.square(topic_dots - tf.eye(config.n_topic)))
# topic_angles = tf.acos(topic_dots)
# topic_angles_mean = tf.reduce_mean(topic_angles)
# topic_angles_vars = tf.reduce_mean(tf.square(topic_angles - topic_angles_mean))
# topic_loss_reg = tf.exp(topic_angles_vars - topic_angles_mean)

# monitor
n_bow = tf.reduce_sum(t_variables['bow'], 1)
topic_ppls = tf.divide(topic_losses_recon, n_bow)
topics_freq_bow_indices = tf.nn.top_k(topic_bow, 10, name='topic_freq_bow').indices

# %% [markdown]
# ## encoder

# %%
# input
input_token_idxs = t_variables['input_token_idxs']
batch_l = t_variables['batch_l']
sent_l = t_variables['sent_l']
max_sent_l = tf.reduce_max(sent_l)

with tf.variable_scope('sent/enc', reuse=False):
    # get word embedding
    enc_input = tf.nn.embedding_lookup(embeddings, input_token_idxs)

    # get sentence embedding
    _, enc_state = dynamic_bi_rnn(enc_input, sent_l, config.dim_hidden, t_variables['keep_prob'])

    # TODO House Holder flow
    hidden_topic_infer =  tf.layers.Dense(units=config.dim_hidden, activation=tf.nn.relu, name='hidden_topic_infer')(enc_state)
    prob_topic_infer = tf.layers.Dense(units=config.n_topic, activation=tf.nn.softmax, name='prob_topic_infer')(hidden_topic_infer)

    w_mean_topic_infer = tf.get_variable('mean_topic_infer/kernel', [config.n_topic, enc_state.shape[-1], config.dim_latent], dtype=tf.float32)
    b_mean_topic_infer = tf.get_variable('mean_topic_infer/bias', [1, config.n_topic, config.dim_latent], dtype=tf.float32)
    means_topic_infer = tf.tensordot(enc_state, w_mean_topic_infer, axes=[[1], [1]]) + b_mean_topic_infer
    
    w_logvar_topic_infer = tf.get_variable('logvar_topic_infer/kernel', [config.n_topic, enc_state.shape[-1], config.dim_latent], dtype=tf.float32, initializer=tf.constant_initializer(0))
    b_logvar_topic_infer = tf.get_variable('logvar_topic_infer/bias', [1, config.n_topic, config.dim_latent], dtype=tf.float32, initializer=tf.constant_initializer(0))
    logvars_topic_infer = tf.tensordot(enc_state, w_logvar_topic_infer, axes=[[1], [1]]) + b_logvar_topic_infer
    sigma_topic_infer = tf.exp(0.5 * logvars_topic_infer)
    gauss_topic_infer = tfd.Normal(loc=means_topic_infer, scale=sigma_topic_infer)
    
    # latent vectors from each gaussian dist.
    latents_topic_infer = sample_latents(means_topic_infer, logvars_topic_infer) 
    # latent vector from gaussian mixture
    latents_input = tf.matmul(tf.expand_dims(prob_topic_infer, -1), latents_topic_infer, transpose_a=True)
    
    # for beam search
    means_input = tf.matmul(tf.expand_dims(prob_topic_infer, -1), means_topic_infer, transpose_a=True)

# %% [markdown]
# ## decoder

# %%
# prepare for decoding
dec_sent_l = tf.add(sent_l, 1)
dec_input_idxs = t_variables['dec_input_idxs']
dec_input = tf.nn.embedding_lookup(embeddings, dec_input_idxs)

dec_latents_input = tf.tile(latents_input, [1, tf.shape(dec_input)[1], 1])
dec_concat_input = tf.concat([dec_input, dec_latents_input], -1)

# decode for training
with tf.variable_scope('sent/dec/rnn', initializer=tf.contrib.layers.xavier_initializer(), dtype = tf.float32, reuse=False):
    dec_cell = tf.contrib.rnn.GRUCell(config.dim_hidden)
    dec_cell = tf.contrib.rnn.DropoutWrapper(dec_cell, output_keep_prob = t_variables['keep_prob'])

    dec_initial_state = tf.layers.Dense(units=config.dim_hidden, activation=tf.nn.relu, name='init_state')(tf.squeeze(latents_input, 1))
    
    helper = tf.contrib.seq2seq.TrainingHelper(inputs=dec_concat_input, sequence_length=dec_sent_l)

    train_decoder = tf.contrib.seq2seq.BasicDecoder(
        cell=dec_cell,
        helper=helper,
        initial_state=dec_initial_state)

    dec_outputs, _, output_sent_l = tf.contrib.seq2seq.dynamic_decode(train_decoder)
    
    output_layer = tf.layers.Dense(config.n_vocab, use_bias=False, name='out')
    output_logits = output_layer(dec_outputs.rnn_output)
    
    output_token_idxs = tf.argmax(output_logits, 2)

# %%
start_tokens = tf.fill([batch_l], config.BOS_IDX)
end_token = config.EOS_IDX

with tf.variable_scope('sent/dec/rnn', reuse=True):
    infer_dec_initial_state = tf.layers.Dense(units=config.dim_hidden, activation=tf.nn.relu, name='init_state')(tf.squeeze(means_input, 1))
    beam_dec_initial_state = tf.contrib.seq2seq.tile_batch(infer_dec_initial_state, multiplier=config.beam_width)
    beam_latents_input = tf.contrib.seq2seq.tile_batch(tf.squeeze(means_input, 1), multiplier=config.beam_width) # added
    
    beam_decoder = BeamSearchDecoder(
        cell=dec_cell,
        embedding=embeddings,
        start_tokens=start_tokens,
        end_token=end_token,
        initial_state=beam_dec_initial_state,
        beam_width=config.beam_width, 
        output_layer=output_layer,
        length_penalty_weight=config.length_penalty_weight,
        latents_input=beam_latents_input)

    beam_dec_outputs, _, _ = tf.contrib.seq2seq.dynamic_decode(
        beam_decoder,
        maximum_iterations = config.maximum_iterations)

    beam_output_token_idxs = beam_dec_outputs.predicted_ids[:, :, 0]

# %%
with tf.variable_scope('sent/dec/rnn', reuse=True):
    inter_means_input = tf.placeholder(tf.float32, [None, config.dim_latent])
    
    inter_dec_initial_state = tf.layers.Dense(units=config.dim_hidden, activation=tf.nn.relu, name='init_state')(inter_means_input)
    inter_beam_dec_initial_state = tf.contrib.seq2seq.tile_batch(inter_dec_initial_state, multiplier=config.beam_width)
    inter_beam_latents_input = tf.contrib.seq2seq.tile_batch(inter_means_input, multiplier=config.beam_width) # added
    
    inter_beam_decoder = BeamSearchDecoder(
        cell=dec_cell,
        embedding=embeddings,
        start_tokens=start_tokens,
        end_token=end_token,
        initial_state=inter_beam_dec_initial_state,
        beam_width=config.beam_width, 
        output_layer=output_layer,
        length_penalty_weight=config.length_penalty_weight,
        latents_input=inter_beam_latents_input)

    inter_beam_dec_outputs, _, _ = tf.contrib.seq2seq.dynamic_decode(
        inter_beam_decoder,
        maximum_iterations = config.maximum_iterations)

    inter_beam_output_token_idxs = inter_beam_dec_outputs.predicted_ids[:, :, 0]

# %%
with tf.variable_scope('sent/dec/rnn', reuse=True):
    topic_dec_initial_state = tf.layers.Dense(units=config.dim_hidden, activation=tf.nn.relu, name='init_state')(means_topic)
    topic_beam_dec_initial_state = tf.contrib.seq2seq.tile_batch(topic_dec_initial_state, multiplier=config.beam_width)
    topic_beam_latents_input = tf.contrib.seq2seq.tile_batch(means_topic, multiplier=config.beam_width) # added
    
    topic_beam_decoder = BeamSearchDecoder(
        cell=dec_cell,
        embedding=embeddings,
        start_tokens=start_tokens,
        end_token=end_token,
        initial_state=topic_beam_dec_initial_state,
        beam_width=config.beam_width, 
        output_layer=output_layer,
        length_penalty_weight=config.length_penalty_weight,
        latents_input=topic_beam_latents_input)

    topic_beam_dec_outputs, _, _ = tf.contrib.seq2seq.dynamic_decode(
        topic_beam_decoder,
        maximum_iterations = config.maximum_iterations)

    topic_beam_output_token_idxs = topic_beam_dec_outputs.predicted_ids[:, :, 0]

# %% [markdown]
# ## language modeling cost

# %%
# target and mask
dec_target_idxs = t_variables['dec_target_idxs']
dec_mask_tokens = tf.sequence_mask(dec_sent_l, maxlen=max_sent_l+1, dtype=tf.float32)

# nll for each token (averaged over batch & sentence)
sent_loss_recon = tf.contrib.seq2seq.sequence_loss(output_logits, dec_target_idxs, dec_mask_tokens)

# %%
doc_l = t_variables['doc_l']
mask_sents = tf.sequence_mask(doc_l)
mask_sents_flatten = tf.reshape(mask_sents, [tf.shape(mask_sents)[0]*tf.shape(mask_sents)[1]])

prob_topic_tiled = tf.tile(tf.expand_dims(prob_topic, 1), [1, tf.shape(mask_sents)[1], 1])
prob_topic_flatten = tf.reshape(prob_topic_tiled, [tf.shape(mask_sents)[0]*tf.shape(mask_sents)[1], config.n_topic])
prob_topic_sents = tf.boolean_mask(prob_topic_flatten, mask_sents_flatten)

# %%
# inferred mixture probabilities (computed for each sentence)
categ_topic_infer = tfd.Categorical(probs=prob_topic_infer)

# prior of mixture probabilities (computed for each document, tiled for each sentence)
categ_topic = tfd.Categorical(probs=prob_topic_sents)

sent_loss_kl_categ = tf.reduce_mean(tfd.kl_divergence(categ_topic_infer, categ_topic))

# inference of each gaussian gaussribution (computed for each sentence)

sent_loss_kl_gauss = tf.reduce_sum(tfd.kl_divergence(gauss_topic_infer, gauss_topic), -1)
sent_loss_kl_gmm = tf.reduce_mean(tf.reduce_sum(tf.multiply(prob_topic_infer, sent_loss_kl_gauss), -1))

sent_loss_kl = sent_loss_kl_categ + sent_loss_kl_gmm

# %% [markdown]
# ## optimizer

# %%
beta = tf.Variable(config.beta, name='beta', trainable=False) if config.warmup > 0 else tf.constant(1., name='beta')
update_beta = tf.assign_add(beta, 1./(config.warmup*len(train_batches)))
sent_loss = sent_loss_recon + beta * sent_loss_kl

topic_loss = topic_loss_recon + topic_loss_kl + config.reg * topic_loss_reg
loss = topic_loss + sent_loss

# define optimizer
if config.opt == 'Adam':
    optimizer = tf.train.AdamOptimizer(config.lr)
elif config.opt == 'Adagrad':
    optimizer = tf.train.AdagradOptimizer(config.lr)
    
grad_vars = optimizer.compute_gradients(loss)
clipped_grad_vars = [(tf.clip_by_value(grad, -config.grad_clip, config.grad_clip), var) for grad, var in grad_vars]

opt = optimizer.apply_gradients(clipped_grad_vars)
# Out:
# /home/m-isonuma/.pyenv/versions/anaconda2-5.3.0/envs/py36/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %% [markdown]
# # run model

# %%
def idxs_to_sents(token_idxs, config, idx_to_word):
    sents = []
    for sent_idxs in token_idxs:
        tokens = []
        for idx in sent_idxs:
            if idx == config.EOS_IDX: break
            tokens.append(idx_to_word[idx])
        sent = ' '.join(tokens)
        sents.append(sent)
    return sents

# %%
def get_loss(sess, batches):
    losses = []
    ppl_list = []
    for ct, batch in batches:
        feed_dict = get_feed_dict(batch, mode='test')
        loss_batch, topic_loss_batch, sent_loss_batch, ppls_batch = sess.run([loss, topic_loss, sent_loss, topic_ppls], feed_dict = feed_dict)
        losses += [[loss_batch, topic_loss_batch, sent_loss_batch]]
        ppl_list += list(ppls_batch)
    loss_mean, topic_loss_mean, sent_loss_mean = np.mean(losses, 0)
    ppl_mean = np.exp(np.mean(ppl_list))
    return loss_mean, topic_loss_mean, sent_loss_mean, ppl_mean

def get_all_losses(sess, batches):
    losses = []
    for ct, batch in batches:
        feed_dict = get_feed_dict(batch, mode='test')
        loss_batch, topic_loss_recon_batch, topic_loss_kl_batch, sent_loss_recon_batch, sent_loss_kl_batch = \
        sess.run([loss, topic_loss_recon, topic_loss_kl, sent_loss_recon, sent_loss_kl], feed_dict = feed_dict)
        losses += [[loss_batch, topic_loss_recon_batch, topic_loss_kl_batch, sent_loss_recon_batch, sent_loss_kl_batch]]
    print('LOSS %.2f | TM NLL: %.2f, KL: %.4f | LM NLL: %.2f, KL: %.4f' %  np.mean(losses, 0))

# %%
def print_sample(sample_batch):
    feed_dict = get_feed_dict(sample_batch)
    pred_token_idxs = sess.run(output_token_idxs, feed_dict = feed_dict)
    true_token_idxs = [sent_idxs for instance in sample_batch for sent_idxs in instance.token_idxs]
    
    assert len(pred_token_idxs) == len(true_token_idxs)
    
    pred_sents = idxs_to_sents(pred_token_idxs, config, idx_to_word)
    true_sents = idxs_to_sents(true_token_idxs, config, idx_to_word)
    
    for i, (true_sent, pred_sent) in enumerate(zip(true_sents, pred_sents)):        
        print(i, 'True: %s' % true_sent)
        print(i, 'Pred: %s' % pred_sent)

def print_topic_sample():
    pred_topics_freq_bow_indices, pred_topic_token_idxs = sess.run([topics_freq_bow_indices, topic_beam_output_token_idxs], 
                                                                                                           feed_dict={t_variables['batch_l']: config.n_topic, t_variables['keep_prob']: 1.,})
    pred_topic_sents = idxs_to_sents(pred_topic_token_idxs, config, idx_to_word)
    
    topics_freq_bow_idxs = bow_idxs[pred_topics_freq_bow_indices]
    
    print('-----------Topic Samples-----------')
    for i, (topic_freq_bow_idxs, pred_topic_sent) in enumerate(zip(topics_freq_bow_idxs, pred_topic_sents)):
        print(i, ' bow:', ' '.join([idx_to_word[idx] for idx in topic_freq_bow_idxs]))
        print(i, ' sent:', pred_topic_sent)

# %%
if 'sess' in globals(): sess.close()
sess = tf.Session()
sess.run(tf.global_variables_initializer())

logs = []
losses_train = []
ppls_train = []
loss_min = np.inf
beta_eval = 1.
epoch = 0
train_batches = get_batches(instances_train, config.batch_size, iterator=True)
saver = tf.train.Saver(max_to_keep=10)

# %%
if len(logs) == 0:
    cmd_rm = 'rm -r %s' % config.modeldir
    res = subprocess.call(cmd_rm.split())

    cmd_mk = 'mkdir %s' % config.modeldir
    res = subprocess.call(cmd_mk.split())

time_start = time.time()
while epoch < config.epochs:
    for ct, batch in train_batches:
        feed_dict = get_feed_dict(batch)
        if config.warmup > 0 and beta_eval < 1.0: sess.run(update_beta)

        _, loss_batch, topic_loss_recon_batch, topic_loss_kl_batch, topic_loss_reg_batch, sent_loss_recon_batch, sent_loss_kl_batch, sent_loss_kl_categ_batch, sent_loss_kl_gmm_batch, ppls_batch = \
        sess.run([opt, loss, topic_loss_recon, topic_loss_kl, topic_loss_reg, sent_loss_recon, sent_loss_kl, sent_loss_kl_categ, sent_loss_kl_gmm, topic_ppls], feed_dict = feed_dict)
        
        if sent_loss_kl_batch == np.inf:
            print('Nan occured')
#             pdb.set_trace()
            ckpt = tf.train.get_checkpoint_state(config.modeldir)
            model_checkpoint_path = ckpt.all_model_checkpoint_paths[-1]
            saver.restore(sess, model_checkpoint_path)            
            break
            
        losses_train += [[loss_batch, topic_loss_recon_batch, topic_loss_kl_batch, topic_loss_reg_batch, sent_loss_recon_batch, sent_loss_kl_batch]]
        ppls_train += list(ppls_batch)

        if ct%config.log_period==0:
            time_dev = time.time()
            loss_train, topic_loss_recon_train, topic_loss_kl_train, topic_loss_reg_train, sent_loss_recon_train, sent_loss_kl_train = np.mean(losses_train, 0)
            ppl_train = np.exp(np.mean(ppls_train))
            loss_dev, topic_loss_dev, sent_loss_dev, ppl_dev = get_loss(sess, dev_batches)
            
            if loss_dev < loss_min:
                loss_min = loss_dev
                saver.save(sess, config.modelpath, global_step=epoch*10000+ct)

            if config.warmup > 0: beta_eval = beta.eval(session=sess)

            clear_output()
            time_finish = time.time()
            time_log = int(time_finish - time_start)
            time_log_dev = int(time_finish - time_dev)
            logs += [(time_log, time_log_dev, epoch, ct, loss_train, ppl_train, topic_loss_recon_train, topic_loss_kl_train, topic_loss_reg_train, sent_loss_recon_train, sent_loss_kl_train, loss_dev, ppl_dev, topic_loss_dev, sent_loss_dev, beta_eval)]
            for log in logs:
                print('%03d[s], %02d[s], Ep: %02d, Ct: %05d|TR LOSS: %.0f, PPL: %.0f|TM NLL: %.0f, KL: %.2f, REG:%.2f | LM NLL: %.2f, KL: %.2f|DE LOSS: %.0f, PPL: %.0f, TM: %.0f, LM: %.2f|BETA: %.6f' %  log)

            print_sample(batch)

            time_start = time.time()
            
            print_topic_sample()
                
    epoch += 1
    train_batches = get_batches(instances_train, config.batch_size, iterator=True)
# Out:
# 032[s], 30[s], Ep: 00, Ct: 00000|TR LOSS: 335, PPL: 2661|TM NLL: 323, KL: 0.65, REG:0.90 | LM NLL: 10.34, KL: 1.43|DE LOSS: 348, PPL: 2656, TM: 338, LM: 10.34|BETA: 0.001000
# 106[s], 29[s], Ep: 00, Ct: 00500|TR LOSS: 328, PPL: 1643|TM NLL: 319, KL: 0.89, REG:0.90 | LM NLL: 7.46, KL: 14.65|DE LOSS: 320, PPL: 1465, TM: 313, LM: 6.84|BETA: 0.001069
# 104[s], 29[s], Ep: 00, Ct: 01000|TR LOSS: 326, PPL: 1521|TM NLL: 316, KL: 1.46, REG:0.90 | LM NLL: 7.15, KL: 13.25|DE LOSS: 318, PPL: 1358, TM: 311, LM: 6.74|BETA: 0.001139
# 105[s], 29[s], Ep: 00, Ct: 01500|TR LOSS: 324, PPL: 1457|TM NLL: 315, KL: 1.75, REG:0.90 | LM NLL: 7.02, KL: 11.57|DE LOSS: 316, PPL: 1300, TM: 309, LM: 6.83|BETA: 0.001208
# 105[s], 29[s], Ep: 00, Ct: 02000|TR LOSS: 323, PPL: 1414|TM NLL: 313, KL: 1.97, REG:0.90 | LM NLL: 6.95, KL: 10.46|DE LOSS: 314, PPL: 1251, TM: 307, LM: 6.61|BETA: 0.001277
# 105[s], 30[s], Ep: 00, Ct: 02500|TR LOSS: 322, PPL: 1374|TM NLL: 312, KL: 2.19, REG:0.90 | LM NLL: 6.89, KL: 9.72|DE LOSS: 313, PPL: 1200, TM: 306, LM: 6.58|BETA: 0.001347
# 087[s], 29[s], Ep: 01, Ct: 00000|TR LOSS: 321, PPL: 1346|TM NLL: 311, KL: 2.31, REG:0.90 | LM NLL: 6.86, KL: 9.29|DE LOSS: 312, PPL: 1181, TM: 305, LM: 6.54|BETA: 0.001400
# 105[s], 29[s], Ep: 01, Ct: 00500|TR LOSS: 320, PPL: 1317|TM NLL: 310, KL: 2.45, REG:0.90 | LM NLL: 6.82, KL: 8.84|DE LOSS: 311, PPL: 1146, TM: 304, LM: 6.51|BETA: 0.001469
# 106[s], 30[s], Ep: 01, Ct: 01000|TR LOSS: 319, PPL: 1294|TM NLL: 309, KL: 2.78, REG:0.90 | LM NLL: 6.78, KL: 8.48|DE LOSS: 310, PPL: 1131, TM: 304, LM: 6.44|BETA: 0.001539
# 106[s], 30[s], Ep: 01, Ct: 01500|TR LOSS: 319, PPL: 1273|TM NLL: 308, KL: 2.85, REG:0.90 | LM NLL: 6.75, KL: 8.19|DE LOSS: 309, PPL: 1107, TM: 303, LM: 6.39|BETA: 0.001608
# 106[s], 30[s], Ep: 01, Ct: 02000|TR LOSS: 318, PPL: 1255|TM NLL: 308, KL: 2.90, REG:0.90 | LM NLL: 6.71, KL: 7.97|DE LOSS: 309, PPL: 1099, TM: 303, LM: 6.34|BETA: 0.001677
# 119[s], 44[s], Ep: 01, Ct: 02500|TR LOSS: 318, PPL: 1239|TM NLL: 307, KL: 2.95, REG:0.90 | LM NLL: 6.68, KL: 7.85|DE LOSS: 309, PPL: 1090, TM: 303, LM: 6.33|BETA: 0.001746
# 088[s], 30[s], Ep: 02, Ct: 00000|TR LOSS: 317, PPL: 1230|TM NLL: 307, KL: 2.99, REG:0.90 | LM NLL: 6.66, KL: 7.88|DE LOSS: 308, PPL: 1081, TM: 302, LM: 6.23|BETA: 0.001800
# 106[s], 30[s], Ep: 02, Ct: 00500|TR LOSS: 317, PPL: 1216|TM NLL: 306, KL: 3.04, REG:0.90 | LM NLL: 6.62, KL: 8.04|DE LOSS: 308, PPL: 1068, TM: 302, LM: 6.12|BETA: 0.001869
# 106[s], 31[s], Ep: 02, Ct: 01000|TR LOSS: 317, PPL: 1204|TM NLL: 306, KL: 3.08, REG:0.90 | LM NLL: 6.58, KL: 8.22|DE LOSS: 307, PPL: 1055, TM: 301, LM: 6.08|BETA: 0.001938
# 126[s], 51[s], Ep: 02, Ct: 01500|TR LOSS: 316, PPL: 1193|TM NLL: 306, KL: 3.13, REG:0.90 | LM NLL: 6.55, KL: 8.41|DE LOSS: 307, PPL: 1045, TM: 301, LM: 5.99|BETA: 0.002008
# 083[s], 08[s], Ep: 02, Ct: 02000|TR LOSS: 316, PPL: 1183|TM NLL: 305, KL: 3.16, REG:0.90 | LM NLL: 6.52, KL: 8.61|DE LOSS: 307, PPL: 1046, TM: 301, LM: 5.91|BETA: 0.002077
# 105[s], 30[s], Ep: 02, Ct: 02500|TR LOSS: 316, PPL: 1173|TM NLL: 305, KL: 3.21, REG:0.90 | LM NLL: 6.48, KL: 8.82|DE LOSS: 306, PPL: 1039, TM: 301, LM: 5.85|BETA: 0.002147
# 111[s], 52[s], Ep: 03, Ct: 00000|TR LOSS: 315, PPL: 1167|TM NLL: 305, KL: 3.23, REG:0.90 | LM NLL: 6.45, KL: 8.99|DE LOSS: 306, PPL: 1036, TM: 301, LM: 5.81|BETA: 0.002200
# 083[s], 08[s], Ep: 03, Ct: 00500|TR LOSS: 315, PPL: 1158|TM NLL: 304, KL: 3.26, REG:0.90 | LM NLL: 6.42, KL: 9.25|DE LOSS: 306, PPL: 1031, TM: 301, LM: 5.78|BETA: 0.002269
# 106[s], 30[s], Ep: 03, Ct: 01000|TR LOSS: 315, PPL: 1151|TM NLL: 304, KL: 3.29, REG:0.90 | LM NLL: 6.38, KL: 9.50|DE LOSS: 306, PPL: 1028, TM: 300, LM: 5.66|BETA: 0.002339
# 105[s], 30[s], Ep: 03, Ct: 01500|TR LOSS: 314, PPL: 1144|TM NLL: 304, KL: 3.31, REG:0.90 | LM NLL: 6.35, KL: 9.74|DE LOSS: 306, PPL: 1034, TM: 300, LM: 5.60|BETA: 0.002408
# 105[s], 30[s], Ep: 03, Ct: 02000|TR LOSS: 314, PPL: 1139|TM NLL: 304, KL: 3.32, REG:0.90 | LM NLL: 6.32, KL: 9.98|DE LOSS: 306, PPL: 1027, TM: 300, LM: 5.53|BETA: 0.002477
# 105[s], 29[s], Ep: 03, Ct: 02500|TR LOSS: 314, PPL: 1133|TM NLL: 303, KL: 3.34, REG:0.90 | LM NLL: 6.28, KL: 10.24|DE LOSS: 305, PPL: 1026, TM: 300, LM: 5.48|BETA: 0.002547
# 088[s], 29[s], Ep: 04, Ct: 00000|TR LOSS: 314, PPL: 1129|TM NLL: 303, KL: 3.36, REG:0.90 | LM NLL: 6.26, KL: 10.45|DE LOSS: 305, PPL: 1024, TM: 300, LM: 5.42|BETA: 0.002600
# 107[s], 32[s], Ep: 04, Ct: 00500|TR LOSS: 314, PPL: 1124|TM NLL: 303, KL: 3.37, REG:0.90 | LM NLL: 6.22, KL: 10.74|DE LOSS: 305, PPL: 1023, TM: 300, LM: 5.34|BETA: 0.002669
# 105[s], 29[s], Ep: 04, Ct: 01000|TR LOSS: 313, PPL: 1119|TM NLL: 303, KL: 3.39, REG:0.90 | LM NLL: 6.19, KL: 11.04|DE LOSS: 305, PPL: 1017, TM: 300, LM: 5.29|BETA: 0.002739
# 083[s], 08[s], Ep: 04, Ct: 01500|TR LOSS: 313, PPL: 1115|TM NLL: 303, KL: 3.40, REG:0.90 | LM NLL: 6.15, KL: 11.33|DE LOSS: 305, PPL: 1018, TM: 300, LM: 5.27|BETA: 0.002808
# 106[s], 30[s], Ep: 04, Ct: 02000|TR LOSS: 313, PPL: 1111|TM NLL: 303, KL: 3.42, REG:0.90 | LM NLL: 6.12, KL: 11.62|DE LOSS: 305, PPL: 1016, TM: 300, LM: 5.21|BETA: 0.002878
# 106[s], 30[s], Ep: 04, Ct: 02500|TR LOSS: 313, PPL: 1107|TM NLL: 302, KL: 3.43, REG:0.90 | LM NLL: 6.09, KL: 11.90|DE LOSS: 305, PPL: 1012, TM: 300, LM: 5.13|BETA: 0.002947
# 066[s], 08[s], Ep: 05, Ct: 00000|TR LOSS: 313, PPL: 1104|TM NLL: 302, KL: 3.43, REG:0.90 | LM NLL: 6.06, KL: 12.12|DE LOSS: 305, PPL: 1017, TM: 300, LM: 5.11|BETA: 0.003000
# 084[s], 08[s], Ep: 05, Ct: 00500|TR LOSS: 313, PPL: 1101|TM NLL: 302, KL: 3.45, REG:0.90 | LM NLL: 6.03, KL: 12.41|DE LOSS: 305, PPL: 1019, TM: 300, LM: 5.08|BETA: 0.003070
# 106[s], 30[s], Ep: 05, Ct: 01000|TR LOSS: 312, PPL: 1098|TM NLL: 302, KL: 3.46, REG:0.90 | LM NLL: 6.00, KL: 12.70|DE LOSS: 305, PPL: 1016, TM: 300, LM: 4.99|BETA: 0.003139
# 105[s], 30[s], Ep: 05, Ct: 01500|TR LOSS: 312, PPL: 1095|TM NLL: 302, KL: 3.47, REG:0.90 | LM NLL: 5.97, KL: 13.00|DE LOSS: 305, PPL: 1012, TM: 300, LM: 4.94|BETA: 0.003208
# 106[s], 30[s], Ep: 05, Ct: 02000|TR LOSS: 312, PPL: 1092|TM NLL: 302, KL: 3.48, REG:0.90 | LM NLL: 5.94, KL: 13.29|DE LOSS: 304, PPL: 1015, TM: 300, LM: 4.91|BETA: 0.003278
# 106[s], 30[s], Ep: 05, Ct: 02500|TR LOSS: 312, PPL: 1089|TM NLL: 302, KL: 3.49, REG:0.90 | LM NLL: 5.91, KL: 13.58|DE LOSS: 304, PPL: 1010, TM: 299, LM: 4.87|BETA: 0.003347
# 088[s], 30[s], Ep: 06, Ct: 00000|TR LOSS: 312, PPL: 1087|TM NLL: 302, KL: 3.49, REG:0.90 | LM NLL: 5.88, KL: 13.80|DE LOSS: 304, PPL: 1007, TM: 299, LM: 4.87|BETA: 0.003400
# 085[s], 08[s], Ep: 06, Ct: 00500|TR LOSS: 312, PPL: 1084|TM NLL: 302, KL: 3.50, REG:0.90 | LM NLL: 5.85, KL: 14.08|DE LOSS: 304, PPL: 1011, TM: 300, LM: 4.77|BETA: 0.003470
# 083[s], 08[s], Ep: 06, Ct: 01000|TR LOSS: 312, PPL: 1082|TM NLL: 301, KL: 3.51, REG:0.90 | LM NLL: 5.83, KL: 14.37|DE LOSS: 304, PPL: 1015, TM: 300, LM: 4.73|BETA: 0.003539
# 083[s], 08[s], Ep: 06, Ct: 01500|TR LOSS: 312, PPL: 1079|TM NLL: 301, KL: 3.52, REG:0.90 | LM NLL: 5.80, KL: 14.64|DE LOSS: 304, PPL: 1010, TM: 300, LM: 4.76|BETA: 0.003609
# 105[s], 29[s], Ep: 06, Ct: 02000|TR LOSS: 312, PPL: 1077|TM NLL: 301, KL: 3.52, REG:0.90 | LM NLL: 5.77, KL: 14.92|DE LOSS: 304, PPL: 1009, TM: 299, LM: 4.67|BETA: 0.003678
# 105[s], 29[s], Ep: 06, Ct: 02500|TR LOSS: 311, PPL: 1075|TM NLL: 301, KL: 3.53, REG:0.90 | LM NLL: 5.74, KL: 15.19|DE LOSS: 304, PPL: 1007, TM: 299, LM: 4.63|BETA: 0.003747
# 087[s], 29[s], Ep: 07, Ct: 00000|TR LOSS: 311, PPL: 1074|TM NLL: 301, KL: 3.54, REG:0.90 | LM NLL: 5.72, KL: 15.39|DE LOSS: 304, PPL: 1004, TM: 299, LM: 4.61|BETA: 0.003801
# 083[s], 08[s], Ep: 07, Ct: 00500|TR LOSS: 311, PPL: 1071|TM NLL: 301, KL: 3.54, REG:0.90 | LM NLL: 5.69, KL: 15.66|DE LOSS: 304, PPL: 1009, TM: 299, LM: 4.60|BETA: 0.003870
# 083[s], 08[s], Ep: 07, Ct: 01000|TR LOSS: 311, PPL: 1069|TM NLL: 301, KL: 3.55, REG:0.90 | LM NLL: 5.66, KL: 15.92|DE LOSS: 304, PPL: 1002, TM: 299, LM: 4.56|BETA: 0.003939
# 083[s], 08[s], Ep: 07, Ct: 01500|TR LOSS: 311, PPL: 1068|TM NLL: 301, KL: 3.56, REG:0.90 | LM NLL: 5.64, KL: 16.18|DE LOSS: 304, PPL: 1010, TM: 300, LM: 4.63|BETA: 0.004009
# 105[s], 30[s], Ep: 07, Ct: 02000|TR LOSS: 311, PPL: 1066|TM NLL: 301, KL: 3.56, REG:0.90 | LM NLL: 5.61, KL: 16.43|DE LOSS: 304, PPL: 1002, TM: 299, LM: 4.53|BETA: 0.004078
# 083[s], 08[s], Ep: 07, Ct: 02500|TR LOSS: 311, PPL: 1064|TM NLL: 301, KL: 3.57, REG:0.90 | LM NLL: 5.59, KL: 16.68|DE LOSS: 304, PPL: 1007, TM: 299, LM: 4.43|BETA: 0.004148
# 099[s], 41[s], Ep: 08, Ct: 00000|TR LOSS: 311, PPL: 1063|TM NLL: 301, KL: 3.57, REG:0.90 | LM NLL: 5.57, KL: 16.87|DE LOSS: 304, PPL: 1002, TM: 299, LM: 4.43|BETA: 0.004201
# 105[s], 30[s], Ep: 08, Ct: 00500|TR LOSS: 311, PPL: 1061|TM NLL: 301, KL: 3.57, REG:0.90 | LM NLL: 5.54, KL: 17.11|DE LOSS: 304, PPL: 1005, TM: 299, LM: 4.37|BETA: 0.004270
# 083[s], 08[s], Ep: 08, Ct: 01000|TR LOSS: 311, PPL: 1060|TM NLL: 301, KL: 3.58, REG:0.90 | LM NLL: 5.52, KL: 17.36|DE LOSS: 304, PPL: 1005, TM: 299, LM: 4.34|BETA: 0.004340
# 126[s], 50[s], Ep: 08, Ct: 01500|TR LOSS: 311, PPL: 1058|TM NLL: 301, KL: 3.59, REG:0.90 | LM NLL: 5.49, KL: 17.60|DE LOSS: 303, PPL: 1000, TM: 299, LM: 4.31|BETA: 0.004409
# 129[s], 54[s], Ep: 08, Ct: 02000|TR LOSS: 310, PPL: 1057|TM NLL: 300, KL: 3.59, REG:0.90 | LM NLL: 5.47, KL: 17.84|DE LOSS: 303, PPL: 1002, TM: 299, LM: 4.27|BETA: 0.004478
# 083[s], 08[s], Ep: 08, Ct: 02500|TR LOSS: 310, PPL: 1056|TM NLL: 300, KL: 3.59, REG:0.90 | LM NLL: 5.44, KL: 18.07|DE LOSS: 303, PPL: 1002, TM: 299, LM: 4.27|BETA: 0.004548
# 092[s], 33[s], Ep: 09, Ct: 00000|TR LOSS: 310, PPL: 1055|TM NLL: 300, KL: 3.60, REG:0.90 | LM NLL: 5.42, KL: 18.25|DE LOSS: 303, PPL: 999, TM: 299, LM: 4.21|BETA: 0.004601
# 105[s], 30[s], Ep: 09, Ct: 00500|TR LOSS: 310, PPL: 1053|TM NLL: 300, KL: 3.60, REG:0.90 | LM NLL: 5.40, KL: 18.48|DE LOSS: 303, PPL: 1003, TM: 299, LM: 4.20|BETA: 0.004670
# 084[s], 08[s], Ep: 09, Ct: 01000|TR LOSS: 310, PPL: 1052|TM NLL: 300, KL: 3.61, REG:0.90 | LM NLL: 5.38, KL: 18.70|DE LOSS: 303, PPL: 1004, TM: 299, LM: 4.18|BETA: 0.004740
# 084[s], 08[s], Ep: 09, Ct: 01500|TR LOSS: 310, PPL: 1051|TM NLL: 300, KL: 3.61, REG:0.90 | LM NLL: 5.35, KL: 18.93|DE LOSS: 303, PPL: 1002, TM: 299, LM: 4.15|BETA: 0.004809
# 105[s], 29[s], Ep: 09, Ct: 02000|TR LOSS: 310, PPL: 1050|TM NLL: 300, KL: 3.61, REG:0.90 | LM NLL: 5.33, KL: 19.14|DE LOSS: 303, PPL: 997, TM: 299, LM: 4.15|BETA: 0.004879
# 105[s], 29[s], Ep: 09, Ct: 02500|TR LOSS: 310, PPL: 1049|TM NLL: 300, KL: 3.62, REG:0.90 | LM NLL: 5.31, KL: 19.36|DE LOSS: 303, PPL: 998, TM: 299, LM: 4.09|BETA: 0.004948
# 067[s], 08[s], Ep: 10, Ct: 00000|TR LOSS: 310, PPL: 1048|TM NLL: 300, KL: 3.62, REG:0.90 | LM NLL: 5.29, KL: 19.52|DE LOSS: 303, PPL: 997, TM: 299, LM: 4.07|BETA: 0.005001
# 132[s], 56[s], Ep: 10, Ct: 00500|TR LOSS: 310, PPL: 1047|TM NLL: 300, KL: 3.62, REG:0.90 | LM NLL: 5.27, KL: 19.73|DE LOSS: 303, PPL: 999, TM: 299, LM: 4.06|BETA: 0.005071
# 081[s], 07[s], Ep: 10, Ct: 01000|TR LOSS: 310, PPL: 1045|TM NLL: 300, KL: 3.63, REG:0.90 | LM NLL: 5.25, KL: 19.94|DE LOSS: 303, PPL: 998, TM: 299, LM: 4.03|BETA: 0.005140
# 083[s], 08[s], Ep: 10, Ct: 01500|TR LOSS: 310, PPL: 1044|TM NLL: 300, KL: 3.63, REG:0.90 | LM NLL: 5.23, KL: 20.14|DE LOSS: 303, PPL: 997, TM: 299, LM: 4.03|BETA: 0.005209
# 129[s], 54[s], Ep: 10, Ct: 02000|TR LOSS: 310, PPL: 1043|TM NLL: 300, KL: 3.64, REG:0.90 | LM NLL: 5.21, KL: 20.34|DE LOSS: 303, PPL: 996, TM: 299, LM: 3.99|BETA: 0.005279
# 151[s], 77[s], Ep: 10, Ct: 02500|TR LOSS: 310, PPL: 1042|TM NLL: 300, KL: 3.64, REG:0.90 | LM NLL: 5.18, KL: 20.53|DE LOSS: 303, PPL: 1002, TM: 299, LM: 3.96|BETA: 0.005348
# 112[s], 55[s], Ep: 11, Ct: 00000|TR LOSS: 310, PPL: 1042|TM NLL: 300, KL: 3.64, REG:0.90 | LM NLL: 5.17, KL: 20.68|DE LOSS: 303, PPL: 993, TM: 299, LM: 3.98|BETA: 0.005401
# 082[s], 07[s], Ep: 11, Ct: 00500|TR LOSS: 310, PPL: 1041|TM NLL: 300, KL: 3.64, REG:0.90 | LM NLL: 5.15, KL: 20.87|DE LOSS: 303, PPL: 998, TM: 299, LM: 3.92|BETA: 0.005471
# 082[s], 07[s], Ep: 11, Ct: 01000|TR LOSS: 309, PPL: 1040|TM NLL: 300, KL: 3.65, REG:0.90 | LM NLL: 5.13, KL: 21.05|DE LOSS: 303, PPL: 1004, TM: 299, LM: 3.92|BETA: 0.005540
# 104[s], 29[s], Ep: 11, Ct: 01500|TR LOSS: 309, PPL: 1039|TM NLL: 300, KL: 3.65, REG:0.90 | LM NLL: 5.11, KL: 21.23|DE LOSS: 303, PPL: 994, TM: 299, LM: 3.90|BETA: 0.005610
# 083[s], 07[s], Ep: 11, Ct: 02000|TR LOSS: 309, PPL: 1038|TM NLL: 300, KL: 3.65, REG:0.90 | LM NLL: 5.09, KL: 21.41|DE LOSS: 303, PPL: 1000, TM: 299, LM: 3.89|BETA: 0.005679
# 104[s], 29[s], Ep: 11, Ct: 02500|TR LOSS: 309, PPL: 1037|TM NLL: 300, KL: 3.66, REG:0.90 | LM NLL: 5.07, KL: 21.58|DE LOSS: 303, PPL: 997, TM: 299, LM: 3.88|BETA: 0.005748
# 065[s], 08[s], Ep: 12, Ct: 00000|TR LOSS: 309, PPL: 1037|TM NLL: 300, KL: 3.66, REG:0.90 | LM NLL: 5.06, KL: 21.71|DE LOSS: 303, PPL: 993, TM: 299, LM: 3.91|BETA: 0.005802
# 082[s], 07[s], Ep: 12, Ct: 00500|TR LOSS: 309, PPL: 1036|TM NLL: 300, KL: 3.66, REG:0.90 | LM NLL: 5.04, KL: 21.88|DE LOSS: 303, PPL: 996, TM: 299, LM: 3.87|BETA: 0.005871
# 085[s], 07[s], Ep: 12, Ct: 01000|TR LOSS: 309, PPL: 1035|TM NLL: 300, KL: 3.66, REG:0.90 | LM NLL: 5.02, KL: 22.04|DE LOSS: 303, PPL: 997, TM: 299, LM: 4.12|BETA: 0.005940
# 083[s], 07[s], Ep: 12, Ct: 01500|TR LOSS: 309, PPL: 1034|TM NLL: 299, KL: 3.67, REG:0.90 | LM NLL: 5.00, KL: 22.20|DE LOSS: 303, PPL: 996, TM: 299, LM: 3.85|BETA: 0.006010
# 146[s], 72[s], Ep: 12, Ct: 02000|TR LOSS: 309, PPL: 1033|TM NLL: 299, KL: 3.67, REG:0.90 | LM NLL: 4.98, KL: 22.35|DE LOSS: 303, PPL: 995, TM: 299, LM: 3.83|BETA: 0.006079
# 131[s], 57[s], Ep: 12, Ct: 02500|TR LOSS: 309, PPL: 1033|TM NLL: 299, KL: 3.67, REG:0.90 | LM NLL: 4.97, KL: 22.50|DE LOSS: 303, PPL: 995, TM: 299, LM: 3.83|BETA: 0.006149
# 065[s], 08[s], Ep: 13, Ct: 00000|TR LOSS: 309, PPL: 1032|TM NLL: 299, KL: 3.67, REG:0.90 | LM NLL: 4.95, KL: 22.61|DE LOSS: 303, PPL: 996, TM: 299, LM: 3.83|BETA: 0.006202
# 084[s], 07[s], Ep: 13, Ct: 00500|TR LOSS: 309, PPL: 1031|TM NLL: 299, KL: 3.68, REG:0.90 | LM NLL: 4.94, KL: 22.76|DE LOSS: 303, PPL: 995, TM: 299, LM: 3.99|BETA: 0.006271
# 082[s], 07[s], Ep: 13, Ct: 01000|TR LOSS: 309, PPL: 1031|TM NLL: 299, KL: 3.68, REG:0.90 | LM NLL: 4.92, KL: 22.90|DE LOSS: 303, PPL: 993, TM: 299, LM: 3.80|BETA: 0.006341
# 082[s], 08[s], Ep: 13, Ct: 01500|TR LOSS: 309, PPL: 1030|TM NLL: 299, KL: 3.68, REG:0.90 | LM NLL: 4.90, KL: 23.04|DE LOSS: 303, PPL: 996, TM: 299, LM: 3.83|BETA: 0.006410
# 082[s], 07[s], Ep: 13, Ct: 02000|TR LOSS: 309, PPL: 1029|TM NLL: 299, KL: 3.68, REG:0.90 | LM NLL: 4.89, KL: 23.17|DE LOSS: 303, PPL: 995, TM: 299, LM: 3.90|BETA: 0.006479
# 083[s], 08[s], Ep: 13, Ct: 02500|TR LOSS: 309, PPL: 1029|TM NLL: 299, KL: 3.69, REG:0.90 | LM NLL: 4.87, KL: 23.30|DE LOSS: 303, PPL: 994, TM: 299, LM: 3.84|BETA: 0.006549
# 066[s], 07[s], Ep: 14, Ct: 00000|TR LOSS: 309, PPL: 1028|TM NLL: 299, KL: 3.69, REG:0.90 | LM NLL: 4.86, KL: 23.40|DE LOSS: 303, PPL: 996, TM: 299, LM: 3.82|BETA: 0.006602
# 105[s], 30[s], Ep: 14, Ct: 00500|TR LOSS: 309, PPL: 1027|TM NLL: 299, KL: 3.69, REG:0.90 | LM NLL: 4.84, KL: 23.53|DE LOSS: 303, PPL: 993, TM: 299, LM: 3.74|BETA: 0.006671
# 106[s], 32[s], Ep: 14, Ct: 01000|TR LOSS: 309, PPL: 1027|TM NLL: 299, KL: 3.69, REG:0.90 | LM NLL: 4.83, KL: 23.65|DE LOSS: 303, PPL: 992, TM: 299, LM: 3.75|BETA: 0.006741
# 081[s], 08[s], Ep: 14, Ct: 01500|TR LOSS: 309, PPL: 1026|TM NLL: 299, KL: 3.70, REG:0.90 | LM NLL: 4.81, KL: 23.77|DE LOSS: 303, PPL: 993, TM: 299, LM: 3.76|BETA: 0.006810
# 082[s], 07[s], Ep: 14, Ct: 02000|TR LOSS: 309, PPL: 1026|TM NLL: 299, KL: 3.70, REG:0.90 | LM NLL: 4.80, KL: 23.89|DE LOSS: 303, PPL: 993, TM: 299, LM: 3.74|BETA: 0.006880
# 082[s], 07[s], Ep: 14, Ct: 02500|TR LOSS: 309, PPL: 1025|TM NLL: 299, KL: 3.70, REG:0.90 | LM NLL: 4.79, KL: 24.00|DE LOSS: 303, PPL: 994, TM: 299, LM: 3.77|BETA: 0.006949
# 064[s], 07[s], Ep: 15, Ct: 00000|TR LOSS: 309, PPL: 1025|TM NLL: 299, KL: 3.70, REG:0.90 | LM NLL: 4.78, KL: 24.08|DE LOSS: 303, PPL: 995, TM: 299, LM: 3.72|BETA: 0.007002
# 083[s], 08[s], Ep: 15, Ct: 00500|TR LOSS: 309, PPL: 1024|TM NLL: 299, KL: 3.70, REG:0.90 | LM NLL: 4.76, KL: 24.19|DE LOSS: 303, PPL: 996, TM: 299, LM: 3.71|BETA: 0.007072
# 082[s], 08[s], Ep: 15, Ct: 01000|TR LOSS: 309, PPL: 1024|TM NLL: 299, KL: 3.71, REG:0.90 | LM NLL: 4.75, KL: 24.30|DE LOSS: 303, PPL: 995, TM: 299, LM: 3.71|BETA: 0.007141
# 082[s], 08[s], Ep: 15, Ct: 01500|TR LOSS: 309, PPL: 1023|TM NLL: 299, KL: 3.71, REG:0.90 | LM NLL: 4.73, KL: 24.40|DE LOSS: 303, PPL: 996, TM: 299, LM: 3.75|BETA: 0.007210
# 082[s], 07[s], Ep: 15, Ct: 02000|TR LOSS: 308, PPL: 1022|TM NLL: 299, KL: 3.71, REG:0.90 | LM NLL: 4.72, KL: 24.51|DE LOSS: 303, PPL: 992, TM: 299, LM: 3.71|BETA: 0.007280
# 082[s], 07[s], Ep: 15, Ct: 02500|TR LOSS: 308, PPL: 1022|TM NLL: 299, KL: 3.71, REG:0.90 | LM NLL: 4.71, KL: 24.60|DE LOSS: 303, PPL: 992, TM: 299, LM: 3.73|BETA: 0.007349
# 101[s], 44[s], Ep: 16, Ct: 00000|TR LOSS: 308, PPL: 1022|TM NLL: 299, KL: 3.71, REG:0.90 | LM NLL: 4.70, KL: 24.68|DE LOSS: 303, PPL: 992, TM: 299, LM: 3.71|BETA: 0.007402
# 081[s], 08[s], Ep: 16, Ct: 00500|TR LOSS: 308, PPL: 1021|TM NLL: 299, KL: 3.72, REG:0.90 | LM NLL: 4.68, KL: 24.78|DE LOSS: 303, PPL: 994, TM: 299, LM: 3.72|BETA: 0.007472
# 082[s], 07[s], Ep: 16, Ct: 01000|TR LOSS: 308, PPL: 1020|TM NLL: 299, KL: 3.72, REG:0.90 | LM NLL: 4.67, KL: 24.87|DE LOSS: 303, PPL: 995, TM: 299, LM: 3.73|BETA: 0.007541
# 083[s], 07[s], Ep: 16, Ct: 01500|TR LOSS: 308, PPL: 1020|TM NLL: 299, KL: 3.72, REG:0.90 | LM NLL: 4.66, KL: 24.96|DE LOSS: 303, PPL: 993, TM: 299, LM: 3.71|BETA: 0.007611
# 128[s], 54[s], Ep: 16, Ct: 02000|TR LOSS: 308, PPL: 1019|TM NLL: 299, KL: 3.72, REG:0.90 | LM NLL: 4.65, KL: 25.05|DE LOSS: 303, PPL: 988, TM: 299, LM: 3.67|BETA: 0.007680
# 081[s], 08[s], Ep: 16, Ct: 02500|TR LOSS: 308, PPL: 1019|TM NLL: 299, KL: 3.72, REG:0.90 | LM NLL: 4.63, KL: 25.14|DE LOSS: 303, PPL: 996, TM: 299, LM: 3.66|BETA: 0.007749
# 087[s], 29[s], Ep: 17, Ct: 00000|TR LOSS: 308, PPL: 1019|TM NLL: 299, KL: 3.72, REG:0.90 | LM NLL: 4.63, KL: 25.20|DE LOSS: 303, PPL: 987, TM: 299, LM: 3.68|BETA: 0.007803
# 082[s], 08[s], Ep: 17, Ct: 00500|TR LOSS: 308, PPL: 1018|TM NLL: 299, KL: 3.73, REG:0.90 | LM NLL: 4.61, KL: 25.29|DE LOSS: 303, PPL: 995, TM: 299, LM: 3.65|BETA: 0.007872
# 082[s], 07[s], Ep: 17, Ct: 01000|TR LOSS: 308, PPL: 1018|TM NLL: 299, KL: 3.73, REG:0.90 | LM NLL: 4.60, KL: 25.37|DE LOSS: 303, PPL: 990, TM: 299, LM: 3.68|BETA: 0.007941
# 104[s], 30[s], Ep: 17, Ct: 01500|TR LOSS: 308, PPL: 1017|TM NLL: 299, KL: 3.73, REG:0.90 | LM NLL: 4.59, KL: 25.45|DE LOSS: 302, PPL: 989, TM: 299, LM: 3.68|BETA: 0.008011
# 081[s], 07[s], Ep: 17, Ct: 02000|TR LOSS: 308, PPL: 1017|TM NLL: 299, KL: 3.73, REG:0.90 | LM NLL: 4.58, KL: 25.53|DE LOSS: 303, PPL: 993, TM: 299, LM: 3.64|BETA: 0.008080
# 082[s], 08[s], Ep: 17, Ct: 02500|TR LOSS: 308, PPL: 1016|TM NLL: 299, KL: 3.73, REG:0.90 | LM NLL: 4.57, KL: 25.60|DE LOSS: 303, PPL: 994, TM: 299, LM: 3.63|BETA: 0.008150
# 065[s], 08[s], Ep: 18, Ct: 00000|TR LOSS: 308, PPL: 1016|TM NLL: 299, KL: 3.73, REG:0.90 | LM NLL: 4.56, KL: 25.66|DE LOSS: 303, PPL: 992, TM: 299, LM: 3.63|BETA: 0.008203
# 082[s], 08[s], Ep: 18, Ct: 00500|TR LOSS: 308, PPL: 1016|TM NLL: 299, KL: 3.74, REG:0.90 | LM NLL: 4.55, KL: 25.73|DE LOSS: 303, PPL: 991, TM: 299, LM: 3.63|BETA: 0.008272
# 083[s], 08[s], Ep: 18, Ct: 01000|TR LOSS: 308, PPL: 1015|TM NLL: 299, KL: 3.74, REG:0.90 | LM NLL: 4.54, KL: 25.81|DE LOSS: 303, PPL: 992, TM: 299, LM: 3.62|BETA: 0.008342
# 082[s], 08[s], Ep: 18, Ct: 01500|TR LOSS: 308, PPL: 1015|TM NLL: 299, KL: 3.74, REG:0.90 | LM NLL: 4.53, KL: 25.88|DE LOSS: 303, PPL: 991, TM: 299, LM: 3.62|BETA: 0.008411
# 130[s], 55[s], Ep: 18, Ct: 02000|TR LOSS: 308, PPL: 1015|TM NLL: 299, KL: 3.74, REG:0.90 | LM NLL: 4.52, KL: 25.95|DE LOSS: 302, PPL: 988, TM: 299, LM: 3.62|BETA: 0.008480
# 081[s], 07[s], Ep: 18, Ct: 02500|TR LOSS: 308, PPL: 1014|TM NLL: 299, KL: 3.74, REG:0.90 | LM NLL: 4.50, KL: 26.01|DE LOSS: 302, PPL: 989, TM: 299, LM: 3.63|BETA: 0.008550
# 065[s], 08[s], Ep: 19, Ct: 00000|TR LOSS: 308, PPL: 1014|TM NLL: 299, KL: 3.74, REG:0.90 | LM NLL: 4.50, KL: 26.06|DE LOSS: 302, PPL: 987, TM: 299, LM: 3.64|BETA: 0.008603
# 083[s], 08[s], Ep: 19, Ct: 00500|TR LOSS: 308, PPL: 1013|TM NLL: 299, KL: 3.75, REG:0.90 | LM NLL: 4.49, KL: 26.13|DE LOSS: 303, PPL: 993, TM: 299, LM: 3.63|BETA: 0.008672
# 082[s], 07[s], Ep: 19, Ct: 01000|TR LOSS: 308, PPL: 1013|TM NLL: 299, KL: 3.75, REG:0.90 | LM NLL: 4.48, KL: 26.19|DE LOSS: 302, PPL: 989, TM: 299, LM: 3.63|BETA: 0.008742
# 105[s], 30[s], Ep: 19, Ct: 01500|TR LOSS: 308, PPL: 1013|TM NLL: 299, KL: 3.75, REG:0.90 | LM NLL: 4.47, KL: 26.25|DE LOSS: 302, PPL: 987, TM: 299, LM: 3.61|BETA: 0.008811
# 103[s], 29[s], Ep: 19, Ct: 02000|TR LOSS: 308, PPL: 1012|TM NLL: 299, KL: 3.75, REG:0.90 | LM NLL: 4.46, KL: 26.31|DE LOSS: 302, PPL: 986, TM: 299, LM: 3.60|BETA: 0.008881
# 082[s], 07[s], Ep: 19, Ct: 02500|TR LOSS: 308, PPL: 1012|TM NLL: 299, KL: 3.75, REG:0.90 | LM NLL: 4.45, KL: 26.37|DE LOSS: 303, PPL: 991, TM: 299, LM: 3.69|BETA: 0.008950
# 065[s], 08[s], Ep: 20, Ct: 00000|TR LOSS: 308, PPL: 1012|TM NLL: 299, KL: 3.75, REG:0.90 | LM NLL: 4.44, KL: 26.41|DE LOSS: 303, PPL: 989, TM: 299, LM: 3.67|BETA: 0.009003
# 084[s], 08[s], Ep: 20, Ct: 00500|TR LOSS: 308, PPL: 1011|TM NLL: 299, KL: 3.76, REG:0.90 | LM NLL: 4.43, KL: 26.47|DE LOSS: 302, PPL: 987, TM: 299, LM: 3.60|BETA: 0.009073
# 083[s], 07[s], Ep: 20, Ct: 01000|TR LOSS: 308, PPL: 1011|TM NLL: 299, KL: 3.76, REG:0.90 | LM NLL: 4.42, KL: 26.53|DE LOSS: 302, PPL: 990, TM: 299, LM: 3.59|BETA: 0.009142
# 082[s], 08[s], Ep: 20, Ct: 01500|TR LOSS: 308, PPL: 1011|TM NLL: 299, KL: 3.76, REG:0.90 | LM NLL: 4.41, KL: 26.58|DE LOSS: 302, PPL: 993, TM: 299, LM: 3.64|BETA: 0.009211
# 082[s], 08[s], Ep: 20, Ct: 02000|TR LOSS: 308, PPL: 1010|TM NLL: 299, KL: 3.76, REG:0.90 | LM NLL: 4.40, KL: 26.63|DE LOSS: 302, PPL: 989, TM: 299, LM: 3.73|BETA: 0.009281
# 134[s], 59[s], Ep: 20, Ct: 02500|TR LOSS: 308, PPL: 1010|TM NLL: 299, KL: 3.76, REG:0.90 | LM NLL: 4.39, KL: 26.69|DE LOSS: 302, PPL: 985, TM: 299, LM: 3.58|BETA: 0.009350
# 065[s], 08[s], Ep: 21, Ct: 00000|TR LOSS: 308, PPL: 1010|TM NLL: 299, KL: 3.76, REG:0.90 | LM NLL: 4.39, KL: 26.72|DE LOSS: 302, PPL: 992, TM: 299, LM: 3.58|BETA: 0.009403
# 082[s], 08[s], Ep: 21, Ct: 00500|TR LOSS: 308, PPL: 1009|TM NLL: 298, KL: 3.76, REG:0.90 | LM NLL: 4.38, KL: 26.77|DE LOSS: 302, PPL: 988, TM: 299, LM: 3.58|BETA: 0.009473
# 082[s], 07[s], Ep: 21, Ct: 01000|TR LOSS: 308, PPL: 1009|TM NLL: 298, KL: 3.76, REG:0.90 | LM NLL: 4.37, KL: 26.82|DE LOSS: 302, PPL: 990, TM: 299, LM: 3.59|BETA: 0.009542
# 083[s], 08[s], Ep: 21, Ct: 01500|TR LOSS: 308, PPL: 1009|TM NLL: 298, KL: 3.77, REG:0.90 | LM NLL: 4.36, KL: 26.87|DE LOSS: 302, PPL: 987, TM: 299, LM: 3.58|BETA: 0.009612
# 082[s], 08[s], Ep: 21, Ct: 02000|TR LOSS: 308, PPL: 1008|TM NLL: 298, KL: 3.77, REG:0.90 | LM NLL: 4.35, KL: 26.92|DE LOSS: 302, PPL: 987, TM: 299, LM: 3.64|BETA: 0.009681
# 082[s], 08[s], Ep: 21, Ct: 02500|TR LOSS: 308, PPL: 1008|TM NLL: 298, KL: 3.77, REG:0.90 | LM NLL: 4.34, KL: 26.96|DE LOSS: 302, PPL: 991, TM: 299, LM: 3.57|BETA: 0.009750
# 065[s], 08[s], Ep: 22, Ct: 00000|TR LOSS: 308, PPL: 1008|TM NLL: 298, KL: 3.77, REG:0.90 | LM NLL: 4.34, KL: 27.00|DE LOSS: 302, PPL: 988, TM: 299, LM: 3.57|BETA: 0.009804
# 082[s], 07[s], Ep: 22, Ct: 00500|TR LOSS: 308, PPL: 1007|TM NLL: 298, KL: 3.77, REG:0.90 | LM NLL: 4.33, KL: 27.04|DE LOSS: 302, PPL: 986, TM: 299, LM: 3.57|BETA: 0.009873
# 082[s], 07[s], Ep: 22, Ct: 01000|TR LOSS: 308, PPL: 1007|TM NLL: 298, KL: 3.77, REG:0.90 | LM NLL: 4.32, KL: 27.09|DE LOSS: 302, PPL: 990, TM: 299, LM: 3.57|BETA: 0.009942
# 082[s], 07[s], Ep: 22, Ct: 01500|TR LOSS: 308, PPL: 1007|TM NLL: 298, KL: 3.77, REG:0.90 | LM NLL: 4.31, KL: 27.13|DE LOSS: 302, PPL: 986, TM: 299, LM: 3.57|BETA: 0.010012
# 082[s], 07[s], Ep: 22, Ct: 02000|TR LOSS: 308, PPL: 1006|TM NLL: 298, KL: 3.77, REG:0.90 | LM NLL: 4.30, KL: 27.17|DE LOSS: 302, PPL: 988, TM: 299, LM: 3.56|BETA: 0.010081
# 082[s], 07[s], Ep: 22, Ct: 02500|TR LOSS: 308, PPL: 1006|TM NLL: 298, KL: 3.78, REG:0.90 | LM NLL: 4.29, KL: 27.21|DE LOSS: 302, PPL: 988, TM: 299, LM: 3.59|BETA: 0.010151
# 108[s], 52[s], Ep: 23, Ct: 00000|TR LOSS: 307, PPL: 1006|TM NLL: 298, KL: 3.78, REG:0.90 | LM NLL: 4.29, KL: 27.24|DE LOSS: 302, PPL: 985, TM: 299, LM: 3.55|BETA: 0.010204
# 081[s], 07[s], Ep: 23, Ct: 00500|TR LOSS: 307, PPL: 1006|TM NLL: 298, KL: 3.78, REG:0.90 | LM NLL: 4.28, KL: 27.28|DE LOSS: 303, PPL: 991, TM: 299, LM: 3.59|BETA: 0.010273
# 082[s], 08[s], Ep: 23, Ct: 01000|TR LOSS: 307, PPL: 1005|TM NLL: 298, KL: 3.78, REG:0.90 | LM NLL: 4.27, KL: 27.32|DE LOSS: 302, PPL: 988, TM: 299, LM: 3.59|BETA: 0.010343
# 082[s], 07[s], Ep: 23, Ct: 01500|TR LOSS: 307, PPL: 1005|TM NLL: 298, KL: 3.78, REG:0.90 | LM NLL: 4.27, KL: 27.35|DE LOSS: 302, PPL: 988, TM: 299, LM: 3.56|BETA: 0.010412
# 082[s], 08[s], Ep: 23, Ct: 02000|TR LOSS: 307, PPL: 1005|TM NLL: 298, KL: 3.78, REG:0.90 | LM NLL: 4.26, KL: 27.39|DE LOSS: 302, PPL: 986, TM: 299, LM: 3.57|BETA: 0.010481
# 141[s], 67[s], Ep: 23, Ct: 02500|TR LOSS: 307, PPL: 1005|TM NLL: 298, KL: 3.78, REG:0.90 | LM NLL: 4.25, KL: 27.43|DE LOSS: 302, PPL: 989, TM: 299, LM: 3.57|BETA: 0.010551
# 098[s], 41[s], Ep: 24, Ct: 00000|TR LOSS: 307, PPL: 1004|TM NLL: 298, KL: 3.78, REG:0.90 | LM NLL: 4.24, KL: 27.47|DE LOSS: 302, PPL: 987, TM: 298, LM: 3.60|BETA: 0.010604
# 125[s], 51[s], Ep: 24, Ct: 00500|TR LOSS: 307, PPL: 1004|TM NLL: 298, KL: 3.79, REG:0.89 | LM NLL: 4.24, KL: 27.51|DE LOSS: 302, PPL: 989, TM: 298, LM: 3.58|BETA: 0.010673
# 128[s], 54[s], Ep: 24, Ct: 01000|TR LOSS: 307, PPL: 1004|TM NLL: 298, KL: 3.79, REG:0.89 | LM NLL: 4.23, KL: 27.55|DE LOSS: 302, PPL: 988, TM: 298, LM: 3.55|BETA: 0.010743
# 109[s], 35[s], Ep: 24, Ct: 01500|TR LOSS: 307, PPL: 1004|TM NLL: 298, KL: 3.79, REG:0.88 | LM NLL: 4.22, KL: 27.59|DE LOSS: 301, PPL: 982, TM: 298, LM: 3.55|BETA: 0.010812
# 081[s], 07[s], Ep: 24, Ct: 02000|TR LOSS: 307, PPL: 1003|TM NLL: 298, KL: 3.79, REG:0.88 | LM NLL: 4.22, KL: 27.63|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.56|BETA: 0.010882
# 082[s], 07[s], Ep: 24, Ct: 02500|TR LOSS: 307, PPL: 1003|TM NLL: 298, KL: 3.79, REG:0.87 | LM NLL: 4.21, KL: 27.67|DE LOSS: 301, PPL: 982, TM: 298, LM: 3.55|BETA: 0.010951
# 065[s], 08[s], Ep: 25, Ct: 00000|TR LOSS: 307, PPL: 1003|TM NLL: 298, KL: 3.79, REG:0.87 | LM NLL: 4.20, KL: 27.69|DE LOSS: 301, PPL: 988, TM: 298, LM: 3.55|BETA: 0.011004
# 082[s], 08[s], Ep: 25, Ct: 00500|TR LOSS: 307, PPL: 1003|TM NLL: 298, KL: 3.79, REG:0.86 | LM NLL: 4.20, KL: 27.73|DE LOSS: 301, PPL: 988, TM: 298, LM: 3.55|BETA: 0.011074
# 083[s], 08[s], Ep: 25, Ct: 01000|TR LOSS: 307, PPL: 1002|TM NLL: 298, KL: 3.79, REG:0.85 | LM NLL: 4.19, KL: 27.77|DE LOSS: 301, PPL: 988, TM: 298, LM: 3.55|BETA: 0.011143
# 084[s], 08[s], Ep: 25, Ct: 01500|TR LOSS: 307, PPL: 1002|TM NLL: 298, KL: 3.79, REG:0.85 | LM NLL: 4.18, KL: 27.80|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.55|BETA: 0.011212
# 082[s], 07[s], Ep: 25, Ct: 02000|TR LOSS: 307, PPL: 1002|TM NLL: 298, KL: 3.80, REG:0.84 | LM NLL: 4.17, KL: 27.84|DE LOSS: 301, PPL: 987, TM: 298, LM: 3.55|BETA: 0.011282
# 082[s], 08[s], Ep: 25, Ct: 02500|TR LOSS: 307, PPL: 1002|TM NLL: 298, KL: 3.80, REG:0.84 | LM NLL: 4.17, KL: 27.87|DE LOSS: 301, PPL: 987, TM: 298, LM: 3.55|BETA: 0.011351
# 065[s], 08[s], Ep: 26, Ct: 00000|TR LOSS: 307, PPL: 1001|TM NLL: 298, KL: 3.80, REG:0.83 | LM NLL: 4.16, KL: 27.89|DE LOSS: 301, PPL: 988, TM: 298, LM: 3.54|BETA: 0.011405
# 082[s], 08[s], Ep: 26, Ct: 00500|TR LOSS: 307, PPL: 1001|TM NLL: 298, KL: 3.80, REG:0.83 | LM NLL: 4.16, KL: 27.93|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.55|BETA: 0.011474
# 082[s], 08[s], Ep: 26, Ct: 01000|TR LOSS: 307, PPL: 1001|TM NLL: 298, KL: 3.80, REG:0.82 | LM NLL: 4.15, KL: 27.96|DE LOSS: 301, PPL: 992, TM: 298, LM: 3.54|BETA: 0.011543
# 083[s], 08[s], Ep: 26, Ct: 01500|TR LOSS: 307, PPL: 1001|TM NLL: 298, KL: 3.80, REG:0.82 | LM NLL: 4.14, KL: 27.99|DE LOSS: 301, PPL: 983, TM: 298, LM: 3.57|BETA: 0.011613
# 081[s], 07[s], Ep: 26, Ct: 02000|TR LOSS: 307, PPL: 1000|TM NLL: 298, KL: 3.80, REG:0.81 | LM NLL: 4.14, KL: 28.02|DE LOSS: 301, PPL: 983, TM: 298, LM: 3.54|BETA: 0.011682
# 082[s], 08[s], Ep: 26, Ct: 02500|TR LOSS: 307, PPL: 1000|TM NLL: 298, KL: 3.80, REG:0.81 | LM NLL: 4.13, KL: 28.05|DE LOSS: 301, PPL: 987, TM: 298, LM: 3.54|BETA: 0.011751
# 065[s], 08[s], Ep: 27, Ct: 00000|TR LOSS: 307, PPL: 1000|TM NLL: 298, KL: 3.80, REG:0.80 | LM NLL: 4.13, KL: 28.07|DE LOSS: 301, PPL: 985, TM: 298, LM: 3.54|BETA: 0.011805
# 083[s], 08[s], Ep: 27, Ct: 00500|TR LOSS: 307, PPL: 1000|TM NLL: 298, KL: 3.80, REG:0.80 | LM NLL: 4.12, KL: 28.10|DE LOSS: 301, PPL: 988, TM: 298, LM: 3.54|BETA: 0.011874
# 082[s], 08[s], Ep: 27, Ct: 01000|TR LOSS: 307, PPL: 1000|TM NLL: 298, KL: 3.81, REG:0.79 | LM NLL: 4.11, KL: 28.13|DE LOSS: 301, PPL: 984, TM: 298, LM: 3.55|BETA: 0.011943
# 084[s], 08[s], Ep: 27, Ct: 01500|TR LOSS: 307, PPL: 999|TM NLL: 298, KL: 3.81, REG:0.79 | LM NLL: 4.11, KL: 28.15|DE LOSS: 301, PPL: 987, TM: 298, LM: 3.54|BETA: 0.012013
# 082[s], 08[s], Ep: 27, Ct: 02000|TR LOSS: 307, PPL: 999|TM NLL: 298, KL: 3.81, REG:0.78 | LM NLL: 4.10, KL: 28.18|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.54|BETA: 0.012082
# 104[s], 30[s], Ep: 27, Ct: 02500|TR LOSS: 307, PPL: 999|TM NLL: 298, KL: 3.81, REG:0.78 | LM NLL: 4.09, KL: 28.20|DE LOSS: 301, PPL: 984, TM: 298, LM: 3.54|BETA: 0.012152
# 087[s], 31[s], Ep: 28, Ct: 00000|TR LOSS: 307, PPL: 999|TM NLL: 298, KL: 3.81, REG:0.77 | LM NLL: 4.09, KL: 28.22|DE LOSS: 301, PPL: 982, TM: 298, LM: 3.53|BETA: 0.012205
# 081[s], 08[s], Ep: 28, Ct: 00500|TR LOSS: 307, PPL: 999|TM NLL: 298, KL: 3.81, REG:0.77 | LM NLL: 4.08, KL: 28.25|DE LOSS: 301, PPL: 988, TM: 298, LM: 3.53|BETA: 0.012274
# 081[s], 07[s], Ep: 28, Ct: 01000|TR LOSS: 307, PPL: 998|TM NLL: 298, KL: 3.81, REG:0.76 | LM NLL: 4.08, KL: 28.27|DE LOSS: 301, PPL: 985, TM: 298, LM: 3.57|BETA: 0.012344
# 132[s], 57[s], Ep: 28, Ct: 01500|TR LOSS: 307, PPL: 998|TM NLL: 298, KL: 3.81, REG:0.76 | LM NLL: 4.07, KL: 28.29|DE LOSS: 301, PPL: 980, TM: 298, LM: 3.53|BETA: 0.012413
# 082[s], 08[s], Ep: 28, Ct: 02000|TR LOSS: 307, PPL: 998|TM NLL: 298, KL: 3.81, REG:0.75 | LM NLL: 4.07, KL: 28.32|DE LOSS: 301, PPL: 987, TM: 298, LM: 3.53|BETA: 0.012482
# 083[s], 08[s], Ep: 28, Ct: 02500|TR LOSS: 307, PPL: 998|TM NLL: 298, KL: 3.82, REG:0.75 | LM NLL: 4.06, KL: 28.34|DE LOSS: 301, PPL: 984, TM: 298, LM: 3.53|BETA: 0.012552
# 065[s], 08[s], Ep: 29, Ct: 00000|TR LOSS: 307, PPL: 998|TM NLL: 298, KL: 3.82, REG:0.75 | LM NLL: 4.06, KL: 28.35|DE LOSS: 301, PPL: 988, TM: 298, LM: 3.54|BETA: 0.012605
# 083[s], 07[s], Ep: 29, Ct: 00500|TR LOSS: 307, PPL: 997|TM NLL: 298, KL: 3.82, REG:0.74 | LM NLL: 4.05, KL: 28.38|DE LOSS: 301, PPL: 987, TM: 298, LM: 3.53|BETA: 0.012675
# 082[s], 07[s], Ep: 29, Ct: 01000|TR LOSS: 307, PPL: 997|TM NLL: 298, KL: 3.82, REG:0.74 | LM NLL: 4.05, KL: 28.40|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.53|BETA: 0.012744
# 082[s], 07[s], Ep: 29, Ct: 01500|TR LOSS: 307, PPL: 997|TM NLL: 298, KL: 3.82, REG:0.73 | LM NLL: 4.04, KL: 28.42|DE LOSS: 301, PPL: 984, TM: 298, LM: 3.53|BETA: 0.012813
# 083[s], 08[s], Ep: 29, Ct: 02000|TR LOSS: 307, PPL: 997|TM NLL: 298, KL: 3.82, REG:0.73 | LM NLL: 4.03, KL: 28.43|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.54|BETA: 0.012883
# 082[s], 08[s], Ep: 29, Ct: 02500|TR LOSS: 307, PPL: 997|TM NLL: 298, KL: 3.82, REG:0.72 | LM NLL: 4.03, KL: 28.45|DE LOSS: 301, PPL: 982, TM: 298, LM: 3.52|BETA: 0.012952
# 090[s], 32[s], Ep: 30, Ct: 00000|TR LOSS: 307, PPL: 996|TM NLL: 298, KL: 3.82, REG:0.72 | LM NLL: 4.02, KL: 28.47|DE LOSS: 301, PPL: 982, TM: 298, LM: 3.52|BETA: 0.013005
# 081[s], 08[s], Ep: 30, Ct: 00500|TR LOSS: 307, PPL: 996|TM NLL: 298, KL: 3.82, REG:0.72 | LM NLL: 4.02, KL: 28.49|DE LOSS: 301, PPL: 989, TM: 298, LM: 3.52|BETA: 0.013075
# 084[s], 08[s], Ep: 30, Ct: 01000|TR LOSS: 307, PPL: 996|TM NLL: 298, KL: 3.82, REG:0.71 | LM NLL: 4.01, KL: 28.50|DE LOSS: 301, PPL: 985, TM: 298, LM: 3.54|BETA: 0.013144
# 084[s], 08[s], Ep: 30, Ct: 01500|TR LOSS: 307, PPL: 996|TM NLL: 298, KL: 3.82, REG:0.71 | LM NLL: 4.01, KL: 28.52|DE LOSS: 301, PPL: 983, TM: 298, LM: 3.52|BETA: 0.013213
# 083[s], 08[s], Ep: 30, Ct: 02000|TR LOSS: 307, PPL: 996|TM NLL: 298, KL: 3.82, REG:0.71 | LM NLL: 4.00, KL: 28.54|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.51|BETA: 0.013283
# 082[s], 08[s], Ep: 30, Ct: 02500|TR LOSS: 307, PPL: 996|TM NLL: 298, KL: 3.83, REG:0.70 | LM NLL: 4.00, KL: 28.56|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.52|BETA: 0.013352
# 065[s], 08[s], Ep: 31, Ct: 00000|TR LOSS: 307, PPL: 995|TM NLL: 298, KL: 3.83, REG:0.70 | LM NLL: 3.99, KL: 28.57|DE LOSS: 301, PPL: 982, TM: 298, LM: 3.52|BETA: 0.013406
# 081[s], 08[s], Ep: 31, Ct: 00500|TR LOSS: 307, PPL: 995|TM NLL: 298, KL: 3.83, REG:0.69 | LM NLL: 3.99, KL: 28.58|DE LOSS: 301, PPL: 982, TM: 298, LM: 3.54|BETA: 0.013475
# 081[s], 08[s], Ep: 31, Ct: 01000|TR LOSS: 307, PPL: 995|TM NLL: 298, KL: 3.83, REG:0.69 | LM NLL: 3.98, KL: 28.60|DE LOSS: 301, PPL: 984, TM: 298, LM: 3.52|BETA: 0.013544
# 082[s], 08[s], Ep: 31, Ct: 01500|TR LOSS: 307, PPL: 995|TM NLL: 298, KL: 3.83, REG:0.69 | LM NLL: 3.98, KL: 28.61|DE LOSS: 301, PPL: 983, TM: 298, LM: 3.60|BETA: 0.013614
# 083[s], 08[s], Ep: 31, Ct: 02000|TR LOSS: 307, PPL: 995|TM NLL: 298, KL: 3.83, REG:0.68 | LM NLL: 3.97, KL: 28.63|DE LOSS: 301, PPL: 982, TM: 298, LM: 3.52|BETA: 0.013683
# 082[s], 08[s], Ep: 31, Ct: 02500|TR LOSS: 307, PPL: 995|TM NLL: 298, KL: 3.83, REG:0.68 | LM NLL: 3.97, KL: 28.64|DE LOSS: 301, PPL: 983, TM: 298, LM: 3.52|BETA: 0.013752
# 064[s], 07[s], Ep: 32, Ct: 00000|TR LOSS: 307, PPL: 994|TM NLL: 298, KL: 3.83, REG:0.68 | LM NLL: 3.96, KL: 28.65|DE LOSS: 301, PPL: 985, TM: 298, LM: 3.54|BETA: 0.013806
# 082[s], 08[s], Ep: 32, Ct: 00500|TR LOSS: 307, PPL: 994|TM NLL: 298, KL: 3.83, REG:0.67 | LM NLL: 3.96, KL: 28.67|DE LOSS: 301, PPL: 985, TM: 298, LM: 3.52|BETA: 0.013875
# 083[s], 08[s], Ep: 32, Ct: 01000|TR LOSS: 307, PPL: 994|TM NLL: 298, KL: 3.83, REG:0.67 | LM NLL: 3.95, KL: 28.68|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.52|BETA: 0.013945
# 082[s], 08[s], Ep: 32, Ct: 01500|TR LOSS: 307, PPL: 994|TM NLL: 298, KL: 3.83, REG:0.67 | LM NLL: 3.95, KL: 28.69|DE LOSS: 301, PPL: 990, TM: 298, LM: 3.53|BETA: 0.014014
# 085[s], 08[s], Ep: 32, Ct: 02000|TR LOSS: 307, PPL: 994|TM NLL: 298, KL: 3.83, REG:0.66 | LM NLL: 3.95, KL: 28.70|DE LOSS: 301, PPL: 984, TM: 298, LM: 3.52|BETA: 0.014083
# 082[s], 08[s], Ep: 32, Ct: 02500|TR LOSS: 307, PPL: 994|TM NLL: 298, KL: 3.84, REG:0.66 | LM NLL: 3.94, KL: 28.72|DE LOSS: 301, PPL: 983, TM: 298, LM: 3.52|BETA: 0.014153
# 064[s], 08[s], Ep: 33, Ct: 00000|TR LOSS: 307, PPL: 993|TM NLL: 298, KL: 3.84, REG:0.66 | LM NLL: 3.94, KL: 28.72|DE LOSS: 301, PPL: 983, TM: 298, LM: 3.56|BETA: 0.014206
# 081[s], 07[s], Ep: 33, Ct: 00500|TR LOSS: 306, PPL: 993|TM NLL: 298, KL: 3.84, REG:0.65 | LM NLL: 3.93, KL: 28.74|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.52|BETA: 0.014275
# 082[s], 08[s], Ep: 33, Ct: 01000|TR LOSS: 306, PPL: 993|TM NLL: 298, KL: 3.84, REG:0.65 | LM NLL: 3.93, KL: 28.75|DE LOSS: 301, PPL: 984, TM: 298, LM: 3.51|BETA: 0.014345
# 081[s], 08[s], Ep: 33, Ct: 01500|TR LOSS: 306, PPL: 993|TM NLL: 298, KL: 3.84, REG:0.65 | LM NLL: 3.92, KL: 28.76|DE LOSS: 301, PPL: 982, TM: 298, LM: 3.52|BETA: 0.014414
# 081[s], 08[s], Ep: 33, Ct: 02000|TR LOSS: 306, PPL: 993|TM NLL: 298, KL: 3.84, REG:0.64 | LM NLL: 3.92, KL: 28.77|DE LOSS: 301, PPL: 988, TM: 298, LM: 3.54|BETA: 0.014483
# 082[s], 08[s], Ep: 33, Ct: 02500|TR LOSS: 306, PPL: 993|TM NLL: 298, KL: 3.84, REG:0.64 | LM NLL: 3.91, KL: 28.78|DE LOSS: 301, PPL: 983, TM: 298, LM: 3.52|BETA: 0.014553
# 066[s], 08[s], Ep: 34, Ct: 00000|TR LOSS: 306, PPL: 992|TM NLL: 298, KL: 3.84, REG:0.64 | LM NLL: 3.91, KL: 28.79|DE LOSS: 301, PPL: 981, TM: 298, LM: 3.52|BETA: 0.014606
# 081[s], 08[s], Ep: 34, Ct: 00500|TR LOSS: 306, PPL: 992|TM NLL: 298, KL: 3.84, REG:0.63 | LM NLL: 3.91, KL: 28.79|DE LOSS: 301, PPL: 981, TM: 298, LM: 3.52|BETA: 0.014676
# 081[s], 07[s], Ep: 34, Ct: 01000|TR LOSS: 306, PPL: 992|TM NLL: 298, KL: 3.84, REG:0.63 | LM NLL: 3.90, KL: 28.80|DE LOSS: 301, PPL: 985, TM: 298, LM: 3.52|BETA: 0.014745
# 082[s], 08[s], Ep: 34, Ct: 01500|TR LOSS: 306, PPL: 992|TM NLL: 298, KL: 3.84, REG:0.63 | LM NLL: 3.90, KL: 28.81|DE LOSS: 301, PPL: 983, TM: 298, LM: 3.52|BETA: 0.014814
# 082[s], 08[s], Ep: 34, Ct: 02000|TR LOSS: 306, PPL: 992|TM NLL: 298, KL: 3.84, REG:0.62 | LM NLL: 3.89, KL: 28.82|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.56|BETA: 0.014884
# 082[s], 08[s], Ep: 34, Ct: 02500|TR LOSS: 306, PPL: 992|TM NLL: 298, KL: 3.85, REG:0.62 | LM NLL: 3.89, KL: 28.83|DE LOSS: 301, PPL: 981, TM: 298, LM: 3.53|BETA: 0.014953
# 065[s], 08[s], Ep: 35, Ct: 00000|TR LOSS: 306, PPL: 992|TM NLL: 298, KL: 3.85, REG:0.62 | LM NLL: 3.88, KL: 28.84|DE LOSS: 301, PPL: 982, TM: 298, LM: 3.52|BETA: 0.015006
# 082[s], 08[s], Ep: 35, Ct: 00500|TR LOSS: 306, PPL: 991|TM NLL: 298, KL: 3.85, REG:0.62 | LM NLL: 3.88, KL: 28.84|DE LOSS: 301, PPL: 982, TM: 298, LM: 3.56|BETA: 0.015076
# 082[s], 08[s], Ep: 35, Ct: 01000|TR LOSS: 306, PPL: 991|TM NLL: 298, KL: 3.85, REG:0.61 | LM NLL: 3.88, KL: 28.85|DE LOSS: 301, PPL: 980, TM: 298, LM: 3.51|BETA: 0.015145
# 082[s], 08[s], Ep: 35, Ct: 01500|TR LOSS: 306, PPL: 991|TM NLL: 298, KL: 3.85, REG:0.61 | LM NLL: 3.87, KL: 28.86|DE LOSS: 301, PPL: 983, TM: 298, LM: 3.53|BETA: 0.015214
# 082[s], 08[s], Ep: 35, Ct: 02000|TR LOSS: 306, PPL: 991|TM NLL: 298, KL: 3.85, REG:0.61 | LM NLL: 3.87, KL: 28.86|DE LOSS: 301, PPL: 983, TM: 298, LM: 3.52|BETA: 0.015284
# 082[s], 08[s], Ep: 35, Ct: 02500|TR LOSS: 306, PPL: 991|TM NLL: 298, KL: 3.85, REG:0.60 | LM NLL: 3.86, KL: 28.87|DE LOSS: 301, PPL: 984, TM: 298, LM: 3.56|BETA: 0.015353
# 064[s], 07[s], Ep: 36, Ct: 00000|TR LOSS: 306, PPL: 991|TM NLL: 298, KL: 3.85, REG:0.60 | LM NLL: 3.86, KL: 28.88|DE LOSS: 301, PPL: 982, TM: 298, LM: 3.53|BETA: 0.015407
# 082[s], 08[s], Ep: 36, Ct: 00500|TR LOSS: 306, PPL: 991|TM NLL: 298, KL: 3.85, REG:0.60 | LM NLL: 3.86, KL: 28.88|DE LOSS: 301, PPL: 984, TM: 298, LM: 3.53|BETA: 0.015476
# 104[s], 30[s], Ep: 36, Ct: 01000|TR LOSS: 306, PPL: 990|TM NLL: 298, KL: 3.85, REG:0.60 | LM NLL: 3.85, KL: 28.89|DE LOSS: 301, PPL: 980, TM: 298, LM: 3.53|BETA: 0.015545
# 082[s], 08[s], Ep: 36, Ct: 01500|TR LOSS: 306, PPL: 990|TM NLL: 298, KL: 3.85, REG:0.59 | LM NLL: 3.85, KL: 28.89|DE LOSS: 301, PPL: 985, TM: 298, LM: 3.52|BETA: 0.015615
# 082[s], 08[s], Ep: 36, Ct: 02000|TR LOSS: 306, PPL: 990|TM NLL: 298, KL: 3.85, REG:0.59 | LM NLL: 3.84, KL: 28.90|DE LOSS: 301, PPL: 984, TM: 298, LM: 3.53|BETA: 0.015684
# 082[s], 08[s], Ep: 36, Ct: 02500|TR LOSS: 306, PPL: 990|TM NLL: 298, KL: 3.85, REG:0.59 | LM NLL: 3.84, KL: 28.90|DE LOSS: 301, PPL: 985, TM: 298, LM: 3.55|BETA: 0.015753
# 065[s], 08[s], Ep: 37, Ct: 00000|TR LOSS: 306, PPL: 990|TM NLL: 298, KL: 3.85, REG:0.59 | LM NLL: 3.84, KL: 28.91|DE LOSS: 301, PPL: 985, TM: 298, LM: 3.53|BETA: 0.015806
# 082[s], 08[s], Ep: 37, Ct: 00500|TR LOSS: 306, PPL: 990|TM NLL: 298, KL: 3.86, REG:0.58 | LM NLL: 3.83, KL: 28.91|DE LOSS: 301, PPL: 987, TM: 298, LM: 3.53|BETA: 0.015874
# 082[s], 07[s], Ep: 37, Ct: 01000|TR LOSS: 306, PPL: 990|TM NLL: 298, KL: 3.86, REG:0.58 | LM NLL: 3.83, KL: 28.92|DE LOSS: 301, PPL: 979, TM: 298, LM: 3.54|BETA: 0.015943
# 082[s], 08[s], Ep: 37, Ct: 01500|TR LOSS: 306, PPL: 989|TM NLL: 298, KL: 3.86, REG:0.58 | LM NLL: 3.83, KL: 28.92|DE LOSS: 301, PPL: 983, TM: 298, LM: 3.53|BETA: 0.016012
# 082[s], 07[s], Ep: 37, Ct: 02000|TR LOSS: 306, PPL: 989|TM NLL: 298, KL: 3.86, REG:0.57 | LM NLL: 3.82, KL: 28.93|DE LOSS: 301, PPL: 984, TM: 298, LM: 3.53|BETA: 0.016081
# 081[s], 08[s], Ep: 37, Ct: 02500|TR LOSS: 306, PPL: 989|TM NLL: 298, KL: 3.86, REG:0.57 | LM NLL: 3.82, KL: 28.93|DE LOSS: 301, PPL: 985, TM: 298, LM: 3.55|BETA: 0.016150
# 065[s], 08[s], Ep: 38, Ct: 00000|TR LOSS: 306, PPL: 989|TM NLL: 298, KL: 3.86, REG:0.57 | LM NLL: 3.81, KL: 28.93|DE LOSS: 301, PPL: 979, TM: 298, LM: 3.53|BETA: 0.016203
# 082[s], 08[s], Ep: 38, Ct: 00500|TR LOSS: 306, PPL: 989|TM NLL: 298, KL: 3.86, REG:0.57 | LM NLL: 3.81, KL: 28.94|DE LOSS: 301, PPL: 982, TM: 298, LM: 3.53|BETA: 0.016272
# 081[s], 08[s], Ep: 38, Ct: 01000|TR LOSS: 306, PPL: 989|TM NLL: 298, KL: 3.86, REG:0.56 | LM NLL: 3.81, KL: 28.94|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.53|BETA: 0.016341
# 082[s], 08[s], Ep: 38, Ct: 01500|TR LOSS: 306, PPL: 989|TM NLL: 298, KL: 3.86, REG:0.56 | LM NLL: 3.80, KL: 28.94|DE LOSS: 301, PPL: 981, TM: 298, LM: 3.52|BETA: 0.016410
# 082[s], 07[s], Ep: 38, Ct: 02000|TR LOSS: 306, PPL: 989|TM NLL: 298, KL: 3.86, REG:0.56 | LM NLL: 3.80, KL: 28.94|DE LOSS: 301, PPL: 980, TM: 298, LM: 3.52|BETA: 0.016479
# 082[s], 08[s], Ep: 38, Ct: 02500|TR LOSS: 306, PPL: 989|TM NLL: 298, KL: 3.86, REG:0.56 | LM NLL: 3.80, KL: 28.95|DE LOSS: 301, PPL: 982, TM: 298, LM: 3.52|BETA: 0.016548
# 065[s], 08[s], Ep: 39, Ct: 00000|TR LOSS: 306, PPL: 988|TM NLL: 298, KL: 3.86, REG:0.56 | LM NLL: 3.79, KL: 28.95|DE LOSS: 301, PPL: 983, TM: 298, LM: 3.52|BETA: 0.016601
# 082[s], 08[s], Ep: 39, Ct: 00500|TR LOSS: 306, PPL: 988|TM NLL: 298, KL: 3.86, REG:0.55 | LM NLL: 3.79, KL: 28.95|DE LOSS: 301, PPL: 982, TM: 298, LM: 3.53|BETA: 0.016669
# 081[s], 08[s], Ep: 39, Ct: 01000|TR LOSS: 306, PPL: 988|TM NLL: 298, KL: 3.86, REG:0.55 | LM NLL: 3.79, KL: 28.95|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.52|BETA: 0.016738
# 081[s], 08[s], Ep: 39, Ct: 01500|TR LOSS: 306, PPL: 988|TM NLL: 298, KL: 3.86, REG:0.55 | LM NLL: 3.78, KL: 28.95|DE LOSS: 301, PPL: 980, TM: 298, LM: 3.53|BETA: 0.016807
# 082[s], 08[s], Ep: 39, Ct: 02000|TR LOSS: 306, PPL: 988|TM NLL: 298, KL: 3.87, REG:0.55 | LM NLL: 3.78, KL: 28.96|DE LOSS: 301, PPL: 985, TM: 298, LM: 3.57|BETA: 0.016876
# 082[s], 08[s], Ep: 39, Ct: 02500|TR LOSS: 306, PPL: 988|TM NLL: 298, KL: 3.87, REG:0.54 | LM NLL: 3.77, KL: 28.96|DE LOSS: 301, PPL: 982, TM: 298, LM: 3.53|BETA: 0.016945
# 065[s], 08[s], Ep: 40, Ct: 00000|TR LOSS: 306, PPL: 988|TM NLL: 298, KL: 3.87, REG:0.54 | LM NLL: 3.77, KL: 28.96|DE LOSS: 301, PPL: 983, TM: 298, LM: 3.53|BETA: 0.016998
# 127[s], 52[s], Ep: 40, Ct: 00500|TR LOSS: 306, PPL: 988|TM NLL: 298, KL: 3.87, REG:0.54 | LM NLL: 3.77, KL: 28.96|DE LOSS: 301, PPL: 980, TM: 298, LM: 3.52|BETA: 0.017067
# 081[s], 07[s], Ep: 40, Ct: 01000|TR LOSS: 306, PPL: 987|TM NLL: 298, KL: 3.87, REG:0.54 | LM NLL: 3.76, KL: 28.96|DE LOSS: 301, PPL: 981, TM: 298, LM: 3.53|BETA: 0.017136
# 081[s], 08[s], Ep: 40, Ct: 01500|TR LOSS: 306, PPL: 987|TM NLL: 298, KL: 3.87, REG:0.53 | LM NLL: 3.76, KL: 28.96|DE LOSS: 301, PPL: 985, TM: 298, LM: 3.53|BETA: 0.017205
# 082[s], 08[s], Ep: 40, Ct: 02000|TR LOSS: 306, PPL: 987|TM NLL: 298, KL: 3.87, REG:0.53 | LM NLL: 3.76, KL: 28.96|DE LOSS: 301, PPL: 981, TM: 298, LM: 3.56|BETA: 0.017274
# 082[s], 07[s], Ep: 40, Ct: 02500|TR LOSS: 306, PPL: 987|TM NLL: 298, KL: 3.87, REG:0.53 | LM NLL: 3.75, KL: 28.96|DE LOSS: 301, PPL: 982, TM: 298, LM: 3.53|BETA: 0.017343
# 066[s], 08[s], Ep: 41, Ct: 00000|TR LOSS: 306, PPL: 987|TM NLL: 298, KL: 3.87, REG:0.53 | LM NLL: 3.75, KL: 28.96|DE LOSS: 301, PPL: 983, TM: 298, LM: 3.53|BETA: 0.017396
# 082[s], 08[s], Ep: 41, Ct: 00500|TR LOSS: 306, PPL: 987|TM NLL: 298, KL: 3.87, REG:0.53 | LM NLL: 3.75, KL: 28.96|DE LOSS: 301, PPL: 983, TM: 298, LM: 3.53|BETA: 0.017465
# 082[s], 07[s], Ep: 41, Ct: 01000|TR LOSS: 306, PPL: 987|TM NLL: 298, KL: 3.87, REG:0.52 | LM NLL: 3.75, KL: 28.96|DE LOSS: 301, PPL: 982, TM: 298, LM: 3.52|BETA: 0.017533
# 081[s], 07[s], Ep: 41, Ct: 01500|TR LOSS: 306, PPL: 987|TM NLL: 298, KL: 3.87, REG:0.52 | LM NLL: 3.74, KL: 28.96|DE LOSS: 301, PPL: 978, TM: 298, LM: 3.53|BETA: 0.017602
# 082[s], 08[s], Ep: 41, Ct: 02000|TR LOSS: 306, PPL: 987|TM NLL: 298, KL: 3.87, REG:0.52 | LM NLL: 3.74, KL: 28.96|DE LOSS: 301, PPL: 982, TM: 298, LM: 3.52|BETA: 0.017671
# 081[s], 07[s], Ep: 41, Ct: 02500|TR LOSS: 306, PPL: 986|TM NLL: 298, KL: 3.87, REG:0.52 | LM NLL: 3.74, KL: 28.96|DE LOSS: 301, PPL: 984, TM: 298, LM: 3.53|BETA: 0.017740
# 064[s], 08[s], Ep: 42, Ct: 00000|TR LOSS: 306, PPL: 986|TM NLL: 298, KL: 3.87, REG:0.52 | LM NLL: 3.73, KL: 28.96|DE LOSS: 301, PPL: 980, TM: 298, LM: 3.53|BETA: 0.017793
# 081[s], 08[s], Ep: 42, Ct: 00500|TR LOSS: 306, PPL: 986|TM NLL: 298, KL: 3.88, REG:0.51 | LM NLL: 3.73, KL: 28.96|DE LOSS: 301, PPL: 981, TM: 298, LM: 3.54|BETA: 0.017862
# 082[s], 08[s], Ep: 42, Ct: 01000|TR LOSS: 306, PPL: 986|TM NLL: 298, KL: 3.88, REG:0.51 | LM NLL: 3.73, KL: 28.96|DE LOSS: 301, PPL: 979, TM: 298, LM: 3.54|BETA: 0.017931
# 081[s], 07[s], Ep: 42, Ct: 01500|TR LOSS: 306, PPL: 986|TM NLL: 298, KL: 3.88, REG:0.51 | LM NLL: 3.72, KL: 28.96|DE LOSS: 301, PPL: 980, TM: 298, LM: 3.56|BETA: 0.018000
# 082[s], 08[s], Ep: 42, Ct: 02000|TR LOSS: 306, PPL: 986|TM NLL: 298, KL: 3.88, REG:0.51 | LM NLL: 3.72, KL: 28.95|DE LOSS: 301, PPL: 981, TM: 298, LM: 3.53|BETA: 0.018069
# 082[s], 07[s], Ep: 42, Ct: 02500|TR LOSS: 306, PPL: 986|TM NLL: 298, KL: 3.88, REG:0.51 | LM NLL: 3.72, KL: 28.95|DE LOSS: 301, PPL: 980, TM: 298, LM: 3.54|BETA: 0.018138
# 107[s], 50[s], Ep: 43, Ct: 00000|TR LOSS: 306, PPL: 986|TM NLL: 298, KL: 3.88, REG:0.50 | LM NLL: 3.71, KL: 28.95|DE LOSS: 301, PPL: 977, TM: 298, LM: 3.54|BETA: 0.018191
# 081[s], 07[s], Ep: 43, Ct: 00500|TR LOSS: 306, PPL: 986|TM NLL: 298, KL: 3.88, REG:0.50 | LM NLL: 3.71, KL: 28.95|DE LOSS: 301, PPL: 980, TM: 298, LM: 3.54|BETA: 0.018260
# 081[s], 07[s], Ep: 43, Ct: 01000|TR LOSS: 306, PPL: 985|TM NLL: 298, KL: 3.88, REG:0.50 | LM NLL: 3.71, KL: 28.95|DE LOSS: 301, PPL: 984, TM: 298, LM: 3.53|BETA: 0.018328
# 081[s], 08[s], Ep: 43, Ct: 01500|TR LOSS: 306, PPL: 985|TM NLL: 297, KL: 3.88, REG:0.50 | LM NLL: 3.70, KL: 28.95|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.54|BETA: 0.018397
# 082[s], 08[s], Ep: 43, Ct: 02000|TR LOSS: 306, PPL: 985|TM NLL: 297, KL: 3.88, REG:0.50 | LM NLL: 3.70, KL: 28.94|DE LOSS: 301, PPL: 981, TM: 298, LM: 3.54|BETA: 0.018466
# 082[s], 08[s], Ep: 43, Ct: 02500|TR LOSS: 306, PPL: 985|TM NLL: 297, KL: 3.88, REG:0.49 | LM NLL: 3.70, KL: 28.94|DE LOSS: 301, PPL: 980, TM: 298, LM: 3.56|BETA: 0.018535
# 065[s], 08[s], Ep: 44, Ct: 00000|TR LOSS: 306, PPL: 985|TM NLL: 297, KL: 3.88, REG:0.49 | LM NLL: 3.70, KL: 28.94|DE LOSS: 301, PPL: 984, TM: 298, LM: 3.54|BETA: 0.018588
# 082[s], 08[s], Ep: 44, Ct: 00500|TR LOSS: 306, PPL: 985|TM NLL: 297, KL: 3.88, REG:0.49 | LM NLL: 3.69, KL: 28.94|DE LOSS: 301, PPL: 984, TM: 298, LM: 3.53|BETA: 0.018657
# 082[s], 07[s], Ep: 44, Ct: 01000|TR LOSS: 306, PPL: 985|TM NLL: 297, KL: 3.88, REG:0.49 | LM NLL: 3.69, KL: 28.93|DE LOSS: 301, PPL: 981, TM: 298, LM: 3.53|BETA: 0.018726
# 081[s], 08[s], Ep: 44, Ct: 01500|TR LOSS: 306, PPL: 985|TM NLL: 297, KL: 3.88, REG:0.49 | LM NLL: 3.69, KL: 28.93|DE LOSS: 301, PPL: 981, TM: 298, LM: 3.53|BETA: 0.018795
# 082[s], 08[s], Ep: 44, Ct: 02000|TR LOSS: 306, PPL: 985|TM NLL: 297, KL: 3.88, REG:0.48 | LM NLL: 3.68, KL: 28.93|DE LOSS: 301, PPL: 976, TM: 298, LM: 3.54|BETA: 0.018864
# 082[s], 08[s], Ep: 44, Ct: 02500|TR LOSS: 306, PPL: 985|TM NLL: 297, KL: 3.88, REG:0.48 | LM NLL: 3.68, KL: 28.92|DE LOSS: 301, PPL: 984, TM: 298, LM: 3.53|BETA: 0.018933
# 064[s], 08[s], Ep: 45, Ct: 00000|TR LOSS: 306, PPL: 984|TM NLL: 297, KL: 3.89, REG:0.48 | LM NLL: 3.68, KL: 28.92|DE LOSS: 301, PPL: 977, TM: 298, LM: 3.54|BETA: 0.018986
# 081[s], 07[s], Ep: 45, Ct: 00500|TR LOSS: 306, PPL: 984|TM NLL: 297, KL: 3.89, REG:0.48 | LM NLL: 3.68, KL: 28.92|DE LOSS: 301, PPL: 983, TM: 298, LM: 3.57|BETA: 0.019055
# 082[s], 08[s], Ep: 45, Ct: 01000|TR LOSS: 306, PPL: 984|TM NLL: 297, KL: 3.89, REG:0.48 | LM NLL: 3.67, KL: 28.91|DE LOSS: 301, PPL: 982, TM: 298, LM: 3.54|BETA: 0.019124
# 082[s], 08[s], Ep: 45, Ct: 01500|TR LOSS: 306, PPL: 984|TM NLL: 297, KL: 3.89, REG:0.48 | LM NLL: 3.67, KL: 28.91|DE LOSS: 301, PPL: 981, TM: 298, LM: 3.55|BETA: 0.019192
# 081[s], 08[s], Ep: 45, Ct: 02000|TR LOSS: 306, PPL: 984|TM NLL: 297, KL: 3.89, REG:0.47 | LM NLL: 3.67, KL: 28.91|DE LOSS: 301, PPL: 978, TM: 298, LM: 3.57|BETA: 0.019261
# 083[s], 08[s], Ep: 45, Ct: 02500|TR LOSS: 306, PPL: 984|TM NLL: 297, KL: 3.89, REG:0.47 | LM NLL: 3.66, KL: 28.90|DE LOSS: 301, PPL: 978, TM: 298, LM: 3.60|BETA: 0.019330
# 065[s], 07[s], Ep: 46, Ct: 00000|TR LOSS: 306, PPL: 984|TM NLL: 297, KL: 3.89, REG:0.47 | LM NLL: 3.66, KL: 28.90|DE LOSS: 301, PPL: 979, TM: 298, LM: 3.54|BETA: 0.019383
# 082[s], 08[s], Ep: 46, Ct: 00500|TR LOSS: 306, PPL: 984|TM NLL: 297, KL: 3.89, REG:0.47 | LM NLL: 3.66, KL: 28.90|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.56|BETA: 0.019452
# 082[s], 08[s], Ep: 46, Ct: 01000|TR LOSS: 306, PPL: 984|TM NLL: 297, KL: 3.89, REG:0.47 | LM NLL: 3.66, KL: 28.89|DE LOSS: 301, PPL: 982, TM: 298, LM: 3.55|BETA: 0.019521
# ...
# 0 Pred: the amended effort to decriminalize possession of marijuana amounts of marijuana would have have to close for november
# 1 True: the new hampshire house overwhelmingly supports a plan to make possession of up to one half an ounce of marijuana a violation level offense rather than a misdemeanor
# 1 Pred: the new hampshire house says rejected a plan to put possession of up to an of of of of the under the of of for a for felony
# 2 True: a bipartisan group of senators were promoting a softer plan to make possession of up to one quarter ounce of marijuana a violation on the first offense
# 2 Pred: a republican of tax democrats is raised a plan plan to make any of up to one year cash ounce cash the record on the november quarter
# 3 True: subsequent violations would be a misdemeanor
# 3 Pred: formal violations would be a misdemeanor
# 4 True: but after a lengthy floor debate thursday , senators moved to table the proposal
# 4 Pred: but if a lengthy floor debate thursday , senators continued to win the proposal
# 5 True: that means it likely wo n't come back until next year
# 5 Pred: that means it ca wo n't come back until next year
# 6 True: the legislature passed a medical marijuana law in # , but the dispensaries are not yet up and running
# 6 Pred: the legislature passed a state education rate in # , but the candidates are not yet left and running
# 7 True: the house has backed <unk> numerous times in recent years
# 7 Pred: the house has backed <unk> last times in recent years
# 8 True: a coralville radio station is protesting a judge 's decision to bar it from covering a trial that would have been open to newspaper and television <unk>
# 8 Pred: a white radio station is announcing the judge 's decision to show it over `` a plea that could have be delayed after he is up
# 9 True: <unk> owner steve <unk> said his station planned to broadcast wednesday 's trial of jeff <unk> on a misdemeanor assault charge in johnson county
# 9 Pred: <unk> owner anthony <unk> says his his planned to resume thursday in <unk> county <unk> , after a charge charge charge in his county
# 10 True: he says court staff told its reporter that magistrate judge lynn rose would n't allow him to use a microphone or other audio equipment
# 10 Pred: he says city judge told his lawyer , robert joseph joseph <unk> will n't afford him to reach a <unk> or with product materials
# 11 True: <unk> had applied for permission to cover the case last month under iowa 's expanded media coverage rules
# 11 Pred: <unk> also applied for more to serve the case last month on state 's latest immigration law program
# 12 True: rose entered an order tuesday limiting courtroom coverage to one still camera and one video camera with a microphone
# 12 Pred: since on his order hearing on media attempts to all charges old and one camera camera with a prostitution
# 13 True: but no radio equipment
# 13 Pred: but no park equipment declined
# 14 True: <unk> says he believes that 's illegal , and he 'll pursue legal action
# 14 Pred: <unk> says he believes that 's illegal , and he would receive legal action
# 15 True: rose did n't immediately return a message
# 15 Pred: rose did n't immediately returned a message
# 16 True: musician and <unk> <unk> friedman says he is n't ruling out another run for governor in #
# 16 Pred: colleague and <unk> <unk> , says he is n't surprised out another visit during governor in #
# 17 True: he said during his saturday night show at a dallas pub , `` everything is on the table .
# 17 Pred: he officially on his cbs friday night at a rock restaurant , `` looks is on the table
# 18 True: the dallas morning news ( http : <unk> # lo ) reports that friedman is currently in the middle of his bi polar world tour , and will be making stops next month in europe
# 18 Pred: the daily morning news ( http : <unk> # d ) reports that <unk> is <unk> in the world of his 's 's world cup , will will be cut back in year its #
# 19 True: friedman ran an independent campaign for governor of texas in # and ran for the democratic nomination for texas agriculture commissioner in #
# 19 Pred: martinez is an independent campaign for governor in # and iraq and faces to the newly nomination for u.s. , commissioner in #
# 20 True: he lost both races
# 20 Pred: he lost both races
# 21 True: rick perry has been governor of texas since #
# 21 Pred: rick perry has been governor of texas since #
# 22 True: <unk> says he 's made out his will , adding , `` i 'm gon na be cremated and i want my ashes spread on rick perry 's hair .
# 22 Pred: <unk> said he 's never his how right to i `` i i 'm sorry na be <unk> for i `` him body `` like `` , and king .
# 23 True: while lawmakers and thousands of petition signers from both missouri and illinois are supporting the idea of naming a new st. louis bridge after stan musial , there are some who favor honoring a worker who died during its construction
# 23 Pred: that supporters and other native corporations groups from other states and syria have challenging the rights of a the new based louis based that they <unk> , who is named member retired of a lawsuit hired filed on last office
# 24 True: andy gammon was a carpenter from park hills
# 24 Pred: andy lunsford was a train from park hills
# 25 True: he died in march when an aerial lift toppled into the mississippi river
# 25 Pred: he died in october when an oil washed leaking into the mississippi river
# 26 True: the bridge carrying interstate # traffic opens next year
# 26 Pred: the bridge carrying interstate # traffic opens next year
# 27 True: since musial 's death on saturday , several state and federal lawmakers have proposed naming the span after the st. louis cardinals great
# 27 Pred: since sunday , left in , , by state university federal officials have approved a ban event `` the st. louis and dispatch
# 28 True: but the park hills daily journal ( http : <unk> # <unk> ) reports that a petition started by friends and supporters of gammon seeks to name the structure for him
# 28 Pred: but the fairbanks daily daily ( ( http : <unk> # <unk> ) reports that a letter called by <unk> <unk> <unk> of of is to force the right for example
# 29 True: democratic state rep. linda black says gammon represents the workers who have built america
# 29 Pred: democratic state sen. ron white and part represents the workers they have power hawaii
# 30 True: a controlled burn in grand teton national park will force some closures this week
# 30 Pred: a controlled burn in grand teton national park is burn their on this week
# 31 True: death canyon road and the death canyon trailhead are closed because of the # acre burn near the phelps lake moraine , which starts monday
# 31 Pred: since canyon road , the northbound canyon winds are closed after of the # acre near near the lake lake , , which began monday
# 32 True: the jackson hole news and guide says officials will decide whether to reopen the road and trail on wednesday afternoon
# 32 Pred: the jackson hole news council transit commission crews will decide whether to reopen the road and rush night wednesday road
# 33 True: meanwhile , a # acre wildfire in yellowstone national park is # percent contained
# 33 Pred: meanwhile , a # acre wildfire in yellowstone national park is # percent contained
# 34 True: the grand loop road between tower fall store and chittenden road has now reopened
# 34 Pred: the grand canyon road on i and , and run road also now reopened
# 35 True: the lightning sparked wildfire is the largest of the # fires reported in the park this year
# 35 Pred: the lightning burning fire is the largest of the # fires started in the city this week
# 36 True: state police say a man driving with two children in his car was legally drunk when troopers stopped him at a sobriety checkpoint
# 36 Pred: state police say a man charged in one men his his body were stopped injured when police arrived fire on a traffic store
# 37 True: they arrested paul robertson around # a.m. sunday on the bear mountain parkway in <unk> after they say he registered a blood alcohol content of . #
# 37 Pred: authorities arrested police april in # , sunday in the front 's level in may , they had had one a large population level of #
# 38 True: the # year old <unk> on hudson man is charged with an aggravated dwi offense that involves driving drunk with a passenger under #
# 38 Pred: the # year old <unk> whose wichita , was charged with an animal assault , and driving driving drunk with a handgun on # car
# 39 True: it 's called <unk> 's law , after an # year old girl killed when a woman <unk> drove a station wagon full of children into a manhattan highway wreck
# 39 Pred: it means still that 's department that after an # year old son struck when a man who on a the in and in about about an park area
# 40 True: robertson is free pending a july # court appearance
# 40 Pred: harrell is free pending a july year court appearance
# 41 True: information on his lawyer was n't immediately available
# 41 Pred: information on his lawyer was n't immediately available
# 42 True: police are searching for a baton rouge man accused of defrauding a gonzales church of more than $ # in labor and materials
# 42 Pred: police are searching for a san rouge man accused of robbing a church county in more than $ # in business and trafficking
# 43 True: the advocate reports ( http : <unk> # ) an arrest warrant has been issued for # year old reginald sheppard
# 43 Pred: the advocate reports ( http : <unk> # ) an arrest warrant has been issued for # year old reginald coats
# 44 True: he is wanted on a felony theft count in excess of $ #
# 44 Pred: he is wanted on a felony theft count of excess of $ #
# 45 True: gonzales police says sheppard falsely identified himself as a representative of superior professional services of zachary and signed a construction contract with life cathedral church
# 45 Pred: christopher a. officer cellini falsely charged himself as a member of u.s. and and of america and signed a civil agreement with fellow church members
# 46 True: they say sheppard began construction and , after several payments from the church , left the job and never returned
# 46 Pred: they say that or operating and , only receiving complaints from the church , on the school and then returned
# 47 True: police detective sgt . steven nethken said that sheppard had worked for superior professional services and was fired but kept company documents
# 47 Pred: police detective sgt j. james <unk> said that <unk> had was in u.s. court services , was placed and that authorities evidence
# 48 True: a federal judge has dismissed greg davis ' federal lawsuit against the lafayette parish school board
# 48 Pred: a federal judge has dismissed judge <unk> ' federal lawsuit against the missouri state school board
# 49 True: davis had filed the suit in august , asking that board members mark <unk> and <unk> <unk> be removed from any termination proceedings against superintendent pat cooper
# 49 Pred: davis had been the suit in july court and that that members , <unk> and <unk> <unk> were serving from her action by law gov mike <unk>
# 50 True: davis also asked that a judge force the school system to use # percent of its budget from last year as it tries to work through a budget deficit
# 50 Pred: <unk> previously wednesday that the teacher in the state system will allocate # percent of its employees on this city , it plans to cut for a budget deficit
# 51 True: in tuesday 's ruling , the advertiser reports ( http : //bit.ly/ # <unk> ) judge richard haik said there was a `` lack of subject matter jurisdiction `` in davis ' suit
# 51 Pred: on tuesday 's ruling , the journal reports ( http : //bit.ly/ # <unk> ) court john <unk> said it was a `` significant of judgment `` `` since since december '
# 52 True: haik continued that while davis is a long standing and respected community member , as well as the grandfather of school aged children , he does not have the proper standing to file such a suit
# 52 Pred: schilling continued that she she came a long term of in medical college , who well as the first of first children children , did did n't understand the same steps to make a a mistake
# 53 True: authorities say a man from rock hill appears to have been electrocuted while working at marlboro county high school
# 53 Pred: authorities say a man in lake county is trying have been electrocuted while working at <unk> county high school
# 54 True: investigators said the body of # year old jeffrey cheek was found around # a.m. wednesday
# 54 Pred: investigators said the body of # year old <unk> sigmon was found around # a.m. wednesday
# 55 True: he was working on a generator in the school 's electrical room
# 55 Pred: he was working at a building in the area 's electrical room
# 56 True: authorities say students were kept in their classrooms for about two hours while the death was investigated
# 56 Pred: authorities say students were allowed in their custody for about two minutes after the arrest is investigated
# 57 True: marlboro county coroner tim brown says all signs point to cheek being electrocuted , but he has scheduled an autopsy thursday to verify the cause of death
# 57 Pred: kootenai county coroner mike <unk> says one person injuries to become after electrocuted , but he had asked an autopsy report to determine the cause of death
# 58 True: while the smithsonian institution 's museums on the national mall opened as usual , despite the snowstorm , they are now closing early
# 58 Pred: so the smithsonian institution 's trails on the national area season or usual , as the weather , which 're still on monday
# 59 True: the smithsonian says all museums will close at # p.m. tuesday due to the weather
# 59 Pred: the museum says all museums will close at # p.m. tuesday due to the weather
# 60 True: the smithsonian 's national zoo has been closed all day , though essential staff are on duty for animal care
# 60 Pred: the smithsonian 's national zoo has been closed at times , prompting emergency personnel were on other for cancer patients
# 61 True: evening classes and events scheduled at the smithsonian have been canceled
# 61 Pred: evening canceled classes classes begins at the visitor have been canceled
# -----------Topic Samples-----------
# 0  bow: school students university board schools education college student district high
# 0  sent: green , however , an annual survey of an increase this week is an annual state budget of the legislative session that includes spending of about # percent of its <unk> and adults and a third grade
# 1  bow: charged charges guilty court prison prosecutors years death arrested murder
# 1  sent: and asked court of assault on him on the agency that may # before her sexual relationship
# 2  bow: percent million company cents revenue share shares billion average rate
# 2  sent: the dow dow was dividend # reported friday was down $ # or # # cents
# 3  bow: people president day national u.s. saturday event church center group
# 3  sent: google 's information comes and many as an email as many as an agreement on twitter
# 4  bow: fire service water area weather national miles river crews power
# 4  sent: as u.s. officials from seeing , an explosion of driving its way on <unk> of entry
# 5  bow: department airport http people health air guard found reports safety
# 5  sent: organized by experts for <unk> , all but an email or one location to his city building
# 6  bow: bill house republican senate gov lawmakers committee democratic election vote
# 6  sent: on supporters of protesters took office on how many items of building failed an accident site
# 7  bow: million company project federal department program plans public http plan
# 7  sent: google 's offer , some who took its systems and an <unk> location for it home
# 8  bow: court federal attorney judge u.s. law filed office lawsuit department
# 8  sent: blankenship led court out of illegally using his <unk> on how much cash on what a government
# 9  bow: authorities found home car woman died hospital sheriff officers shot
# 9  sent: baker escaped , led by someone in connection with what their lives occurred at that the dogs

# %% [markdown]
# # confirm variables

# %%
_prob_topic, _prob_topic_sents, _prob_topic_infer, _means_topic_infer = debug_value([prob_topic, prob_topic_sents, prob_topic_infer, means_topic_infer], return_value=True)

# %%
batch_i = 4
_prob_topic_sents[batch_i], _prob_topic_infer[batch_i]
# Out:
# (array([1.2281889e-02, 6.7835855e-03, 2.0132679e-01, 1.1674699e-02,
#         6.5264981e-03, 1.1411838e-02, 6.9189700e-03, 2.8612482e-04,
#         7.4042326e-01, 2.3663496e-03], dtype=float32),
#  array([0.09889801, 0.11335436, 0.12141278, 0.10027827, 0.13508864,
#         0.09455997, 0.0860846 , 0.08042429, 0.09635323, 0.07354581],
#        dtype=float32))

# %%
_means_topic_infer[0][:, :4]
# Out:
# array([[-0.02824139, -0.22793637,  0.3788033 , -0.02814816],
#        [ 0.06249218, -0.08085692,  0.06756439,  0.2259818 ],
#        [-0.1377574 ,  0.28185233,  0.23656711, -0.3201025 ],
#        [-0.03711405,  0.16953555,  0.16389738, -0.16461828],
#        [ 0.27302447, -0.22462857,  0.37200606, -0.00549014],
#        [-0.16755986,  0.11964113,  0.17052333,  0.18083367],
#        [ 0.26351342, -0.33828875,  0.3920058 , -0.17029142],
#        [ 0.21033517, -0.1955087 ,  0.20963705, -0.24809986],
#        [ 0.01922028, -0.03185754,  0.28022933, -0.13928899],
#        [-0.26817918, -0.3364467 ,  0.36924574,  0.15818927]],
#       dtype=float32)

# %%
w_means_topic, b_means_topic = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, "topic/dec/mean_topic")

pred_topic_embeddings, pred_topic_bow, pred_means_topic, pred_logvars_topic, pred_token_idxs, _w_means_topic, _b_means_topic, _w_mean_topic_infer = \
                                sess.run([topic_embeddings, topic_bow, means_topic, logvars_topic, topic_beam_output_token_idxs, w_means_topic, b_means_topic, w_mean_topic_infer], 
                                         feed_dict={t_variables['batch_l']: config.n_topic, t_variables['keep_prob']: 1.,})

pred_sents = idxs_to_sents(pred_token_idxs, config, idx_to_word)

pred_topics_freq_bow_indices = np.argsort(pred_topic_bow, 1)[:, ::-1][:, :10]
pred_topics_freq_bow_idxs = bow_idxs[pred_topics_freq_bow_indices]

# %%
for idxs in pred_topics_freq_bow_idxs:
    print([idx_to_word[idx] for idx in idxs])
# Out:
# ['million', 'http', 'years', 'tuesday', 'federal', 'u.s.', 'month', 'office', 'people', 'monday']
# ['reports', 'department', 'thursday', 'court', 'time', 'u.s.', 'years', 'monday', 'tuesday', "'"]
# ['school', 'public', 'u.s.', 'board', 'university', 'federal', 'president', 'program', 'health', 'students']
# ['fire', 'found', 'authorities', 'hospital', 'home', 'a.m.', 'dead', 'investigation', 'chief', 'morning']
# ['service', 'national', 'department', 'http', 'water', 'park', 'area', 'center', 'wednesday', 'weather']
# ['percent', 'company', 'million', 'billion', 'shares', 'inc.', 'revenue', 'average', 'cents', 'price']
# ['design', 'researchers', 'donations', 'prize', 'encourage', 'peak', 'awards', 'feature', 'chapter', 'affect']
# ['court', 'arrested', 'charged', 'attorney', 'death', 'authorities', 'found', 'prison', 'shooting', 'woman']
# ['bill', 'senate', 'house', 'republican', 'committee', 'public', 'board', 'approved', 'u.s.', 'law']
# ['todd', 'rear', 'drowned', 'confronted', 'foul', 'transported', 'assaulted', 'loaded', 'defender', 'unidentified']

# %%
pred_topic_embeddings[:, :10]
# Out:
# array([[ 0.09207956,  0.09077395,  0.06120839, -0.22176096,  0.19921999,
#         -0.05485373, -0.23069587,  0.05650459,  0.142239  , -0.17410392],
#        [ 0.29974467, -0.03281972,  0.25064805, -0.2893645 , -0.1312135 ,
#         -0.11136644,  0.02060958, -0.13598587,  0.24592783, -0.18463418],
#        [ 0.22819577,  0.14566512,  0.05597903, -0.1109414 , -0.00879419,
#         -0.1605561 ,  0.11445126,  0.00916692, -0.04847115, -0.0603605 ],
#        [ 0.3365141 , -0.06439152,  0.3631938 ,  0.14203475,  0.10052318,
#         -0.09119357, -0.08768138, -0.28562906,  0.3186355 , -0.08452626],
#        [ 0.26727033,  0.03540339,  0.28315246, -0.1286456 , -0.02444943,
#         -0.163507  , -0.02146725, -0.21729966,  0.26542294, -0.1589102 ],
#        [ 0.28826687, -0.18438952,  0.2760168 , -0.12692557,  0.05485712,
#          0.17983724,  0.14970489, -0.36168167,  0.30563408, -0.13128197],
#        [-0.32988435, -0.11005852, -0.27013943,  0.26166642, -0.3013388 ,
#         -0.2234488 ,  0.02287463,  0.20320751, -0.10510623,  0.28636736],
#        [ 0.37211177, -0.00585993,  0.2853141 , -0.05771174,  0.15170154,
#          0.05411884, -0.24091715, -0.01475959, -0.0408047 , -0.17167823],
#        [ 0.20512433,  0.18697639, -0.08326819,  0.03792854,  0.03214281,
#          0.05618311,  0.09544107,  0.03913466, -0.06514693, -0.04000437],
#        [-0.3745221 , -0.06385167, -0.29924905,  0.08158813, -0.28344202,
#         -0.01799835,  0.02471407,  0.408938  , -0.169172  ,  0.37273586]],
#       dtype=float32)

# %%
pred_topic_bow
# Out:
# array([[1.0327697e-03, 4.6811462e-03, 1.7024261e-04, ..., 3.3795869e-04,
#         1.5871278e-04, 6.6570101e-05],
#        [5.9443718e-04, 7.4376534e-03, 2.0111131e-04, ..., 7.4048399e-04,
#         1.5028552e-04, 8.9953668e-05],
#        [8.5580017e-04, 2.8901210e-03, 1.6464434e-04, ..., 3.1770146e-04,
#         1.9349743e-04, 3.0012103e-04],
#        ...,
#        [1.3188391e-04, 2.6697975e-03, 2.3009101e-04, ..., 8.1575691e-04,
#         1.5104198e-04, 3.2140684e-05],
#        [3.8558390e-04, 4.0810513e-03, 1.4347673e-04, ..., 1.4157601e-04,
#         1.8342295e-04, 4.7484271e-05],
#        [7.1679087e-06, 2.9757638e-07, 1.8662996e-04, ..., 5.9841594e-05,
#         1.7972868e-04, 5.0798093e-04]], dtype=float32)

# %%
_w_means_topic
# Out:
# array([[ 0.09637171, -0.09069463,  0.09532599, ..., -0.02989542,
#         -0.02514938,  0.01415634],
#        [-0.02764424,  0.01254364,  0.03703775, ..., -0.01512817,
#          0.02590305,  0.01404281],
#        [-0.08408152, -0.00924051, -0.08365072, ...,  0.05623364,
#         -0.05008389,  0.0209127 ],
#        ...,
#        [-0.00629492, -0.05131948, -0.05206006, ..., -0.0955721 ,
#         -0.01980347, -0.02646225],
#        [-0.00839109, -0.05062511, -0.05731497, ...,  0.07618995,
#          0.03893617,  0.06835916],
#        [ 0.07883421, -0.02804748,  0.09326512, ..., -0.0734218 ,
#          0.0045918 , -0.10043538]], dtype=float32)

# %%
_b_means_topic
# Out:
# array([ 0.03207342, -0.08436021,  0.36105958, -0.02925379, -0.26779142,
#        -0.4809294 , -0.04713235, -0.6384421 ,  0.49655244, -0.18943405,
#         0.32139724,  0.00376519, -0.02733823,  0.06968141,  0.12723993,
#         0.17086434,  0.4321125 ,  0.2930171 ,  0.43750855, -0.32728267,
#        -0.29320472,  0.46633536,  0.03467208, -0.11661331,  0.02106199,
#         0.10828511,  0.14413024,  0.00801178, -0.16259423,  0.31461757,
#        -0.25328413,  0.11320477], dtype=float32)

# %%
pred_means_topic
# Out:
# array([[ 0.03563995, -0.3379975 ,  1.6953684 , -0.3394102 , -1.3313038 ,
#         -1.9561913 , -0.34439525, -3.1041431 ,  2.302101  , -0.80340064,
#          1.374892  ,  0.10505254,  0.13142577,  0.36230466,  0.5036737 ,
#          0.6154421 ,  1.8879794 ,  1.263777  ,  2.0281937 , -1.4289141 ,
#         -1.3110695 ,  2.0390706 ,  0.32288784, -0.39520237,  0.10320839,
#          0.35608286,  0.61754334, -0.1438482 , -0.74413097,  1.4731948 ,
#         -1.1249324 ,  0.33894244],
#        [ 0.03510073, -0.3374708 ,  1.6888778 , -0.3363807 , -1.3308815 ,
#         -1.9608293 , -0.34732953, -3.1081154 ,  2.3005512 , -0.80602133,
#          1.3695524 ,  0.10256523,  0.13283278,  0.36182955,  0.49822897,
#          0.6213894 ,  1.8883276 ,  1.266403  ,  2.023539  , -1.426166  ,
#         -1.3108103 ,  2.0448976 ,  0.32430837, -0.38903922,  0.10560946,
#          0.3596735 ,  0.6160856 , -0.14840832, -0.74532497,  1.4738762 ,
#         -1.1249926 ,  0.33331037],
#        [ 0.03490497, -0.33676392,  1.6840277 , -0.335459  , -1.3295547 ,
#         -1.95664   , -0.3462094 , -3.1003447 ,  2.296549  , -0.80408335,
#          1.367739  ,  0.10281808,  0.13425133,  0.36240244,  0.4972452 ,
#          0.6206323 ,  1.885982  ,  1.2645416 ,  2.0215812 , -1.4212072 ,
#         -1.3081043 ,  2.0386996 ,  0.32136053, -0.39039296,  0.1050597 ,
#          0.36023104,  0.6137113 , -0.15039542, -0.7433981 ,  1.4694595 ,
#         -1.1245916 ,  0.3360805 ],
#        [ 0.03728028, -0.33768234,  1.6832604 , -0.3353232 , -1.325423  ,
#         -1.9593027 , -0.34599763, -3.1006794 ,  2.2962196 , -0.80693865,
#          1.3678529 ,  0.10114851,  0.13371727,  0.36420822,  0.49783063,
#          0.62049437,  1.8832903 ,  1.2625886 ,  2.0200832 , -1.421174  ,
#         -1.3108637 ,  2.0388248 ,  0.32396334, -0.38813725,  0.10552703,
#          0.3586173 ,  0.6122677 , -0.15264365, -0.74335086,  1.468328  ,
#         -1.1214948 ,  0.337562  ],
#        [ 0.0355639 , -0.33673748,  1.6850188 , -0.334822  , -1.3297123 ,
#         -1.9579692 , -0.34517902, -3.0999303 ,  2.296747  , -0.8048171 ,
#          1.3683693 ,  0.10311563,  0.13507861,  0.36239594,  0.4968614 ,
#          0.61993766,  1.8848993 ,  1.2634866 ,  2.0213115 , -1.4220002 ,
#         -1.3081868 ,  2.0382977 ,  0.32180363, -0.39071375,  0.10513556,
#          0.35903966,  0.6132862 , -0.15032193, -0.74355686,  1.4703372 ,
#         -1.1240762 ,  0.3361809 ],
#        [ 0.03776056, -0.33906677,  1.6886759 , -0.33578348, -1.3277831 ,
#         -1.9574624 , -0.3511446 , -3.1008887 ,  2.298576  , -0.80058026,
#          1.3695161 ,  0.10116885,  0.13310117,  0.36374724,  0.49994904,
#          0.62002206,  1.8863395 ,  1.2639412 ,  2.0218256 , -1.4257591 ,
#         -1.3068638 ,  2.038707  ,  0.3251842 , -0.38946715,  0.10602362,
#          0.3615039 ,  0.6127277 , -0.15162012, -0.739843  ,  1.4696462 ,
#         -1.1235677 ,  0.34125343],
#        [ 0.03675649, -0.33748797,  1.6818695 , -0.3343631 , -1.3270382 ,
#         -1.9566132 , -0.34484407, -3.0962553 ,  2.2958052 , -0.8025343 ,
#          1.365838  ,  0.10129849,  0.13410446,  0.36187994,  0.49527365,
#          0.62073433,  1.8827194 ,  1.264018  ,  2.019868  , -1.4191431 ,
#         -1.3083122 ,  2.036423  ,  0.32277   , -0.38972613,  0.10532874,
#          0.36029965,  0.6137044 , -0.14923215, -0.7424054 ,  1.4679198 ,
#         -1.1228634 ,  0.33640632],
#        [ 0.03632384, -0.33631054,  1.6842166 , -0.33446336, -1.3275865 ,
#         -1.959459  , -0.34500512, -3.1014085 ,  2.2958436 , -0.804686  ,
#          1.3688817 ,  0.10245646,  0.13472772,  0.3634492 ,  0.49877107,
#          0.61891234,  1.8855013 ,  1.263787  ,  2.0223496 , -1.4211094 ,
#         -1.309351  ,  2.0364125 ,  0.32266062, -0.3891954 ,  0.10458721,
#          0.35922444,  0.61319816, -0.14912874, -0.7429457 ,  1.469351  ,
#         -1.1232082 ,  0.3378038 ],
#        [ 0.03574873, -0.3368752 ,  1.6819855 , -0.33521634, -1.3290966 ,
#         -1.9556532 , -0.34607896, -3.0987115 ,  2.2963123 , -0.80486095,
#          1.3669474 ,  0.10132913,  0.13473387,  0.36283588,  0.49758494,
#          0.6216788 ,  1.8858868 ,  1.2627757 ,  2.0219636 , -1.4208897 ,
#         -1.3082187 ,  2.0389626 ,  0.32159996, -0.39116064,  0.1062526 ,
#          0.35957128,  0.6122661 , -0.14942539, -0.74453473,  1.468337  ,
#         -1.123489  ,  0.33671775],
#        [ 0.03600421, -0.33810538,  1.6826388 , -0.33433414, -1.3267329 ,
#         -1.9560882 , -0.34396413, -3.096003  ,  2.2952938 , -0.8032101 ,
#          1.366725  ,  0.10274363,  0.13443008,  0.36315334,  0.4956261 ,
#          0.6213716 ,  1.882305  ,  1.2623034 ,  2.0204127 , -1.4200761 ,
#         -1.3082595 ,  2.034914  ,  0.32189733, -0.38998067,  0.10444504,
#          0.35928738,  0.6142209 , -0.1489011 , -0.74237704,  1.4684169 ,
#         -1.1216142 ,  0.3379858 ]], dtype=float32)

# %%
_w_mean_topic_infer[:, :10, 0]
# Out:
# array([[ 0.02438005, -0.02036242, -0.01039507,  0.00277665,  0.02350294,
#          0.01473409, -0.02157389,  0.02251465,  0.00814133,  0.01785252],
#        [ 0.00074128, -0.001453  , -0.01162554, -0.0014644 , -0.02097618,
#          0.00570552,  0.00674119, -0.01879225,  0.02161046,  0.01941887],
#        [ 0.01402811, -0.00613734, -0.0027943 , -0.01052572, -0.00041091,
#          0.0045091 , -0.01547336,  0.0194314 ,  0.00784631,  0.00505763],
#        [ 0.01655601, -0.02403533,  0.01607199, -0.01643238,  0.00686195,
#         -0.01788632,  0.01109112,  0.00087933,  0.00448566, -0.00823843],
#        [-0.00695892,  0.01631877,  0.01657149,  0.01772625,  0.02026216,
#          0.01811663,  0.02153757, -0.00020743, -0.02066918, -0.00025119],
#        [ 0.02195978,  0.00867016, -0.02278856,  0.0122384 , -0.02183604,
#          0.00798479,  0.00545774,  0.00923075,  0.01814621,  0.02018008],
#        [ 0.02242495, -0.00673729,  0.01447002,  0.02163557,  0.02312511,
#         -0.00920323, -0.01116639,  0.01708085, -0.01181559, -0.00763743],
#        [-0.01978129,  0.00916991, -0.00304236,  0.00106503,  0.00690803,
#         -0.01416942,  0.0063372 ,  0.00018093,  0.00393429, -0.00307162],
#        [-0.01821756,  0.01890057,  0.00228031, -0.01240117, -0.01108933,
#         -0.01674686, -0.01161283, -0.01693372,  0.00370204, -0.00271433],
#        [-0.0158878 ,  0.01951969, -0.01606018, -0.00457847,  0.00044555,
#         -0.0050344 , -0.0013686 ,  0.00539651,  0.02015766, -0.00510509]],
#       dtype=float32)

# %%
_b_means_topic
# Out:
# array([ 0.03922943,  0.46112132, -0.08166478, -0.06917454, -0.01617851,
#         0.18225916, -0.28025913, -0.06620797,  0.03231472, -0.02211766,
#        -0.38082743,  0.11382294,  0.39363608, -0.4168986 ,  1.1677127 ,
#         0.08979508,  0.03593519, -0.07863234,  0.12493958,  0.03175303,
#         0.13351525,  0.8176425 , -0.28750482,  0.37927672, -0.01720515,
#        -0.21228473, -0.05377329, -0.10451841, -0.24399954, -0.25936088,
#         0.0845396 ,  0.33591354], dtype=float32)

# %%
_enc_state_infer, _means_topic_infer = debug_value([enc_state_infer, means_topic_infer], return_value=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-ee7c3cd147b5> in <module>
# ----> 1 _enc_state_infer, _means_topic_infer = debug_value([enc_state_infer, means_topic_infer], return_value=True)
#
# NameError: name 'enc_state_infer' is not defined

# %%
_enc_state_infer.shape
# Out:
# (67, 10, 1024)

# %%
_means_topic_infer[0]
# Out:
# array([[-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00],
#        [-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00],
#        [-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00],
#        [-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00],
#        [-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00],
#        [-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00],
#        [-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00],
#        [-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00],
#        [-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00],
#        [-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00]],
#       dtype=float32)
