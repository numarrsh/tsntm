# %%
# %%javascript
# IPython.notebook.kernel.execute('nb_name = "' + IPython.notebook.notebook_name + '"')

# %%
# %load_ext autoreload
# %autoreload
from IPython.display import clear_output

import os
import pdb
import _pickle as cPickle
import time
import subprocess
import glob

import random
import numpy as np
import pandas as pd
import tensorflow as tf

from collections import defaultdict, Counter
from ncrp import Topic, Doc, init, sample, get_perplexity, get_topic_specialization, get_hierarchical_affinities, get_freq_tokens_ncrp, get_docs
from configure import get_config

# %% [markdown]
# # load config & data

# %%
config = get_config(nb_name)
np.random.seed(config.seed)
random.seed(config.seed)

# %%
instances_train, instances_dev, instances_test, word_to_idx, idx_to_word, bow_idxs = cPickle.load(open(config.path_data,'rb'))

# %%
config.n_doc = len(instances_train)
config.n_vocab = len(bow_idxs)
config.n_doc, config.n_vocab
# Out:
# (31943, 1035)

# %% [markdown]
# # run

# %% [markdown]
# ## initialize log

# %%
checkpoint = []
ppl_min = np.inf
epoch = 0

cmd_rm = 'rm -r %s' % config.dir_model
res = subprocess.call(cmd_rm.split())
cmd_mk = 'mkdir %s' % config.dir_model
res = subprocess.call(cmd_mk.split())

log_df = pd.DataFrame(columns=pd.MultiIndex.from_tuples(
                    list(zip(*[['','','','TRAIN:','VALID:','TEST:','SPEC:', '', '', 'HIER:', ''],
                            ['Time','Ep','Ct','PPL','PPL', 'PPL','1', '2', '3', 'CHILD', 'OTHER']]))))

def update_checkpoint(config, checkpoint, epoch):
    checkpoint.append(config.path_model + '-%i' % epoch)
    if len(checkpoint) > config.max_to_keep:
        path_model = checkpoint.pop(0)
        for p in glob.glob(path_model):
            os.remove(p)
    cPickle.dump(checkpoint, open(config.path_checkpoint, 'wb'))

# %% [markdown]
# ## initialize data

# %%
topic_root = Topic(idx='0', sibling_idx=0, parent=None, depth=0, config=config)
train_docs = get_docs(instances_train, config)
dev_docs = get_docs(instances_dev, config)
test_docs = get_docs(instances_test, config)
init(train_docs, dev_docs, test_docs, topic_root)
# Out:
# 0 10000 20000 30000 0 0

# %% [markdown]
# ## run

# %%
time_start = time.time()
while epoch < config.n_epochs:
    sample(train_docs, dev_docs, test_docs, topic_root)
    ppl_train = get_perplexity(train_docs, topic_root)
    ppl_dev = get_perplexity(dev_docs, topic_root)
    
    if ppl_dev < ppl_min:
        ppl_min = ppl_dev
        ppl_test = get_perplexity(test_docs, topic_root)
        cPickle.dump([test_docs, topic_root], open(config.path_model + '-%i'%epoch, 'wb'))
        update_checkpoint(config, checkpoint, epoch)
        
    depth_spec = get_topic_specialization(test_docs, topic_root)
    hierarchical_affinities = get_hierarchical_affinities(topic_root)
    
    clear_output()
    time_log = int(time.time() - time_start)
    time_start = time.time()
    log_series = pd.Series([time_log, epoch, 0, \
            '%.0f'%ppl_train, '%.0f'%ppl_dev, '%.0f'%ppl_test, \
            '%.2f'%depth_spec[1], '%.2f'%depth_spec[2], '%.2f'%depth_spec[3], \
            '%.2f'%hierarchical_affinities[0], '%.2f'%hierarchical_affinities[1]],
            index=log_df.columns)
    log_df.loc[epoch] = log_series    
    display(log_df)
    get_freq_tokens_ncrp(topic_root, idx_to_word, bow_idxs)
    
    cPickle.dump(log_df, open(config.path_log, 'wb'))
    epoch += 1
# Out:
#                TRAIN: VALID: TEST: SPEC:             HIER:
#    Time  Ep Ct    PPL    PPL   PPL   PPL     1     2     3 CHILD
# 0   199   0  0    367    349   348  0.09  0.50  0.64  0.47  0.34
# 1   242   1  0    328    320   322  0.10  0.53  0.66  0.44  0.29
# 2   266   2  0    317    315   312  0.10  0.52  0.67  0.46  0.29
# 3   286   3  0    306    305   304  0.10  0.54  0.65  0.44  0.29
# 4   339   4  0    291    293   288  0.11  0.56  0.66  0.40  0.28
# 5   360   5  0    288    292   286  0.11  0.55  0.66  0.35  0.25
# 6   371   6  0    290    296   286  0.12  0.56  0.65  0.35  0.25
# 7   416   7  0    286    287   287  0.12  0.57  0.64  0.35  0.26
# 8   442   8  0    280    281   279  0.12  0.57  0.63  0.34  0.25
# 9   458   9  0    279    282   279  0.12  0.58  0.62  0.36  0.28
# 10  476  10  0    280    281   280  0.12  0.58  0.62  0.36  0.28
# 11  526  11  0    279    281   280  0.12  0.59  0.61  0.36  0.29
#  0 31943 272017.0 ! nice bought price quality love made 'm put recommend
#    0-1 1357 9752.0 ! love color cover perfect mac recommend perfectly pro easy
#      0-1-2 185 132.0 wait sleek card doubt acer put ! print couple aspire
#      0-1-4 535 334.0 compliments green picture glove sony clear cool quick retina professional
#      0-1-5 637 618.0 keyboard cover mcover highly scratches smell blue wireless condition protector
#    0-2 714 6344.0 travel carry handle security easy work airport trip compartments business
#      0-2-1 123 100.0 deep paper class business fix walk entire dimensions easier week
#      0-2-2 523 496.0 paperwork trips short luggage wheels worked airports system everyday open
#      0-2-3 68 70.0 difference point storage doesnt main couple convenient protect extremely pens
#    0-3 700 6375.0 pocket netbook power mouse cord room small charger perfect sleeve
#      0-3-2 655 630.0 dvd player inside portable plenty adapter drive ipad chargers size
#      0-3-3 41 31.0 gray seat width original expectations happy left appears sold equipment
#      0-3-4 4 4.0 turned inch decided smaller fault finally flaw flat flash flap
#    0-4 542 5060.0 bottom cover months corners top cracked speck started piece broke
#      0-4-1 538 477.0 cover top holding portion months weak rubber keyboard corner excited
#      0-4-3 4 7.0 pulls mcover feeling / handy matter damage zips flap fingerprints
#    0-5 1982 15569.0 ! love carry room & pockets perfect ; ipad plenty
#      0-5-2 93 127.0 & ; reasonable likes base surface storage stores past pack
#      0-5-3 1125 883.0 convenient keys charging home lightweight professional student carry spare front
#      0-5-4 414 1078.0 ; & tablet ! asus pack gear tightly feature finally
#      0-5-5 350 330.0 camera canon lens lenses stuff lots room ago spare player
#    0-6 2096 15923.0 ! cover color apple mac pro keyboard ordered $ received
#      0-6-1 767 601.0 dollars spend affordable thought im longer fact wait colors feet
#      0-6-2 104 71.0 mbp darker shows compared finish black daughter dark vibrant outer
#      0-6-3 615 830.0 keyboard cover keys protector ipearl skin screen type free key
#      0-6-4 610 791.0 return protector item customer service seller screen shipping people process
#    0-7 250 2142.0 cards sd memory card slots camera plastic small pockets sleeves
#      0-7-1 201 131.0 dvd keeping car odor tiny sd compact access free expecting
#      0-7-2 49 41.0 slot lost free place center photo paperwork happen originally terrible
#    0-8 425 3949.0 broke months zipper quality year years strap return warranty ago
#      0-8-1 31 34.0 short giving solid refund build bucks reasonable wear feature adequate
#      0-8-2 89 70.0 + equipment build roller scratch bunch ago completely snaps plastic
#      0-8-3 305 304.0 quality photos week $ regret point year pay process contacted
#    0-9 1560 13058.0 cover color keyboard ! love mac apple easy hard pro
#      0-9-2 111 86.0 bright easily half picture bottom cool expectations true seller experience
#      0-9-3 84 293.0 & ; portion customer ago feels feel fell initially grip
#      0-9-4 270 434.0 keyboard keys protector screen typing key cover match deal picture
#      0-9-5 1076 1301.0 & ; keyboard keys mcover perfectly install helps darker hands
#      0-9-6 19 19.0 doesnt enjoy earlier cell tend brand finish inexpensive avoid asked
#    0-10 524 5718.0 pocket pockets small water bottle carry compartment books front side
#      0-10-1 104 113.0 plan weeks file stated fitting show advertised area slot standard
#      0-10-2 280 274.0 cord iphone clip essentials replacement removed exterior numerous flash straps
#      0-10-3 124 120.0 ipad lot tabs loaded correctly adjustable student vaio wallet phone
#      0-10-4 16 23.0 additional asked securely empty cute previous online wear change basically
#    0-11 1261 8789.0 sleeve inch ; pocket & pro small tight laptops big
#      0-11-1 84 84.0 front offered regret prefer difficult slight sleeves means incase opened
#      0-11-3 604 599.0 inches dimensions inch size description amazon wide smell correct computers
#      0-11-4 207 853.0 & ; dimensions description compartment asus dell correct return zip
#      0-11-5 243 503.0 & ; retina pro display mbp late loose reviews slides
#      0-11-6 80 69.0 chromebook cord neoprene cables turned zippered designed surface stitching care
#      0-11-7 43 30.0 nicely cushioned machine stars bucks standard pack fold thick portion
#    0-12 381 3801.0 zipper strap handle broke months shoulder straps zippers weeks started
#      0-12-2 86 99.0 grab walking falls terrible short cheap covers expected guess makes
#      0-12-3 276 248.0 binder snapped ripped properly falling fully support tear car designed
#      0-12-4 19 21.0 spare low snugly tear spend shows usage stand minor offered
#    0-13 742 7564.0 camera lenses carry lens pack straps room equipment gear compartment
#      0-13-1 120 109.0 airport compact swiss smaller convenient previous long future build ca
#      0-13-2 447 757.0 camera lenses canon battery body lens attached flash tripod access
#      0-13-3 175 257.0 lens cards battery attached canon cleaning batteries tight body lenses
#    0-14 1062 9505.0 cover bottom top plastic piece part keyboard hard apple feet
#      0-14-1 294 570.0 keyboard protector screen cover keys mouse key type set fan
#      0-14-2 274 295.0 ports surface mcover easily quickly holes original notice falls returning
#      0-14-3 202 358.0 : cons pros dust cut scratch mbp fingerprints update left
#      0-14-4 292 307.0 slide chromebook base ended lower secure smooth careful apple snuggly
#    0-15 805 6774.0 back carry books heavy pack straps stuff work pockets comfortable
#      0-15-1 122 102.0 chargers player end dvd constructed constantly clothes wheels overnight dirty
#      0-15-2 10 21.0 number campus lower replace missing day star targus hours closed
#      0-15-3 563 522.0 stuff swiss day load heavier rugged carrying class feels functional
#      0-15-4 110 73.0 documents choose normal bottle basis sized lap storage favorite flimsy
#    0-16 613 6541.0 room carry pockets plenty pocket small hold power items accessories
#      0-16-2 58 53.0 screen portable plenty extended wear manufacturer waste read entire swiss
#      0-16-4 2 1.0 wear zips foam flimsy flexible flaw flat flash flap fix
#      0-16-5 488 535.0 ; & ipad player lots lenovo weekend folders dvd accommodate
#      0-16-6 20 31.0 figured sleeves seat carried plan pieces broken battery owned headphones
#      0-16-7 40 41.0 shape main attached spot cord found choice place large laptops
#      0-16-8 5 8.0 gray shoulder normal features protection decided adapter adjustable zips fitting
#    0-17 2889 21358.0 ! handle ... years strap pockets shoulder straps heavy months
#      0-17-1 347 354.0 -inch plastic description fix sizes flaw suitcase expectations ? specifically
#      0-17-2 231 441.0 return item & ; shipping seller amazon online delivered refund
#      0-17-3 668 939.0 christmas husband swiss loves gift gear daughter loved lunch ago
#      0-17-4 266 361.0 & ; years model chargers lower brand briefcase correct ago
#      0-17-5 829 881.0 problem long years traveling functional handles lenses pleased 've swissgear
#      0-17-6 548 569.0 pockets coming pocket leather important house amazing reviewers stitching front
#    0-18 592 4967.0 sleeve protection protect air neoprene inside scratches pro padding material
#      0-18-1 146 158.0 mbp retina display added late mba function bonus tight perfectly
#      0-18-2 125 91.0 chromebook paper memory compared slides stretch tiny model pc briefcase
#      0-18-3 321 301.0 purchased offered additional air throw slightly lined attractive acer sewn
#    0-19 633 4566.0 mouse power netbook usb works drive : keyboard battery fine
#      0-19-1 206 925.0 drive usb hard cable port external ports card plug adapter
#      0-19-2 174 171.0 buying machine & keys weak protector road stretch screen heat
#      0-19-3 144 178.0 dvd player car portable mini security flash happier unit set
#      0-19-4 109 95.0 hot mind netbook attractive bright package professional ac choice white
#    0-20 818 9759.0 strap - pockets pocket shoulder compartment handle straps : carry
#      0-20-1 116 192.0 player & ; dvd / center textbooks low idea rain
#      0-20-2 410 849.0 & ; - pros cons : security handle phone high
#      0-20-3 203 212.0 metal flap negative handles downside front removable cord awkward sharp
#      0-20-4 89 99.0 targus worry included professional trips sticks mp office paper smart
#    0-21 2639 22810.0 sleeve pocket pockets inside strap room padding protection carry power
#      0-21-1 172 322.0 & ; resistant rain access seams construction convenient cushioned ultrabook
#      0-21-2 561 762.0 - bit surface cons pros slim pink & replace accessory
#      0-21-3 943 1294.0 ipad cover iphone devices smart cable travel fitting sleeve inside
#      0-21-4 462 560.0 offers dvd limited sufficient external extras player protective protects thicker
#      0-21-5 283 335.0 vaio storage supply impressed end transport hope impossible sony lightweight
#      0-21-6 218 306.0 makes angle targus long canvas travel care extended thickness purse
#    0-22 7113 44271.0 sleeve cover ! air protection color pro zipper scratches protect
#      0-22-1 351 1290.0 smell strong chemical smells odor days bad cute & horrible
#      0-22-2 868 2627.0 & ; retina pro smell - return display leather description
#      0-22-3 1077 1412.0 orange speck picture shown pattern color decent darker ports colors
#      0-22-4 2676 3727.0 ipad smell keyboard protector screen cover bad return stars pink
#      0-22-5 892 1633.0 & ; box orange pens mini % interior neoprene mbp
#      0-22-6 1249 1429.0 fall shell protector pattern provide chromebook smell shipping offers !
#    0-23 1830 14921.0 pockets strap carry shoulder pocket compartment room compartments comfortable straps
#      0-23-1 339 920.0 player dvd portable car seat sony tsa storing $ stores
#      0-23-2 715 1026.0 metal ipad college usb end smell stand added cord loves
#      0-23-3 776 1236.0 - pockets cell files -- con construction & build phone
#    0-24 374 2575.0 netbook toshiba bags camera amazon ' ? system pockets velcro
#      0-24-1 372 783.0 battery review local camera moving gear wife paper ; returned
#      0-24-2 2 7.0 perfectly set tiny handy hands bunch holder flat flash fine
#    0-25 41 294.0 surface change couple luggage covered skin samsung returned rolling cleaning
#      0-25-1 41 115.0 coming rear business kids supplies skin replace suitcase enjoy cloth
# 0 10000 20000 30000 0 0
