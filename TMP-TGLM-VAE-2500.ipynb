# %%
# %load_ext autoreload
# %autoreload
from IPython.display import clear_output

import os
import sys
import subprocess
import pdb
import time
import datetime
import math
import random
import _pickle as cPickle
from collections import defaultdict

from six.moves import zip_longest
import numpy as np

import tensorflow as tf
from tensorflow import distributions as tfd
from tensorflow.keras.preprocessing.sequence import pad_sequences

from data_structure import get_batches
from components import tf_log, sample_latents, compute_kl_loss, dynamic_rnn, dynamic_bi_rnn
from topic_model import TopicModel

from topic_beam_search_decoder import BeamSearchDecoder

# %%
PAD = '<pad>' # This has a vocab id, which is used to pad the encoder input, decoder input and target sequence
UNK = '<unk>' # This has a vocab id, which is used to represent out-of-vocabulary words
BOS = '<p>' # This has a vocab id, which is used at the beginning of every decoder input sequence
EOS = '</p>' # This has a vocab id, which is used at the end of untruncated target sequences

# %% [markdown]
# # load data & set config

# %%
def del_all_flags(FLAGS):
    flags_dict = FLAGS._flags()    
    keys_list = [keys for keys in flags_dict]    
    for keys in keys_list:
        FLAGS.__delattr__(keys)

del_all_flags(tf.flags.FLAGS)

flags = tf.app.flags

flags.DEFINE_string('gpu', '3', 'visible gpu')

flags.DEFINE_string('mode', 'train', 'set train or eval')

flags.DEFINE_string('data_path', 'data/apnews/instances.pkl', 'path of data')
flags.DEFINE_string('modeldir', 'model/tglm_vae_tmp2', 'directory of model')
flags.DEFINE_string('modelname', 'apnews', 'name of model')

flags.DEFINE_integer('epochs', 1000, 'epochs')
flags.DEFINE_integer('batch_size', 64, 'number of sentences in each batch')
flags.DEFINE_integer('log_period', 500, 'valid period')

flags.DEFINE_string('opt', 'Adagrad', 'optimizer')
flags.DEFINE_float('lr', 0.1, 'lr')
flags.DEFINE_float('reg', 1., 'regularization term')
flags.DEFINE_float('beta', 0.001, 'initial value of beta')
flags.DEFINE_float('grad_clip', 5., 'grad_clip')

flags.DEFINE_float('keep_prob', 0.8, 'dropout rate')
flags.DEFINE_float('word_keep_prob', 0.75, 'word dropout rate')

flags.DEFINE_integer('warmup', 2500, 'warmup period for KL')
flags.DEFINE_integer('warmup_topic', 0, 'warmup period for KL of topic')

flags.DEFINE_integer('beam_width', 2, 'beam_width')
flags.DEFINE_float('length_penalty_weight', 0.0, 'length_penalty_weight')

flags.DEFINE_integer('n_topic', 10, 'number of topic')
flags.DEFINE_integer('dim_hidden_bow', 256, 'dim of hidden bow')
flags.DEFINE_integer('dim_latent_bow', 32, 'dim of latent topic')
flags.DEFINE_integer('dim_emb', 256, 'dim_emb')
flags.DEFINE_integer('dim_hidden', 512, 'dim_hidden')
flags.DEFINE_integer('dim_hidden_topic', 512, 'dim_hidden_topic')
flags.DEFINE_integer('dim_latent', 32, 'dim_latent')
flags.DEFINE_bool('bidirectional', True, 'flg of bidirectional encoding')

# for evaluation
flags.DEFINE_string('refdir', 'ref', 'refdir')
flags.DEFINE_string('outdir', 'out', 'outdir')

flags.DEFINE_string('f', '', 'kernel')
flags.DEFINE_bool('logtostderr', True, 'kernel')
flags.DEFINE_bool('showprefixforinfo', False, '')
flags.DEFINE_bool('verbosity', False, '')
# flags.DEFINE_integer('stderrthreshold', 20, 'kernel')

config = flags.FLAGS

flags.DEFINE_string('modelpath', os.path.join(config.modeldir, config.modelname), 'path of model')

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = config.gpu

# %%
instances_train, instances_dev, instances_test, word_to_idx, idx_to_word, bow_idxs = cPickle.load(open(config.data_path,'rb'))

# %%
train_batches = get_batches(instances_train, config.batch_size)
dev_batches = get_batches(instances_dev, config.batch_size)
test_batches = get_batches(instances_test, config.batch_size)

# %%
flags.DEFINE_integer('PAD_IDX', word_to_idx[PAD], 'PAD_IDX')
flags.DEFINE_integer('UNK_IDX', word_to_idx[UNK], 'UNK_IDX')
flags.DEFINE_integer('BOS_IDX', word_to_idx[BOS], 'BOS_IDX')
flags.DEFINE_integer('EOS_IDX', word_to_idx[EOS], 'EOS_IDX')

flags.DEFINE_integer('n_vocab', len(word_to_idx), 'n_vocab')
flags.DEFINE_integer('dim_bow', len(bow_idxs), 'dim_bow')

maximum_iterations = max([max([instance.max_sent_l for instance in batch]) for ct, batch in dev_batches])
flags.DEFINE_integer('maximum_iterations', maximum_iterations, 'maximum_iterations')

# %% [markdown]
# # build language model

# %% [markdown]
# ## feed dict

# %%
tf.reset_default_graph()

t_variables = {}
t_variables['bow'] = tf.placeholder(tf.float32, [None, config.dim_bow], name='bow')
t_variables['input_token_idxs'] = tf.placeholder(tf.int32, [None, None], name='input_token_idxs')
t_variables['dec_input_idxs'] = tf.placeholder(tf.int32, [None, None], name='dec_input_idxs')
t_variables['dec_target_idxs'] = tf.placeholder(tf.int32, [None, None], name='dec_target_idxs')
t_variables['batch_l'] = tf.placeholder(tf.int32, name='batch_l')
t_variables['doc_l'] = tf.placeholder(tf.int32, [None], name='doc_l')
t_variables['sent_l'] = tf.placeholder(tf.int32, [None], name='sent_l')
t_variables['keep_prob'] = tf.placeholder(tf.float32, name='keep_prob')

# %%
def get_feed_dict(batch, mode='train', assertion=False):
    def token_dropout(sent_idxs):
        sent_idxs_dropout = np.asarray(sent_idxs)
        sent_idxs_dropout[np.random.rand(len(sent_idxs)) > config.word_keep_prob] = config.UNK_IDX
        return list(sent_idxs_dropout)

    bow = np.array([instance.bow for instance in batch]).astype(np.float32)
    
    doc_l = np.array([len(instance.token_idxs) for instance in batch])
    
    feed_input_token_idxs_list = [sent_idxs for instance in batch for sent_idxs in instance.token_idxs]
    feed_dec_input_idxs_list = [[config.BOS_IDX] + token_dropout(sent_idxs) for sent_idxs in feed_input_token_idxs_list]
    feed_dec_target_idxs_list = [sent_idxs + [config.EOS_IDX]  for sent_idxs in feed_input_token_idxs_list]
        
    sent_l = np.array([len(sent_idxs) for sent_idxs in feed_input_token_idxs_list], np.int32)
    batch_l = len(sent_l)
    
    feed_input_token_idxs = pad_sequences(feed_input_token_idxs_list, padding='post', value=config.PAD_IDX, dtype=np.int32)
    feed_dec_input_idxs = pad_sequences(feed_dec_input_idxs_list, padding='post', value=config.PAD_IDX, dtype=np.int32)
    feed_dec_target_idxs = pad_sequences(feed_dec_target_idxs_list, padding='post', value=config.PAD_IDX, dtype=np.int32)
    
    if assertion:
        index = 0
        for instance in batch:
            for line_idxs in instance.token_idxs:
                assert feed_input_token_idxs_list[index] == line_idxs
                index += 1
        assert feed_input_token_idxs.shape[1] == np.max(sent_l)
        assert feed_dec_input_idxs.shape[1] == np.max(sent_l) + 1
        assert feed_dec_target_idxs.shape[1] == np.max(sent_l) + 1
    
    keep_prob = config.keep_prob if mode == 'train' else 1.0

    feed_dict = {
                t_variables['bow']: bow, 
                t_variables['batch_l']: batch_l, t_variables['doc_l']: doc_l, t_variables['sent_l']: sent_l, 
                t_variables['input_token_idxs']: feed_input_token_idxs, t_variables['dec_input_idxs']: feed_dec_input_idxs, t_variables['dec_target_idxs']: feed_dec_target_idxs, 
                t_variables['keep_prob']: keep_prob
    }
    return  feed_dict

# %%
def debug_shape(variables):
    sample_batch = test_batches[0][1]
    feed_dict = get_feed_dict(sample_batch)
    _variables = sess.run(variables, feed_dict=feed_dict)
    for _variable, variable in zip(_variables, variables):
        if hasattr(variable, 'name'):
            print(variable.name, ':', _variable.shape)
        else:
            print(_variable.shape)

def debug_value(variables, return_value=False):
    sample_batch = test_batches[0][1]
    feed_dict = get_feed_dict(sample_batch)
    _variables = sess.run(variables, feed_dict=feed_dict)

    if return_value: 
        return _variables
    else:
        for _variable, variable in zip(_variables, variables):
            if hasattr(variable, 'name'):
                print(variable.name, ':', _variable)
            else:
                print(_variable)
                
def check_shape(variables):
    if 'sess' in globals(): raise
    sess = tf.Session()
    sess.run(tf.global_variables_initializer())
    
    sample_batch = test_batches[0][1]
    feed_dict = get_feed_dict(sample_batch)
    _variables = sess.run(variables, feed_dict=feed_dict)
    for _variable, variable in zip(_variables, variables):
        if hasattr(variable, 'name'):
            print(variable.name, ':', _variable.shape)
        else:
            print(_variable.shape)
            
    sess.close()
    
def check_value(variables):
    if 'sess' in globals(): raise
    sess = tf.Session()
    sess.run(tf.global_variables_initializer())
    
    sample_batch = test_batches[0][1]
    feed_dict = get_feed_dict(sample_batch)
    _variables = sess.run(variables, feed_dict=feed_dict)
    for _variable, variable in zip(_variables, variables):
        if hasattr(variable, 'name'):
            print(variable.name, ':', _variable)
        else:
            print(_variable.shape)
            
    sess.close()    
    
# sent_loss_kl_categ_tmp = tf.reduce_mean(tf.reduce_sum(tf.multiply(prob_topic_infer, tf_log(prob_topic_infer/prob_topic_sents)), 1))
# debug_value([sent_loss_kl_categ, sent_loss_kl_categ_tmp])
# sent_loss_kl_gauss_tmp = 0.5 * tf.reduce_sum(tf.exp(logvars_topic_infer-logvars_topic) + tf.square(means_topic - means_topic_infer) / tf.exp(logvars_topic) - 1 + (logvars_topic - logvars_topic_infer), -1)
# sent_loss_kl_gmm_tmp = tf.reduce_mean(tf.reduce_sum(tf.multiply(prob_topic_infer, sent_loss_kl_gauss_tmp), -1))
# debug_value([sent_loss_kl_gmm_tmp, sent_loss_kl_gmm])

# %% [markdown]
# ## topic model

# %%
# encode bow
with tf.variable_scope('topic/enc', reuse=False):
    hidden_bow_ = tf.layers.Dense(units=config.dim_hidden_bow, activation=tf.nn.relu, name='hidden_bow')(t_variables['bow'])
    hidden_bow = tf.layers.Dropout(t_variables['keep_prob'])(hidden_bow_)
    means_bow = tf.layers.Dense(units=config.dim_latent_bow, name='mean_bow')(hidden_bow)
    logvars_bow = tf.layers.Dense(units=config.dim_latent_bow, kernel_initializer=tf.constant_initializer(0), bias_initializer=tf.constant_initializer(0), name='logvar_topic')(hidden_bow)
    latents_bow = sample_latents(means_bow, logvars_bow) # sample latent vectors

    prob_topic = tf.layers.Dense(units=config.n_topic, activation=tf.nn.softmax, name='prob_topic')(latents_bow) # inference of topic probabilities

# decode bow
with tf.variable_scope('shared', reuse=False):
    embeddings = tf.get_variable('emb', [config.n_vocab, config.dim_emb], dtype=tf.float32, initializer=tf.contrib.layers.xavier_initializer()) # embeddings of vocab

bow_embeddings = tf.nn.embedding_lookup(embeddings, bow_idxs) # embeddings of each bow features

with tf.variable_scope('topic/dec', reuse=False):
    topic_embeddings = tf.get_variable('topic_emb', [config.n_topic, config.dim_emb], dtype=tf.float32, initializer=tf.contrib.layers.xavier_initializer()) # embeddings of topics

    topic_bow = tf.nn.softmax(tf.matmul(topic_embeddings, bow_embeddings, transpose_b=True), 1) # bow vectors for each topic
    logits_bow = tf_log(tf.matmul(prob_topic, topic_bow)) # predicted bow distribution

    # prior of each gaussian distribution (computed for each topic)
    hidden_topic = tf.layers.Dense(units=config.dim_hidden_topic, activation=tf.nn.relu, name='hidden_topic')(topic_bow)
    means_topic = tf.layers.Dense(units=config.dim_latent, name='mean_topic')(hidden_topic)
    logvars_topic = tf.layers.Dense(units=config.dim_latent, kernel_initializer=tf.constant_initializer(0), bias_initializer=tf.constant_initializer(0), name='logvar_topic')(hidden_topic)
    sigma_topic = tf.exp(0.5 * logvars_topic)
    gauss_topic = tfd.Normal(loc=means_topic, scale=sigma_topic)    
    
# define losses
topic_losses_recon = -tf.reduce_sum(tf.multiply(t_variables['bow'], logits_bow), 1)
topic_loss_recon = tf.reduce_mean(topic_losses_recon) # negative log likelihood of each words

topic_loss_kl = compute_kl_loss(means_bow, logvars_bow) # KL divergence b/w latent dist & gaussian std

topic_bow_norm = topic_bow / tf.norm(topic_bow, axis=1, keepdims=True)
topic_dots = tf.clip_by_value(tf.matmul(topic_bow_norm, tf.transpose(topic_bow_norm)), -1., 1.)
topic_loss_reg = tf.reduce_mean(tf.square(topic_dots - tf.eye(config.n_topic)))
# topic_angles = tf.acos(topic_dots)
# topic_angles_mean = tf.reduce_mean(topic_angles)
# topic_angles_vars = tf.reduce_mean(tf.square(topic_angles - topic_angles_mean))
# topic_loss_reg = tf.exp(topic_angles_vars - topic_angles_mean)

# monitor
n_bow = tf.reduce_sum(t_variables['bow'], 1)
topic_ppls = tf.divide(topic_losses_recon, n_bow)
topics_freq_bow_indices = tf.nn.top_k(topic_bow, 10, name='topic_freq_bow').indices

# %% [markdown]
# ## encoder

# %%
# input
input_token_idxs = t_variables['input_token_idxs']
batch_l = t_variables['batch_l']
sent_l = t_variables['sent_l']
max_sent_l = tf.reduce_max(sent_l)

with tf.variable_scope('sent/enc', reuse=False):
    # get word embedding
    enc_input = tf.nn.embedding_lookup(embeddings, input_token_idxs)

    # get sentence embedding
    _, enc_state = dynamic_bi_rnn(enc_input, sent_l, config.dim_hidden, t_variables['keep_prob'])

    # TODO House Holder flow
    hidden_topic_infer =  tf.layers.Dense(units=config.dim_hidden, activation=tf.nn.relu, name='hidden_topic_infer')(enc_state)
    prob_topic_infer = tf.layers.Dense(units=config.n_topic, activation=tf.nn.softmax, name='prob_topic_infer')(hidden_topic_infer)

    w_mean_topic_infer = tf.get_variable('mean_topic_infer/kernel', [config.n_topic, enc_state.shape[-1], config.dim_latent], dtype=tf.float32)
    b_mean_topic_infer = tf.get_variable('mean_topic_infer/bias', [1, config.n_topic, config.dim_latent], dtype=tf.float32)
    means_topic_infer = tf.tensordot(enc_state, w_mean_topic_infer, axes=[[1], [1]]) + b_mean_topic_infer
    
    w_logvar_topic_infer = tf.get_variable('logvar_topic_infer/kernel', [config.n_topic, enc_state.shape[-1], config.dim_latent], dtype=tf.float32, initializer=tf.constant_initializer(0))
    b_logvar_topic_infer = tf.get_variable('logvar_topic_infer/bias', [1, config.n_topic, config.dim_latent], dtype=tf.float32, initializer=tf.constant_initializer(0))
    logvars_topic_infer = tf.tensordot(enc_state, w_logvar_topic_infer, axes=[[1], [1]]) + b_logvar_topic_infer
    sigma_topic_infer = tf.exp(0.5 * logvars_topic_infer)
    gauss_topic_infer = tfd.Normal(loc=means_topic_infer, scale=sigma_topic_infer)
    
    # latent vectors from each gaussian dist.
    latents_topic_infer = sample_latents(means_topic_infer, logvars_topic_infer) 
    # latent vector from gaussian mixture
    latents_input = tf.matmul(tf.expand_dims(prob_topic_infer, -1), latents_topic_infer, transpose_a=True)
    
    # for beam search
    means_input = tf.matmul(tf.expand_dims(prob_topic_infer, -1), means_topic_infer, transpose_a=True)

# %% [markdown]
# ## decoder

# %%
# prepare for decoding
dec_sent_l = tf.add(sent_l, 1)
dec_input_idxs = t_variables['dec_input_idxs']
dec_input = tf.nn.embedding_lookup(embeddings, dec_input_idxs)

dec_latents_input = tf.tile(latents_input, [1, tf.shape(dec_input)[1], 1])
dec_concat_input = tf.concat([dec_input, dec_latents_input], -1)

# decode for training
with tf.variable_scope('sent/dec/rnn', initializer=tf.contrib.layers.xavier_initializer(), dtype = tf.float32, reuse=False):
    dec_cell = tf.contrib.rnn.GRUCell(config.dim_hidden)
    dec_cell = tf.contrib.rnn.DropoutWrapper(dec_cell, output_keep_prob = t_variables['keep_prob'])

    dec_initial_state = tf.layers.Dense(units=config.dim_hidden, activation=tf.nn.relu, name='init_state')(tf.squeeze(latents_input, 1))
    
    helper = tf.contrib.seq2seq.TrainingHelper(inputs=dec_concat_input, sequence_length=dec_sent_l)

    train_decoder = tf.contrib.seq2seq.BasicDecoder(
        cell=dec_cell,
        helper=helper,
        initial_state=dec_initial_state)

    dec_outputs, _, output_sent_l = tf.contrib.seq2seq.dynamic_decode(train_decoder)
    
    output_layer = tf.layers.Dense(config.n_vocab, use_bias=False, name='out')
    output_logits = output_layer(dec_outputs.rnn_output)
    
    output_token_idxs = tf.argmax(output_logits, 2)

# %%
start_tokens = tf.fill([batch_l], config.BOS_IDX)
end_token = config.EOS_IDX

with tf.variable_scope('sent/dec/rnn', reuse=True):
    infer_dec_initial_state = tf.layers.Dense(units=config.dim_hidden, activation=tf.nn.relu, name='init_state')(tf.squeeze(means_input, 1))
    beam_dec_initial_state = tf.contrib.seq2seq.tile_batch(infer_dec_initial_state, multiplier=config.beam_width)
    beam_latents_input = tf.contrib.seq2seq.tile_batch(tf.squeeze(means_input, 1), multiplier=config.beam_width) # added
    
    beam_decoder = BeamSearchDecoder(
        cell=dec_cell,
        embedding=embeddings,
        start_tokens=start_tokens,
        end_token=end_token,
        initial_state=beam_dec_initial_state,
        beam_width=config.beam_width, 
        output_layer=output_layer,
        length_penalty_weight=config.length_penalty_weight,
        latents_input=beam_latents_input)

    beam_dec_outputs, _, _ = tf.contrib.seq2seq.dynamic_decode(
        beam_decoder,
        maximum_iterations = config.maximum_iterations)

    beam_output_token_idxs = beam_dec_outputs.predicted_ids[:, :, 0]

# %%
with tf.variable_scope('sent/dec/rnn', reuse=True):
    inter_means_input = tf.placeholder(tf.float32, [None, config.dim_latent])
    
    inter_dec_initial_state = tf.layers.Dense(units=config.dim_hidden, activation=tf.nn.relu, name='init_state')(inter_means_input)
    inter_beam_dec_initial_state = tf.contrib.seq2seq.tile_batch(inter_dec_initial_state, multiplier=config.beam_width)
    inter_beam_latents_input = tf.contrib.seq2seq.tile_batch(inter_means_input, multiplier=config.beam_width) # added
    
    inter_beam_decoder = BeamSearchDecoder(
        cell=dec_cell,
        embedding=embeddings,
        start_tokens=start_tokens,
        end_token=end_token,
        initial_state=inter_beam_dec_initial_state,
        beam_width=config.beam_width, 
        output_layer=output_layer,
        length_penalty_weight=config.length_penalty_weight,
        latents_input=inter_beam_latents_input)

    inter_beam_dec_outputs, _, _ = tf.contrib.seq2seq.dynamic_decode(
        inter_beam_decoder,
        maximum_iterations = config.maximum_iterations)

    inter_beam_output_token_idxs = inter_beam_dec_outputs.predicted_ids[:, :, 0]

# %%
with tf.variable_scope('sent/dec/rnn', reuse=True):
    topic_dec_initial_state = tf.layers.Dense(units=config.dim_hidden, activation=tf.nn.relu, name='init_state')(means_topic)
    topic_beam_dec_initial_state = tf.contrib.seq2seq.tile_batch(topic_dec_initial_state, multiplier=config.beam_width)
    topic_beam_latents_input = tf.contrib.seq2seq.tile_batch(means_topic, multiplier=config.beam_width) # added
    
    topic_beam_decoder = BeamSearchDecoder(
        cell=dec_cell,
        embedding=embeddings,
        start_tokens=start_tokens,
        end_token=end_token,
        initial_state=topic_beam_dec_initial_state,
        beam_width=config.beam_width, 
        output_layer=output_layer,
        length_penalty_weight=config.length_penalty_weight,
        latents_input=topic_beam_latents_input)

    topic_beam_dec_outputs, _, _ = tf.contrib.seq2seq.dynamic_decode(
        topic_beam_decoder,
        maximum_iterations = config.maximum_iterations)

    topic_beam_output_token_idxs = topic_beam_dec_outputs.predicted_ids[:, :, 0]

# %% [markdown]
# ## language modeling cost

# %%
# target and mask
dec_target_idxs = t_variables['dec_target_idxs']
dec_mask_tokens = tf.sequence_mask(dec_sent_l, maxlen=max_sent_l+1, dtype=tf.float32)

# nll for each token (averaged over batch & sentence)
sent_loss_recon = tf.contrib.seq2seq.sequence_loss(output_logits, dec_target_idxs, dec_mask_tokens)

# %%
doc_l = t_variables['doc_l']
mask_sents = tf.sequence_mask(doc_l)
mask_sents_flatten = tf.reshape(mask_sents, [tf.shape(mask_sents)[0]*tf.shape(mask_sents)[1]])

prob_topic_tiled = tf.tile(tf.expand_dims(prob_topic, 1), [1, tf.shape(mask_sents)[1], 1])
prob_topic_flatten = tf.reshape(prob_topic_tiled, [tf.shape(mask_sents)[0]*tf.shape(mask_sents)[1], config.n_topic])
prob_topic_sents = tf.boolean_mask(prob_topic_flatten, mask_sents_flatten)

# %%
# inferred mixture probabilities (computed for each sentence)
categ_topic_infer = tfd.Categorical(probs=prob_topic_infer)

# prior of mixture probabilities (computed for each document, tiled for each sentence)
categ_topic = tfd.Categorical(probs=prob_topic_sents)

sent_loss_kl_categ = tf.reduce_mean(tfd.kl_divergence(categ_topic_infer, categ_topic))

# inference of each gaussian gaussribution (computed for each sentence)

sent_loss_kl_gauss = tf.reduce_sum(tfd.kl_divergence(gauss_topic_infer, gauss_topic), -1)
sent_loss_kl_gmm = tf.reduce_mean(tf.reduce_sum(tf.multiply(prob_topic_infer, sent_loss_kl_gauss), -1))

sent_loss_kl = sent_loss_kl_categ + sent_loss_kl_gmm

# %% [markdown]
# ## optimizer

# %%
beta = tf.Variable(config.beta, name='beta', trainable=False) if config.warmup > 0 else tf.constant(1., name='beta')
update_beta = tf.assign_add(beta, 1./(config.warmup*len(train_batches)))
sent_loss = sent_loss_recon + beta * sent_loss_kl

topic_loss = topic_loss_recon + topic_loss_kl + config.reg * topic_loss_reg
loss = topic_loss + sent_loss

# define optimizer
if config.opt == 'Adam':
    optimizer = tf.train.AdamOptimizer(config.lr)
elif config.opt == 'Adagrad':
    optimizer = tf.train.AdagradOptimizer(config.lr)
    
grad_vars = optimizer.compute_gradients(loss)
clipped_grad_vars = [(tf.clip_by_value(grad, -config.grad_clip, config.grad_clip), var) for grad, var in grad_vars]

opt = optimizer.apply_gradients(clipped_grad_vars)
# Out:
# /home/m-isonuma/.pyenv/versions/anaconda2-5.3.0/envs/py36/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %% [markdown]
# # run model

# %%
def idxs_to_sents(token_idxs, config, idx_to_word):
    sents = []
    for sent_idxs in token_idxs:
        tokens = []
        for idx in sent_idxs:
            if idx == config.EOS_IDX: break
            tokens.append(idx_to_word[idx])
        sent = ' '.join(tokens)
        sents.append(sent)
    return sents

# %%
def get_loss(sess, batches):
    losses = []
    ppl_list = []
    for ct, batch in batches:
        feed_dict = get_feed_dict(batch, mode='test')
        loss_batch, topic_loss_batch, sent_loss_batch, ppls_batch = sess.run([loss, topic_loss, sent_loss, topic_ppls], feed_dict = feed_dict)
        losses += [[loss_batch, topic_loss_batch, sent_loss_batch]]
        ppl_list += list(ppls_batch)
    loss_mean, topic_loss_mean, sent_loss_mean = np.mean(losses, 0)
    ppl_mean = np.exp(np.mean(ppl_list))
    return loss_mean, topic_loss_mean, sent_loss_mean, ppl_mean

def get_all_losses(sess, batches):
    losses = []
    for ct, batch in batches:
        feed_dict = get_feed_dict(batch, mode='test')
        loss_batch, topic_loss_recon_batch, topic_loss_kl_batch, sent_loss_recon_batch, sent_loss_kl_batch = \
        sess.run([loss, topic_loss_recon, topic_loss_kl, sent_loss_recon, sent_loss_kl], feed_dict = feed_dict)
        losses += [[loss_batch, topic_loss_recon_batch, topic_loss_kl_batch, sent_loss_recon_batch, sent_loss_kl_batch]]
    print('LOSS %.2f | TM NLL: %.2f, KL: %.4f | LM NLL: %.2f, KL: %.4f' %  np.mean(losses, 0))

# %%
def print_sample(sample_batch):
    feed_dict = get_feed_dict(sample_batch)
    pred_token_idxs = sess.run(output_token_idxs, feed_dict = feed_dict)
    true_token_idxs = [sent_idxs for instance in sample_batch for sent_idxs in instance.token_idxs]
    
    assert len(pred_token_idxs) == len(true_token_idxs)
    
    pred_sents = idxs_to_sents(pred_token_idxs, config, idx_to_word)
    true_sents = idxs_to_sents(true_token_idxs, config, idx_to_word)
    
    for i, (true_sent, pred_sent) in enumerate(zip(true_sents, pred_sents)):        
        print(i, 'True: %s' % true_sent)
        print(i, 'Pred: %s' % pred_sent)

def print_topic_sample():
    pred_topics_freq_bow_indices, pred_topic_token_idxs = sess.run([topics_freq_bow_indices, topic_beam_output_token_idxs], 
                                                                                                           feed_dict={t_variables['batch_l']: config.n_topic, t_variables['keep_prob']: 1.,})
    pred_topic_sents = idxs_to_sents(pred_topic_token_idxs, config, idx_to_word)
    
    topics_freq_bow_idxs = bow_idxs[pred_topics_freq_bow_indices]
    
    print('-----------Topic Samples-----------')
    for i, (topic_freq_bow_idxs, pred_topic_sent) in enumerate(zip(topics_freq_bow_idxs, pred_topic_sents)):
        print(i, ' bow:', ' '.join([idx_to_word[idx] for idx in topic_freq_bow_idxs]))
        print(i, ' sent:', pred_topic_sent)

# %%
if 'sess' in globals(): sess.close()
sess = tf.Session()
sess.run(tf.global_variables_initializer())

logs = []
losses_train = []
ppls_train = []
loss_min = np.inf
beta_eval = 1.
epoch = 0
train_batches = get_batches(instances_train, config.batch_size, iterator=True)
saver = tf.train.Saver(max_to_keep=10)

# %%
if len(logs) == 0:
    cmd_rm = 'rm -r %s' % config.modeldir
    res = subprocess.call(cmd_rm.split())

    cmd_mk = 'mkdir %s' % config.modeldir
    res = subprocess.call(cmd_mk.split())

time_start = time.time()
while epoch < config.epochs:
    for ct, batch in train_batches:
        feed_dict = get_feed_dict(batch)
        if config.warmup > 0 and beta_eval < 1.0: sess.run(update_beta)

        _, loss_batch, topic_loss_recon_batch, topic_loss_kl_batch, topic_loss_reg_batch, sent_loss_recon_batch, sent_loss_kl_batch, sent_loss_kl_categ_batch, sent_loss_kl_gmm_batch, ppls_batch = \
        sess.run([opt, loss, topic_loss_recon, topic_loss_kl, topic_loss_reg, sent_loss_recon, sent_loss_kl, sent_loss_kl_categ, sent_loss_kl_gmm, topic_ppls], feed_dict = feed_dict)
        
        if sent_loss_kl_batch == np.inf:
            print('Nan occured')
#             pdb.set_trace()
            ckpt = tf.train.get_checkpoint_state(config.modeldir)
            model_checkpoint_path = ckpt.all_model_checkpoint_paths[-1]
            saver.restore(sess, model_checkpoint_path)            
            break
            
        losses_train += [[loss_batch, topic_loss_recon_batch, topic_loss_kl_batch, topic_loss_reg_batch, sent_loss_recon_batch, sent_loss_kl_batch]]
        ppls_train += list(ppls_batch)

        if ct%config.log_period==0:
            time_dev = time.time()
            loss_train, topic_loss_recon_train, topic_loss_kl_train, topic_loss_reg_train, sent_loss_recon_train, sent_loss_kl_train = np.mean(losses_train, 0)
            ppl_train = np.exp(np.mean(ppls_train))
            loss_dev, topic_loss_dev, sent_loss_dev, ppl_dev = get_loss(sess, dev_batches)
            
            if loss_dev < loss_min:
                loss_min = loss_dev
                saver.save(sess, config.modelpath, global_step=epoch*10000+ct)

            if config.warmup > 0: beta_eval = beta.eval(session=sess)

            clear_output()
            time_finish = time.time()
            time_log = int(time_finish - time_start)
            time_log_dev = int(time_finish - time_dev)
            logs += [(time_log, time_log_dev, epoch, ct, loss_train, ppl_train, topic_loss_recon_train, topic_loss_kl_train, topic_loss_reg_train, sent_loss_recon_train, sent_loss_kl_train, loss_dev, ppl_dev, topic_loss_dev, sent_loss_dev, beta_eval)]
            for log in logs:
                print('%03d[s], %02d[s], Ep: %02d, Ct: %05d|TR LOSS: %.0f, PPL: %.0f|TM NLL: %.0f, KL: %.2f, REG:%.2f | LM NLL: %.2f, KL: %.2f|DE LOSS: %.0f, PPL: %.0f, TM: %.0f, LM: %.2f|BETA: %.6f' %  log)

            print_sample(batch)

            time_start = time.time()
            
            print_topic_sample()
                
    epoch += 1
    train_batches = get_batches(instances_train, config.batch_size, iterator=True)
# Out:
# 053[s], 51[s], Ep: 00, Ct: 00000|TR LOSS: 345, PPL: 2662|TM NLL: 333, KL: 0.59, REG:0.90 | LM NLL: 10.34, KL: 1.45|DE LOSS: 348, PPL: 2656, TM: 337, LM: 10.34|BETA: 0.001000
# 107[s], 29[s], Ep: 00, Ct: 00500|TR LOSS: 327, PPL: 1600|TM NLL: 318, KL: 1.15, REG:0.48 | LM NLL: 7.44, KL: 14.09|DE LOSS: 318, PPL: 1406, TM: 312, LM: 6.90|BETA: 0.001069
# 117[s], 29[s], Ep: 01, Ct: 00000|TR LOSS: 325, PPL: 1519|TM NLL: 316, KL: 1.53, REG:0.36 | LM NLL: 7.20, KL: 13.26|DE LOSS: 318, PPL: 1407, TM: 311, LM: 6.82|BETA: 0.001069
# 105[s], 29[s], Ep: 01, Ct: 00500|TR LOSS: 324, PPL: 1466|TM NLL: 315, KL: 1.73, REG:0.29 | LM NLL: 7.07, KL: 12.43|DE LOSS: 316, PPL: 1344, TM: 309, LM: 6.72|BETA: 0.001139
# 107[s], 30[s], Ep: 01, Ct: 01000|TR LOSS: 323, PPL: 1424|TM NLL: 313, KL: 1.94, REG:0.24 | LM NLL: 6.99, KL: 10.97|DE LOSS: 313, PPL: 1259, TM: 307, LM: 6.67|BETA: 0.001208
# 104[s], 29[s], Ep: 01, Ct: 01500|TR LOSS: 321, PPL: 1381|TM NLL: 312, KL: 2.11, REG:0.20 | LM NLL: 6.93, KL: 9.91|DE LOSS: 312, PPL: 1208, TM: 305, LM: 6.62|BETA: 0.001277
# 106[s], 30[s], Ep: 01, Ct: 02000|TR LOSS: 320, PPL: 1347|TM NLL: 311, KL: 2.27, REG:0.18 | LM NLL: 6.89, KL: 9.23|DE LOSS: 311, PPL: 1168, TM: 304, LM: 6.58|BETA: 0.001347
# 108[s], 29[s], Ep: 01, Ct: 02500|TR LOSS: 319, PPL: 1317|TM NLL: 310, KL: 2.38, REG:0.16 | LM NLL: 6.85, KL: 8.76|DE LOSS: 310, PPL: 1140, TM: 303, LM: 6.53|BETA: 0.001416
# 092[s], 34[s], Ep: 02, Ct: 00000|TR LOSS: 319, PPL: 1299|TM NLL: 309, KL: 2.46, REG:0.15 | LM NLL: 6.82, KL: 8.47|DE LOSS: 310, PPL: 1132, TM: 303, LM: 6.64|BETA: 0.001469
# 119[s], 43[s], Ep: 02, Ct: 00500|TR LOSS: 318, PPL: 1276|TM NLL: 309, KL: 2.56, REG:0.14 | LM NLL: 6.79, KL: 8.19|DE LOSS: 309, PPL: 1118, TM: 302, LM: 6.54|BETA: 0.001539
# 068[s], 30[s], Ep: 03, Ct: 00000|TR LOSS: 318, PPL: 1272|TM NLL: 308, KL: 2.58, REG:0.14 | LM NLL: 6.78, KL: 8.14|DE LOSS: 309, PPL: 1120, TM: 302, LM: 6.43|BETA: 0.001539
# 109[s], 30[s], Ep: 04, Ct: 00000|TR LOSS: 317, PPL: 1257|TM NLL: 308, KL: 2.64, REG:0.13 | LM NLL: 6.76, KL: 7.98|DE LOSS: 309, PPL: 1120, TM: 302, LM: 6.45|BETA: 0.001539
# 107[s], 30[s], Ep: 04, Ct: 00500|TR LOSS: 317, PPL: 1243|TM NLL: 308, KL: 2.71, REG:0.12 | LM NLL: 6.73, KL: 7.80|DE LOSS: 308, PPL: 1111, TM: 302, LM: 6.40|BETA: 0.001608
# 106[s], 29[s], Ep: 04, Ct: 01000|TR LOSS: 317, PPL: 1230|TM NLL: 307, KL: 2.77, REG:0.12 | LM NLL: 6.70, KL: 7.65|DE LOSS: 308, PPL: 1100, TM: 302, LM: 6.34|BETA: 0.001678
# 126[s], 50[s], Ep: 04, Ct: 01500|TR LOSS: 316, PPL: 1218|TM NLL: 307, KL: 2.83, REG:0.11 | LM NLL: 6.68, KL: 7.53|DE LOSS: 308, PPL: 1085, TM: 301, LM: 6.27|BETA: 0.001747
# 126[s], 50[s], Ep: 04, Ct: 02000|TR LOSS: 316, PPL: 1208|TM NLL: 306, KL: 2.87, REG:0.11 | LM NLL: 6.65, KL: 7.50|DE LOSS: 307, PPL: 1079, TM: 301, LM: 6.19|BETA: 0.001816
# 037[s], 08[s], Ep: 05, Ct: 00000|TR LOSS: 316, PPL: 1206|TM NLL: 306, KL: 2.87, REG:0.11 | LM NLL: 6.65, KL: 7.50|DE LOSS: 307, PPL: 1084, TM: 301, LM: 6.23|BETA: 0.001816
# 126[s], 50[s], Ep: 05, Ct: 00500|TR LOSS: 315, PPL: 1197|TM NLL: 306, KL: 2.92, REG:0.10 | LM NLL: 6.62, KL: 7.51|DE LOSS: 307, PPL: 1082, TM: 301, LM: 6.12|BETA: 0.001886
# 126[s], 50[s], Ep: 06, Ct: 00000|TR LOSS: 315, PPL: 1192|TM NLL: 306, KL: 2.95, REG:0.10 | LM NLL: 6.60, KL: 7.53|DE LOSS: 307, PPL: 1078, TM: 301, LM: 6.13|BETA: 0.001886
# 119[s], 43[s], Ep: 06, Ct: 00500|TR LOSS: 315, PPL: 1184|TM NLL: 305, KL: 2.98, REG:0.10 | LM NLL: 6.57, KL: 7.55|DE LOSS: 307, PPL: 1073, TM: 301, LM: 6.06|BETA: 0.001955
# 126[s], 50[s], Ep: 06, Ct: 01000|TR LOSS: 315, PPL: 1178|TM NLL: 305, KL: 3.01, REG:0.10 | LM NLL: 6.54, KL: 7.61|DE LOSS: 307, PPL: 1073, TM: 301, LM: 6.03|BETA: 0.002025
# 126[s], 50[s], Ep: 06, Ct: 01500|TR LOSS: 315, PPL: 1172|TM NLL: 305, KL: 3.04, REG:0.09 | LM NLL: 6.51, KL: 7.69|DE LOSS: 307, PPL: 1068, TM: 301, LM: 5.92|BETA: 0.002094
# 083[s], 08[s], Ep: 06, Ct: 02000|TR LOSS: 314, PPL: 1165|TM NLL: 305, KL: 3.06, REG:0.09 | LM NLL: 6.48, KL: 7.80|DE LOSS: 307, PPL: 1068, TM: 301, LM: 5.87|BETA: 0.002163
# 105[s], 29[s], Ep: 06, Ct: 02500|TR LOSS: 314, PPL: 1160|TM NLL: 304, KL: 3.18, REG:0.09 | LM NLL: 6.46, KL: 7.91|DE LOSS: 306, PPL: 1062, TM: 301, LM: 5.82|BETA: 0.002233
# 088[s], 29[s], Ep: 07, Ct: 00000|TR LOSS: 314, PPL: 1155|TM NLL: 304, KL: 3.19, REG:0.09 | LM NLL: 6.43, KL: 8.02|DE LOSS: 306, PPL: 1060, TM: 300, LM: 5.80|BETA: 0.002286
# 084[s], 08[s], Ep: 07, Ct: 00500|TR LOSS: 314, PPL: 1151|TM NLL: 304, KL: 3.21, REG:0.09 | LM NLL: 6.40, KL: 8.18|DE LOSS: 306, PPL: 1059, TM: 300, LM: 5.74|BETA: 0.002355
# 106[s], 29[s], Ep: 07, Ct: 01000|TR LOSS: 314, PPL: 1146|TM NLL: 304, KL: 3.23, REG:0.09 | LM NLL: 6.37, KL: 8.36|DE LOSS: 306, PPL: 1051, TM: 300, LM: 5.64|BETA: 0.002425
# 067[s], 08[s], Ep: 08, Ct: 00000|TR LOSS: 314, PPL: 1145|TM NLL: 304, KL: 3.23, REG:0.08 | LM NLL: 6.37, KL: 8.41|DE LOSS: 306, PPL: 1054, TM: 300, LM: 5.65|BETA: 0.002425
# 018[s], 08[s], Ep: 09, Ct: 00000|TR LOSS: 314, PPL: 1144|TM NLL: 304, KL: 3.24, REG:0.08 | LM NLL: 6.36, KL: 8.43|DE LOSS: 306, PPL: 1052, TM: 300, LM: 5.67|BETA: 0.002425
# 105[s], 30[s], Ep: 09, Ct: 00500|TR LOSS: 313, PPL: 1140|TM NLL: 304, KL: 3.25, REG:0.08 | LM NLL: 6.33, KL: 8.61|DE LOSS: 306, PPL: 1047, TM: 300, LM: 5.57|BETA: 0.002494
# 085[s], 08[s], Ep: 09, Ct: 01000|TR LOSS: 313, PPL: 1136|TM NLL: 304, KL: 3.27, REG:0.08 | LM NLL: 6.31, KL: 8.79|DE LOSS: 306, PPL: 1049, TM: 300, LM: 5.52|BETA: 0.002564
# 119[s], 42[s], Ep: 09, Ct: 01500|TR LOSS: 313, PPL: 1133|TM NLL: 303, KL: 3.28, REG:0.08 | LM NLL: 6.28, KL: 8.99|DE LOSS: 305, PPL: 1045, TM: 300, LM: 5.49|BETA: 0.002633
# 125[s], 50[s], Ep: 09, Ct: 02000|TR LOSS: 314, PPL: 1129|TM NLL: 303, KL: 4.37, REG:0.08 | LM NLL: 6.25, KL: 9.19|DE LOSS: 305, PPL: 1045, TM: 300, LM: 5.43|BETA: 0.002702
# 110[s], 34[s], Ep: 09, Ct: 02500|TR LOSS: 314, PPL: 1126|TM NLL: 303, KL: 4.35, REG:0.08 | LM NLL: 6.22, KL: 9.41|DE LOSS: 305, PPL: 1041, TM: 300, LM: 5.37|BETA: 0.002772
# 108[s], 50[s], Ep: 10, Ct: 00000|TR LOSS: 314, PPL: 1124|TM NLL: 303, KL: 4.33, REG:0.08 | LM NLL: 6.20, KL: 9.58|DE LOSS: 305, PPL: 1040, TM: 300, LM: 5.32|BETA: 0.002825
# 053[s], 08[s], Ep: 11, Ct: 00000|TR LOSS: 314, PPL: 1123|TM NLL: 303, KL: 4.32, REG:0.08 | LM NLL: 6.19, KL: 9.66|DE LOSS: 305, PPL: 1043, TM: 300, LM: 5.33|BETA: 0.002825
# 104[s], 29[s], Ep: 11, Ct: 00500|TR LOSS: 313, PPL: 1119|TM NLL: 303, KL: 4.30, REG:0.08 | LM NLL: 6.16, KL: 9.89|DE LOSS: 305, PPL: 1036, TM: 300, LM: 5.29|BETA: 0.002895
# 084[s], 08[s], Ep: 11, Ct: 01000|TR LOSS: 313, PPL: 1117|TM NLL: 303, KL: 4.29, REG:0.08 | LM NLL: 6.13, KL: 10.12|DE LOSS: 305, PPL: 1041, TM: 300, LM: 5.20|BETA: 0.002964
# 040[s], 08[s], Ep: 12, Ct: 00000|TR LOSS: 313, PPL: 1116|TM NLL: 303, KL: 4.29, REG:0.08 | LM NLL: 6.13, KL: 10.15|DE LOSS: 305, PPL: 1042, TM: 300, LM: 5.32|BETA: 0.002895
# 042[s], 08[s], Ep: 13, Ct: 00000|TR LOSS: 313, PPL: 1115|TM NLL: 303, KL: 4.28, REG:0.08 | LM NLL: 6.12, KL: 10.24|DE LOSS: 305, PPL: 1040, TM: 300, LM: 5.33|BETA: 0.002895
# 086[s], 08[s], Ep: 13, Ct: 00500|TR LOSS: 313, PPL: 1112|TM NLL: 303, KL: 4.26, REG:0.08 | LM NLL: 6.09, KL: 10.45|DE LOSS: 305, PPL: 1038, TM: 300, LM: 5.26|BETA: 0.002964
# 108[s], 31[s], Ep: 13, Ct: 01000|TR LOSS: 313, PPL: 1110|TM NLL: 303, KL: 4.25, REG:0.08 | LM NLL: 6.07, KL: 10.66|DE LOSS: 305, PPL: 1042, TM: 300, LM: 5.16|BETA: 0.003034
# 106[s], 30[s], Ep: 13, Ct: 01500|TR LOSS: 313, PPL: 1107|TM NLL: 303, KL: 4.24, REG:0.08 | LM NLL: 6.04, KL: 10.88|DE LOSS: 305, PPL: 1031, TM: 300, LM: 5.10|BETA: 0.003103
# 084[s], 08[s], Ep: 13, Ct: 02000|TR LOSS: 313, PPL: 1105|TM NLL: 302, KL: 4.23, REG:0.08 | LM NLL: 6.02, KL: 11.10|DE LOSS: 305, PPL: 1036, TM: 300, LM: 5.08|BETA: 0.003172
# 088[s], 08[s], Ep: 13, Ct: 02500|TR LOSS: 313, PPL: 1103|TM NLL: 302, KL: 4.22, REG:0.08 | LM NLL: 5.99, KL: 11.32|DE LOSS: 305, PPL: 1036, TM: 300, LM: 5.05|BETA: 0.003242
# 068[s], 08[s], Ep: 14, Ct: 00000|TR LOSS: 313, PPL: 1101|TM NLL: 302, KL: 4.21, REG:0.08 | LM NLL: 5.97, KL: 11.49|DE LOSS: 305, PPL: 1038, TM: 300, LM: 4.98|BETA: 0.003295
# 108[s], 30[s], Ep: 14, Ct: 00500|TR LOSS: 312, PPL: 1099|TM NLL: 302, KL: 4.20, REG:0.08 | LM NLL: 5.95, KL: 11.72|DE LOSS: 305, PPL: 1033, TM: 300, LM: 5.01|BETA: 0.003364
# 120[s], 45[s], Ep: 14, Ct: 01000|TR LOSS: 312, PPL: 1097|TM NLL: 302, KL: 4.19, REG:0.07 | LM NLL: 5.92, KL: 11.95|DE LOSS: 304, PPL: 1034, TM: 300, LM: 4.89|BETA: 0.003434
# 116[s], 41[s], Ep: 14, Ct: 01500|TR LOSS: 312, PPL: 1095|TM NLL: 302, KL: 4.18, REG:0.07 | LM NLL: 5.90, KL: 12.18|DE LOSS: 304, PPL: 1028, TM: 299, LM: 4.97|BETA: 0.003503
# 104[s], 29[s], Ep: 14, Ct: 02000|TR LOSS: 312, PPL: 1093|TM NLL: 302, KL: 4.18, REG:0.07 | LM NLL: 5.87, KL: 12.41|DE LOSS: 304, PPL: 1025, TM: 299, LM: 4.82|BETA: 0.003572
# 104[s], 29[s], Ep: 14, Ct: 02500|TR LOSS: 312, PPL: 1091|TM NLL: 302, KL: 4.17, REG:0.07 | LM NLL: 5.85, KL: 12.64|DE LOSS: 304, PPL: 1026, TM: 299, LM: 4.77|BETA: 0.003642
# 066[s], 08[s], Ep: 15, Ct: 00000|TR LOSS: 312, PPL: 1090|TM NLL: 302, KL: 4.16, REG:0.07 | LM NLL: 5.83, KL: 12.82|DE LOSS: 304, PPL: 1030, TM: 299, LM: 4.76|BETA: 0.003695
# 085[s], 08[s], Ep: 15, Ct: 00500|TR LOSS: 312, PPL: 1088|TM NLL: 302, KL: 4.15, REG:0.07 | LM NLL: 5.81, KL: 13.05|DE LOSS: 304, PPL: 1035, TM: 300, LM: 4.72|BETA: 0.003765
# 085[s], 08[s], Ep: 15, Ct: 01000|TR LOSS: 312, PPL: 1086|TM NLL: 302, KL: 4.15, REG:0.07 | LM NLL: 5.78, KL: 13.28|DE LOSS: 305, PPL: 1023, TM: 300, LM: 4.67|BETA: 0.003834
# 105[s], 29[s], Ep: 15, Ct: 01500|TR LOSS: 312, PPL: 1085|TM NLL: 302, KL: 4.14, REG:0.07 | LM NLL: 5.76, KL: 13.51|DE LOSS: 304, PPL: 1021, TM: 299, LM: 4.66|BETA: 0.003903
# 118[s], 43[s], Ep: 15, Ct: 02000|TR LOSS: 312, PPL: 1083|TM NLL: 302, KL: 4.14, REG:0.07 | LM NLL: 5.73, KL: 13.74|DE LOSS: 304, PPL: 1025, TM: 299, LM: 4.60|BETA: 0.003973
# 123[s], 50[s], Ep: 15, Ct: 02500|TR LOSS: 311, PPL: 1081|TM NLL: 302, KL: 4.13, REG:0.07 | LM NLL: 5.71, KL: 13.96|DE LOSS: 303, PPL: 1021, TM: 299, LM: 4.56|BETA: 0.004042
# 089[s], 31[s], Ep: 16, Ct: 00000|TR LOSS: 311, PPL: 1080|TM NLL: 301, KL: 4.13, REG:0.07 | LM NLL: 5.69, KL: 14.14|DE LOSS: 303, PPL: 1011, TM: 299, LM: 4.54|BETA: 0.004095
# 082[s], 08[s], Ep: 16, Ct: 00500|TR LOSS: 311, PPL: 1079|TM NLL: 301, KL: 4.13, REG:0.07 | LM NLL: 5.67, KL: 14.37|DE LOSS: 303, PPL: 1014, TM: 299, LM: 4.56|BETA: 0.004165
# 082[s], 08[s], Ep: 16, Ct: 01000|TR LOSS: 311, PPL: 1077|TM NLL: 301, KL: 4.12, REG:0.07 | LM NLL: 5.65, KL: 14.59|DE LOSS: 303, PPL: 1016, TM: 299, LM: 4.49|BETA: 0.004234
# 114[s], 40[s], Ep: 16, Ct: 01500|TR LOSS: 311, PPL: 1076|TM NLL: 301, KL: 4.12, REG:0.07 | LM NLL: 5.62, KL: 14.82|DE LOSS: 303, PPL: 1015, TM: 299, LM: 4.43|BETA: 0.004304
# 138[s], 63[s], Ep: 16, Ct: 02000|TR LOSS: 311, PPL: 1074|TM NLL: 301, KL: 4.11, REG:0.07 | LM NLL: 5.60, KL: 15.05|DE LOSS: 303, PPL: 1014, TM: 299, LM: 4.39|BETA: 0.004373
# 124[s], 50[s], Ep: 16, Ct: 02500|TR LOSS: 311, PPL: 1073|TM NLL: 301, KL: 4.11, REG:0.07 | LM NLL: 5.58, KL: 15.27|DE LOSS: 303, PPL: 1015, TM: 299, LM: 4.34|BETA: 0.004442
# 099[s], 41[s], Ep: 17, Ct: 00000|TR LOSS: 311, PPL: 1072|TM NLL: 301, KL: 4.11, REG:0.07 | LM NLL: 5.56, KL: 15.45|DE LOSS: 303, PPL: 1009, TM: 299, LM: 4.33|BETA: 0.004496
# 120[s], 46[s], Ep: 17, Ct: 00500|TR LOSS: 311, PPL: 1070|TM NLL: 301, KL: 4.10, REG:0.07 | LM NLL: 5.54, KL: 15.67|DE LOSS: 303, PPL: 1008, TM: 299, LM: 4.32|BETA: 0.004565
# 081[s], 08[s], Ep: 17, Ct: 01000|TR LOSS: 311, PPL: 1069|TM NLL: 301, KL: 4.10, REG:0.07 | LM NLL: 5.51, KL: 15.90|DE LOSS: 303, PPL: 1013, TM: 299, LM: 4.31|BETA: 0.004634
# 120[s], 46[s], Ep: 17, Ct: 01500|TR LOSS: 311, PPL: 1067|TM NLL: 301, KL: 4.10, REG:0.07 | LM NLL: 5.49, KL: 16.12|DE LOSS: 303, PPL: 1008, TM: 299, LM: 4.23|BETA: 0.004704
# 104[s], 29[s], Ep: 17, Ct: 02000|TR LOSS: 311, PPL: 1066|TM NLL: 301, KL: 4.09, REG:0.07 | LM NLL: 5.47, KL: 16.33|DE LOSS: 303, PPL: 1008, TM: 299, LM: 4.21|BETA: 0.004773
# 080[s], 07[s], Ep: 17, Ct: 02500|TR LOSS: 310, PPL: 1065|TM NLL: 301, KL: 4.09, REG:0.07 | LM NLL: 5.45, KL: 16.55|DE LOSS: 303, PPL: 1011, TM: 299, LM: 4.23|BETA: 0.004842
# 111[s], 55[s], Ep: 18, Ct: 00000|TR LOSS: 310, PPL: 1064|TM NLL: 301, KL: 4.09, REG:0.07 | LM NLL: 5.43, KL: 16.71|DE LOSS: 303, PPL: 1007, TM: 299, LM: 4.18|BETA: 0.004896
# 081[s], 07[s], Ep: 18, Ct: 00500|TR LOSS: 310, PPL: 1063|TM NLL: 301, KL: 4.09, REG:0.07 | LM NLL: 5.41, KL: 16.93|DE LOSS: 303, PPL: 1003, TM: 299, LM: 4.18|BETA: 0.004965
# 082[s], 07[s], Ep: 18, Ct: 01000|TR LOSS: 310, PPL: 1061|TM NLL: 301, KL: 4.09, REG:0.07 | LM NLL: 5.39, KL: 17.13|DE LOSS: 303, PPL: 1006, TM: 299, LM: 4.15|BETA: 0.005035
# 128[s], 53[s], Ep: 18, Ct: 01500|TR LOSS: 310, PPL: 1060|TM NLL: 301, KL: 4.08, REG:0.07 | LM NLL: 5.37, KL: 17.34|DE LOSS: 303, PPL: 1003, TM: 299, LM: 4.11|BETA: 0.005104
# 081[s], 08[s], Ep: 18, Ct: 02000|TR LOSS: 310, PPL: 1059|TM NLL: 301, KL: 4.08, REG:0.07 | LM NLL: 5.35, KL: 17.54|DE LOSS: 303, PPL: 1005, TM: 299, LM: 4.09|BETA: 0.005173
# 140[s], 67[s], Ep: 18, Ct: 02500|TR LOSS: 310, PPL: 1058|TM NLL: 301, KL: 4.08, REG:0.07 | LM NLL: 5.33, KL: 17.74|DE LOSS: 302, PPL: 1000, TM: 298, LM: 4.05|BETA: 0.005243
# 064[s], 07[s], Ep: 19, Ct: 00000|TR LOSS: 310, PPL: 1057|TM NLL: 301, KL: 4.08, REG:0.07 | LM NLL: 5.31, KL: 17.88|DE LOSS: 302, PPL: 1001, TM: 298, LM: 4.07|BETA: 0.005296
# 081[s], 08[s], Ep: 19, Ct: 00500|TR LOSS: 310, PPL: 1056|TM NLL: 300, KL: 4.08, REG:0.07 | LM NLL: 5.29, KL: 18.08|DE LOSS: 303, PPL: 1009, TM: 299, LM: 4.03|BETA: 0.005365
# 082[s], 07[s], Ep: 19, Ct: 01000|TR LOSS: 310, PPL: 1055|TM NLL: 300, KL: 4.07, REG:0.07 | LM NLL: 5.27, KL: 18.27|DE LOSS: 302, PPL: 1004, TM: 298, LM: 4.01|BETA: 0.005435
# 081[s], 08[s], Ep: 19, Ct: 01500|TR LOSS: 310, PPL: 1054|TM NLL: 300, KL: 4.07, REG:0.07 | LM NLL: 5.25, KL: 18.46|DE LOSS: 302, PPL: 1007, TM: 298, LM: 3.99|BETA: 0.005504
# 081[s], 07[s], Ep: 19, Ct: 02000|TR LOSS: 310, PPL: 1053|TM NLL: 300, KL: 4.07, REG:0.07 | LM NLL: 5.23, KL: 18.64|DE LOSS: 302, PPL: 1000, TM: 298, LM: 4.06|BETA: 0.005574
# 083[s], 08[s], Ep: 19, Ct: 02500|TR LOSS: 310, PPL: 1052|TM NLL: 300, KL: 4.07, REG:0.07 | LM NLL: 5.22, KL: 18.82|DE LOSS: 302, PPL: 1010, TM: 299, LM: 3.97|BETA: 0.005643
# 064[s], 08[s], Ep: 20, Ct: 00000|TR LOSS: 310, PPL: 1052|TM NLL: 300, KL: 4.07, REG:0.07 | LM NLL: 5.20, KL: 18.96|DE LOSS: 302, PPL: 1003, TM: 298, LM: 3.97|BETA: 0.005696
# 124[s], 50[s], Ep: 20, Ct: 00500|TR LOSS: 310, PPL: 1051|TM NLL: 300, KL: 4.07, REG:0.07 | LM NLL: 5.18, KL: 19.13|DE LOSS: 302, PPL: 996, TM: 298, LM: 3.95|BETA: 0.005766
# 081[s], 07[s], Ep: 20, Ct: 01000|TR LOSS: 310, PPL: 1050|TM NLL: 300, KL: 4.07, REG:0.07 | LM NLL: 5.16, KL: 19.30|DE LOSS: 302, PPL: 1000, TM: 299, LM: 3.92|BETA: 0.005835
# 081[s], 07[s], Ep: 20, Ct: 01500|TR LOSS: 310, PPL: 1049|TM NLL: 300, KL: 4.06, REG:0.07 | LM NLL: 5.15, KL: 19.47|DE LOSS: 302, PPL: 1000, TM: 298, LM: 3.91|BETA: 0.005904
# 081[s], 07[s], Ep: 20, Ct: 02000|TR LOSS: 309, PPL: 1048|TM NLL: 300, KL: 4.06, REG:0.07 | LM NLL: 5.13, KL: 19.63|DE LOSS: 303, PPL: 1009, TM: 299, LM: 3.91|BETA: 0.005974
# 103[s], 29[s], Ep: 20, Ct: 02500|TR LOSS: 309, PPL: 1047|TM NLL: 300, KL: 4.06, REG:0.07 | LM NLL: 5.11, KL: 19.79|DE LOSS: 302, PPL: 996, TM: 298, LM: 3.89|BETA: 0.006043
# 064[s], 08[s], Ep: 21, Ct: 00000|TR LOSS: 309, PPL: 1047|TM NLL: 300, KL: 4.06, REG:0.07 | LM NLL: 5.10, KL: 19.92|DE LOSS: 302, PPL: 1000, TM: 298, LM: 3.95|BETA: 0.006096
# 082[s], 07[s], Ep: 21, Ct: 00500|TR LOSS: 309, PPL: 1046|TM NLL: 300, KL: 4.06, REG:0.07 | LM NLL: 5.08, KL: 20.07|DE LOSS: 302, PPL: 1001, TM: 298, LM: 3.85|BETA: 0.006166
# 083[s], 07[s], Ep: 21, Ct: 01000|TR LOSS: 309, PPL: 1045|TM NLL: 300, KL: 4.06, REG:0.07 | LM NLL: 5.06, KL: 20.22|DE LOSS: 302, PPL: 1003, TM: 298, LM: 3.88|BETA: 0.006235
# 081[s], 08[s], Ep: 21, Ct: 01500|TR LOSS: 309, PPL: 1044|TM NLL: 300, KL: 4.06, REG:0.07 | LM NLL: 5.05, KL: 20.37|DE LOSS: 302, PPL: 1004, TM: 298, LM: 3.83|BETA: 0.006305
# 082[s], 08[s], Ep: 21, Ct: 02000|TR LOSS: 309, PPL: 1043|TM NLL: 300, KL: 4.06, REG:0.07 | LM NLL: 5.03, KL: 20.52|DE LOSS: 302, PPL: 1002, TM: 298, LM: 3.83|BETA: 0.006374
# 083[s], 07[s], Ep: 21, Ct: 02500|TR LOSS: 309, PPL: 1043|TM NLL: 300, KL: 4.05, REG:0.07 | LM NLL: 5.02, KL: 20.66|DE LOSS: 302, PPL: 1007, TM: 299, LM: 3.85|BETA: 0.006443
# 094[s], 35[s], Ep: 22, Ct: 00000|TR LOSS: 309, PPL: 1042|TM NLL: 300, KL: 4.05, REG:0.07 | LM NLL: 5.00, KL: 20.77|DE LOSS: 302, PPL: 998, TM: 298, LM: 3.82|BETA: 0.006497
# 136[s], 60[s], Ep: 22, Ct: 00500|TR LOSS: 309, PPL: 1041|TM NLL: 300, KL: 4.05, REG:0.06 | LM NLL: 4.99, KL: 20.90|DE LOSS: 302, PPL: 996, TM: 298, LM: 3.81|BETA: 0.006566
# 083[s], 08[s], Ep: 22, Ct: 01000|TR LOSS: 309, PPL: 1041|TM NLL: 300, KL: 4.05, REG:0.06 | LM NLL: 4.97, KL: 21.04|DE LOSS: 302, PPL: 999, TM: 298, LM: 3.85|BETA: 0.006635
# 084[s], 08[s], Ep: 22, Ct: 01500|TR LOSS: 309, PPL: 1040|TM NLL: 300, KL: 4.05, REG:0.06 | LM NLL: 4.96, KL: 21.17|DE LOSS: 302, PPL: 997, TM: 298, LM: 3.85|BETA: 0.006705
# 083[s], 08[s], Ep: 22, Ct: 02000|TR LOSS: 309, PPL: 1039|TM NLL: 300, KL: 4.05, REG:0.06 | LM NLL: 4.94, KL: 21.30|DE LOSS: 302, PPL: 995, TM: 298, LM: 3.79|BETA: 0.006774
# 146[s], 71[s], Ep: 22, Ct: 02500|TR LOSS: 309, PPL: 1039|TM NLL: 300, KL: 4.05, REG:0.06 | LM NLL: 4.93, KL: 21.42|DE LOSS: 302, PPL: 998, TM: 298, LM: 3.77|BETA: 0.006844
# 101[s], 44[s], Ep: 23, Ct: 00000|TR LOSS: 309, PPL: 1038|TM NLL: 300, KL: 4.05, REG:0.06 | LM NLL: 4.92, KL: 21.51|DE LOSS: 302, PPL: 999, TM: 298, LM: 3.79|BETA: 0.006897
# 112[s], 37[s], Ep: 23, Ct: 00500|TR LOSS: 309, PPL: 1037|TM NLL: 300, KL: 4.05, REG:0.06 | LM NLL: 4.90, KL: 21.64|DE LOSS: 302, PPL: 994, TM: 298, LM: 3.76|BETA: 0.006966
# 081[s], 07[s], Ep: 23, Ct: 01000|TR LOSS: 309, PPL: 1037|TM NLL: 300, KL: 4.05, REG:0.06 | LM NLL: 4.89, KL: 21.75|DE LOSS: 302, PPL: 1006, TM: 298, LM: 3.76|BETA: 0.007036
# 083[s], 08[s], Ep: 23, Ct: 01500|TR LOSS: 309, PPL: 1036|TM NLL: 300, KL: 4.05, REG:0.06 | LM NLL: 4.87, KL: 21.87|DE LOSS: 302, PPL: 993, TM: 298, LM: 3.78|BETA: 0.007105
# 083[s], 08[s], Ep: 23, Ct: 02000|TR LOSS: 309, PPL: 1035|TM NLL: 300, KL: 4.05, REG:0.06 | LM NLL: 4.86, KL: 21.98|DE LOSS: 302, PPL: 993, TM: 298, LM: 3.76|BETA: 0.007174
# 083[s], 08[s], Ep: 23, Ct: 02500|TR LOSS: 309, PPL: 1035|TM NLL: 300, KL: 4.05, REG:0.06 | LM NLL: 4.85, KL: 22.09|DE LOSS: 302, PPL: 996, TM: 298, LM: 3.74|BETA: 0.007244
# 066[s], 08[s], Ep: 24, Ct: 00000|TR LOSS: 309, PPL: 1034|TM NLL: 300, KL: 4.05, REG:0.06 | LM NLL: 4.84, KL: 22.18|DE LOSS: 302, PPL: 997, TM: 298, LM: 3.74|BETA: 0.007297
# 083[s], 08[s], Ep: 24, Ct: 00500|TR LOSS: 309, PPL: 1034|TM NLL: 300, KL: 4.05, REG:0.06 | LM NLL: 4.82, KL: 22.28|DE LOSS: 302, PPL: 999, TM: 298, LM: 3.80|BETA: 0.007366
# 082[s], 07[s], Ep: 24, Ct: 01000|TR LOSS: 309, PPL: 1033|TM NLL: 300, KL: 4.05, REG:0.06 | LM NLL: 4.81, KL: 22.39|DE LOSS: 302, PPL: 998, TM: 298, LM: 3.76|BETA: 0.007436
# 082[s], 08[s], Ep: 24, Ct: 01500|TR LOSS: 309, PPL: 1033|TM NLL: 300, KL: 4.05, REG:0.06 | LM NLL: 4.80, KL: 22.49|DE LOSS: 302, PPL: 998, TM: 298, LM: 3.72|BETA: 0.007505
# 082[s], 07[s], Ep: 24, Ct: 02000|TR LOSS: 308, PPL: 1032|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.78, KL: 22.59|DE LOSS: 302, PPL: 998, TM: 298, LM: 3.72|BETA: 0.007575
# 107[s], 30[s], Ep: 24, Ct: 02500|TR LOSS: 308, PPL: 1032|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.77, KL: 22.69|DE LOSS: 302, PPL: 995, TM: 298, LM: 3.70|BETA: 0.007644
# 120[s], 61[s], Ep: 25, Ct: 00000|TR LOSS: 308, PPL: 1031|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.76, KL: 22.76|DE LOSS: 302, PPL: 993, TM: 298, LM: 3.74|BETA: 0.007697
# 082[s], 07[s], Ep: 25, Ct: 00500|TR LOSS: 308, PPL: 1031|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.75, KL: 22.86|DE LOSS: 302, PPL: 998, TM: 298, LM: 3.76|BETA: 0.007767
# 083[s], 07[s], Ep: 25, Ct: 01000|TR LOSS: 308, PPL: 1030|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.74, KL: 22.95|DE LOSS: 302, PPL: 998, TM: 298, LM: 3.68|BETA: 0.007836
# 082[s], 08[s], Ep: 25, Ct: 01500|TR LOSS: 308, PPL: 1030|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.72, KL: 23.04|DE LOSS: 302, PPL: 998, TM: 298, LM: 3.69|BETA: 0.007905
# 082[s], 07[s], Ep: 25, Ct: 02000|TR LOSS: 308, PPL: 1029|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.71, KL: 23.13|DE LOSS: 302, PPL: 995, TM: 298, LM: 3.69|BETA: 0.007975
# 081[s], 07[s], Ep: 25, Ct: 02500|TR LOSS: 308, PPL: 1029|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.70, KL: 23.22|DE LOSS: 302, PPL: 996, TM: 298, LM: 3.67|BETA: 0.008044
# 064[s], 08[s], Ep: 26, Ct: 00000|TR LOSS: 308, PPL: 1028|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.69, KL: 23.28|DE LOSS: 302, PPL: 993, TM: 298, LM: 3.71|BETA: 0.008097
# 081[s], 07[s], Ep: 26, Ct: 00500|TR LOSS: 308, PPL: 1028|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.68, KL: 23.37|DE LOSS: 302, PPL: 1000, TM: 298, LM: 3.68|BETA: 0.008167
# 103[s], 29[s], Ep: 26, Ct: 01000|TR LOSS: 308, PPL: 1027|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.67, KL: 23.45|DE LOSS: 302, PPL: 991, TM: 298, LM: 3.69|BETA: 0.008236
# 081[s], 08[s], Ep: 26, Ct: 01500|TR LOSS: 308, PPL: 1027|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.66, KL: 23.53|DE LOSS: 302, PPL: 992, TM: 298, LM: 3.68|BETA: 0.008306
# 105[s], 31[s], Ep: 26, Ct: 02000|TR LOSS: 308, PPL: 1026|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.65, KL: 23.61|DE LOSS: 302, PPL: 988, TM: 298, LM: 3.65|BETA: 0.008375
# 081[s], 08[s], Ep: 26, Ct: 02500|TR LOSS: 308, PPL: 1026|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.64, KL: 23.69|DE LOSS: 302, PPL: 996, TM: 298, LM: 3.66|BETA: 0.008444
# 064[s], 07[s], Ep: 27, Ct: 00000|TR LOSS: 308, PPL: 1026|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.63, KL: 23.74|DE LOSS: 302, PPL: 998, TM: 298, LM: 3.68|BETA: 0.008498
# 081[s], 07[s], Ep: 27, Ct: 00500|TR LOSS: 308, PPL: 1025|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.62, KL: 23.82|DE LOSS: 302, PPL: 1000, TM: 298, LM: 3.66|BETA: 0.008567
# 080[s], 07[s], Ep: 27, Ct: 01000|TR LOSS: 308, PPL: 1025|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.61, KL: 23.89|DE LOSS: 302, PPL: 998, TM: 298, LM: 3.67|BETA: 0.008636
# 081[s], 07[s], Ep: 27, Ct: 01500|TR LOSS: 308, PPL: 1024|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.60, KL: 23.96|DE LOSS: 302, PPL: 991, TM: 298, LM: 3.65|BETA: 0.008706
# 080[s], 08[s], Ep: 27, Ct: 02000|TR LOSS: 308, PPL: 1024|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.59, KL: 24.03|DE LOSS: 302, PPL: 991, TM: 298, LM: 3.63|BETA: 0.008775
# 081[s], 07[s], Ep: 27, Ct: 02500|TR LOSS: 308, PPL: 1023|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.58, KL: 24.10|DE LOSS: 302, PPL: 994, TM: 298, LM: 3.63|BETA: 0.008845
# 064[s], 07[s], Ep: 28, Ct: 00000|TR LOSS: 308, PPL: 1023|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.57, KL: 24.15|DE LOSS: 302, PPL: 998, TM: 298, LM: 3.63|BETA: 0.008898
# 080[s], 07[s], Ep: 28, Ct: 00500|TR LOSS: 308, PPL: 1023|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.56, KL: 24.22|DE LOSS: 302, PPL: 994, TM: 298, LM: 3.70|BETA: 0.008967
# 082[s], 08[s], Ep: 28, Ct: 01000|TR LOSS: 308, PPL: 1022|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.55, KL: 24.29|DE LOSS: 302, PPL: 993, TM: 298, LM: 3.62|BETA: 0.009037
# 081[s], 07[s], Ep: 28, Ct: 01500|TR LOSS: 308, PPL: 1022|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.54, KL: 24.35|DE LOSS: 302, PPL: 992, TM: 298, LM: 3.64|BETA: 0.009106
# 081[s], 07[s], Ep: 28, Ct: 02000|TR LOSS: 308, PPL: 1021|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.53, KL: 24.41|DE LOSS: 302, PPL: 996, TM: 298, LM: 3.61|BETA: 0.009175
# 081[s], 07[s], Ep: 28, Ct: 02500|TR LOSS: 308, PPL: 1021|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.52, KL: 24.47|DE LOSS: 302, PPL: 999, TM: 298, LM: 3.62|BETA: 0.009245
# 064[s], 08[s], Ep: 29, Ct: 00000|TR LOSS: 308, PPL: 1021|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.51, KL: 24.52|DE LOSS: 302, PPL: 991, TM: 298, LM: 3.62|BETA: 0.009298
# 081[s], 07[s], Ep: 29, Ct: 00500|TR LOSS: 308, PPL: 1020|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.50, KL: 24.58|DE LOSS: 302, PPL: 993, TM: 298, LM: 3.61|BETA: 0.009367
# 081[s], 07[s], Ep: 29, Ct: 01000|TR LOSS: 308, PPL: 1020|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.49, KL: 24.64|DE LOSS: 302, PPL: 996, TM: 298, LM: 3.62|BETA: 0.009437
# 080[s], 08[s], Ep: 29, Ct: 01500|TR LOSS: 308, PPL: 1020|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.48, KL: 24.69|DE LOSS: 302, PPL: 996, TM: 298, LM: 3.66|BETA: 0.009506
# 081[s], 07[s], Ep: 29, Ct: 02000|TR LOSS: 308, PPL: 1019|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.47, KL: 24.75|DE LOSS: 302, PPL: 996, TM: 298, LM: 3.60|BETA: 0.009576
# 082[s], 08[s], Ep: 29, Ct: 02500|TR LOSS: 308, PPL: 1019|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.46, KL: 24.80|DE LOSS: 302, PPL: 999, TM: 298, LM: 3.60|BETA: 0.009645
# 065[s], 07[s], Ep: 30, Ct: 00000|TR LOSS: 308, PPL: 1019|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.46, KL: 24.85|DE LOSS: 302, PPL: 993, TM: 298, LM: 3.61|BETA: 0.009698
# 081[s], 07[s], Ep: 30, Ct: 00500|TR LOSS: 308, PPL: 1018|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.45, KL: 24.90|DE LOSS: 302, PPL: 994, TM: 298, LM: 3.70|BETA: 0.009768
# 081[s], 07[s], Ep: 30, Ct: 01000|TR LOSS: 308, PPL: 1018|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.44, KL: 24.95|DE LOSS: 302, PPL: 989, TM: 298, LM: 3.62|BETA: 0.009837
# 124[s], 51[s], Ep: 30, Ct: 01500|TR LOSS: 308, PPL: 1017|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.43, KL: 25.00|DE LOSS: 302, PPL: 991, TM: 298, LM: 3.60|BETA: 0.009906
# 080[s], 07[s], Ep: 30, Ct: 02000|TR LOSS: 308, PPL: 1017|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.42, KL: 25.05|DE LOSS: 302, PPL: 993, TM: 298, LM: 3.61|BETA: 0.009976
# 085[s], 08[s], Ep: 30, Ct: 02500|TR LOSS: 308, PPL: 1017|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.42, KL: 25.10|DE LOSS: 302, PPL: 989, TM: 298, LM: 3.58|BETA: 0.010045
# 066[s], 08[s], Ep: 31, Ct: 00000|TR LOSS: 308, PPL: 1017|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.41, KL: 25.13|DE LOSS: 302, PPL: 992, TM: 298, LM: 3.62|BETA: 0.010098
# 082[s], 08[s], Ep: 31, Ct: 00500|TR LOSS: 307, PPL: 1016|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.40, KL: 25.18|DE LOSS: 302, PPL: 994, TM: 298, LM: 3.60|BETA: 0.010168
# 083[s], 08[s], Ep: 31, Ct: 01000|TR LOSS: 307, PPL: 1016|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.39, KL: 25.23|DE LOSS: 302, PPL: 994, TM: 298, LM: 3.60|BETA: 0.010237
# 082[s], 08[s], Ep: 31, Ct: 01500|TR LOSS: 307, PPL: 1016|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.38, KL: 25.27|DE LOSS: 302, PPL: 995, TM: 298, LM: 3.57|BETA: 0.010307
# 082[s], 07[s], Ep: 31, Ct: 02000|TR LOSS: 307, PPL: 1015|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.38, KL: 25.32|DE LOSS: 302, PPL: 994, TM: 298, LM: 3.58|BETA: 0.010376
# 083[s], 07[s], Ep: 31, Ct: 02500|TR LOSS: 307, PPL: 1015|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.37, KL: 25.36|DE LOSS: 302, PPL: 990, TM: 298, LM: 3.59|BETA: 0.010445
# 065[s], 08[s], Ep: 32, Ct: 00000|TR LOSS: 307, PPL: 1015|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.36, KL: 25.39|DE LOSS: 302, PPL: 996, TM: 298, LM: 3.57|BETA: 0.010499
# 083[s], 08[s], Ep: 32, Ct: 00500|TR LOSS: 307, PPL: 1014|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.35, KL: 25.43|DE LOSS: 302, PPL: 996, TM: 298, LM: 3.61|BETA: 0.010568
# 082[s], 08[s], Ep: 32, Ct: 01000|TR LOSS: 307, PPL: 1014|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.35, KL: 25.47|DE LOSS: 302, PPL: 991, TM: 298, LM: 3.57|BETA: 0.010637
# 082[s], 07[s], Ep: 32, Ct: 01500|TR LOSS: 307, PPL: 1014|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.34, KL: 25.51|DE LOSS: 302, PPL: 991, TM: 298, LM: 3.57|BETA: 0.010707
# 083[s], 08[s], Ep: 32, Ct: 02000|TR LOSS: 307, PPL: 1014|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.33, KL: 25.55|DE LOSS: 302, PPL: 991, TM: 298, LM: 3.58|BETA: 0.010776
# 082[s], 08[s], Ep: 32, Ct: 02500|TR LOSS: 307, PPL: 1013|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.32, KL: 25.59|DE LOSS: 302, PPL: 996, TM: 298, LM: 3.55|BETA: 0.010846
# 067[s], 08[s], Ep: 33, Ct: 00000|TR LOSS: 307, PPL: 1013|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.32, KL: 25.62|DE LOSS: 302, PPL: 989, TM: 298, LM: 3.60|BETA: 0.010899
# 083[s], 08[s], Ep: 33, Ct: 00500|TR LOSS: 307, PPL: 1013|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.31, KL: 25.66|DE LOSS: 302, PPL: 991, TM: 298, LM: 3.57|BETA: 0.010968
# 082[s], 08[s], Ep: 33, Ct: 01000|TR LOSS: 307, PPL: 1012|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.30, KL: 25.69|DE LOSS: 302, PPL: 992, TM: 298, LM: 3.57|BETA: 0.011038
# 083[s], 08[s], Ep: 33, Ct: 01500|TR LOSS: 307, PPL: 1012|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.30, KL: 25.73|DE LOSS: 302, PPL: 991, TM: 298, LM: 3.57|BETA: 0.011107
# 083[s], 08[s], Ep: 33, Ct: 02000|TR LOSS: 307, PPL: 1012|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.29, KL: 25.76|DE LOSS: 302, PPL: 986, TM: 298, LM: 3.55|BETA: 0.011176
# 082[s], 08[s], Ep: 33, Ct: 02500|TR LOSS: 307, PPL: 1012|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.28, KL: 25.80|DE LOSS: 302, PPL: 997, TM: 298, LM: 3.58|BETA: 0.011246
# 065[s], 08[s], Ep: 34, Ct: 00000|TR LOSS: 307, PPL: 1011|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.28, KL: 25.82|DE LOSS: 302, PPL: 991, TM: 298, LM: 3.59|BETA: 0.011299
# 129[s], 54[s], Ep: 34, Ct: 00500|TR LOSS: 307, PPL: 1011|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.27, KL: 25.86|DE LOSS: 301, PPL: 988, TM: 298, LM: 3.56|BETA: 0.011368
# 082[s], 08[s], Ep: 34, Ct: 01000|TR LOSS: 307, PPL: 1011|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.26, KL: 25.89|DE LOSS: 302, PPL: 988, TM: 298, LM: 3.58|BETA: 0.011438
# 082[s], 08[s], Ep: 34, Ct: 01500|TR LOSS: 307, PPL: 1010|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.26, KL: 25.92|DE LOSS: 302, PPL: 993, TM: 298, LM: 3.57|BETA: 0.011507
# 082[s], 08[s], Ep: 34, Ct: 02000|TR LOSS: 307, PPL: 1010|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.25, KL: 25.95|DE LOSS: 302, PPL: 993, TM: 298, LM: 3.55|BETA: 0.011577
# 082[s], 08[s], Ep: 34, Ct: 02500|TR LOSS: 307, PPL: 1010|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.24, KL: 25.98|DE LOSS: 302, PPL: 989, TM: 298, LM: 3.55|BETA: 0.011646
# 065[s], 08[s], Ep: 35, Ct: 00000|TR LOSS: 307, PPL: 1010|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.24, KL: 26.00|DE LOSS: 302, PPL: 989, TM: 298, LM: 3.60|BETA: 0.011699
# 082[s], 08[s], Ep: 35, Ct: 00500|TR LOSS: 307, PPL: 1010|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.23, KL: 26.03|DE LOSS: 302, PPL: 990, TM: 298, LM: 3.55|BETA: 0.011769
# 082[s], 08[s], Ep: 35, Ct: 01000|TR LOSS: 307, PPL: 1009|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.22, KL: 26.06|DE LOSS: 302, PPL: 992, TM: 298, LM: 3.54|BETA: 0.011838
# 081[s], 08[s], Ep: 35, Ct: 01500|TR LOSS: 307, PPL: 1009|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.22, KL: 26.09|DE LOSS: 302, PPL: 988, TM: 298, LM: 3.57|BETA: 0.011907
# 082[s], 07[s], Ep: 35, Ct: 02000|TR LOSS: 307, PPL: 1009|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.21, KL: 26.12|DE LOSS: 302, PPL: 988, TM: 298, LM: 3.55|BETA: 0.011977
# 082[s], 08[s], Ep: 35, Ct: 02500|TR LOSS: 307, PPL: 1009|TM NLL: 299, KL: 4.05, REG:0.06 | LM NLL: 4.20, KL: 26.14|DE LOSS: 302, PPL: 993, TM: 298, LM: 3.61|BETA: 0.012046
# 065[s], 08[s], Ep: 36, Ct: 00000|TR LOSS: 307, PPL: 1008|TM NLL: 298, KL: 4.05, REG:0.06 | LM NLL: 4.20, KL: 26.16|DE LOSS: 302, PPL: 993, TM: 298, LM: 3.53|BETA: 0.012099
# 082[s], 08[s], Ep: 36, Ct: 00500|TR LOSS: 307, PPL: 1008|TM NLL: 298, KL: 4.05, REG:0.06 | LM NLL: 4.19, KL: 26.19|DE LOSS: 302, PPL: 991, TM: 298, LM: 3.60|BETA: 0.012169
# 082[s], 08[s], Ep: 36, Ct: 01000|TR LOSS: 307, PPL: 1008|TM NLL: 298, KL: 4.05, REG:0.06 | LM NLL: 4.19, KL: 26.21|DE LOSS: 302, PPL: 989, TM: 298, LM: 3.56|BETA: 0.012238
# 083[s], 08[s], Ep: 36, Ct: 01500|TR LOSS: 307, PPL: 1008|TM NLL: 298, KL: 4.05, REG:0.06 | LM NLL: 4.18, KL: 26.24|DE LOSS: 302, PPL: 988, TM: 298, LM: 3.53|BETA: 0.012308
# 083[s], 08[s], Ep: 36, Ct: 02000|TR LOSS: 307, PPL: 1007|TM NLL: 298, KL: 4.05, REG:0.06 | LM NLL: 4.17, KL: 26.26|DE LOSS: 302, PPL: 989, TM: 298, LM: 3.54|BETA: 0.012377
# 104[s], 30[s], Ep: 36, Ct: 02500|TR LOSS: 307, PPL: 1007|TM NLL: 298, KL: 4.05, REG:0.06 | LM NLL: 4.17, KL: 26.29|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.54|BETA: 0.012446
# 065[s], 08[s], Ep: 37, Ct: 00000|TR LOSS: 307, PPL: 1007|TM NLL: 298, KL: 4.05, REG:0.06 | LM NLL: 4.16, KL: 26.31|DE LOSS: 301, PPL: 988, TM: 298, LM: 3.52|BETA: 0.012500
# 082[s], 07[s], Ep: 37, Ct: 00500|TR LOSS: 307, PPL: 1007|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.16, KL: 26.33|DE LOSS: 302, PPL: 995, TM: 298, LM: 3.53|BETA: 0.012569
# 083[s], 08[s], Ep: 37, Ct: 01000|TR LOSS: 307, PPL: 1007|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.15, KL: 26.35|DE LOSS: 302, PPL: 987, TM: 298, LM: 3.53|BETA: 0.012638
# 084[s], 08[s], Ep: 37, Ct: 01500|TR LOSS: 307, PPL: 1006|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.15, KL: 26.37|DE LOSS: 302, PPL: 989, TM: 298, LM: 3.53|BETA: 0.012708
# 082[s], 08[s], Ep: 37, Ct: 02000|TR LOSS: 307, PPL: 1006|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.14, KL: 26.40|DE LOSS: 302, PPL: 992, TM: 298, LM: 3.53|BETA: 0.012777
# 122[s], 47[s], Ep: 37, Ct: 02500|TR LOSS: 307, PPL: 1006|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.13, KL: 26.42|DE LOSS: 301, PPL: 988, TM: 298, LM: 3.53|BETA: 0.012847
# 066[s], 08[s], Ep: 38, Ct: 00000|TR LOSS: 307, PPL: 1006|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.13, KL: 26.43|DE LOSS: 302, PPL: 989, TM: 298, LM: 3.55|BETA: 0.012900
# 082[s], 08[s], Ep: 38, Ct: 00500|TR LOSS: 307, PPL: 1005|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.12, KL: 26.45|DE LOSS: 302, PPL: 990, TM: 298, LM: 3.57|BETA: 0.012969
# 083[s], 08[s], Ep: 38, Ct: 01000|TR LOSS: 307, PPL: 1005|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.12, KL: 26.47|DE LOSS: 302, PPL: 994, TM: 298, LM: 3.54|BETA: 0.013039
# 082[s], 08[s], Ep: 38, Ct: 01500|TR LOSS: 307, PPL: 1005|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.11, KL: 26.49|DE LOSS: 302, PPL: 987, TM: 298, LM: 3.54|BETA: 0.013108
# 082[s], 08[s], Ep: 38, Ct: 02000|TR LOSS: 307, PPL: 1005|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.11, KL: 26.51|DE LOSS: 301, PPL: 985, TM: 298, LM: 3.53|BETA: 0.013177
# 083[s], 07[s], Ep: 38, Ct: 02500|TR LOSS: 307, PPL: 1005|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.10, KL: 26.53|DE LOSS: 302, PPL: 989, TM: 298, LM: 3.53|BETA: 0.013247
# 066[s], 08[s], Ep: 39, Ct: 00000|TR LOSS: 307, PPL: 1005|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.10, KL: 26.54|DE LOSS: 302, PPL: 984, TM: 298, LM: 3.56|BETA: 0.013300
# 104[s], 30[s], Ep: 39, Ct: 00500|TR LOSS: 307, PPL: 1004|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.09, KL: 26.56|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.52|BETA: 0.013369
# 082[s], 08[s], Ep: 39, Ct: 01000|TR LOSS: 307, PPL: 1004|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.09, KL: 26.58|DE LOSS: 302, PPL: 993, TM: 298, LM: 3.53|BETA: 0.013439
# 083[s], 08[s], Ep: 39, Ct: 01500|TR LOSS: 307, PPL: 1004|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.08, KL: 26.59|DE LOSS: 302, PPL: 989, TM: 298, LM: 3.54|BETA: 0.013508
# 083[s], 08[s], Ep: 39, Ct: 02000|TR LOSS: 307, PPL: 1004|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.08, KL: 26.61|DE LOSS: 302, PPL: 987, TM: 298, LM: 3.52|BETA: 0.013578
# 082[s], 08[s], Ep: 39, Ct: 02500|TR LOSS: 307, PPL: 1003|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.07, KL: 26.63|DE LOSS: 302, PPL: 989, TM: 298, LM: 3.54|BETA: 0.013647
# 064[s], 08[s], Ep: 40, Ct: 00000|TR LOSS: 307, PPL: 1003|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.07, KL: 26.64|DE LOSS: 302, PPL: 991, TM: 298, LM: 3.60|BETA: 0.013700
# 083[s], 08[s], Ep: 40, Ct: 00500|TR LOSS: 307, PPL: 1003|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.06, KL: 26.66|DE LOSS: 302, PPL: 991, TM: 298, LM: 3.53|BETA: 0.013770
# 082[s], 08[s], Ep: 40, Ct: 01000|TR LOSS: 307, PPL: 1003|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.06, KL: 26.67|DE LOSS: 302, PPL: 987, TM: 298, LM: 3.53|BETA: 0.013839
# 082[s], 08[s], Ep: 40, Ct: 01500|TR LOSS: 307, PPL: 1003|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.05, KL: 26.69|DE LOSS: 301, PPL: 988, TM: 298, LM: 3.54|BETA: 0.013908
# 105[s], 30[s], Ep: 40, Ct: 02000|TR LOSS: 307, PPL: 1003|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.05, KL: 26.70|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.54|BETA: 0.013978
# 082[s], 08[s], Ep: 40, Ct: 02500|TR LOSS: 307, PPL: 1002|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.04, KL: 26.71|DE LOSS: 302, PPL: 993, TM: 298, LM: 3.52|BETA: 0.014047
# 065[s], 08[s], Ep: 41, Ct: 00000|TR LOSS: 307, PPL: 1002|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.04, KL: 26.72|DE LOSS: 301, PPL: 990, TM: 298, LM: 3.51|BETA: 0.014100
# 082[s], 08[s], Ep: 41, Ct: 00500|TR LOSS: 307, PPL: 1002|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.03, KL: 26.74|DE LOSS: 301, PPL: 982, TM: 298, LM: 3.52|BETA: 0.014170
# 082[s], 08[s], Ep: 41, Ct: 01000|TR LOSS: 307, PPL: 1002|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.03, KL: 26.75|DE LOSS: 301, PPL: 985, TM: 298, LM: 3.52|BETA: 0.014239
# 083[s], 08[s], Ep: 41, Ct: 01500|TR LOSS: 307, PPL: 1002|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.02, KL: 26.76|DE LOSS: 301, PPL: 987, TM: 298, LM: 3.53|BETA: 0.014309
# 083[s], 08[s], Ep: 41, Ct: 02000|TR LOSS: 307, PPL: 1002|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.02, KL: 26.78|DE LOSS: 302, PPL: 989, TM: 298, LM: 3.55|BETA: 0.014378
# 082[s], 07[s], Ep: 41, Ct: 02500|TR LOSS: 307, PPL: 1001|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.01, KL: 26.79|DE LOSS: 302, PPL: 993, TM: 298, LM: 3.52|BETA: 0.014447
# 065[s], 08[s], Ep: 42, Ct: 00000|TR LOSS: 307, PPL: 1001|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.01, KL: 26.80|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.54|BETA: 0.014501
# 082[s], 07[s], Ep: 42, Ct: 00500|TR LOSS: 307, PPL: 1001|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.00, KL: 26.81|DE LOSS: 302, PPL: 989, TM: 298, LM: 3.52|BETA: 0.014570
# 082[s], 08[s], Ep: 42, Ct: 01000|TR LOSS: 307, PPL: 1001|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 4.00, KL: 26.82|DE LOSS: 302, PPL: 993, TM: 298, LM: 3.53|BETA: 0.014639
# 082[s], 08[s], Ep: 42, Ct: 01500|TR LOSS: 307, PPL: 1001|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 3.99, KL: 26.83|DE LOSS: 302, PPL: 989, TM: 298, LM: 3.52|BETA: 0.014709
# 082[s], 07[s], Ep: 42, Ct: 02000|TR LOSS: 306, PPL: 1000|TM NLL: 298, KL: 4.06, REG:0.06 | LM NLL: 3.99, KL: 26.84|DE LOSS: 301, PPL: 987, TM: 298, LM: 3.52|BETA: 0.014778
# 083[s], 08[s], Ep: 42, Ct: 02500|TR LOSS: 306, PPL: 1000|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.98, KL: 26.85|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.52|BETA: 0.014848
# 065[s], 07[s], Ep: 43, Ct: 00000|TR LOSS: 306, PPL: 1000|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.98, KL: 26.86|DE LOSS: 301, PPL: 985, TM: 298, LM: 3.52|BETA: 0.014901
# 082[s], 08[s], Ep: 43, Ct: 00500|TR LOSS: 306, PPL: 1000|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.98, KL: 26.87|DE LOSS: 301, PPL: 989, TM: 298, LM: 3.52|BETA: 0.014970
# 082[s], 08[s], Ep: 43, Ct: 01000|TR LOSS: 306, PPL: 1000|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.97, KL: 26.88|DE LOSS: 301, PPL: 989, TM: 298, LM: 3.52|BETA: 0.015040
# 083[s], 08[s], Ep: 43, Ct: 01500|TR LOSS: 306, PPL: 1000|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.97, KL: 26.89|DE LOSS: 302, PPL: 987, TM: 298, LM: 3.52|BETA: 0.015109
# 082[s], 08[s], Ep: 43, Ct: 02000|TR LOSS: 306, PPL: 1000|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.96, KL: 26.90|DE LOSS: 301, PPL: 985, TM: 298, LM: 3.52|BETA: 0.015178
# 083[s], 08[s], Ep: 43, Ct: 02500|TR LOSS: 306, PPL: 999|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.96, KL: 26.91|DE LOSS: 302, PPL: 990, TM: 298, LM: 3.55|BETA: 0.015248
# 089[s], 31[s], Ep: 44, Ct: 00000|TR LOSS: 306, PPL: 999|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.96, KL: 26.92|DE LOSS: 301, PPL: 984, TM: 298, LM: 3.51|BETA: 0.015301
# 082[s], 08[s], Ep: 44, Ct: 00500|TR LOSS: 306, PPL: 999|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.95, KL: 26.92|DE LOSS: 302, PPL: 987, TM: 298, LM: 3.52|BETA: 0.015370
# 083[s], 08[s], Ep: 44, Ct: 01000|TR LOSS: 306, PPL: 999|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.95, KL: 26.93|DE LOSS: 301, PPL: 984, TM: 298, LM: 3.53|BETA: 0.015440
# 081[s], 07[s], Ep: 44, Ct: 01500|TR LOSS: 306, PPL: 999|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.94, KL: 26.94|DE LOSS: 301, PPL: 987, TM: 298, LM: 3.52|BETA: 0.015509
# 082[s], 08[s], Ep: 44, Ct: 02000|TR LOSS: 306, PPL: 999|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.94, KL: 26.95|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.57|BETA: 0.015579
# 082[s], 08[s], Ep: 44, Ct: 02500|TR LOSS: 306, PPL: 998|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.93, KL: 26.96|DE LOSS: 301, PPL: 984, TM: 298, LM: 3.52|BETA: 0.015648
# 065[s], 08[s], Ep: 45, Ct: 00000|TR LOSS: 306, PPL: 998|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.93, KL: 26.96|DE LOSS: 301, PPL: 984, TM: 298, LM: 3.57|BETA: 0.015701
# 083[s], 08[s], Ep: 45, Ct: 00500|TR LOSS: 306, PPL: 998|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.93, KL: 26.97|DE LOSS: 301, PPL: 985, TM: 298, LM: 3.55|BETA: 0.015770
# 082[s], 08[s], Ep: 45, Ct: 01000|TR LOSS: 306, PPL: 998|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.92, KL: 26.97|DE LOSS: 301, PPL: 987, TM: 298, LM: 3.52|BETA: 0.015839
# 083[s], 08[s], Ep: 45, Ct: 01500|TR LOSS: 306, PPL: 998|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.92, KL: 26.98|DE LOSS: 302, PPL: 988, TM: 298, LM: 3.53|BETA: 0.015908
# 082[s], 08[s], Ep: 45, Ct: 02000|TR LOSS: 306, PPL: 998|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.91, KL: 26.99|DE LOSS: 302, PPL: 985, TM: 298, LM: 3.65|BETA: 0.015976
# 083[s], 08[s], Ep: 45, Ct: 02500|TR LOSS: 306, PPL: 998|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.91, KL: 26.99|DE LOSS: 301, PPL: 984, TM: 298, LM: 3.52|BETA: 0.016045
# 088[s], 30[s], Ep: 46, Ct: 00000|TR LOSS: 306, PPL: 997|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.91, KL: 27.00|DE LOSS: 301, PPL: 984, TM: 298, LM: 3.54|BETA: 0.016098
# 082[s], 08[s], Ep: 46, Ct: 00500|TR LOSS: 306, PPL: 997|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.90, KL: 27.00|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.53|BETA: 0.016167
# 082[s], 08[s], Ep: 46, Ct: 01000|TR LOSS: 306, PPL: 997|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.90, KL: 27.01|DE LOSS: 301, PPL: 987, TM: 298, LM: 3.53|BETA: 0.016236
# 125[s], 50[s], Ep: 46, Ct: 01500|TR LOSS: 306, PPL: 997|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.89, KL: 27.01|DE LOSS: 301, PPL: 983, TM: 298, LM: 3.52|BETA: 0.016305
# 082[s], 08[s], Ep: 46, Ct: 02000|TR LOSS: 306, PPL: 997|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.89, KL: 27.02|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.52|BETA: 0.016374
# 103[s], 29[s], Ep: 46, Ct: 02500|TR LOSS: 306, PPL: 997|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.89, KL: 27.02|DE LOSS: 301, PPL: 978, TM: 298, LM: 3.53|BETA: 0.016443
# 066[s], 08[s], Ep: 47, Ct: 00000|TR LOSS: 306, PPL: 997|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.88, KL: 27.03|DE LOSS: 301, PPL: 987, TM: 298, LM: 3.52|BETA: 0.016496
# 083[s], 08[s], Ep: 47, Ct: 00500|TR LOSS: 306, PPL: 996|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.88, KL: 27.03|DE LOSS: 301, PPL: 988, TM: 298, LM: 3.53|BETA: 0.016565
# 082[s], 08[s], Ep: 47, Ct: 01000|TR LOSS: 306, PPL: 996|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.88, KL: 27.04|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.53|BETA: 0.016634
# 083[s], 08[s], Ep: 47, Ct: 01500|TR LOSS: 306, PPL: 996|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.87, KL: 27.04|DE LOSS: 301, PPL: 985, TM: 298, LM: 3.53|BETA: 0.016703
# 083[s], 08[s], Ep: 47, Ct: 02000|TR LOSS: 306, PPL: 996|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.87, KL: 27.04|DE LOSS: 301, PPL: 987, TM: 298, LM: 3.54|BETA: 0.016771
# 082[s], 08[s], Ep: 47, Ct: 02500|TR LOSS: 306, PPL: 996|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.86, KL: 27.05|DE LOSS: 301, PPL: 989, TM: 298, LM: 3.53|BETA: 0.016840
# 066[s], 08[s], Ep: 48, Ct: 00000|TR LOSS: 306, PPL: 996|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.86, KL: 27.05|DE LOSS: 301, PPL: 987, TM: 298, LM: 3.53|BETA: 0.016893
# 082[s], 08[s], Ep: 48, Ct: 00500|TR LOSS: 306, PPL: 996|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.86, KL: 27.05|DE LOSS: 301, PPL: 987, TM: 298, LM: 3.52|BETA: 0.016962
# 083[s], 08[s], Ep: 48, Ct: 01000|TR LOSS: 306, PPL: 995|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.85, KL: 27.06|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.54|BETA: 0.017031
# 082[s], 08[s], Ep: 48, Ct: 01500|TR LOSS: 306, PPL: 995|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.85, KL: 27.06|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.53|BETA: 0.017100
# 082[s], 08[s], Ep: 48, Ct: 02000|TR LOSS: 306, PPL: 995|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.85, KL: 27.06|DE LOSS: 301, PPL: 988, TM: 298, LM: 3.53|BETA: 0.017169
# 084[s], 08[s], Ep: 48, Ct: 02500|TR LOSS: 306, PPL: 995|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.84, KL: 27.07|DE LOSS: 302, PPL: 995, TM: 298, LM: 3.53|BETA: 0.017238
# 065[s], 08[s], Ep: 49, Ct: 00000|TR LOSS: 306, PPL: 995|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.84, KL: 27.07|DE LOSS: 301, PPL: 987, TM: 298, LM: 3.53|BETA: 0.017291
# 083[s], 08[s], Ep: 49, Ct: 00500|TR LOSS: 306, PPL: 995|TM NLL: 298, KL: 4.07, REG:0.06 | LM NLL: 3.84, KL: 27.07|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.53|BETA: 0.017360
# 083[s], 08[s], Ep: 49, Ct: 01000|TR LOSS: 306, PPL: 995|TM NLL: 298, KL: 4.08, REG:0.06 | LM NLL: 3.83, KL: 27.07|DE LOSS: 302, PPL: 984, TM: 298, LM: 3.52|BETA: 0.017429
# 083[s], 08[s], Ep: 49, Ct: 01500|TR LOSS: 306, PPL: 995|TM NLL: 298, KL: 4.08, REG:0.06 | LM NLL: 3.83, KL: 27.08|DE LOSS: 301, PPL: 984, TM: 298, LM: 3.52|BETA: 0.017498
# 083[s], 07[s], Ep: 49, Ct: 02000|TR LOSS: 306, PPL: 994|TM NLL: 298, KL: 4.08, REG:0.06 | LM NLL: 3.83, KL: 27.08|DE LOSS: 301, PPL: 981, TM: 298, LM: 3.53|BETA: 0.017567
# 084[s], 08[s], Ep: 49, Ct: 02500|TR LOSS: 306, PPL: 994|TM NLL: 298, KL: 4.08, REG:0.06 | LM NLL: 3.82, KL: 27.08|DE LOSS: 302, PPL: 988, TM: 298, LM: 3.53|BETA: 0.017635
# 066[s], 08[s], Ep: 50, Ct: 00000|TR LOSS: 306, PPL: 994|TM NLL: 298, KL: 4.08, REG:0.06 | LM NLL: 3.82, KL: 27.08|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.52|BETA: 0.017688
# 082[s], 08[s], Ep: 50, Ct: 00500|TR LOSS: 306, PPL: 994|TM NLL: 298, KL: 4.08, REG:0.06 | LM NLL: 3.82, KL: 27.08|DE LOSS: 301, PPL: 987, TM: 298, LM: 3.53|BETA: 0.017757
# 083[s], 08[s], Ep: 50, Ct: 01000|TR LOSS: 306, PPL: 994|TM NLL: 298, KL: 4.08, REG:0.06 | LM NLL: 3.81, KL: 27.08|DE LOSS: 302, PPL: 988, TM: 298, LM: 3.55|BETA: 0.017826
# 083[s], 08[s], Ep: 50, Ct: 01500|TR LOSS: 306, PPL: 994|TM NLL: 298, KL: 4.08, REG:0.06 | LM NLL: 3.81, KL: 27.08|DE LOSS: 301, PPL: 985, TM: 298, LM: 3.54|BETA: 0.017895
# 083[s], 08[s], Ep: 50, Ct: 02000|TR LOSS: 306, PPL: 994|TM NLL: 298, KL: 4.08, REG:0.06 | LM NLL: 3.80, KL: 27.09|DE LOSS: 301, PPL: 988, TM: 298, LM: 3.54|BETA: 0.017964
# 084[s], 08[s], Ep: 50, Ct: 02500|TR LOSS: 306, PPL: 994|TM NLL: 298, KL: 4.08, REG:0.06 | LM NLL: 3.80, KL: 27.09|DE LOSS: 301, PPL: 987, TM: 298, LM: 3.53|BETA: 0.018033
# 066[s], 08[s], Ep: 51, Ct: 00000|TR LOSS: 306, PPL: 994|TM NLL: 298, KL: 4.08, REG:0.06 | LM NLL: 3.80, KL: 27.09|DE LOSS: 301, PPL: 988, TM: 298, LM: 3.53|BETA: 0.018086
# 083[s], 08[s], Ep: 51, Ct: 00500|TR LOSS: 306, PPL: 993|TM NLL: 298, KL: 4.08, REG:0.06 | LM NLL: 3.80, KL: 27.09|DE LOSS: 302, PPL: 987, TM: 298, LM: 3.53|BETA: 0.018155
# 082[s], 08[s], Ep: 51, Ct: 01000|TR LOSS: 306, PPL: 993|TM NLL: 298, KL: 4.08, REG:0.06 | LM NLL: 3.79, KL: 27.09|DE LOSS: 301, PPL: 985, TM: 298, LM: 3.53|BETA: 0.018224
# 083[s], 08[s], Ep: 51, Ct: 01500|TR LOSS: 306, PPL: 993|TM NLL: 298, KL: 4.08, REG:0.06 | LM NLL: 3.79, KL: 27.09|DE LOSS: 301, PPL: 985, TM: 298, LM: 3.54|BETA: 0.018293
# 083[s], 08[s], Ep: 51, Ct: 02000|TR LOSS: 306, PPL: 993|TM NLL: 298, KL: 4.08, REG:0.06 | LM NLL: 3.79, KL: 27.09|DE LOSS: 301, PPL: 989, TM: 298, LM: 3.54|BETA: 0.018362
# 082[s], 08[s], Ep: 51, Ct: 02500|TR LOSS: 306, PPL: 993|TM NLL: 298, KL: 4.08, REG:0.06 | LM NLL: 3.78, KL: 27.09|DE LOSS: 301, PPL: 981, TM: 298, LM: 3.53|BETA: 0.018430
# 065[s], 08[s], Ep: 52, Ct: 00000|TR LOSS: 306, PPL: 993|TM NLL: 298, KL: 4.08, REG:0.06 | LM NLL: 3.78, KL: 27.09|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.53|BETA: 0.018483
# 083[s], 08[s], Ep: 52, Ct: 00500|TR LOSS: 306, PPL: 993|TM NLL: 298, KL: 4.08, REG:0.06 | LM NLL: 3.78, KL: 27.09|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.54|BETA: 0.018552
# 082[s], 08[s], Ep: 52, Ct: 01000|TR LOSS: 306, PPL: 993|TM NLL: 298, KL: 4.08, REG:0.06 | LM NLL: 3.77, KL: 27.09|DE LOSS: 302, PPL: 983, TM: 298, LM: 3.58|BETA: 0.018621
# 083[s], 08[s], Ep: 52, Ct: 01500|TR LOSS: 306, PPL: 992|TM NLL: 298, KL: 4.08, REG:0.06 | LM NLL: 3.77, KL: 27.09|DE LOSS: 301, PPL: 986, TM: 298, LM: 3.53|BETA: 0.018690
# 082[s], 08[s], Ep: 52, Ct: 02000|TR LOSS: 306, PPL: 992|TM NLL: 298, KL: 4.08, REG:0.06 | LM NLL: 3.77, KL: 27.09|DE LOSS: 301, PPL: 989, TM: 298, LM: 3.54|BETA: 0.018759
# 083[s], 08[s], Ep: 52, Ct: 02500|TR LOSS: 306, PPL: 992|TM NLL: 298, KL: 4.08, REG:0.06 | LM NLL: 3.76, KL: 27.09|DE LOSS: 301, PPL: 981, TM: 298, LM: 3.53|BETA: 0.018828
# ...
# 17 Pred: officials in green bay are holding part on a bill that would allow water trucks to stop on metro highways
# 18 True: press gazette media ( http : //gbpg.net/ # <unk> # s ) reports the city 's common council voted # on tuesday to send the ordinance back to committee
# 18 Pred: assemblywoman herald ( ( http : //gbpg.net/ # <unk> # <unk> ) reports the university 's education council voted # signatures tuesday to send the action to to lawmakers
# 19 True: the city all but bars food trucks from operating except on private property
# 19 Pred: the city most drivers and food and by those notices on new property
# 20 True: alderman guy <unk> opposed the ordinance and said that more food trucks would destabilize restaurants
# 20 Pred: alderman rachael <unk> calls the ordinance and said that using harmful can can <unk> restaurants
# 21 True: alderman randy <unk> said the ordinance would get more people downtown and help everyone
# 21 Pred: mta randy <unk> said the ordinance would make more time # and animals adults
# 22 True: city staff proposed the ordinance , hoping to increase the number of food trucks as they try to draw people to downtown
# 22 Pred: city law for the ordinance , which to hold the number of smoke trucks while to can to break down to nearby
# 23 True: it also includes new regulations , such as a # foot buffer between food trucks and restaurants
# 23 Pred: it has includes new health and such for a # foot buffer between food trucks and trucks
# 24 True: delaware state police have charged the driver of a tour bus that crashed in new castle , killing two passengers and injuring dozens
# 24 Pred: delaware state police have charged the driver of a home bus that robbed two # castle , killing both passengers and injuring them
# 25 True: troopers said tuesday that # year old <unk> zhao of flushing , new york , has been charged with two counts of the operation of a vehicle causing death of another person
# 25 Pred: troopers say that that # year old <unk> <unk> of # , new hampshire , has been charged with two counts of the theft of a collision causing death of a drowning
# 26 True: fifty four year old <unk> ' y chen of new york city and # year old <unk> <unk> of istanbul , turkey , were killed in sunday 's crash
# 26 Pred: fifty four year old <unk> <unk> <unk> of of new york city # north year old <unk> <unk> of <unk> , n.y. , were killed in sunday near afternoon
# 27 True: police say # passengers were on the bus when it drove onto a curve exit ramp and overturned
# 27 Pred: police say # people were on the motorcycle when it crashed onto a semi on road and overturned
# 28 True: state police spokesman sgt . paul shavack said in a news release that zhao was driving at an unsafe speed as it entered the curve
# 28 Pred: albuquerque police sgt sgt . anthony scott said in a news release that dna was driving in an oncoming belt when it left the scene
# 29 True: zhao is being held on $ # secured bond
# 29 Pred: pinto is being held on $ # secured bond
# 30 True: it is not known if he has a lawyer
# 30 Pred: it is not known if he has a lawyer
# 31 True: a small plane has crashed in the foothills of the san gabriel mountains above <unk> , prompting a <unk> helicopter rescue of two men onboard
# 31 Pred: a small plane has crashed in the backyard of the northern gabriel mountains as <unk> , with a <unk> rescue and at two people workers
# 32 True: faa spokesman ian gregor says the single engine cessna # went down in a ravine under unknown circumstances just before # p.m. monday
# 32 Pred: fire spokeswoman croxton crane says the single engine winds received is down on a ravine for an airplane that before # p.m. monday
# 33 True: los angeles county fire dispatch supervisor melanie flores says the plane made a hard landing on an inaccessible hillside near a school
# 33 Pred: los angeles county fire chief supervisor laura flores says the plane made the flight landing on an inaccessible trail in a park
# 34 True: she says a helicopter rescue crew lifted a flight instructor and student to safety
# 34 Pred: she says a helicopter and crew responded a precautionary service and fire to safety
# 35 True: one person was strapped to a <unk>
# 35 Pred: one person was with to a <unk>
# 36 True: flores says they were both in stable condition and one man was walking around when the helicopter arrived
# 36 Pred: <unk> also they were living in stable condition and one man was pronounced on after the man wednesday
# 37 True: gov . bill walker has made official alaska 's intent to change the name of a census area named for confederate military officer wade hampton
# 37 Pred: gov . bill walker has ordered office 's 's plans to seek the death of a texas leader involving of former soldiers soldiers daniel children
# 38 True: walker sent a letter to u.s. census bureau director john thompson , saying he planned to now refer to the region in western alaska as the <unk> census area to honor the wishes of local residents
# 38 Pred: walker sent a letter to u.s. district bureau director david <unk> , who is is to help to to the university of of of community of community system <unk> to save the nation of people
# 39 True: the area is home to the <unk> mountains
# 39 Pred: the area is home to the <unk> mountains
# 40 True: last month , the city and village of hooper bay passed a resolution calling for that specific name change
# 40 Pred: last march , the city and community of main bay made the resolution after for it action email changes
# 41 True: the president of the association of village council presidents says the push began months before the deadly june shootings in south carolina that brought renewed attention to remnants of confederate history
# 41 Pred: the president of the center of christian outside says the the dispute to after after the # # # in # carolina that was it to afghanistan indiana of confederate war
# 42 True: but myron <unk> sr. said that elevated the issue
# 42 Pred: but herbert <unk> sr. said that blocked the set
# 43 True: a lynnwood , wash. , police spokeswoman says an officer who suffered multiple pelvic fractures in an # foot fall down an embankment has undergone surgery for those injuries
# 43 Pred: a brown , wash. , police spokesman says an officer who suffered severe fractures fractures in his # s # 's an injury is been surgery for rabies injuries
# 44 True: officer ryan <unk> ( hi rup ) was struggling with a felony warrant suspect on sunday evening when they both went over the embankment
# 44 Pred: officer michael <unk> tells chase tv ) were fired with a felony warrant after in sunday night when they drove one off the car
# 45 True: spokeswoman shannon sessions says the officer came through monday 's surgery well
# 45 Pred: spokeswoman andrea huckaby says the man came on sunday 's surgery well
# 46 True: he was reported in serious condition at a seattle hospital
# 46 Pred: he was found in serious condition at a richmond hospital
# 47 True: the daily herald reports ( http : <unk> ) the # year old , five year veteran of the department was unable to move after the fall and had to be rescued by firefighters
# 47 Pred: the daily news reports ( http : <unk> ) the # year old and # of family , the area was able to work in the crash but did n't be euthanized by firefighters
# 48 True: other officers captured the # year old suspect and jailed him for investigation of assault
# 48 Pred: both officers arrested the # year old man and arrested without for investigation of assault
# 49 True: the state board that oversees elections in wisconsin plans to reverse course and rescind its previous advice that stickers with expiration dates could be used on college identification cards to meet requirements under a new voter identification law
# 49 Pred: the state board says and elections in # wants to place course that all its 's day on 's with fewer money is be subject for state system and to pay in of the new voter registration
# 50 True: the government accountability board in september said stickers would be ok , but lawmakers objected and colleges and universities said they were seeking other ways to comply with the law
# 50 Pred: the union board board in december says it are be students , but teachers and and teachers , lawmakers had have concerned their requirements changes to change the the law
# 51 True: the board was slated to vote wednesday on reversing its previous position that stickers would be acceptable
# 51 Pred: the board was asked to vote tuesday evening tuesday its previous ruling that fails would be worse
# 52 True: the board was also expected to recommend that technical college ids be an acceptable form of identification for voting
# 52 Pred: the board has n't required to recommend that local college ids be an important form of for for voting
# 53 True: current law does not allow them to be used for voting
# 53 Pred: current law does not allow them to be them for voting
# 54 True: university of maryland police have charged a man they believe robbed a student last week on the college park campus
# 54 Pred: university of maryland police have investigating a child who believe she the home last week in the college college academy
# 55 True: police say # year old isaiah graham of riverdale , md . has been charged with armed robbery and assault
# 55 Pred: police say # year old deanna riggs of riverdale , n.h. also have been charged with armed robbery and assault
# 56 True: he had been arrested in washington d.c. on robbery charges unrelated to the incident on campus and he is being held without bond
# 56 Pred: he had been arrested in chicago d.c. on charges of after to the scene on police police has was expected held on bond
# 57 True: a maryland student told police that he was approached by two masked men and one pulled a knife and demanded the student 's property
# 57 Pred: a maryland police officer police that he was shot by two armed boyfriend and dragged man a gun and fired the clerk 's property
# 58 True: campus police say detectives are working with metropolitan police and george washington university police to identify a second man involved in a robbery on thursday near cecil hall on the college park campus
# 58 Pred: fire police say officers are investigating at saint police baptist st. e. and and to to a person man shot in the fight and campus and <unk> hall on the state campus campus
# 59 True: maine firefighters are on the scene of a fire at berwick academy
# 59 Pred: memphis firefighters are on the scene of a fire at upmc academy
# 60 True: police say firefighters were called to the arts center at the private school at # p.m. tuesday
# 60 Pred: police say students were called to the arts center at the delta school at # p.m. tuesday
# 61 True: the fire was called in by students <unk> a production of `` les <unk> .
# 61 Pred: the fire was called in rough researchers , a common of `` freedom <unk> .
# 62 True: the fire chief told wcsh tv that the fire had escalated to two alarms
# 62 Pred: the police chief told wcsh tv that the fire had escalated to two alarms
# -----------Topic Samples-----------
# 0  bow: charged charges guilty years prison prosecutors court arrested death sentenced
# 0  sent: one man accused of fatally shooting his house as much of violence and his death is in custody of the victim
# 1  bow: million budget tax bill health gov plan money lawmakers care
# 1  sent: jindal spending
# 2  bow: percent million company cents share shares average revenue billion quarter
# 2  sent: clouse seacor seacor seacor seacor clouse seacor semiconductor clouse clouse seacor seacor seacor seacor seacor seacor seacor seacor seacor seacor seacor seacor seacor seacor seacor seacor seacor seacor seacor seacor seacor seacor seacor seacor seacor seacor seacor seacor seacor seacor
# 3  bow: republican senate house bill democratic election gov campaign governor vote
# 3  sent: jindal 's republicans included some democrats as its budget as part of jindal 's final support for its senate budget committee
# 4  bow: fire service area water weather national tuesday monday river miles
# 4  sent: aerial en cars from <unk> , about a plane wednesday night and one lane received some minor and a fire
# 5  bow: court federal judge attorney u.s. law filed lawsuit office case
# 5  sent: nelson 's case released their status as part of their lawsuit brought in her plea as an example of on appeal
# 6  bow: national people center day years event u.s. world museum group
# 6  sent: online
# 7  bow: department http company reports million project water health public plant
# 7  sent: one <unk>
# 8  bow: found authorities home hospital car died fire woman sheriff officers
# 8  sent: one man and his officers died in an accident after their car collided with a car who died at injuries
# 9  bow: school students university board schools education college district student high
# 9  sent: its democrats assumes top republicans for the senate also incorporates hathaway spending for consideration of jindal spending
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-997319395edd> in <module>
#      13
#      14         _, loss_batch, topic_loss_recon_batch, topic_loss_kl_batch, topic_loss_reg_batch, sent_loss_recon_batch, sent_loss_kl_batch, sent_loss_kl_categ_batch, sent_loss_kl_gmm_batch, ppls_batch = \
# ---> 15         sess.run([opt, loss, topic_loss_recon, topic_loss_kl, topic_loss_reg, sent_loss_recon, sent_loss_kl, sent_loss_kl_categ, sent_loss_kl_gmm, topic_ppls], feed_dict = feed_dict)
#      16
#      17         if sent_loss_kl_batch == np.inf:
#
# ~/.pyenv/versions/anaconda2-5.3.0/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/.pyenv/versions/anaconda2-5.3.0/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# ~/.pyenv/versions/anaconda2-5.3.0/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/.pyenv/versions/anaconda2-5.3.0/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# ~/.pyenv/versions/anaconda2-5.3.0/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/.pyenv/versions/anaconda2-5.3.0/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# # confirm variables

# %%
_prob_topic, _prob_topic_sents, _prob_topic_infer, _means_topic_infer = debug_value([prob_topic, prob_topic_sents, prob_topic_infer, means_topic_infer], return_value=True)

# %%
batch_i = 4
_prob_topic_sents[batch_i], _prob_topic_infer[batch_i]
# Out:
# (array([1.2281889e-02, 6.7835855e-03, 2.0132679e-01, 1.1674699e-02,
#         6.5264981e-03, 1.1411838e-02, 6.9189700e-03, 2.8612482e-04,
#         7.4042326e-01, 2.3663496e-03], dtype=float32),
#  array([0.09889801, 0.11335436, 0.12141278, 0.10027827, 0.13508864,
#         0.09455997, 0.0860846 , 0.08042429, 0.09635323, 0.07354581],
#        dtype=float32))

# %%
_means_topic_infer[0][:, :4]
# Out:
# array([[-0.02824139, -0.22793637,  0.3788033 , -0.02814816],
#        [ 0.06249218, -0.08085692,  0.06756439,  0.2259818 ],
#        [-0.1377574 ,  0.28185233,  0.23656711, -0.3201025 ],
#        [-0.03711405,  0.16953555,  0.16389738, -0.16461828],
#        [ 0.27302447, -0.22462857,  0.37200606, -0.00549014],
#        [-0.16755986,  0.11964113,  0.17052333,  0.18083367],
#        [ 0.26351342, -0.33828875,  0.3920058 , -0.17029142],
#        [ 0.21033517, -0.1955087 ,  0.20963705, -0.24809986],
#        [ 0.01922028, -0.03185754,  0.28022933, -0.13928899],
#        [-0.26817918, -0.3364467 ,  0.36924574,  0.15818927]],
#       dtype=float32)

# %%
w_means_topic, b_means_topic = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, "topic/dec/mean_topic")

pred_topic_embeddings, pred_topic_bow, pred_means_topic, pred_logvars_topic, pred_token_idxs, _w_means_topic, _b_means_topic, _w_mean_topic_infer = \
                                sess.run([topic_embeddings, topic_bow, means_topic, logvars_topic, topic_beam_output_token_idxs, w_means_topic, b_means_topic, w_mean_topic_infer], 
                                         feed_dict={t_variables['batch_l']: config.n_topic, t_variables['keep_prob']: 1.,})

pred_sents = idxs_to_sents(pred_token_idxs, config, idx_to_word)

pred_topics_freq_bow_indices = np.argsort(pred_topic_bow, 1)[:, ::-1][:, :10]
pred_topics_freq_bow_idxs = bow_idxs[pred_topics_freq_bow_indices]

# %%
for idxs in pred_topics_freq_bow_idxs:
    print([idx_to_word[idx] for idx in idxs])
# Out:
# ['million', 'http', 'years', 'tuesday', 'federal', 'u.s.', 'month', 'office', 'people', 'monday']
# ['reports', 'department', 'thursday', 'court', 'time', 'u.s.', 'years', 'monday', 'tuesday', "'"]
# ['school', 'public', 'u.s.', 'board', 'university', 'federal', 'president', 'program', 'health', 'students']
# ['fire', 'found', 'authorities', 'hospital', 'home', 'a.m.', 'dead', 'investigation', 'chief', 'morning']
# ['service', 'national', 'department', 'http', 'water', 'park', 'area', 'center', 'wednesday', 'weather']
# ['percent', 'company', 'million', 'billion', 'shares', 'inc.', 'revenue', 'average', 'cents', 'price']
# ['design', 'researchers', 'donations', 'prize', 'encourage', 'peak', 'awards', 'feature', 'chapter', 'affect']
# ['court', 'arrested', 'charged', 'attorney', 'death', 'authorities', 'found', 'prison', 'shooting', 'woman']
# ['bill', 'senate', 'house', 'republican', 'committee', 'public', 'board', 'approved', 'u.s.', 'law']
# ['todd', 'rear', 'drowned', 'confronted', 'foul', 'transported', 'assaulted', 'loaded', 'defender', 'unidentified']

# %%
pred_topic_embeddings[:, :10]
# Out:
# array([[ 0.09207956,  0.09077395,  0.06120839, -0.22176096,  0.19921999,
#         -0.05485373, -0.23069587,  0.05650459,  0.142239  , -0.17410392],
#        [ 0.29974467, -0.03281972,  0.25064805, -0.2893645 , -0.1312135 ,
#         -0.11136644,  0.02060958, -0.13598587,  0.24592783, -0.18463418],
#        [ 0.22819577,  0.14566512,  0.05597903, -0.1109414 , -0.00879419,
#         -0.1605561 ,  0.11445126,  0.00916692, -0.04847115, -0.0603605 ],
#        [ 0.3365141 , -0.06439152,  0.3631938 ,  0.14203475,  0.10052318,
#         -0.09119357, -0.08768138, -0.28562906,  0.3186355 , -0.08452626],
#        [ 0.26727033,  0.03540339,  0.28315246, -0.1286456 , -0.02444943,
#         -0.163507  , -0.02146725, -0.21729966,  0.26542294, -0.1589102 ],
#        [ 0.28826687, -0.18438952,  0.2760168 , -0.12692557,  0.05485712,
#          0.17983724,  0.14970489, -0.36168167,  0.30563408, -0.13128197],
#        [-0.32988435, -0.11005852, -0.27013943,  0.26166642, -0.3013388 ,
#         -0.2234488 ,  0.02287463,  0.20320751, -0.10510623,  0.28636736],
#        [ 0.37211177, -0.00585993,  0.2853141 , -0.05771174,  0.15170154,
#          0.05411884, -0.24091715, -0.01475959, -0.0408047 , -0.17167823],
#        [ 0.20512433,  0.18697639, -0.08326819,  0.03792854,  0.03214281,
#          0.05618311,  0.09544107,  0.03913466, -0.06514693, -0.04000437],
#        [-0.3745221 , -0.06385167, -0.29924905,  0.08158813, -0.28344202,
#         -0.01799835,  0.02471407,  0.408938  , -0.169172  ,  0.37273586]],
#       dtype=float32)

# %%
pred_topic_bow
# Out:
# array([[1.0327697e-03, 4.6811462e-03, 1.7024261e-04, ..., 3.3795869e-04,
#         1.5871278e-04, 6.6570101e-05],
#        [5.9443718e-04, 7.4376534e-03, 2.0111131e-04, ..., 7.4048399e-04,
#         1.5028552e-04, 8.9953668e-05],
#        [8.5580017e-04, 2.8901210e-03, 1.6464434e-04, ..., 3.1770146e-04,
#         1.9349743e-04, 3.0012103e-04],
#        ...,
#        [1.3188391e-04, 2.6697975e-03, 2.3009101e-04, ..., 8.1575691e-04,
#         1.5104198e-04, 3.2140684e-05],
#        [3.8558390e-04, 4.0810513e-03, 1.4347673e-04, ..., 1.4157601e-04,
#         1.8342295e-04, 4.7484271e-05],
#        [7.1679087e-06, 2.9757638e-07, 1.8662996e-04, ..., 5.9841594e-05,
#         1.7972868e-04, 5.0798093e-04]], dtype=float32)

# %%
_w_means_topic
# Out:
# array([[ 0.09637171, -0.09069463,  0.09532599, ..., -0.02989542,
#         -0.02514938,  0.01415634],
#        [-0.02764424,  0.01254364,  0.03703775, ..., -0.01512817,
#          0.02590305,  0.01404281],
#        [-0.08408152, -0.00924051, -0.08365072, ...,  0.05623364,
#         -0.05008389,  0.0209127 ],
#        ...,
#        [-0.00629492, -0.05131948, -0.05206006, ..., -0.0955721 ,
#         -0.01980347, -0.02646225],
#        [-0.00839109, -0.05062511, -0.05731497, ...,  0.07618995,
#          0.03893617,  0.06835916],
#        [ 0.07883421, -0.02804748,  0.09326512, ..., -0.0734218 ,
#          0.0045918 , -0.10043538]], dtype=float32)

# %%
_b_means_topic
# Out:
# array([ 0.03207342, -0.08436021,  0.36105958, -0.02925379, -0.26779142,
#        -0.4809294 , -0.04713235, -0.6384421 ,  0.49655244, -0.18943405,
#         0.32139724,  0.00376519, -0.02733823,  0.06968141,  0.12723993,
#         0.17086434,  0.4321125 ,  0.2930171 ,  0.43750855, -0.32728267,
#        -0.29320472,  0.46633536,  0.03467208, -0.11661331,  0.02106199,
#         0.10828511,  0.14413024,  0.00801178, -0.16259423,  0.31461757,
#        -0.25328413,  0.11320477], dtype=float32)

# %%
pred_means_topic
# Out:
# array([[ 0.03563995, -0.3379975 ,  1.6953684 , -0.3394102 , -1.3313038 ,
#         -1.9561913 , -0.34439525, -3.1041431 ,  2.302101  , -0.80340064,
#          1.374892  ,  0.10505254,  0.13142577,  0.36230466,  0.5036737 ,
#          0.6154421 ,  1.8879794 ,  1.263777  ,  2.0281937 , -1.4289141 ,
#         -1.3110695 ,  2.0390706 ,  0.32288784, -0.39520237,  0.10320839,
#          0.35608286,  0.61754334, -0.1438482 , -0.74413097,  1.4731948 ,
#         -1.1249324 ,  0.33894244],
#        [ 0.03510073, -0.3374708 ,  1.6888778 , -0.3363807 , -1.3308815 ,
#         -1.9608293 , -0.34732953, -3.1081154 ,  2.3005512 , -0.80602133,
#          1.3695524 ,  0.10256523,  0.13283278,  0.36182955,  0.49822897,
#          0.6213894 ,  1.8883276 ,  1.266403  ,  2.023539  , -1.426166  ,
#         -1.3108103 ,  2.0448976 ,  0.32430837, -0.38903922,  0.10560946,
#          0.3596735 ,  0.6160856 , -0.14840832, -0.74532497,  1.4738762 ,
#         -1.1249926 ,  0.33331037],
#        [ 0.03490497, -0.33676392,  1.6840277 , -0.335459  , -1.3295547 ,
#         -1.95664   , -0.3462094 , -3.1003447 ,  2.296549  , -0.80408335,
#          1.367739  ,  0.10281808,  0.13425133,  0.36240244,  0.4972452 ,
#          0.6206323 ,  1.885982  ,  1.2645416 ,  2.0215812 , -1.4212072 ,
#         -1.3081043 ,  2.0386996 ,  0.32136053, -0.39039296,  0.1050597 ,
#          0.36023104,  0.6137113 , -0.15039542, -0.7433981 ,  1.4694595 ,
#         -1.1245916 ,  0.3360805 ],
#        [ 0.03728028, -0.33768234,  1.6832604 , -0.3353232 , -1.325423  ,
#         -1.9593027 , -0.34599763, -3.1006794 ,  2.2962196 , -0.80693865,
#          1.3678529 ,  0.10114851,  0.13371727,  0.36420822,  0.49783063,
#          0.62049437,  1.8832903 ,  1.2625886 ,  2.0200832 , -1.421174  ,
#         -1.3108637 ,  2.0388248 ,  0.32396334, -0.38813725,  0.10552703,
#          0.3586173 ,  0.6122677 , -0.15264365, -0.74335086,  1.468328  ,
#         -1.1214948 ,  0.337562  ],
#        [ 0.0355639 , -0.33673748,  1.6850188 , -0.334822  , -1.3297123 ,
#         -1.9579692 , -0.34517902, -3.0999303 ,  2.296747  , -0.8048171 ,
#          1.3683693 ,  0.10311563,  0.13507861,  0.36239594,  0.4968614 ,
#          0.61993766,  1.8848993 ,  1.2634866 ,  2.0213115 , -1.4220002 ,
#         -1.3081868 ,  2.0382977 ,  0.32180363, -0.39071375,  0.10513556,
#          0.35903966,  0.6132862 , -0.15032193, -0.74355686,  1.4703372 ,
#         -1.1240762 ,  0.3361809 ],
#        [ 0.03776056, -0.33906677,  1.6886759 , -0.33578348, -1.3277831 ,
#         -1.9574624 , -0.3511446 , -3.1008887 ,  2.298576  , -0.80058026,
#          1.3695161 ,  0.10116885,  0.13310117,  0.36374724,  0.49994904,
#          0.62002206,  1.8863395 ,  1.2639412 ,  2.0218256 , -1.4257591 ,
#         -1.3068638 ,  2.038707  ,  0.3251842 , -0.38946715,  0.10602362,
#          0.3615039 ,  0.6127277 , -0.15162012, -0.739843  ,  1.4696462 ,
#         -1.1235677 ,  0.34125343],
#        [ 0.03675649, -0.33748797,  1.6818695 , -0.3343631 , -1.3270382 ,
#         -1.9566132 , -0.34484407, -3.0962553 ,  2.2958052 , -0.8025343 ,
#          1.365838  ,  0.10129849,  0.13410446,  0.36187994,  0.49527365,
#          0.62073433,  1.8827194 ,  1.264018  ,  2.019868  , -1.4191431 ,
#         -1.3083122 ,  2.036423  ,  0.32277   , -0.38972613,  0.10532874,
#          0.36029965,  0.6137044 , -0.14923215, -0.7424054 ,  1.4679198 ,
#         -1.1228634 ,  0.33640632],
#        [ 0.03632384, -0.33631054,  1.6842166 , -0.33446336, -1.3275865 ,
#         -1.959459  , -0.34500512, -3.1014085 ,  2.2958436 , -0.804686  ,
#          1.3688817 ,  0.10245646,  0.13472772,  0.3634492 ,  0.49877107,
#          0.61891234,  1.8855013 ,  1.263787  ,  2.0223496 , -1.4211094 ,
#         -1.309351  ,  2.0364125 ,  0.32266062, -0.3891954 ,  0.10458721,
#          0.35922444,  0.61319816, -0.14912874, -0.7429457 ,  1.469351  ,
#         -1.1232082 ,  0.3378038 ],
#        [ 0.03574873, -0.3368752 ,  1.6819855 , -0.33521634, -1.3290966 ,
#         -1.9556532 , -0.34607896, -3.0987115 ,  2.2963123 , -0.80486095,
#          1.3669474 ,  0.10132913,  0.13473387,  0.36283588,  0.49758494,
#          0.6216788 ,  1.8858868 ,  1.2627757 ,  2.0219636 , -1.4208897 ,
#         -1.3082187 ,  2.0389626 ,  0.32159996, -0.39116064,  0.1062526 ,
#          0.35957128,  0.6122661 , -0.14942539, -0.74453473,  1.468337  ,
#         -1.123489  ,  0.33671775],
#        [ 0.03600421, -0.33810538,  1.6826388 , -0.33433414, -1.3267329 ,
#         -1.9560882 , -0.34396413, -3.096003  ,  2.2952938 , -0.8032101 ,
#          1.366725  ,  0.10274363,  0.13443008,  0.36315334,  0.4956261 ,
#          0.6213716 ,  1.882305  ,  1.2623034 ,  2.0204127 , -1.4200761 ,
#         -1.3082595 ,  2.034914  ,  0.32189733, -0.38998067,  0.10444504,
#          0.35928738,  0.6142209 , -0.1489011 , -0.74237704,  1.4684169 ,
#         -1.1216142 ,  0.3379858 ]], dtype=float32)

# %%
_w_mean_topic_infer[:, :10, 0]
# Out:
# array([[ 0.02438005, -0.02036242, -0.01039507,  0.00277665,  0.02350294,
#          0.01473409, -0.02157389,  0.02251465,  0.00814133,  0.01785252],
#        [ 0.00074128, -0.001453  , -0.01162554, -0.0014644 , -0.02097618,
#          0.00570552,  0.00674119, -0.01879225,  0.02161046,  0.01941887],
#        [ 0.01402811, -0.00613734, -0.0027943 , -0.01052572, -0.00041091,
#          0.0045091 , -0.01547336,  0.0194314 ,  0.00784631,  0.00505763],
#        [ 0.01655601, -0.02403533,  0.01607199, -0.01643238,  0.00686195,
#         -0.01788632,  0.01109112,  0.00087933,  0.00448566, -0.00823843],
#        [-0.00695892,  0.01631877,  0.01657149,  0.01772625,  0.02026216,
#          0.01811663,  0.02153757, -0.00020743, -0.02066918, -0.00025119],
#        [ 0.02195978,  0.00867016, -0.02278856,  0.0122384 , -0.02183604,
#          0.00798479,  0.00545774,  0.00923075,  0.01814621,  0.02018008],
#        [ 0.02242495, -0.00673729,  0.01447002,  0.02163557,  0.02312511,
#         -0.00920323, -0.01116639,  0.01708085, -0.01181559, -0.00763743],
#        [-0.01978129,  0.00916991, -0.00304236,  0.00106503,  0.00690803,
#         -0.01416942,  0.0063372 ,  0.00018093,  0.00393429, -0.00307162],
#        [-0.01821756,  0.01890057,  0.00228031, -0.01240117, -0.01108933,
#         -0.01674686, -0.01161283, -0.01693372,  0.00370204, -0.00271433],
#        [-0.0158878 ,  0.01951969, -0.01606018, -0.00457847,  0.00044555,
#         -0.0050344 , -0.0013686 ,  0.00539651,  0.02015766, -0.00510509]],
#       dtype=float32)

# %%
_b_means_topic
# Out:
# array([ 0.03922943,  0.46112132, -0.08166478, -0.06917454, -0.01617851,
#         0.18225916, -0.28025913, -0.06620797,  0.03231472, -0.02211766,
#        -0.38082743,  0.11382294,  0.39363608, -0.4168986 ,  1.1677127 ,
#         0.08979508,  0.03593519, -0.07863234,  0.12493958,  0.03175303,
#         0.13351525,  0.8176425 , -0.28750482,  0.37927672, -0.01720515,
#        -0.21228473, -0.05377329, -0.10451841, -0.24399954, -0.25936088,
#         0.0845396 ,  0.33591354], dtype=float32)

# %%
_enc_state_infer, _means_topic_infer = debug_value([enc_state_infer, means_topic_infer], return_value=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-ee7c3cd147b5> in <module>
# ----> 1 _enc_state_infer, _means_topic_infer = debug_value([enc_state_infer, means_topic_infer], return_value=True)
#
# NameError: name 'enc_state_infer' is not defined

# %%
_enc_state_infer.shape
# Out:
# (67, 10, 1024)

# %%
_means_topic_infer[0]
# Out:
# array([[-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00],
#        [-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00],
#        [-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00],
#        [-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00],
#        [-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00],
#        [-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00],
#        [-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00],
#        [-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00],
#        [-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00],
#        [-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00]],
#       dtype=float32)
