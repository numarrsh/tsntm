# %%
# %load_ext autoreload
# %autoreload
from IPython.display import clear_output

import os
import sys
import subprocess
import pdb
import time
import datetime
import math
import random
import _pickle as cPickle
from collections import defaultdict

from six.moves import zip_longest
import numpy as np

import tensorflow as tf
from tensorflow import distributions as tfd
from tensorflow.keras.preprocessing.sequence import pad_sequences

from data_structure import get_batches
from components import tf_log, sample_latents, compute_kl_loss, dynamic_rnn, dynamic_bi_rnn
from topic_model import TopicModel

from topic_beam_search_decoder import BeamSearchDecoder

# %%
PAD = '<pad>' # This has a vocab id, which is used to pad the encoder input, decoder input and target sequence
UNK = '<unk>' # This has a vocab id, which is used to represent out-of-vocabulary words
BOS = '<p>' # This has a vocab id, which is used at the beginning of every decoder input sequence
EOS = '</p>' # This has a vocab id, which is used at the end of untruncated target sequences

# %% [markdown]
# # load data & set config

# %%
def del_all_flags(FLAGS):
    flags_dict = FLAGS._flags()    
    keys_list = [keys for keys in flags_dict]    
    for keys in keys_list:
        FLAGS.__delattr__(keys)

del_all_flags(tf.flags.FLAGS)

flags = tf.app.flags

flags.DEFINE_string('gpu', '5', 'visible gpu')

flags.DEFINE_string('mode', 'train', 'set train or eval')

flags.DEFINE_string('data_path', 'data/apnews/instances.pkl', 'path of data')
flags.DEFINE_string('modeldir', 'model/nvdm_vae', 'directory of model')
flags.DEFINE_string('modelname', 'apnews', 'name of model')

flags.DEFINE_integer('epochs', 1000, 'epochs')
flags.DEFINE_integer('batch_size', 64, 'number of sentences in each batch')
flags.DEFINE_integer('log_period', 500, 'valid period')

flags.DEFINE_string('opt', 'Adagrad', 'optimizer')
flags.DEFINE_float('lr', 0.1, 'lr')
flags.DEFINE_float('reg', 1., 'regularization term')
flags.DEFINE_float('beta', 0.001, 'initial value of beta')
flags.DEFINE_float('grad_clip', 5., 'grad_clip')

flags.DEFINE_float('keep_prob', 0.8, 'dropout rate')
flags.DEFINE_float('word_keep_prob', 0.75, 'word dropout rate')

flags.DEFINE_integer('warmup', 5000, 'warmup period for KL')
flags.DEFINE_integer('warmup_topic', 0, 'warmup period for KL of topic')

flags.DEFINE_integer('beam_width', 2, 'beam_width')
flags.DEFINE_float('length_penalty_weight', 0.0, 'length_penalty_weight')

flags.DEFINE_integer('n_topic', 10, 'number of topic')
flags.DEFINE_integer('dim_hidden_bow', 256, 'dim of hidden bow')
flags.DEFINE_integer('dim_latent_bow', 32, 'dim of latent topic')
flags.DEFINE_integer('dim_emb', 256, 'dim_emb')
flags.DEFINE_integer('dim_hidden', 512, 'dim_hidden')
flags.DEFINE_integer('dim_hidden_topic', 512, 'dim_hidden_topic')
flags.DEFINE_integer('dim_latent', 32, 'dim_latent')
flags.DEFINE_bool('bidirectional', True, 'flg of bidirectional encoding')

# for evaluation
flags.DEFINE_string('refdir', 'ref', 'refdir')
flags.DEFINE_string('outdir', 'out', 'outdir')

flags.DEFINE_string('f', '', 'kernel')
flags.DEFINE_bool('logtostderr', True, 'kernel')
flags.DEFINE_bool('showprefixforinfo', False, '')
flags.DEFINE_bool('verbosity', False, '')
# flags.DEFINE_integer('stderrthreshold', 20, 'kernel')

config = flags.FLAGS

flags.DEFINE_string('modelpath', os.path.join(config.modeldir, config.modelname), 'path of model')

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = config.gpu

# %%
instances_train, instances_dev, instances_test, word_to_idx, idx_to_word, bow_idxs = cPickle.load(open(config.data_path,'rb'))

# %%
train_batches = get_batches(instances_train, config.batch_size)
dev_batches = get_batches(instances_dev, config.batch_size)
test_batches = get_batches(instances_test, config.batch_size)

# %%
flags.DEFINE_integer('PAD_IDX', word_to_idx[PAD], 'PAD_IDX')
flags.DEFINE_integer('UNK_IDX', word_to_idx[UNK], 'UNK_IDX')
flags.DEFINE_integer('BOS_IDX', word_to_idx[BOS], 'BOS_IDX')
flags.DEFINE_integer('EOS_IDX', word_to_idx[EOS], 'EOS_IDX')

flags.DEFINE_integer('n_vocab', len(word_to_idx), 'n_vocab')
flags.DEFINE_integer('dim_bow', len(bow_idxs), 'dim_bow')

maximum_iterations = max([max([instance.max_sent_l for instance in batch]) for ct, batch in dev_batches])
flags.DEFINE_integer('maximum_iterations', maximum_iterations, 'maximum_iterations')

# %% [markdown]
# # build language model

# %% [markdown]
# ## feed dict

# %%
tf.reset_default_graph()

t_variables = {}
t_variables['bow'] = tf.placeholder(tf.float32, [None, config.dim_bow], name='bow')
t_variables['input_token_idxs'] = tf.placeholder(tf.int32, [None, None], name='input_token_idxs')
t_variables['dec_input_idxs'] = tf.placeholder(tf.int32, [None, None], name='dec_input_idxs')
t_variables['dec_target_idxs'] = tf.placeholder(tf.int32, [None, None], name='dec_target_idxs')
t_variables['batch_l'] = tf.placeholder(tf.int32, name='batch_l')
t_variables['doc_l'] = tf.placeholder(tf.int32, [None], name='doc_l')
t_variables['sent_l'] = tf.placeholder(tf.int32, [None], name='sent_l')
t_variables['keep_prob'] = tf.placeholder(tf.float32, name='keep_prob')

# %%
def get_feed_dict(batch, mode='train', assertion=False):
    def token_dropout(sent_idxs):
        sent_idxs_dropout = np.asarray(sent_idxs)
        sent_idxs_dropout[np.random.rand(len(sent_idxs)) > config.word_keep_prob] = config.UNK_IDX
        return list(sent_idxs_dropout)

    bow = np.array([instance.bow for instance in batch]).astype(np.float32)
    
    doc_l = np.array([len(instance.token_idxs) for instance in batch])
    
    feed_input_token_idxs_list = [sent_idxs for instance in batch for sent_idxs in instance.token_idxs]
    feed_dec_input_idxs_list = [[config.BOS_IDX] + token_dropout(sent_idxs) for sent_idxs in feed_input_token_idxs_list]
    feed_dec_target_idxs_list = [sent_idxs + [config.EOS_IDX]  for sent_idxs in feed_input_token_idxs_list]
        
    sent_l = np.array([len(sent_idxs) for sent_idxs in feed_input_token_idxs_list], np.int32)
    batch_l = len(sent_l)
    
    feed_input_token_idxs = pad_sequences(feed_input_token_idxs_list, padding='post', value=config.PAD_IDX, dtype=np.int32)
    feed_dec_input_idxs = pad_sequences(feed_dec_input_idxs_list, padding='post', value=config.PAD_IDX, dtype=np.int32)
    feed_dec_target_idxs = pad_sequences(feed_dec_target_idxs_list, padding='post', value=config.PAD_IDX, dtype=np.int32)
    
    if assertion:
        index = 0
        for instance in batch:
            for line_idxs in instance.token_idxs:
                assert feed_input_token_idxs_list[index] == line_idxs
                index += 1
        assert feed_input_token_idxs.shape[1] == np.max(sent_l)
        assert feed_dec_input_idxs.shape[1] == np.max(sent_l) + 1
        assert feed_dec_target_idxs.shape[1] == np.max(sent_l) + 1
    
    keep_prob = config.keep_prob if mode == 'train' else 1.0

    feed_dict = {
                t_variables['bow']: bow, 
                t_variables['batch_l']: batch_l, t_variables['doc_l']: doc_l, t_variables['sent_l']: sent_l, 
                t_variables['input_token_idxs']: feed_input_token_idxs, t_variables['dec_input_idxs']: feed_dec_input_idxs, t_variables['dec_target_idxs']: feed_dec_target_idxs, 
                t_variables['keep_prob']: keep_prob
    }
    return  feed_dict

# %%
def debug_shape(variables):
    sample_batch = test_batches[0][1]
    feed_dict = get_feed_dict(sample_batch)
    _variables = sess.run(variables, feed_dict=feed_dict)
    for _variable, variable in zip(_variables, variables):
        if hasattr(variable, 'name'):
            print(variable.name, ':', _variable.shape)
        else:
            print(_variable.shape)

def debug_value(variables, return_value=False):
    sample_batch = test_batches[0][1]
    feed_dict = get_feed_dict(sample_batch)
    _variables = sess.run(variables, feed_dict=feed_dict)

    if return_value: 
        return _variables
    else:
        for _variable, variable in zip(_variables, variables):
            if hasattr(variable, 'name'):
                print(variable.name, ':', _variable)
            else:
                print(_variable)
                
def check_shape(variables):
    if 'sess' in globals(): raise
    sess = tf.Session()
    sess.run(tf.global_variables_initializer())
    
    sample_batch = test_batches[0][1]
    feed_dict = get_feed_dict(sample_batch)
    _variables = sess.run(variables, feed_dict=feed_dict)
    for _variable, variable in zip(_variables, variables):
        if hasattr(variable, 'name'):
            print(variable.name, ':', _variable.shape)
        else:
            print(_variable.shape)
            
    sess.close()
    
def check_value(variables):
    if 'sess' in globals(): raise
    sess = tf.Session()
    sess.run(tf.global_variables_initializer())
    
    sample_batch = test_batches[0][1]
    feed_dict = get_feed_dict(sample_batch)
    _variables = sess.run(variables, feed_dict=feed_dict)
    for _variable, variable in zip(_variables, variables):
        if hasattr(variable, 'name'):
            print(variable.name, ':', _variable)
        else:
            print(_variable.shape)
            
    sess.close()    
    
# sent_loss_kl_categ_tmp = tf.reduce_mean(tf.reduce_sum(tf.multiply(prob_topic_infer, tf_log(prob_topic_infer/prob_topic_sents)), 1))
# debug_value([sent_loss_kl_categ, sent_loss_kl_categ_tmp])
# sent_loss_kl_gauss_tmp = 0.5 * tf.reduce_sum(tf.exp(logvars_topic_infer-logvars_topic) + tf.square(means_topic - means_topic_infer) / tf.exp(logvars_topic) - 1 + (logvars_topic - logvars_topic_infer), -1)
# sent_loss_kl_gmm_tmp = tf.reduce_mean(tf.reduce_sum(tf.multiply(prob_topic_infer, sent_loss_kl_gauss_tmp), -1))
# debug_value([sent_loss_kl_gmm_tmp, sent_loss_kl_gmm])

# %% [markdown]
# ## topic model

# %%
# encode bow
with tf.variable_scope('topic/enc', reuse=False):
    hidden_bow_ = tf.layers.Dense(units=config.dim_hidden_bow, activation=tf.nn.relu, name='hidden_bow')(t_variables['bow'])
    hidden_bow = tf.layers.Dropout(t_variables['keep_prob'])(hidden_bow_)
    means_bow = tf.layers.Dense(units=config.dim_latent_bow, name='mean_bow')(hidden_bow)
    logvars_bow = tf.layers.Dense(units=config.dim_latent_bow, kernel_initializer=tf.constant_initializer(0), bias_initializer=tf.constant_initializer(0), name='logvar_topic')(hidden_bow)
    latents_bow = sample_latents(means_bow, logvars_bow) # sample latent vectors

    prob_topic = tf.layers.Dense(units=config.n_topic, activation=tf.nn.softmax, name='prob_topic')(latents_bow) # inference of topic probabilities

# decode bow
with tf.variable_scope('shared', reuse=False):
    embeddings = tf.get_variable('emb', [config.n_vocab, config.dim_emb], dtype=tf.float32, initializer=tf.contrib.layers.xavier_initializer()) # embeddings of vocab

bow_embeddings = tf.nn.embedding_lookup(embeddings, bow_idxs) # embeddings of each bow features

with tf.variable_scope('topic/dec', reuse=False):
    topic_bow = tf.get_variable('topic_bow', [config.n_topic, config.dim_bow], dtype=tf.float32, initializer=tf.contrib.layers.xavier_initializer()) # embeddings of topics
    logits_bow = tf_log(tf.nn.softmax(tf.tensordot(prob_topic, topic_bow, axes=[[1], [0]]), 1))

    # prior of each gaussian distribution (computed for each topic)
    hidden_topic = tf.layers.Dense(units=config.dim_hidden_topic, activation=tf.nn.relu, name='hidden_topic')(topic_bow)
    means_topic = tf.layers.Dense(units=config.dim_latent, name='mean_topic')(hidden_topic)
    logvars_topic = tf.layers.Dense(units=config.dim_latent, kernel_initializer=tf.constant_initializer(0), bias_initializer=tf.constant_initializer(0), name='logvar_topic')(hidden_topic)
    sigma_topic = tf.exp(0.5 * logvars_topic)
    gauss_topic = tfd.Normal(loc=means_topic, scale=sigma_topic)    
    
# define losses
topic_losses_recon = -tf.reduce_sum(tf.multiply(t_variables['bow'], logits_bow), 1)
topic_loss_recon = tf.reduce_mean(topic_losses_recon) # negative log likelihood of each words

topic_loss_kl = compute_kl_loss(means_bow, logvars_bow) # KL divergence b/w latent dist & gaussian std

topic_bow_norm = topic_bow / tf.norm(topic_bow, axis=1, keepdims=True)
topic_dots = tf.clip_by_value(tf.matmul(topic_bow_norm, tf.transpose(topic_bow_norm)), -1., 1.)
topic_loss_reg = tf.reduce_mean(tf.square(topic_dots - tf.eye(config.n_topic)))
# topic_angles = tf.acos(topic_dots)
# topic_angles_mean = tf.reduce_mean(topic_angles)
# topic_angles_vars = tf.reduce_mean(tf.square(topic_angles - topic_angles_mean))
# topic_loss_reg = tf.exp(topic_angles_vars - topic_angles_mean)

# monitor
n_bow = tf.reduce_sum(t_variables['bow'], 1)
topic_ppls = tf.divide(topic_losses_recon, n_bow)
topics_freq_bow_indices = tf.nn.top_k(topic_bow, 10, name='topic_freq_bow').indices

# %% [markdown]
# ## encoder

# %%
# input
input_token_idxs = t_variables['input_token_idxs']
batch_l = t_variables['batch_l']
sent_l = t_variables['sent_l']
max_sent_l = tf.reduce_max(sent_l)

with tf.variable_scope('sent/enc', reuse=False):
    # get word embedding
    enc_input = tf.nn.embedding_lookup(embeddings, input_token_idxs)

    # get sentence embedding
    _, enc_state = dynamic_bi_rnn(enc_input, sent_l, config.dim_hidden, t_variables['keep_prob'])

    # TODO House Holder flow
    hidden_topic_infer =  tf.layers.Dense(units=config.dim_hidden, activation=tf.nn.relu, name='hidden_topic_infer')(enc_state)
    prob_topic_infer = tf.layers.Dense(units=config.n_topic, activation=tf.nn.softmax, name='prob_topic_infer')(hidden_topic_infer)

    w_mean_topic_infer = tf.get_variable('mean_topic_infer/kernel', [config.n_topic, enc_state.shape[-1], config.dim_latent], dtype=tf.float32)
    b_mean_topic_infer = tf.get_variable('mean_topic_infer/bias', [1, config.n_topic, config.dim_latent], dtype=tf.float32)
    means_topic_infer = tf.tensordot(enc_state, w_mean_topic_infer, axes=[[1], [1]]) + b_mean_topic_infer
    
    w_logvar_topic_infer = tf.get_variable('logvar_topic_infer/kernel', [config.n_topic, enc_state.shape[-1], config.dim_latent], dtype=tf.float32, initializer=tf.constant_initializer(0))
    b_logvar_topic_infer = tf.get_variable('logvar_topic_infer/bias', [1, config.n_topic, config.dim_latent], dtype=tf.float32, initializer=tf.constant_initializer(0))
    logvars_topic_infer = tf.tensordot(enc_state, w_logvar_topic_infer, axes=[[1], [1]]) + b_logvar_topic_infer
    sigma_topic_infer = tf.exp(0.5 * logvars_topic_infer)
    gauss_topic_infer = tfd.Normal(loc=means_topic_infer, scale=sigma_topic_infer)
    
    # latent vectors from each gaussian dist.
    latents_topic_infer = sample_latents(means_topic_infer, logvars_topic_infer) 
    # latent vector from gaussian mixture
    latents_input = tf.matmul(tf.expand_dims(prob_topic_infer, -1), latents_topic_infer, transpose_a=True)
    
    # for beam search
    means_input = tf.matmul(tf.expand_dims(prob_topic_infer, -1), means_topic_infer, transpose_a=True)

# %% [markdown]
# ## decoder

# %%
# prepare for decoding
dec_sent_l = tf.add(sent_l, 1)
dec_input_idxs = t_variables['dec_input_idxs']
dec_input = tf.nn.embedding_lookup(embeddings, dec_input_idxs)

dec_latents_input = tf.tile(latents_input, [1, tf.shape(dec_input)[1], 1])
dec_concat_input = tf.concat([dec_input, dec_latents_input], -1)

# decode for training
with tf.variable_scope('sent/dec/rnn', initializer=tf.contrib.layers.xavier_initializer(), dtype = tf.float32, reuse=False):
    dec_cell = tf.contrib.rnn.GRUCell(config.dim_hidden)
    dec_cell = tf.contrib.rnn.DropoutWrapper(dec_cell, output_keep_prob = t_variables['keep_prob'])

    dec_initial_state = tf.layers.Dense(units=config.dim_hidden, activation=tf.nn.relu, name='init_state')(tf.squeeze(latents_input, 1))
    
    helper = tf.contrib.seq2seq.TrainingHelper(inputs=dec_concat_input, sequence_length=dec_sent_l)

    train_decoder = tf.contrib.seq2seq.BasicDecoder(
        cell=dec_cell,
        helper=helper,
        initial_state=dec_initial_state)

    dec_outputs, _, output_sent_l = tf.contrib.seq2seq.dynamic_decode(train_decoder)
    
    output_layer = tf.layers.Dense(config.n_vocab, use_bias=False, name='out')
    output_logits = output_layer(dec_outputs.rnn_output)
    
    output_token_idxs = tf.argmax(output_logits, 2)

# %%
start_tokens = tf.fill([batch_l], config.BOS_IDX)
end_token = config.EOS_IDX

with tf.variable_scope('sent/dec/rnn', reuse=True):
    infer_dec_initial_state = tf.layers.Dense(units=config.dim_hidden, activation=tf.nn.relu, name='init_state')(tf.squeeze(means_input, 1))
    beam_dec_initial_state = tf.contrib.seq2seq.tile_batch(infer_dec_initial_state, multiplier=config.beam_width)
    beam_latents_input = tf.contrib.seq2seq.tile_batch(tf.squeeze(means_input, 1), multiplier=config.beam_width) # added
    
    beam_decoder = BeamSearchDecoder(
        cell=dec_cell,
        embedding=embeddings,
        start_tokens=start_tokens,
        end_token=end_token,
        initial_state=beam_dec_initial_state,
        beam_width=config.beam_width, 
        output_layer=output_layer,
        length_penalty_weight=config.length_penalty_weight,
        latents_input=beam_latents_input)

    beam_dec_outputs, _, _ = tf.contrib.seq2seq.dynamic_decode(
        beam_decoder,
        maximum_iterations = config.maximum_iterations)

    beam_output_token_idxs = beam_dec_outputs.predicted_ids[:, :, 0]

# %%
with tf.variable_scope('sent/dec/rnn', reuse=True):
    inter_means_input = tf.placeholder(tf.float32, [None, config.dim_latent])
    
    inter_dec_initial_state = tf.layers.Dense(units=config.dim_hidden, activation=tf.nn.relu, name='init_state')(inter_means_input)
    inter_beam_dec_initial_state = tf.contrib.seq2seq.tile_batch(inter_dec_initial_state, multiplier=config.beam_width)
    inter_beam_latents_input = tf.contrib.seq2seq.tile_batch(inter_means_input, multiplier=config.beam_width) # added
    
    inter_beam_decoder = BeamSearchDecoder(
        cell=dec_cell,
        embedding=embeddings,
        start_tokens=start_tokens,
        end_token=end_token,
        initial_state=inter_beam_dec_initial_state,
        beam_width=config.beam_width, 
        output_layer=output_layer,
        length_penalty_weight=config.length_penalty_weight,
        latents_input=inter_beam_latents_input)

    inter_beam_dec_outputs, _, _ = tf.contrib.seq2seq.dynamic_decode(
        inter_beam_decoder,
        maximum_iterations = config.maximum_iterations)

    inter_beam_output_token_idxs = inter_beam_dec_outputs.predicted_ids[:, :, 0]

# %%
with tf.variable_scope('sent/dec/rnn', reuse=True):
    topic_dec_initial_state = tf.layers.Dense(units=config.dim_hidden, activation=tf.nn.relu, name='init_state')(means_topic)
    topic_beam_dec_initial_state = tf.contrib.seq2seq.tile_batch(topic_dec_initial_state, multiplier=config.beam_width)
    topic_beam_latents_input = tf.contrib.seq2seq.tile_batch(means_topic, multiplier=config.beam_width) # added
    
    topic_beam_decoder = BeamSearchDecoder(
        cell=dec_cell,
        embedding=embeddings,
        start_tokens=start_tokens,
        end_token=end_token,
        initial_state=topic_beam_dec_initial_state,
        beam_width=config.beam_width, 
        output_layer=output_layer,
        length_penalty_weight=config.length_penalty_weight,
        latents_input=topic_beam_latents_input)

    topic_beam_dec_outputs, _, _ = tf.contrib.seq2seq.dynamic_decode(
        topic_beam_decoder,
        maximum_iterations = config.maximum_iterations)

    topic_beam_output_token_idxs = topic_beam_dec_outputs.predicted_ids[:, :, 0]

# %% [markdown]
# ## language modeling cost

# %%
# target and mask
dec_target_idxs = t_variables['dec_target_idxs']
dec_mask_tokens = tf.sequence_mask(dec_sent_l, maxlen=max_sent_l+1, dtype=tf.float32)

# nll for each token (averaged over batch & sentence)
sent_loss_recon = tf.contrib.seq2seq.sequence_loss(output_logits, dec_target_idxs, dec_mask_tokens)

# %%
doc_l = t_variables['doc_l']
mask_sents = tf.sequence_mask(doc_l)
mask_sents_flatten = tf.reshape(mask_sents, [tf.shape(mask_sents)[0]*tf.shape(mask_sents)[1]])

prob_topic_tiled = tf.tile(tf.expand_dims(prob_topic, 1), [1, tf.shape(mask_sents)[1], 1])
prob_topic_flatten = tf.reshape(prob_topic_tiled, [tf.shape(mask_sents)[0]*tf.shape(mask_sents)[1], config.n_topic])
prob_topic_sents = tf.boolean_mask(prob_topic_flatten, mask_sents_flatten)

# %%
# inferred mixture probabilities (computed for each sentence)
categ_topic_infer = tfd.Categorical(probs=prob_topic_infer)

# prior of mixture probabilities (computed for each document, tiled for each sentence)
categ_topic = tfd.Categorical(probs=prob_topic_sents)

sent_loss_kl_categ = tf.reduce_mean(tfd.kl_divergence(categ_topic_infer, categ_topic))

# inference of each gaussian gaussribution (computed for each sentence)

sent_loss_kl_gauss = tf.reduce_sum(tfd.kl_divergence(gauss_topic_infer, gauss_topic), -1)
sent_loss_kl_gmm = tf.reduce_mean(tf.reduce_sum(tf.multiply(prob_topic_infer, sent_loss_kl_gauss), -1))

sent_loss_kl = sent_loss_kl_categ + sent_loss_kl_gmm

# %% [markdown]
# ## optimizer

# %%
beta = tf.Variable(config.beta, name='beta', trainable=False) if config.warmup > 0 else tf.constant(1., name='beta')
update_beta = tf.assign_add(beta, 1./(config.warmup*len(train_batches)))
sent_loss = sent_loss_recon + beta * sent_loss_kl

topic_loss = topic_loss_recon + topic_loss_kl + config.reg * topic_loss_reg
loss = topic_loss + sent_loss

# define optimizer
if config.opt == 'Adam':
    optimizer = tf.train.AdamOptimizer(config.lr)
elif config.opt == 'Adagrad':
    optimizer = tf.train.AdagradOptimizer(config.lr)
    
grad_vars = optimizer.compute_gradients(loss)
clipped_grad_vars = [(tf.clip_by_value(grad, -config.grad_clip, config.grad_clip), var) for grad, var in grad_vars]

opt = optimizer.apply_gradients(clipped_grad_vars)
# Out:
# /home/m-isonuma/.pyenv/versions/anaconda2-5.3.0/envs/py36/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %% [markdown]
# # run model

# %%
def idxs_to_sents(token_idxs, config, idx_to_word):
    sents = []
    for sent_idxs in token_idxs:
        tokens = []
        for idx in sent_idxs:
            if idx == config.EOS_IDX: break
            tokens.append(idx_to_word[idx])
        sent = ' '.join(tokens)
        sents.append(sent)
    return sents

# %%
def get_loss(sess, batches):
    losses = []
    ppl_list = []
    for ct, batch in batches:
        feed_dict = get_feed_dict(batch, mode='test')
        loss_batch, topic_loss_batch, sent_loss_batch, ppls_batch = sess.run([loss, topic_loss, sent_loss, topic_ppls], feed_dict = feed_dict)
        losses += [[loss_batch, topic_loss_batch, sent_loss_batch]]
        ppl_list += list(ppls_batch)
    loss_mean, topic_loss_mean, sent_loss_mean = np.mean(losses, 0)
    ppl_mean = np.exp(np.mean(ppl_list))
    return loss_mean, topic_loss_mean, sent_loss_mean, ppl_mean

def get_all_losses(sess, batches):
    losses = []
    for ct, batch in batches:
        feed_dict = get_feed_dict(batch, mode='test')
        loss_batch, topic_loss_recon_batch, topic_loss_kl_batch, sent_loss_recon_batch, sent_loss_kl_batch = \
        sess.run([loss, topic_loss_recon, topic_loss_kl, sent_loss_recon, sent_loss_kl], feed_dict = feed_dict)
        losses += [[loss_batch, topic_loss_recon_batch, topic_loss_kl_batch, sent_loss_recon_batch, sent_loss_kl_batch]]
    print('LOSS %.2f | TM NLL: %.2f, KL: %.4f | LM NLL: %.2f, KL: %.4f' %  np.mean(losses, 0))

# %%
def print_sample(sample_batch):
    feed_dict = get_feed_dict(sample_batch)
    pred_token_idxs = sess.run(output_token_idxs, feed_dict = feed_dict)
    true_token_idxs = [sent_idxs for instance in sample_batch for sent_idxs in instance.token_idxs]
    
    assert len(pred_token_idxs) == len(true_token_idxs)
    
    pred_sents = idxs_to_sents(pred_token_idxs, config, idx_to_word)
    true_sents = idxs_to_sents(true_token_idxs, config, idx_to_word)
    
    for i, (true_sent, pred_sent) in enumerate(zip(true_sents, pred_sents)):        
        print(i, 'True: %s' % true_sent)
        print(i, 'Pred: %s' % pred_sent)

def print_topic_sample():
    pred_topics_freq_bow_indices, pred_topic_token_idxs = sess.run([topics_freq_bow_indices, topic_beam_output_token_idxs], 
                                                                                                           feed_dict={t_variables['batch_l']: config.n_topic, t_variables['keep_prob']: 1.,})
    pred_topic_sents = idxs_to_sents(pred_topic_token_idxs, config, idx_to_word)
    
    topics_freq_bow_idxs = bow_idxs[pred_topics_freq_bow_indices]
    
    print('-----------Topic Samples-----------')
    for i, (topic_freq_bow_idxs, pred_topic_sent) in enumerate(zip(topics_freq_bow_idxs, pred_topic_sents)):
        print(i, ' bow:', ' '.join([idx_to_word[idx] for idx in topic_freq_bow_idxs]))
        print(i, ' sent:', pred_topic_sent)

# %%
if 'sess' in globals(): sess.close()
sess = tf.Session()
sess.run(tf.global_variables_initializer())

logs = []
losses_train = []
ppls_train = []
loss_min = np.inf
beta_eval = 1.
epoch = 0
train_batches = get_batches(instances_train, config.batch_size, iterator=True)
saver = tf.train.Saver(max_to_keep=10)

# %%
if len(logs) == 0:
    cmd_rm = 'rm -r %s' % config.modeldir
    res = subprocess.call(cmd_rm.split())

    cmd_mk = 'mkdir %s' % config.modeldir
    res = subprocess.call(cmd_mk.split())

time_start = time.time()
while epoch < config.epochs:
    for ct, batch in train_batches:
        feed_dict = get_feed_dict(batch)
        if config.warmup > 0 and beta_eval < 1.0: sess.run(update_beta)

        _, loss_batch, topic_loss_recon_batch, topic_loss_kl_batch, topic_loss_reg_batch, sent_loss_recon_batch, sent_loss_kl_batch, sent_loss_kl_categ_batch, sent_loss_kl_gmm_batch, ppls_batch = \
        sess.run([opt, loss, topic_loss_recon, topic_loss_kl, topic_loss_reg, sent_loss_recon, sent_loss_kl, sent_loss_kl_categ, sent_loss_kl_gmm, topic_ppls], feed_dict = feed_dict)
        
        if sent_loss_kl_batch == np.inf:
            print('Nan occured')
#             pdb.set_trace()
            ckpt = tf.train.get_checkpoint_state(config.modeldir)
            model_checkpoint_path = ckpt.all_model_checkpoint_paths[-1]
            saver.restore(sess, model_checkpoint_path)            
            break
            
        losses_train += [[loss_batch, topic_loss_recon_batch, topic_loss_kl_batch, topic_loss_reg_batch, sent_loss_recon_batch, sent_loss_kl_batch]]
        ppls_train += list(ppls_batch)

        if ct%config.log_period==0:
            time_dev = time.time()
            loss_train, topic_loss_recon_train, topic_loss_kl_train, topic_loss_reg_train, sent_loss_recon_train, sent_loss_kl_train = np.mean(losses_train, 0)
            ppl_train = np.exp(np.mean(ppls_train))
            loss_dev, topic_loss_dev, sent_loss_dev, ppl_dev = get_loss(sess, dev_batches)
            
            if loss_dev < loss_min:
                loss_min = loss_dev
                saver.save(sess, config.modelpath, global_step=epoch*10000+ct)

            if config.warmup > 0: beta_eval = beta.eval(session=sess)

            clear_output()
            time_finish = time.time()
            time_log = int(time_finish - time_start)
            time_log_dev = int(time_finish - time_dev)
            logs += [(time_log, time_log_dev, epoch, ct, loss_train, ppl_train, topic_loss_recon_train, topic_loss_kl_train, topic_loss_reg_train, sent_loss_recon_train, sent_loss_kl_train, loss_dev, ppl_dev, topic_loss_dev, sent_loss_dev, beta_eval)]
            for log in logs:
                print('%03d[s], %02d[s], Ep: %02d, Ct: %05d|TR LOSS: %.0f, PPL: %.0f|TM NLL: %.0f, KL: %.2f, REG:%.2f | LM NLL: %.2f, KL: %.2f|DE LOSS: %.0f, PPL: %.0f, TM: %.0f, LM: %.2f|BETA: %.6f' %  log)

            print_sample(batch)

            time_start = time.time()
            
            print_topic_sample()
                
    epoch += 1
    train_batches = get_batches(instances_train, config.batch_size, iterator=True)
# Out:
# 053[s], 51[s], Ep: 00, Ct: 00000|TR LOSS: 325, PPL: 2661|TM NLL: 314, KL: 0.52, REG:0.00 | LM NLL: 10.34, KL: 1.26|DE LOSS: 347, PPL: 2659, TM: 337, LM: 10.34|BETA: 0.001000
# 106[s], 30[s], Ep: 00, Ct: 00500|TR LOSS: 335, PPL: 1973|TM NLL: 327, KL: 0.63, REG:0.06 | LM NLL: 7.43, KL: 14.76|DE LOSS: 324, PPL: 1705, TM: 318, LM: 6.81|BETA: 0.001035
# 105[s], 30[s], Ep: 00, Ct: 01000|TR LOSS: 331, PPL: 1817|TM NLL: 324, KL: 0.35, REG:0.03 | LM NLL: 7.13, KL: 13.55|DE LOSS: 323, PPL: 1647, TM: 316, LM: 6.82|BETA: 0.001069
# 106[s], 31[s], Ep: 00, Ct: 01500|TR LOSS: 330, PPL: 1761|TM NLL: 322, KL: 0.24, REG:0.02 | LM NLL: 7.01, KL: 12.88|DE LOSS: 322, PPL: 1636, TM: 316, LM: 6.67|BETA: 0.001104
# 109[s], 32[s], Ep: 00, Ct: 02000|TR LOSS: 329, PPL: 1729|TM NLL: 322, KL: 0.18, REG:0.02 | LM NLL: 6.94, KL: 12.47|DE LOSS: 322, PPL: 1631, TM: 315, LM: 6.75|BETA: 0.001139
# 106[s], 30[s], Ep: 00, Ct: 02500|TR LOSS: 328, PPL: 1710|TM NLL: 321, KL: 0.14, REG:0.01 | LM NLL: 6.90, KL: 12.24|DE LOSS: 322, PPL: 1629, TM: 315, LM: 6.63|BETA: 0.001173
# 088[s], 30[s], Ep: 01, Ct: 00000|TR LOSS: 328, PPL: 1701|TM NLL: 321, KL: 0.13, REG:0.01 | LM NLL: 6.87, KL: 12.14|DE LOSS: 322, PPL: 1629, TM: 315, LM: 6.61|BETA: 0.001200
# 084[s], 08[s], Ep: 01, Ct: 00500|TR LOSS: 328, PPL: 1690|TM NLL: 321, KL: 0.11, REG:0.01 | LM NLL: 6.84, KL: 12.05|DE LOSS: 322, PPL: 1630, TM: 315, LM: 6.63|BETA: 0.001235
# 106[s], 30[s], Ep: 01, Ct: 01000|TR LOSS: 328, PPL: 1683|TM NLL: 321, KL: 0.09, REG:0.01 | LM NLL: 6.82, KL: 11.99|DE LOSS: 322, PPL: 1629, TM: 315, LM: 6.60|BETA: 0.001269
# 109[s], 32[s], Ep: 01, Ct: 01500|TR LOSS: 327, PPL: 1678|TM NLL: 321, KL: 0.08, REG:0.01 | LM NLL: 6.80, KL: 11.95|DE LOSS: 322, PPL: 1629, TM: 315, LM: 6.57|BETA: 0.001304
# 109[s], 32[s], Ep: 01, Ct: 02000|TR LOSS: 327, PPL: 1674|TM NLL: 320, KL: 0.07, REG:0.01 | LM NLL: 6.78, KL: 12.11|DE LOSS: 322, PPL: 1628, TM: 315, LM: 6.49|BETA: 0.001339
# 084[s], 08[s], Ep: 01, Ct: 02500|TR LOSS: 327, PPL: 1670|TM NLL: 320, KL: 0.07, REG:0.01 | LM NLL: 6.76, KL: 12.44|DE LOSS: 322, PPL: 1628, TM: 315, LM: 6.54|BETA: 0.001374
# 090[s], 31[s], Ep: 02, Ct: 00000|TR LOSS: 327, PPL: 1668|TM NLL: 320, KL: 0.07, REG:0.01 | LM NLL: 6.74, KL: 12.70|DE LOSS: 322, PPL: 1627, TM: 315, LM: 6.38|BETA: 0.001400
# 130[s], 53[s], Ep: 02, Ct: 00500|TR LOSS: 327, PPL: 1665|TM NLL: 320, KL: 0.06, REG:0.01 | LM NLL: 6.71, KL: 13.03|DE LOSS: 322, PPL: 1628, TM: 315, LM: 6.32|BETA: 0.001435
# 129[s], 52[s], Ep: 02, Ct: 01000|TR LOSS: 327, PPL: 1662|TM NLL: 320, KL: 0.06, REG:0.01 | LM NLL: 6.68, KL: 13.36|DE LOSS: 322, PPL: 1628, TM: 315, LM: 6.22|BETA: 0.001470
# 106[s], 30[s], Ep: 02, Ct: 01500|TR LOSS: 327, PPL: 1661|TM NLL: 320, KL: 0.05, REG:0.01 | LM NLL: 6.65, KL: 13.70|DE LOSS: 321, PPL: 1629, TM: 315, LM: 6.15|BETA: 0.001504
# 107[s], 31[s], Ep: 02, Ct: 02000|TR LOSS: 327, PPL: 1659|TM NLL: 320, KL: 0.05, REG:0.00 | LM NLL: 6.62, KL: 14.04|DE LOSS: 321, PPL: 1628, TM: 315, LM: 6.11|BETA: 0.001539
# 106[s], 30[s], Ep: 02, Ct: 02500|TR LOSS: 327, PPL: 1658|TM NLL: 320, KL: 0.05, REG:0.00 | LM NLL: 6.59, KL: 14.33|DE LOSS: 321, PPL: 1628, TM: 315, LM: 6.09|BETA: 0.001574
# 089[s], 30[s], Ep: 03, Ct: 00000|TR LOSS: 327, PPL: 1657|TM NLL: 320, KL: 0.04, REG:0.00 | LM NLL: 6.57, KL: 14.56|DE LOSS: 321, PPL: 1627, TM: 315, LM: 5.99|BETA: 0.001600
# 106[s], 30[s], Ep: 03, Ct: 00500|TR LOSS: 326, PPL: 1655|TM NLL: 320, KL: 0.04, REG:0.00 | LM NLL: 6.53, KL: 14.92|DE LOSS: 321, PPL: 1628, TM: 315, LM: 5.94|BETA: 0.001635
# 107[s], 30[s], Ep: 03, Ct: 01000|TR LOSS: 326, PPL: 1654|TM NLL: 320, KL: 0.04, REG:0.00 | LM NLL: 6.50, KL: 15.30|DE LOSS: 321, PPL: 1628, TM: 315, LM: 5.85|BETA: 0.001670
# 112[s], 35[s], Ep: 03, Ct: 01500|TR LOSS: 326, PPL: 1653|TM NLL: 320, KL: 0.04, REG:0.00 | LM NLL: 6.47, KL: 15.75|DE LOSS: 321, PPL: 1628, TM: 315, LM: 5.80|BETA: 0.001704
# 124[s], 47[s], Ep: 03, Ct: 02000|TR LOSS: 326, PPL: 1652|TM NLL: 320, KL: 0.04, REG:0.00 | LM NLL: 6.44, KL: 16.26|DE LOSS: 321, PPL: 1627, TM: 315, LM: 5.75|BETA: 0.001739
# 117[s], 42[s], Ep: 03, Ct: 02500|TR LOSS: 326, PPL: 1651|TM NLL: 320, KL: 0.03, REG:0.00 | LM NLL: 6.40, KL: 16.80|DE LOSS: 321, PPL: 1628, TM: 315, LM: 5.71|BETA: 0.001774
# 087[s], 29[s], Ep: 04, Ct: 00000|TR LOSS: 326, PPL: 1651|TM NLL: 320, KL: 0.03, REG:0.00 | LM NLL: 6.38, KL: 17.22|DE LOSS: 321, PPL: 1627, TM: 315, LM: 5.55|BETA: 0.001800
# 108[s], 32[s], Ep: 04, Ct: 00500|TR LOSS: 326, PPL: 1650|TM NLL: 320, KL: 0.03, REG:0.00 | LM NLL: 6.35, KL: 17.77|DE LOSS: 321, PPL: 1628, TM: 315, LM: 5.51|BETA: 0.001835
# 132[s], 57[s], Ep: 04, Ct: 01000|TR LOSS: 326, PPL: 1649|TM NLL: 320, KL: 0.03, REG:0.00 | LM NLL: 6.31, KL: 18.33|DE LOSS: 321, PPL: 1628, TM: 315, LM: 5.46|BETA: 0.001870
# 130[s], 55[s], Ep: 04, Ct: 01500|TR LOSS: 326, PPL: 1648|TM NLL: 320, KL: 0.03, REG:0.00 | LM NLL: 6.28, KL: 18.90|DE LOSS: 321, PPL: 1628, TM: 315, LM: 5.37|BETA: 0.001904
# 105[s], 29[s], Ep: 04, Ct: 02000|TR LOSS: 326, PPL: 1648|TM NLL: 320, KL: 0.03, REG:0.00 | LM NLL: 6.25, KL: 19.50|DE LOSS: 321, PPL: 1627, TM: 315, LM: 5.34|BETA: 0.001939
# 083[s], 08[s], Ep: 04, Ct: 02500|TR LOSS: 326, PPL: 1648|TM NLL: 320, KL: 0.03, REG:0.00 | LM NLL: 6.21, KL: 20.10|DE LOSS: 321, PPL: 1627, TM: 315, LM: 5.38|BETA: 0.001974
# 107[s], 49[s], Ep: 05, Ct: 00000|TR LOSS: 326, PPL: 1648|TM NLL: 320, KL: 0.03, REG:0.00 | LM NLL: 6.19, KL: 20.56|DE LOSS: 320, PPL: 1628, TM: 315, LM: 5.21|BETA: 0.002001
# 083[s], 08[s], Ep: 05, Ct: 00500|TR LOSS: 326, PPL: 1647|TM NLL: 320, KL: 0.03, REG:0.00 | LM NLL: 6.16, KL: 21.18|DE LOSS: 320, PPL: 1628, TM: 315, LM: 5.21|BETA: 0.002035
# 116[s], 41[s], Ep: 05, Ct: 01000|TR LOSS: 326, PPL: 1647|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 6.12, KL: 21.80|DE LOSS: 320, PPL: 1628, TM: 315, LM: 5.21|BETA: 0.002070
# 130[s], 56[s], Ep: 05, Ct: 01500|TR LOSS: 326, PPL: 1646|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 6.09, KL: 22.41|DE LOSS: 320, PPL: 1628, TM: 315, LM: 5.06|BETA: 0.002105
# 125[s], 49[s], Ep: 05, Ct: 02000|TR LOSS: 326, PPL: 1646|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 6.06, KL: 23.02|DE LOSS: 320, PPL: 1627, TM: 315, LM: 5.02|BETA: 0.002139
# 151[s], 76[s], Ep: 05, Ct: 02500|TR LOSS: 326, PPL: 1646|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 6.03, KL: 23.61|DE LOSS: 320, PPL: 1627, TM: 315, LM: 4.94|BETA: 0.002174
# 103[s], 46[s], Ep: 06, Ct: 00000|TR LOSS: 326, PPL: 1645|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 6.01, KL: 24.05|DE LOSS: 320, PPL: 1628, TM: 315, LM: 4.93|BETA: 0.002201
# 105[s], 30[s], Ep: 06, Ct: 00500|TR LOSS: 326, PPL: 1645|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.98, KL: 24.63|DE LOSS: 320, PPL: 1628, TM: 315, LM: 4.88|BETA: 0.002235
# 105[s], 29[s], Ep: 06, Ct: 01000|TR LOSS: 326, PPL: 1644|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.95, KL: 25.21|DE LOSS: 320, PPL: 1628, TM: 315, LM: 4.88|BETA: 0.002270
# 105[s], 30[s], Ep: 06, Ct: 01500|TR LOSS: 326, PPL: 1644|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.92, KL: 25.76|DE LOSS: 320, PPL: 1628, TM: 315, LM: 4.78|BETA: 0.002305
# 083[s], 08[s], Ep: 06, Ct: 02000|TR LOSS: 326, PPL: 1644|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.89, KL: 26.26|DE LOSS: 320, PPL: 1628, TM: 315, LM: 4.85|BETA: 0.002339
# 130[s], 55[s], Ep: 06, Ct: 02500|TR LOSS: 326, PPL: 1644|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.86, KL: 26.68|DE LOSS: 320, PPL: 1628, TM: 315, LM: 4.71|BETA: 0.002374
# 088[s], 30[s], Ep: 07, Ct: 00000|TR LOSS: 326, PPL: 1644|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.83, KL: 26.96|DE LOSS: 320, PPL: 1627, TM: 315, LM: 4.68|BETA: 0.002401
# 105[s], 29[s], Ep: 07, Ct: 00500|TR LOSS: 325, PPL: 1643|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.81, KL: 27.28|DE LOSS: 320, PPL: 1628, TM: 315, LM: 4.60|BETA: 0.002435
# 106[s], 30[s], Ep: 07, Ct: 01000|TR LOSS: 325, PPL: 1643|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.78, KL: 27.57|DE LOSS: 320, PPL: 1627, TM: 315, LM: 4.57|BETA: 0.002470
# 104[s], 30[s], Ep: 07, Ct: 01500|TR LOSS: 325, PPL: 1643|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.75, KL: 27.83|DE LOSS: 320, PPL: 1628, TM: 315, LM: 4.53|BETA: 0.002505
# 083[s], 08[s], Ep: 07, Ct: 02000|TR LOSS: 325, PPL: 1643|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.72, KL: 28.06|DE LOSS: 320, PPL: 1627, TM: 315, LM: 4.61|BETA: 0.002539
# 105[s], 30[s], Ep: 07, Ct: 02500|TR LOSS: 325, PPL: 1642|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.69, KL: 28.27|DE LOSS: 320, PPL: 1627, TM: 315, LM: 4.49|BETA: 0.002574
# 087[s], 29[s], Ep: 08, Ct: 00000|TR LOSS: 325, PPL: 1642|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.67, KL: 28.42|DE LOSS: 320, PPL: 1627, TM: 315, LM: 4.38|BETA: 0.002601
# 083[s], 08[s], Ep: 08, Ct: 00500|TR LOSS: 325, PPL: 1642|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.64, KL: 28.60|DE LOSS: 320, PPL: 1627, TM: 315, LM: 4.45|BETA: 0.002636
# 083[s], 08[s], Ep: 08, Ct: 01000|TR LOSS: 325, PPL: 1642|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.62, KL: 28.76|DE LOSS: 320, PPL: 1627, TM: 315, LM: 4.41|BETA: 0.002670
# 083[s], 08[s], Ep: 08, Ct: 01500|TR LOSS: 325, PPL: 1642|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.59, KL: 28.90|DE LOSS: 320, PPL: 1627, TM: 315, LM: 4.47|BETA: 0.002705
# 105[s], 30[s], Ep: 08, Ct: 02000|TR LOSS: 325, PPL: 1642|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.56, KL: 29.03|DE LOSS: 320, PPL: 1627, TM: 315, LM: 4.28|BETA: 0.002740
# 085[s], 08[s], Ep: 08, Ct: 02500|TR LOSS: 325, PPL: 1641|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.54, KL: 29.14|DE LOSS: 320, PPL: 1627, TM: 315, LM: 4.28|BETA: 0.002774
# 089[s], 31[s], Ep: 09, Ct: 00000|TR LOSS: 325, PPL: 1641|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.52, KL: 29.21|DE LOSS: 319, PPL: 1627, TM: 315, LM: 4.17|BETA: 0.002801
# 105[s], 29[s], Ep: 09, Ct: 00500|TR LOSS: 325, PPL: 1641|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.49, KL: 29.31|DE LOSS: 319, PPL: 1627, TM: 315, LM: 4.17|BETA: 0.002836
# 123[s], 48[s], Ep: 09, Ct: 01000|TR LOSS: 325, PPL: 1641|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.47, KL: 29.39|DE LOSS: 319, PPL: 1627, TM: 315, LM: 4.16|BETA: 0.002870
# 105[s], 29[s], Ep: 09, Ct: 01500|TR LOSS: 325, PPL: 1641|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.44, KL: 29.47|DE LOSS: 319, PPL: 1627, TM: 315, LM: 4.07|BETA: 0.002905
# 106[s], 31[s], Ep: 09, Ct: 02000|TR LOSS: 325, PPL: 1641|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.42, KL: 29.53|DE LOSS: 319, PPL: 1626, TM: 315, LM: 4.03|BETA: 0.002940
# 082[s], 08[s], Ep: 09, Ct: 02500|TR LOSS: 325, PPL: 1640|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.39, KL: 29.60|DE LOSS: 319, PPL: 1627, TM: 315, LM: 4.05|BETA: 0.002974
# 066[s], 07[s], Ep: 10, Ct: 00000|TR LOSS: 325, PPL: 1640|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.38, KL: 29.64|DE LOSS: 319, PPL: 1626, TM: 315, LM: 4.13|BETA: 0.003001
# 083[s], 08[s], Ep: 10, Ct: 00500|TR LOSS: 325, PPL: 1640|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.35, KL: 29.69|DE LOSS: 319, PPL: 1626, TM: 315, LM: 4.14|BETA: 0.003036
# 082[s], 08[s], Ep: 10, Ct: 01000|TR LOSS: 325, PPL: 1640|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.33, KL: 29.73|DE LOSS: 319, PPL: 1627, TM: 315, LM: 4.10|BETA: 0.003070
# 106[s], 31[s], Ep: 10, Ct: 01500|TR LOSS: 325, PPL: 1640|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.30, KL: 29.77|DE LOSS: 319, PPL: 1625, TM: 315, LM: 3.90|BETA: 0.003105
# 083[s], 08[s], Ep: 10, Ct: 02000|TR LOSS: 325, PPL: 1640|TM NLL: 319, KL: 0.02, REG:0.00 | LM NLL: 5.28, KL: 29.80|DE LOSS: 319, PPL: 1624, TM: 315, LM: 3.97|BETA: 0.003140
# 128[s], 53[s], Ep: 10, Ct: 02500|TR LOSS: 325, PPL: 1640|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.26, KL: 29.82|DE LOSS: 319, PPL: 1623, TM: 315, LM: 3.86|BETA: 0.003174
# 065[s], 08[s], Ep: 11, Ct: 00000|TR LOSS: 325, PPL: 1639|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.24, KL: 29.83|DE LOSS: 319, PPL: 1624, TM: 315, LM: 3.91|BETA: 0.003201
# 116[s], 40[s], Ep: 11, Ct: 00500|TR LOSS: 325, PPL: 1639|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.22, KL: 29.85|DE LOSS: 319, PPL: 1624, TM: 315, LM: 3.83|BETA: 0.003236
# 084[s], 08[s], Ep: 11, Ct: 01000|TR LOSS: 325, PPL: 1639|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.20, KL: 29.86|DE LOSS: 319, PPL: 1623, TM: 315, LM: 3.91|BETA: 0.003271
# 105[s], 29[s], Ep: 11, Ct: 01500|TR LOSS: 325, PPL: 1639|TM NLL: 320, KL: 0.02, REG:0.00 | LM NLL: 5.18, KL: 29.86|DE LOSS: 319, PPL: 1624, TM: 315, LM: 3.78|BETA: 0.003305
# 105[s], 30[s], Ep: 11, Ct: 02000|TR LOSS: 325, PPL: 1639|TM NLL: 319, KL: 0.02, REG:0.00 | LM NLL: 5.16, KL: 29.86|DE LOSS: 319, PPL: 1622, TM: 315, LM: 3.77|BETA: 0.003340
# 106[s], 31[s], Ep: 11, Ct: 02500|TR LOSS: 325, PPL: 1639|TM NLL: 320, KL: 0.03, REG:0.00 | LM NLL: 5.14, KL: 29.86|DE LOSS: 319, PPL: 1617, TM: 315, LM: 3.80|BETA: 0.003375
# 089[s], 31[s], Ep: 12, Ct: 00000|TR LOSS: 325, PPL: 1638|TM NLL: 319, KL: 0.03, REG:0.00 | LM NLL: 5.12, KL: 29.85|DE LOSS: 319, PPL: 1615, TM: 315, LM: 3.74|BETA: 0.003401
# 105[s], 30[s], Ep: 12, Ct: 00500|TR LOSS: 325, PPL: 1638|TM NLL: 319, KL: 0.03, REG:0.00 | LM NLL: 5.10, KL: 29.85|DE LOSS: 319, PPL: 1613, TM: 315, LM: 3.71|BETA: 0.003436
# 139[s], 65[s], Ep: 12, Ct: 01000|TR LOSS: 325, PPL: 1638|TM NLL: 320, KL: 0.03, REG:0.00 | LM NLL: 5.08, KL: 29.83|DE LOSS: 319, PPL: 1612, TM: 315, LM: 3.71|BETA: 0.003471
# 124[s], 49[s], Ep: 12, Ct: 01500|TR LOSS: 325, PPL: 1638|TM NLL: 320, KL: 0.04, REG:0.00 | LM NLL: 5.06, KL: 29.82|DE LOSS: 319, PPL: 1604, TM: 315, LM: 3.69|BETA: 0.003505
# 105[s], 30[s], Ep: 12, Ct: 02000|TR LOSS: 325, PPL: 1637|TM NLL: 319, KL: 0.04, REG:0.00 | LM NLL: 5.04, KL: 29.80|DE LOSS: 319, PPL: 1594, TM: 315, LM: 3.67|BETA: 0.003540
# 082[s], 08[s], Ep: 12, Ct: 02500|TR LOSS: 325, PPL: 1637|TM NLL: 319, KL: 0.05, REG:0.00 | LM NLL: 5.03, KL: 29.77|DE LOSS: 319, PPL: 1589, TM: 315, LM: 3.92|BETA: 0.003575
# 114[s], 57[s], Ep: 13, Ct: 00000|TR LOSS: 325, PPL: 1636|TM NLL: 319, KL: 0.05, REG:0.00 | LM NLL: 5.01, KL: 29.75|DE LOSS: 318, PPL: 1579, TM: 315, LM: 3.66|BETA: 0.003601
# 105[s], 29[s], Ep: 13, Ct: 00500|TR LOSS: 325, PPL: 1635|TM NLL: 319, KL: 0.06, REG:0.00 | LM NLL: 4.99, KL: 29.72|DE LOSS: 318, PPL: 1558, TM: 314, LM: 3.81|BETA: 0.003636
# 106[s], 31[s], Ep: 13, Ct: 01000|TR LOSS: 325, PPL: 1635|TM NLL: 319, KL: 0.07, REG:0.00 | LM NLL: 4.97, KL: 29.69|DE LOSS: 317, PPL: 1545, TM: 314, LM: 3.63|BETA: 0.003671
# 105[s], 29[s], Ep: 13, Ct: 01500|TR LOSS: 324, PPL: 1633|TM NLL: 319, KL: 0.08, REG:0.00 | LM NLL: 4.96, KL: 29.66|DE LOSS: 317, PPL: 1523, TM: 313, LM: 3.62|BETA: 0.003705
# 106[s], 31[s], Ep: 13, Ct: 02000|TR LOSS: 324, PPL: 1632|TM NLL: 319, KL: 0.09, REG:0.00 | LM NLL: 4.94, KL: 29.63|DE LOSS: 317, PPL: 1511, TM: 313, LM: 3.68|BETA: 0.003740
# 105[s], 30[s], Ep: 13, Ct: 02500|TR LOSS: 324, PPL: 1630|TM NLL: 319, KL: 0.10, REG:0.00 | LM NLL: 4.92, KL: 29.60|DE LOSS: 316, PPL: 1498, TM: 313, LM: 3.58|BETA: 0.003775
# 087[s], 30[s], Ep: 14, Ct: 00000|TR LOSS: 324, PPL: 1629|TM NLL: 319, KL: 0.10, REG:0.00 | LM NLL: 4.91, KL: 29.57|DE LOSS: 316, PPL: 1480, TM: 312, LM: 3.58|BETA: 0.003801
# 108[s], 32[s], Ep: 14, Ct: 00500|TR LOSS: 324, PPL: 1627|TM NLL: 319, KL: 0.12, REG:0.00 | LM NLL: 4.89, KL: 29.54|DE LOSS: 315, PPL: 1464, TM: 312, LM: 3.57|BETA: 0.003836
# 124[s], 47[s], Ep: 14, Ct: 01000|TR LOSS: 324, PPL: 1625|TM NLL: 319, KL: 0.13, REG:0.00 | LM NLL: 4.88, KL: 29.51|DE LOSS: 315, PPL: 1454, TM: 311, LM: 3.59|BETA: 0.003871
# 106[s], 30[s], Ep: 14, Ct: 01500|TR LOSS: 324, PPL: 1623|TM NLL: 319, KL: 0.14, REG:0.00 | LM NLL: 4.86, KL: 29.47|DE LOSS: 315, PPL: 1442, TM: 311, LM: 3.60|BETA: 0.003906
# 120[s], 44[s], Ep: 14, Ct: 02000|TR LOSS: 324, PPL: 1620|TM NLL: 319, KL: 0.15, REG:0.00 | LM NLL: 4.84, KL: 29.43|DE LOSS: 314, PPL: 1434, TM: 311, LM: 3.53|BETA: 0.003940
# 106[s], 30[s], Ep: 14, Ct: 02500|TR LOSS: 324, PPL: 1618|TM NLL: 319, KL: 0.16, REG:0.00 | LM NLL: 4.83, KL: 29.39|DE LOSS: 314, PPL: 1430, TM: 311, LM: 3.64|BETA: 0.003975
# 088[s], 29[s], Ep: 15, Ct: 00000|TR LOSS: 324, PPL: 1616|TM NLL: 319, KL: 0.17, REG:0.00 | LM NLL: 4.82, KL: 29.36|DE LOSS: 314, PPL: 1421, TM: 310, LM: 3.55|BETA: 0.004002
# 121[s], 45[s], Ep: 15, Ct: 00500|TR LOSS: 324, PPL: 1614|TM NLL: 319, KL: 0.18, REG:0.00 | LM NLL: 4.80, KL: 29.32|DE LOSS: 314, PPL: 1413, TM: 310, LM: 3.54|BETA: 0.004036
# 152[s], 76[s], Ep: 15, Ct: 01000|TR LOSS: 324, PPL: 1612|TM NLL: 319, KL: 0.19, REG:0.00 | LM NLL: 4.79, KL: 29.29|DE LOSS: 314, PPL: 1408, TM: 310, LM: 3.51|BETA: 0.004071
# 109[s], 33[s], Ep: 15, Ct: 01500|TR LOSS: 324, PPL: 1609|TM NLL: 319, KL: 0.20, REG:0.00 | LM NLL: 4.77, KL: 29.24|DE LOSS: 313, PPL: 1403, TM: 310, LM: 3.48|BETA: 0.004106
# 117[s], 41[s], Ep: 15, Ct: 02000|TR LOSS: 324, PPL: 1607|TM NLL: 319, KL: 0.21, REG:0.00 | LM NLL: 4.76, KL: 29.20|DE LOSS: 313, PPL: 1396, TM: 310, LM: 3.50|BETA: 0.004140
# 127[s], 52[s], Ep: 15, Ct: 02500|TR LOSS: 324, PPL: 1604|TM NLL: 319, KL: 0.22, REG:0.00 | LM NLL: 4.74, KL: 29.16|DE LOSS: 313, PPL: 1401, TM: 310, LM: 3.52|BETA: 0.004175
# 104[s], 46[s], Ep: 16, Ct: 00000|TR LOSS: 324, PPL: 1603|TM NLL: 319, KL: 0.23, REG:0.00 | LM NLL: 4.73, KL: 29.12|DE LOSS: 313, PPL: 1395, TM: 310, LM: 3.46|BETA: 0.004202
# 105[s], 30[s], Ep: 16, Ct: 00500|TR LOSS: 324, PPL: 1600|TM NLL: 318, KL: 0.24, REG:0.00 | LM NLL: 4.72, KL: 29.08|DE LOSS: 313, PPL: 1386, TM: 310, LM: 3.44|BETA: 0.004236
# 106[s], 30[s], Ep: 16, Ct: 01000|TR LOSS: 323, PPL: 1598|TM NLL: 318, KL: 0.25, REG:0.00 | LM NLL: 4.70, KL: 29.04|DE LOSS: 313, PPL: 1388, TM: 309, LM: 3.47|BETA: 0.004271
# 129[s], 53[s], Ep: 16, Ct: 01500|TR LOSS: 323, PPL: 1595|TM NLL: 318, KL: 0.26, REG:0.00 | LM NLL: 4.69, KL: 28.99|DE LOSS: 313, PPL: 1381, TM: 309, LM: 3.45|BETA: 0.004306
# 122[s], 46[s], Ep: 16, Ct: 02000|TR LOSS: 323, PPL: 1593|TM NLL: 318, KL: 0.27, REG:0.00 | LM NLL: 4.68, KL: 28.94|DE LOSS: 313, PPL: 1374, TM: 309, LM: 3.43|BETA: 0.004340
# 083[s], 08[s], Ep: 16, Ct: 02500|TR LOSS: 323, PPL: 1591|TM NLL: 318, KL: 0.28, REG:0.00 | LM NLL: 4.66, KL: 28.90|DE LOSS: 313, PPL: 1373, TM: 309, LM: 3.60|BETA: 0.004375
# 099[s], 42[s], Ep: 17, Ct: 00000|TR LOSS: 323, PPL: 1589|TM NLL: 318, KL: 0.29, REG:0.00 | LM NLL: 4.65, KL: 28.86|DE LOSS: 313, PPL: 1375, TM: 309, LM: 3.40|BETA: 0.004402
# 105[s], 30[s], Ep: 17, Ct: 00500|TR LOSS: 323, PPL: 1587|TM NLL: 318, KL: 0.30, REG:0.00 | LM NLL: 4.64, KL: 28.81|DE LOSS: 312, PPL: 1367, TM: 309, LM: 3.41|BETA: 0.004436
# 082[s], 08[s], Ep: 17, Ct: 01000|TR LOSS: 323, PPL: 1584|TM NLL: 318, KL: 0.30, REG:0.00 | LM NLL: 4.63, KL: 28.76|DE LOSS: 313, PPL: 1368, TM: 309, LM: 3.51|BETA: 0.004471
# 129[s], 54[s], Ep: 17, Ct: 01500|TR LOSS: 323, PPL: 1582|TM NLL: 318, KL: 0.31, REG:0.00 | LM NLL: 4.61, KL: 28.72|DE LOSS: 312, PPL: 1363, TM: 309, LM: 3.39|BETA: 0.004506
# 105[s], 29[s], Ep: 17, Ct: 02000|TR LOSS: 323, PPL: 1580|TM NLL: 318, KL: 0.32, REG:0.00 | LM NLL: 4.60, KL: 28.67|DE LOSS: 312, PPL: 1361, TM: 309, LM: 3.37|BETA: 0.004541
# 082[s], 08[s], Ep: 17, Ct: 02500|TR LOSS: 323, PPL: 1577|TM NLL: 318, KL: 0.33, REG:0.00 | LM NLL: 4.59, KL: 28.62|DE LOSS: 312, PPL: 1360, TM: 309, LM: 3.37|BETA: 0.004575
# 101[s], 44[s], Ep: 18, Ct: 00000|TR LOSS: 323, PPL: 1576|TM NLL: 318, KL: 0.34, REG:0.00 | LM NLL: 4.58, KL: 28.58|DE LOSS: 312, PPL: 1357, TM: 309, LM: 3.34|BETA: 0.004602
# 149[s], 75[s], Ep: 18, Ct: 00500|TR LOSS: 323, PPL: 1573|TM NLL: 318, KL: 0.35, REG:0.00 | LM NLL: 4.57, KL: 28.53|DE LOSS: 312, PPL: 1356, TM: 309, LM: 3.34|BETA: 0.004637
# 105[s], 31[s], Ep: 18, Ct: 01000|TR LOSS: 323, PPL: 1571|TM NLL: 318, KL: 0.36, REG:0.00 | LM NLL: 4.55, KL: 28.48|DE LOSS: 312, PPL: 1354, TM: 309, LM: 3.35|BETA: 0.004671
# 082[s], 08[s], Ep: 18, Ct: 01500|TR LOSS: 323, PPL: 1569|TM NLL: 318, KL: 0.37, REG:0.00 | LM NLL: 4.54, KL: 28.43|DE LOSS: 312, PPL: 1349, TM: 309, LM: 3.41|BETA: 0.004706
# 114[s], 40[s], Ep: 18, Ct: 02000|TR LOSS: 323, PPL: 1567|TM NLL: 318, KL: 0.38, REG:0.00 | LM NLL: 4.53, KL: 28.38|DE LOSS: 312, PPL: 1348, TM: 308, LM: 3.37|BETA: 0.004741
# 107[s], 32[s], Ep: 18, Ct: 02500|TR LOSS: 322, PPL: 1565|TM NLL: 317, KL: 0.38, REG:0.00 | LM NLL: 4.52, KL: 28.33|DE LOSS: 312, PPL: 1345, TM: 308, LM: 3.33|BETA: 0.004775
# 066[s], 08[s], Ep: 19, Ct: 00000|TR LOSS: 322, PPL: 1563|TM NLL: 317, KL: 0.39, REG:0.00 | LM NLL: 4.51, KL: 28.29|DE LOSS: 312, PPL: 1346, TM: 309, LM: 3.43|BETA: 0.004802
# 133[s], 58[s], Ep: 19, Ct: 00500|TR LOSS: 322, PPL: 1561|TM NLL: 317, KL: 0.40, REG:0.00 | LM NLL: 4.50, KL: 28.24|DE LOSS: 312, PPL: 1344, TM: 308, LM: 3.30|BETA: 0.004837
# 106[s], 31[s], Ep: 19, Ct: 01000|TR LOSS: 322, PPL: 1559|TM NLL: 317, KL: 0.41, REG:0.00 | LM NLL: 4.49, KL: 28.19|DE LOSS: 312, PPL: 1341, TM: 308, LM: 3.31|BETA: 0.004871
# 082[s], 08[s], Ep: 19, Ct: 01500|TR LOSS: 322, PPL: 1557|TM NLL: 317, KL: 0.42, REG:0.00 | LM NLL: 4.48, KL: 28.14|DE LOSS: 312, PPL: 1343, TM: 308, LM: 3.51|BETA: 0.004906
# 107[s], 32[s], Ep: 19, Ct: 02000|TR LOSS: 322, PPL: 1555|TM NLL: 317, KL: 0.42, REG:0.00 | LM NLL: 4.46, KL: 28.09|DE LOSS: 312, PPL: 1337, TM: 308, LM: 3.29|BETA: 0.004941
# 082[s], 08[s], Ep: 19, Ct: 02500|TR LOSS: 322, PPL: 1553|TM NLL: 317, KL: 0.43, REG:0.00 | LM NLL: 4.45, KL: 28.04|DE LOSS: 312, PPL: 1340, TM: 308, LM: 3.31|BETA: 0.004975
# 089[s], 31[s], Ep: 20, Ct: 00000|TR LOSS: 322, PPL: 1551|TM NLL: 317, KL: 0.44, REG:0.00 | LM NLL: 4.44, KL: 28.00|DE LOSS: 311, PPL: 1335, TM: 308, LM: 3.27|BETA: 0.005002
# 104[s], 30[s], Ep: 20, Ct: 00500|TR LOSS: 322, PPL: 1549|TM NLL: 317, KL: 0.45, REG:0.00 | LM NLL: 4.43, KL: 27.95|DE LOSS: 311, PPL: 1337, TM: 308, LM: 3.27|BETA: 0.005037
# 104[s], 30[s], Ep: 20, Ct: 01000|TR LOSS: 322, PPL: 1548|TM NLL: 317, KL: 0.45, REG:0.00 | LM NLL: 4.42, KL: 27.90|DE LOSS: 311, PPL: 1335, TM: 308, LM: 3.25|BETA: 0.005071
# 083[s], 08[s], Ep: 20, Ct: 01500|TR LOSS: 322, PPL: 1546|TM NLL: 317, KL: 0.46, REG:0.00 | LM NLL: 4.41, KL: 27.85|DE LOSS: 312, PPL: 1336, TM: 308, LM: 3.36|BETA: 0.005106
# 103[s], 29[s], Ep: 20, Ct: 02000|TR LOSS: 322, PPL: 1544|TM NLL: 317, KL: 0.47, REG:0.00 | LM NLL: 4.40, KL: 27.80|DE LOSS: 311, PPL: 1331, TM: 308, LM: 3.30|BETA: 0.005141
# 104[s], 29[s], Ep: 20, Ct: 02500|TR LOSS: 322, PPL: 1542|TM NLL: 317, KL: 0.48, REG:0.00 | LM NLL: 4.39, KL: 27.75|DE LOSS: 311, PPL: 1329, TM: 308, LM: 3.27|BETA: 0.005176
# 087[s], 30[s], Ep: 21, Ct: 00000|TR LOSS: 322, PPL: 1540|TM NLL: 317, KL: 0.48, REG:0.00 | LM NLL: 4.38, KL: 27.71|DE LOSS: 311, PPL: 1334, TM: 308, LM: 3.27|BETA: 0.005202
# 119[s], 45[s], Ep: 21, Ct: 00500|TR LOSS: 322, PPL: 1539|TM NLL: 317, KL: 0.49, REG:0.00 | LM NLL: 4.37, KL: 27.66|DE LOSS: 311, PPL: 1328, TM: 308, LM: 3.23|BETA: 0.005237
# 082[s], 08[s], Ep: 21, Ct: 01000|TR LOSS: 322, PPL: 1537|TM NLL: 317, KL: 0.50, REG:0.00 | LM NLL: 4.36, KL: 27.61|DE LOSS: 311, PPL: 1327, TM: 308, LM: 3.21|BETA: 0.005272
# 082[s], 08[s], Ep: 21, Ct: 01500|TR LOSS: 322, PPL: 1535|TM NLL: 317, KL: 0.50, REG:0.00 | LM NLL: 4.35, KL: 27.56|DE LOSS: 311, PPL: 1328, TM: 308, LM: 3.23|BETA: 0.005306
# 127[s], 52[s], Ep: 21, Ct: 02000|TR LOSS: 322, PPL: 1533|TM NLL: 317, KL: 0.51, REG:0.00 | LM NLL: 4.34, KL: 27.51|DE LOSS: 311, PPL: 1327, TM: 308, LM: 3.21|BETA: 0.005341
# 083[s], 08[s], Ep: 21, Ct: 02500|TR LOSS: 321, PPL: 1532|TM NLL: 317, KL: 0.52, REG:0.00 | LM NLL: 4.34, KL: 27.46|DE LOSS: 311, PPL: 1330, TM: 308, LM: 3.37|BETA: 0.005376
# 087[s], 30[s], Ep: 22, Ct: 00000|TR LOSS: 321, PPL: 1530|TM NLL: 317, KL: 0.52, REG:0.00 | LM NLL: 4.33, KL: 27.42|DE LOSS: 311, PPL: 1326, TM: 308, LM: 3.20|BETA: 0.005402
# 107[s], 32[s], Ep: 22, Ct: 00500|TR LOSS: 321, PPL: 1529|TM NLL: 316, KL: 0.53, REG:0.00 | LM NLL: 4.32, KL: 27.37|DE LOSS: 311, PPL: 1323, TM: 308, LM: 3.21|BETA: 0.005437
# 105[s], 30[s], Ep: 22, Ct: 01000|TR LOSS: 321, PPL: 1527|TM NLL: 316, KL: 0.54, REG:0.00 | LM NLL: 4.31, KL: 27.32|DE LOSS: 311, PPL: 1323, TM: 308, LM: 3.19|BETA: 0.005472
# 134[s], 59[s], Ep: 22, Ct: 01500|TR LOSS: 321, PPL: 1525|TM NLL: 316, KL: 0.54, REG:0.00 | LM NLL: 4.30, KL: 27.27|DE LOSS: 311, PPL: 1321, TM: 308, LM: 3.18|BETA: 0.005506
# 083[s], 08[s], Ep: 22, Ct: 02000|TR LOSS: 321, PPL: 1523|TM NLL: 316, KL: 0.55, REG:0.00 | LM NLL: 4.29, KL: 27.22|DE LOSS: 311, PPL: 1323, TM: 308, LM: 3.18|BETA: 0.005541
# 083[s], 08[s], Ep: 22, Ct: 02500|TR LOSS: 321, PPL: 1522|TM NLL: 316, KL: 0.56, REG:0.00 | LM NLL: 4.28, KL: 27.17|DE LOSS: 311, PPL: 1324, TM: 308, LM: 3.17|BETA: 0.005576
# 065[s], 08[s], Ep: 23, Ct: 00000|TR LOSS: 321, PPL: 1521|TM NLL: 316, KL: 0.56, REG:0.00 | LM NLL: 4.27, KL: 27.13|DE LOSS: 311, PPL: 1322, TM: 308, LM: 3.27|BETA: 0.005602
# 104[s], 30[s], Ep: 23, Ct: 00500|TR LOSS: 321, PPL: 1519|TM NLL: 316, KL: 0.57, REG:0.00 | LM NLL: 4.27, KL: 27.08|DE LOSS: 311, PPL: 1321, TM: 308, LM: 3.17|BETA: 0.005637
# 104[s], 30[s], Ep: 23, Ct: 01000|TR LOSS: 321, PPL: 1518|TM NLL: 316, KL: 0.57, REG:0.00 | LM NLL: 4.26, KL: 27.03|DE LOSS: 311, PPL: 1318, TM: 308, LM: 3.17|BETA: 0.005672
# 083[s], 08[s], Ep: 23, Ct: 01500|TR LOSS: 321, PPL: 1516|TM NLL: 316, KL: 0.58, REG:0.00 | LM NLL: 4.25, KL: 26.98|DE LOSS: 311, PPL: 1320, TM: 308, LM: 3.16|BETA: 0.005706
# 125[s], 49[s], Ep: 23, Ct: 02000|TR LOSS: 321, PPL: 1514|TM NLL: 316, KL: 0.59, REG:0.00 | LM NLL: 4.24, KL: 26.93|DE LOSS: 311, PPL: 1317, TM: 308, LM: 3.14|BETA: 0.005741
# 083[s], 08[s], Ep: 23, Ct: 02500|TR LOSS: 321, PPL: 1513|TM NLL: 316, KL: 0.59, REG:0.00 | LM NLL: 4.23, KL: 26.88|DE LOSS: 311, PPL: 1317, TM: 308, LM: 3.16|BETA: 0.005776
# 066[s], 08[s], Ep: 24, Ct: 00000|TR LOSS: 321, PPL: 1512|TM NLL: 316, KL: 0.60, REG:0.00 | LM NLL: 4.22, KL: 26.85|DE LOSS: 311, PPL: 1317, TM: 308, LM: 3.14|BETA: 0.005802
# 106[s], 30[s], Ep: 24, Ct: 00500|TR LOSS: 321, PPL: 1510|TM NLL: 316, KL: 0.60, REG:0.00 | LM NLL: 4.22, KL: 26.80|DE LOSS: 311, PPL: 1317, TM: 308, LM: 3.14|BETA: 0.005837
# 106[s], 30[s], Ep: 24, Ct: 01000|TR LOSS: 321, PPL: 1509|TM NLL: 316, KL: 0.61, REG:0.00 | LM NLL: 4.21, KL: 26.75|DE LOSS: 311, PPL: 1314, TM: 308, LM: 3.14|BETA: 0.005872
# 083[s], 08[s], Ep: 24, Ct: 01500|TR LOSS: 321, PPL: 1507|TM NLL: 316, KL: 0.61, REG:0.00 | LM NLL: 4.20, KL: 26.70|DE LOSS: 311, PPL: 1313, TM: 308, LM: 3.14|BETA: 0.005907
# 105[s], 30[s], Ep: 24, Ct: 02000|TR LOSS: 321, PPL: 1506|TM NLL: 316, KL: 0.62, REG:0.00 | LM NLL: 4.19, KL: 26.65|DE LOSS: 311, PPL: 1314, TM: 308, LM: 3.13|BETA: 0.005941
# 106[s], 30[s], Ep: 24, Ct: 02500|TR LOSS: 321, PPL: 1505|TM NLL: 316, KL: 0.62, REG:0.00 | LM NLL: 4.18, KL: 26.60|DE LOSS: 311, PPL: 1314, TM: 308, LM: 3.13|BETA: 0.005976
# 066[s], 08[s], Ep: 25, Ct: 00000|TR LOSS: 321, PPL: 1504|TM NLL: 316, KL: 0.63, REG:0.00 | LM NLL: 4.18, KL: 26.56|DE LOSS: 311, PPL: 1312, TM: 308, LM: 3.13|BETA: 0.006003
# 107[s], 31[s], Ep: 25, Ct: 00500|TR LOSS: 321, PPL: 1502|TM NLL: 316, KL: 0.63, REG:0.00 | LM NLL: 4.17, KL: 26.51|DE LOSS: 311, PPL: 1311, TM: 308, LM: 3.14|BETA: 0.006037
# 084[s], 08[s], Ep: 25, Ct: 01000|TR LOSS: 321, PPL: 1501|TM NLL: 316, KL: 0.64, REG:0.00 | LM NLL: 4.16, KL: 26.46|DE LOSS: 311, PPL: 1311, TM: 308, LM: 3.12|BETA: 0.006072
# 084[s], 08[s], Ep: 25, Ct: 01500|TR LOSS: 320, PPL: 1499|TM NLL: 316, KL: 0.65, REG:0.00 | LM NLL: 4.15, KL: 26.42|DE LOSS: 311, PPL: 1314, TM: 308, LM: 3.17|BETA: 0.006107
# 123[s], 47[s], Ep: 25, Ct: 02000|TR LOSS: 320, PPL: 1498|TM NLL: 316, KL: 0.65, REG:0.00 | LM NLL: 4.14, KL: 26.37|DE LOSS: 311, PPL: 1311, TM: 308, LM: 3.10|BETA: 0.006141
# 128[s], 52[s], Ep: 25, Ct: 02500|TR LOSS: 320, PPL: 1497|TM NLL: 316, KL: 0.66, REG:0.00 | LM NLL: 4.14, KL: 26.32|DE LOSS: 311, PPL: 1311, TM: 307, LM: 3.13|BETA: 0.006176
# 067[s], 08[s], Ep: 26, Ct: 00000|TR LOSS: 320, PPL: 1496|TM NLL: 316, KL: 0.66, REG:0.00 | LM NLL: 4.13, KL: 26.28|DE LOSS: 311, PPL: 1311, TM: 308, LM: 3.12|BETA: 0.006203
# 084[s], 08[s], Ep: 26, Ct: 00500|TR LOSS: 320, PPL: 1494|TM NLL: 315, KL: 0.67, REG:0.00 | LM NLL: 4.12, KL: 26.24|DE LOSS: 311, PPL: 1312, TM: 307, LM: 3.12|BETA: 0.006237
# 084[s], 08[s], Ep: 26, Ct: 01000|TR LOSS: 320, PPL: 1493|TM NLL: 315, KL: 0.67, REG:0.00 | LM NLL: 4.11, KL: 26.19|DE LOSS: 311, PPL: 1312, TM: 307, LM: 3.11|BETA: 0.006272
# 107[s], 31[s], Ep: 26, Ct: 01500|TR LOSS: 320, PPL: 1492|TM NLL: 315, KL: 0.68, REG:0.00 | LM NLL: 4.11, KL: 26.14|DE LOSS: 311, PPL: 1310, TM: 307, LM: 3.08|BETA: 0.006307
# 106[s], 31[s], Ep: 26, Ct: 02000|TR LOSS: 320, PPL: 1491|TM NLL: 315, KL: 0.68, REG:0.00 | LM NLL: 4.10, KL: 26.09|DE LOSS: 311, PPL: 1307, TM: 307, LM: 3.08|BETA: 0.006341
# 084[s], 08[s], Ep: 26, Ct: 02500|TR LOSS: 320, PPL: 1489|TM NLL: 315, KL: 0.69, REG:0.00 | LM NLL: 4.09, KL: 26.05|DE LOSS: 311, PPL: 1308, TM: 307, LM: 3.14|BETA: 0.006376
# 088[s], 30[s], Ep: 27, Ct: 00000|TR LOSS: 320, PPL: 1488|TM NLL: 315, KL: 0.69, REG:0.00 | LM NLL: 4.09, KL: 26.01|DE LOSS: 310, PPL: 1309, TM: 307, LM: 3.09|BETA: 0.006403
# 084[s], 08[s], Ep: 27, Ct: 00500|TR LOSS: 320, PPL: 1487|TM NLL: 315, KL: 0.69, REG:0.00 | LM NLL: 4.08, KL: 25.96|DE LOSS: 311, PPL: 1309, TM: 307, LM: 3.09|BETA: 0.006437
# 084[s], 08[s], Ep: 27, Ct: 01000|TR LOSS: 320, PPL: 1486|TM NLL: 315, KL: 0.70, REG:0.00 | LM NLL: 4.07, KL: 25.92|DE LOSS: 311, PPL: 1308, TM: 307, LM: 3.13|BETA: 0.006472
# 084[s], 08[s], Ep: 27, Ct: 01500|TR LOSS: 320, PPL: 1485|TM NLL: 315, KL: 0.70, REG:0.00 | LM NLL: 4.07, KL: 25.87|DE LOSS: 310, PPL: 1309, TM: 307, LM: 3.06|BETA: 0.006507
# 083[s], 08[s], Ep: 27, Ct: 02000|TR LOSS: 320, PPL: 1484|TM NLL: 315, KL: 0.71, REG:0.00 | LM NLL: 4.06, KL: 25.83|DE LOSS: 310, PPL: 1306, TM: 307, LM: 3.08|BETA: 0.006542
# 105[s], 30[s], Ep: 27, Ct: 02500|TR LOSS: 320, PPL: 1483|TM NLL: 315, KL: 0.71, REG:0.00 | LM NLL: 4.05, KL: 25.78|DE LOSS: 310, PPL: 1308, TM: 307, LM: 3.04|BETA: 0.006576
# 066[s], 08[s], Ep: 28, Ct: 00000|TR LOSS: 320, PPL: 1482|TM NLL: 315, KL: 0.72, REG:0.00 | LM NLL: 4.05, KL: 25.74|DE LOSS: 310, PPL: 1309, TM: 307, LM: 3.05|BETA: 0.006603
# 106[s], 30[s], Ep: 28, Ct: 00500|TR LOSS: 320, PPL: 1480|TM NLL: 315, KL: 0.72, REG:0.00 | LM NLL: 4.04, KL: 25.70|DE LOSS: 310, PPL: 1304, TM: 307, LM: 3.04|BETA: 0.006638
# 084[s], 08[s], Ep: 28, Ct: 01000|TR LOSS: 320, PPL: 1479|TM NLL: 315, KL: 0.73, REG:0.00 | LM NLL: 4.03, KL: 25.65|DE LOSS: 310, PPL: 1304, TM: 307, LM: 3.03|BETA: 0.006672
# 083[s], 08[s], Ep: 28, Ct: 01500|TR LOSS: 320, PPL: 1478|TM NLL: 315, KL: 0.73, REG:0.00 | LM NLL: 4.02, KL: 25.61|DE LOSS: 310, PPL: 1303, TM: 307, LM: 3.05|BETA: 0.006707
# 084[s], 08[s], Ep: 28, Ct: 02000|TR LOSS: 320, PPL: 1477|TM NLL: 315, KL: 0.74, REG:0.00 | LM NLL: 4.02, KL: 25.56|DE LOSS: 310, PPL: 1309, TM: 307, LM: 3.10|BETA: 0.006742
# 083[s], 08[s], Ep: 28, Ct: 02500|TR LOSS: 320, PPL: 1476|TM NLL: 315, KL: 0.74, REG:0.00 | LM NLL: 4.01, KL: 25.52|DE LOSS: 310, PPL: 1303, TM: 307, LM: 3.04|BETA: 0.006776
# 066[s], 08[s], Ep: 29, Ct: 00000|TR LOSS: 320, PPL: 1475|TM NLL: 315, KL: 0.74, REG:0.00 | LM NLL: 4.01, KL: 25.48|DE LOSS: 310, PPL: 1304, TM: 307, LM: 3.05|BETA: 0.006803
# 125[s], 50[s], Ep: 29, Ct: 00500|TR LOSS: 320, PPL: 1474|TM NLL: 315, KL: 0.75, REG:0.00 | LM NLL: 4.00, KL: 25.44|DE LOSS: 310, PPL: 1300, TM: 307, LM: 3.03|BETA: 0.006838
# 083[s], 08[s], Ep: 29, Ct: 01000|TR LOSS: 320, PPL: 1473|TM NLL: 315, KL: 0.75, REG:0.00 | LM NLL: 3.99, KL: 25.39|DE LOSS: 310, PPL: 1304, TM: 307, LM: 3.03|BETA: 0.006872
# 084[s], 08[s], Ep: 29, Ct: 01500|TR LOSS: 320, PPL: 1472|TM NLL: 315, KL: 0.76, REG:0.00 | LM NLL: 3.99, KL: 25.35|DE LOSS: 310, PPL: 1301, TM: 307, LM: 3.10|BETA: 0.006907
# 084[s], 08[s], Ep: 29, Ct: 02000|TR LOSS: 320, PPL: 1471|TM NLL: 315, KL: 0.76, REG:0.00 | LM NLL: 3.98, KL: 25.31|DE LOSS: 310, PPL: 1303, TM: 307, LM: 3.01|BETA: 0.006942
# 083[s], 08[s], Ep: 29, Ct: 02500|TR LOSS: 320, PPL: 1470|TM NLL: 315, KL: 0.76, REG:0.00 | LM NLL: 3.97, KL: 25.26|DE LOSS: 310, PPL: 1308, TM: 307, LM: 3.00|BETA: 0.006976
# 088[s], 30[s], Ep: 30, Ct: 00000|TR LOSS: 320, PPL: 1469|TM NLL: 315, KL: 0.77, REG:0.00 | LM NLL: 3.97, KL: 25.23|DE LOSS: 310, PPL: 1303, TM: 307, LM: 3.01|BETA: 0.007003
# 084[s], 08[s], Ep: 30, Ct: 00500|TR LOSS: 320, PPL: 1468|TM NLL: 315, KL: 0.77, REG:0.00 | LM NLL: 3.96, KL: 25.18|DE LOSS: 310, PPL: 1301, TM: 307, LM: 3.02|BETA: 0.007038
# 084[s], 08[s], Ep: 30, Ct: 01000|TR LOSS: 320, PPL: 1467|TM NLL: 315, KL: 0.78, REG:0.00 | LM NLL: 3.96, KL: 25.14|DE LOSS: 310, PPL: 1302, TM: 307, LM: 3.03|BETA: 0.007072
# 121[s], 45[s], Ep: 30, Ct: 01500|TR LOSS: 319, PPL: 1466|TM NLL: 315, KL: 0.78, REG:0.00 | LM NLL: 3.95, KL: 25.10|DE LOSS: 310, PPL: 1300, TM: 307, LM: 3.02|BETA: 0.007107
# 083[s], 08[s], Ep: 30, Ct: 02000|TR LOSS: 319, PPL: 1465|TM NLL: 315, KL: 0.78, REG:0.00 | LM NLL: 3.94, KL: 25.06|DE LOSS: 310, PPL: 1301, TM: 307, LM: 3.01|BETA: 0.007142
# 084[s], 08[s], Ep: 30, Ct: 02500|TR LOSS: 319, PPL: 1464|TM NLL: 315, KL: 0.79, REG:0.00 | LM NLL: 3.94, KL: 25.01|DE LOSS: 310, PPL: 1301, TM: 307, LM: 3.00|BETA: 0.007177
# 067[s], 08[s], Ep: 31, Ct: 00000|TR LOSS: 319, PPL: 1464|TM NLL: 315, KL: 0.79, REG:0.00 | LM NLL: 3.93, KL: 24.98|DE LOSS: 310, PPL: 1304, TM: 307, LM: 3.03|BETA: 0.007203
# 084[s], 08[s], Ep: 31, Ct: 00500|TR LOSS: 319, PPL: 1463|TM NLL: 315, KL: 0.80, REG:0.00 | LM NLL: 3.93, KL: 24.94|DE LOSS: 310, PPL: 1303, TM: 307, LM: 3.02|BETA: 0.007238
# 084[s], 08[s], Ep: 31, Ct: 01000|TR LOSS: 319, PPL: 1462|TM NLL: 315, KL: 0.80, REG:0.00 | LM NLL: 3.92, KL: 24.89|DE LOSS: 310, PPL: 1299, TM: 307, LM: 3.01|BETA: 0.007273
# 084[s], 08[s], Ep: 31, Ct: 01500|TR LOSS: 319, PPL: 1461|TM NLL: 315, KL: 0.80, REG:0.00 | LM NLL: 3.91, KL: 24.85|DE LOSS: 310, PPL: 1303, TM: 307, LM: 2.99|BETA: 0.007307
# 105[s], 30[s], Ep: 31, Ct: 02000|TR LOSS: 319, PPL: 1460|TM NLL: 314, KL: 0.81, REG:0.00 | LM NLL: 3.91, KL: 24.81|DE LOSS: 310, PPL: 1300, TM: 307, LM: 2.96|BETA: 0.007342
# 084[s], 08[s], Ep: 31, Ct: 02500|TR LOSS: 319, PPL: 1459|TM NLL: 314, KL: 0.81, REG:0.00 | LM NLL: 3.90, KL: 24.77|DE LOSS: 310, PPL: 1300, TM: 307, LM: 3.02|BETA: 0.007377
# 066[s], 08[s], Ep: 32, Ct: 00000|TR LOSS: 319, PPL: 1458|TM NLL: 314, KL: 0.81, REG:0.00 | LM NLL: 3.90, KL: 24.73|DE LOSS: 310, PPL: 1300, TM: 307, LM: 2.98|BETA: 0.007403
# 083[s], 08[s], Ep: 32, Ct: 00500|TR LOSS: 319, PPL: 1457|TM NLL: 314, KL: 0.82, REG:0.00 | LM NLL: 3.89, KL: 24.69|DE LOSS: 310, PPL: 1301, TM: 307, LM: 2.98|BETA: 0.007438
# 106[s], 31[s], Ep: 32, Ct: 01000|TR LOSS: 319, PPL: 1456|TM NLL: 314, KL: 0.82, REG:0.00 | LM NLL: 3.89, KL: 24.65|DE LOSS: 310, PPL: 1296, TM: 307, LM: 3.00|BETA: 0.007473
# 082[s], 08[s], Ep: 32, Ct: 01500|TR LOSS: 319, PPL: 1456|TM NLL: 314, KL: 0.83, REG:0.00 | LM NLL: 3.88, KL: 24.61|DE LOSS: 310, PPL: 1299, TM: 307, LM: 2.96|BETA: 0.007507
# 115[s], 40[s], Ep: 32, Ct: 02000|TR LOSS: 319, PPL: 1455|TM NLL: 314, KL: 0.83, REG:0.00 | LM NLL: 3.88, KL: 24.57|DE LOSS: 310, PPL: 1300, TM: 307, LM: 2.97|BETA: 0.007542
# 083[s], 08[s], Ep: 32, Ct: 02500|TR LOSS: 319, PPL: 1454|TM NLL: 314, KL: 0.83, REG:0.00 | LM NLL: 3.87, KL: 24.52|DE LOSS: 310, PPL: 1300, TM: 307, LM: 2.95|BETA: 0.007577
# 088[s], 30[s], Ep: 33, Ct: 00000|TR LOSS: 319, PPL: 1453|TM NLL: 314, KL: 0.84, REG:0.00 | LM NLL: 3.87, KL: 24.49|DE LOSS: 310, PPL: 1295, TM: 307, LM: 2.99|BETA: 0.007603
# 105[s], 30[s], Ep: 33, Ct: 00500|TR LOSS: 319, PPL: 1452|TM NLL: 314, KL: 0.84, REG:0.00 | LM NLL: 3.86, KL: 24.45|DE LOSS: 310, PPL: 1298, TM: 307, LM: 2.95|BETA: 0.007638
# 107[s], 32[s], Ep: 33, Ct: 01000|TR LOSS: 319, PPL: 1452|TM NLL: 314, KL: 0.84, REG:0.00 | LM NLL: 3.85, KL: 24.41|DE LOSS: 310, PPL: 1297, TM: 307, LM: 2.95|BETA: 0.007673
# 083[s], 08[s], Ep: 33, Ct: 01500|TR LOSS: 319, PPL: 1451|TM NLL: 314, KL: 0.85, REG:0.00 | LM NLL: 3.85, KL: 24.37|DE LOSS: 310, PPL: 1300, TM: 307, LM: 2.94|BETA: 0.007707
# 083[s], 08[s], Ep: 33, Ct: 02000|TR LOSS: 319, PPL: 1450|TM NLL: 314, KL: 0.85, REG:0.00 | LM NLL: 3.84, KL: 24.33|DE LOSS: 310, PPL: 1299, TM: 307, LM: 2.97|BETA: 0.007742
# 110[s], 35[s], Ep: 33, Ct: 02500|TR LOSS: 319, PPL: 1449|TM NLL: 314, KL: 0.85, REG:0.00 | LM NLL: 3.84, KL: 24.29|DE LOSS: 310, PPL: 1295, TM: 307, LM: 2.94|BETA: 0.007777
# 066[s], 08[s], Ep: 34, Ct: 00000|TR LOSS: 319, PPL: 1448|TM NLL: 314, KL: 0.86, REG:0.00 | LM NLL: 3.83, KL: 24.25|DE LOSS: 310, PPL: 1298, TM: 307, LM: 2.94|BETA: 0.007803
# 083[s], 08[s], Ep: 34, Ct: 00500|TR LOSS: 319, PPL: 1448|TM NLL: 314, KL: 0.86, REG:0.00 | LM NLL: 3.83, KL: 24.21|DE LOSS: 310, PPL: 1298, TM: 307, LM: 2.94|BETA: 0.007838
# 130[s], 55[s], Ep: 34, Ct: 01000|TR LOSS: 319, PPL: 1447|TM NLL: 314, KL: 0.86, REG:0.00 | LM NLL: 3.82, KL: 24.17|DE LOSS: 310, PPL: 1296, TM: 307, LM: 2.93|BETA: 0.007872
# 082[s], 08[s], Ep: 34, Ct: 01500|TR LOSS: 319, PPL: 1446|TM NLL: 314, KL: 0.87, REG:0.00 | LM NLL: 3.82, KL: 24.13|DE LOSS: 310, PPL: 1294, TM: 307, LM: 2.97|BETA: 0.007907
# 082[s], 08[s], Ep: 34, Ct: 02000|TR LOSS: 319, PPL: 1445|TM NLL: 314, KL: 0.87, REG:0.00 | LM NLL: 3.81, KL: 24.09|DE LOSS: 310, PPL: 1296, TM: 307, LM: 2.96|BETA: 0.007941
# 083[s], 08[s], Ep: 34, Ct: 02500|TR LOSS: 319, PPL: 1444|TM NLL: 314, KL: 0.87, REG:0.00 | LM NLL: 3.81, KL: 24.05|DE LOSS: 310, PPL: 1294, TM: 307, LM: 2.96|BETA: 0.007976
# 066[s], 08[s], Ep: 35, Ct: 00000|TR LOSS: 319, PPL: 1444|TM NLL: 314, KL: 0.87, REG:0.00 | LM NLL: 3.80, KL: 24.02|DE LOSS: 310, PPL: 1296, TM: 307, LM: 2.93|BETA: 0.008002
# 127[s], 51[s], Ep: 35, Ct: 00500|TR LOSS: 319, PPL: 1443|TM NLL: 314, KL: 0.88, REG:0.00 | LM NLL: 3.80, KL: 23.98|DE LOSS: 310, PPL: 1293, TM: 307, LM: 2.91|BETA: 0.008037
# 083[s], 08[s], Ep: 35, Ct: 01000|TR LOSS: 319, PPL: 1442|TM NLL: 314, KL: 0.88, REG:0.00 | LM NLL: 3.79, KL: 23.94|DE LOSS: 310, PPL: 1294, TM: 307, LM: 2.92|BETA: 0.008071
# 083[s], 08[s], Ep: 35, Ct: 01500|TR LOSS: 319, PPL: 1442|TM NLL: 314, KL: 0.88, REG:0.00 | LM NLL: 3.79, KL: 23.90|DE LOSS: 310, PPL: 1295, TM: 307, LM: 2.92|BETA: 0.008106
# 083[s], 08[s], Ep: 35, Ct: 02000|TR LOSS: 319, PPL: 1441|TM NLL: 314, KL: 0.89, REG:0.00 | LM NLL: 3.78, KL: 23.86|DE LOSS: 310, PPL: 1297, TM: 307, LM: 2.93|BETA: 0.008140
# 083[s], 08[s], Ep: 35, Ct: 02500|TR LOSS: 319, PPL: 1440|TM NLL: 314, KL: 0.89, REG:0.00 | LM NLL: 3.78, KL: 23.82|DE LOSS: 310, PPL: 1293, TM: 307, LM: 2.91|BETA: 0.008175
# 066[s], 08[s], Ep: 36, Ct: 00000|TR LOSS: 319, PPL: 1439|TM NLL: 314, KL: 0.89, REG:0.00 | LM NLL: 3.77, KL: 23.79|DE LOSS: 310, PPL: 1301, TM: 307, LM: 2.91|BETA: 0.008201
# 083[s], 08[s], Ep: 36, Ct: 00500|TR LOSS: 319, PPL: 1439|TM NLL: 314, KL: 0.90, REG:0.00 | LM NLL: 3.77, KL: 23.75|DE LOSS: 310, PPL: 1294, TM: 307, LM: 2.98|BETA: 0.008236
# 083[s], 08[s], Ep: 36, Ct: 01000|TR LOSS: 319, PPL: 1438|TM NLL: 314, KL: 0.90, REG:0.00 | LM NLL: 3.76, KL: 23.71|DE LOSS: 310, PPL: 1294, TM: 308, LM: 2.91|BETA: 0.008270
# 083[s], 08[s], Ep: 36, Ct: 01500|TR LOSS: 319, PPL: 1437|TM NLL: 314, KL: 0.90, REG:0.00 | LM NLL: 3.76, KL: 23.68|DE LOSS: 310, PPL: 1295, TM: 307, LM: 2.96|BETA: 0.008304
# 082[s], 08[s], Ep: 36, Ct: 02000|TR LOSS: 319, PPL: 1437|TM NLL: 314, KL: 0.91, REG:0.00 | LM NLL: 3.75, KL: 23.64|DE LOSS: 310, PPL: 1296, TM: 307, LM: 2.91|BETA: 0.008339
# 135[s], 60[s], Ep: 36, Ct: 02500|TR LOSS: 319, PPL: 1436|TM NLL: 314, KL: 0.91, REG:0.00 | LM NLL: 3.75, KL: 23.60|DE LOSS: 310, PPL: 1292, TM: 307, LM: 2.90|BETA: 0.008373
# 065[s], 08[s], Ep: 37, Ct: 00000|TR LOSS: 318, PPL: 1435|TM NLL: 314, KL: 0.91, REG:0.00 | LM NLL: 3.74, KL: 23.57|DE LOSS: 310, PPL: 1295, TM: 307, LM: 2.89|BETA: 0.008400
# 083[s], 08[s], Ep: 37, Ct: 00500|TR LOSS: 318, PPL: 1435|TM NLL: 314, KL: 0.91, REG:0.00 | LM NLL: 3.74, KL: 23.53|DE LOSS: 310, PPL: 1296, TM: 307, LM: 2.89|BETA: 0.008434
# 083[s], 08[s], Ep: 37, Ct: 01000|TR LOSS: 318, PPL: 1434|TM NLL: 314, KL: 0.92, REG:0.00 | LM NLL: 3.74, KL: 23.49|DE LOSS: 310, PPL: 1296, TM: 307, LM: 2.88|BETA: 0.008469
# 083[s], 08[s], Ep: 37, Ct: 01500|TR LOSS: 318, PPL: 1433|TM NLL: 314, KL: 0.92, REG:0.00 | LM NLL: 3.73, KL: 23.45|DE LOSS: 310, PPL: 1293, TM: 307, LM: 2.92|BETA: 0.008503
# 082[s], 08[s], Ep: 37, Ct: 02000|TR LOSS: 318, PPL: 1433|TM NLL: 314, KL: 0.92, REG:0.00 | LM NLL: 3.73, KL: 23.42|DE LOSS: 310, PPL: 1293, TM: 307, LM: 2.90|BETA: 0.008538
# 083[s], 08[s], Ep: 37, Ct: 02500|TR LOSS: 318, PPL: 1432|TM NLL: 314, KL: 0.93, REG:0.00 | LM NLL: 3.72, KL: 23.38|DE LOSS: 310, PPL: 1295, TM: 307, LM: 2.89|BETA: 0.008572
# 066[s], 08[s], Ep: 38, Ct: 00000|TR LOSS: 318, PPL: 1431|TM NLL: 314, KL: 0.93, REG:0.00 | LM NLL: 3.72, KL: 23.35|DE LOSS: 310, PPL: 1292, TM: 307, LM: 2.90|BETA: 0.008599
# 082[s], 08[s], Ep: 38, Ct: 00500|TR LOSS: 318, PPL: 1431|TM NLL: 314, KL: 0.93, REG:0.00 | LM NLL: 3.71, KL: 23.31|DE LOSS: 310, PPL: 1294, TM: 307, LM: 2.91|BETA: 0.008633
# 083[s], 08[s], Ep: 38, Ct: 01000|TR LOSS: 318, PPL: 1430|TM NLL: 314, KL: 0.93, REG:0.00 | LM NLL: 3.71, KL: 23.27|DE LOSS: 310, PPL: 1294, TM: 307, LM: 2.88|BETA: 0.008667
# 083[s], 08[s], Ep: 38, Ct: 01500|TR LOSS: 318, PPL: 1430|TM NLL: 314, KL: 0.94, REG:0.00 | LM NLL: 3.70, KL: 23.24|DE LOSS: 310, PPL: 1293, TM: 307, LM: 2.88|BETA: 0.008702
# 082[s], 08[s], Ep: 38, Ct: 02000|TR LOSS: 318, PPL: 1429|TM NLL: 314, KL: 0.94, REG:0.00 | LM NLL: 3.70, KL: 23.20|DE LOSS: 310, PPL: 1293, TM: 307, LM: 2.87|BETA: 0.008736
# 105[s], 30[s], Ep: 38, Ct: 02500|TR LOSS: 318, PPL: 1428|TM NLL: 314, KL: 0.94, REG:0.00 | LM NLL: 3.69, KL: 23.16|DE LOSS: 310, PPL: 1292, TM: 307, LM: 2.87|BETA: 0.008771
# 066[s], 08[s], Ep: 39, Ct: 00000|TR LOSS: 318, PPL: 1428|TM NLL: 314, KL: 0.94, REG:0.00 | LM NLL: 3.69, KL: 23.14|DE LOSS: 310, PPL: 1290, TM: 307, LM: 2.94|BETA: 0.008797
# 083[s], 08[s], Ep: 39, Ct: 00500|TR LOSS: 318, PPL: 1427|TM NLL: 313, KL: 0.95, REG:0.00 | LM NLL: 3.69, KL: 23.10|DE LOSS: 310, PPL: 1296, TM: 307, LM: 2.90|BETA: 0.008832
# 115[s], 40[s], Ep: 39, Ct: 01000|TR LOSS: 318, PPL: 1426|TM NLL: 313, KL: 0.95, REG:0.00 | LM NLL: 3.68, KL: 23.06|DE LOSS: 310, PPL: 1290, TM: 307, LM: 2.87|BETA: 0.008866
# 082[s], 08[s], Ep: 39, Ct: 01500|TR LOSS: 318, PPL: 1426|TM NLL: 313, KL: 0.95, REG:0.00 | LM NLL: 3.68, KL: 23.03|DE LOSS: 310, PPL: 1289, TM: 307, LM: 2.92|BETA: 0.008901
# 083[s], 08[s], Ep: 39, Ct: 02000|TR LOSS: 318, PPL: 1425|TM NLL: 313, KL: 0.95, REG:0.00 | LM NLL: 3.67, KL: 22.99|DE LOSS: 310, PPL: 1293, TM: 307, LM: 2.87|BETA: 0.008935
# 082[s], 08[s], Ep: 39, Ct: 02500|TR LOSS: 318, PPL: 1425|TM NLL: 313, KL: 0.96, REG:0.00 | LM NLL: 3.67, KL: 22.95|DE LOSS: 310, PPL: 1291, TM: 307, LM: 2.87|BETA: 0.008970
# 066[s], 08[s], Ep: 40, Ct: 00000|TR LOSS: 318, PPL: 1424|TM NLL: 313, KL: 0.96, REG:0.00 | LM NLL: 3.67, KL: 22.93|DE LOSS: 310, PPL: 1293, TM: 307, LM: 2.85|BETA: 0.008996
# 083[s], 08[s], Ep: 40, Ct: 00500|TR LOSS: 318, PPL: 1424|TM NLL: 313, KL: 0.96, REG:0.00 | LM NLL: 3.66, KL: 22.89|DE LOSS: 310, PPL: 1294, TM: 307, LM: 2.89|BETA: 0.009031
# 083[s], 08[s], Ep: 40, Ct: 01000|TR LOSS: 318, PPL: 1423|TM NLL: 313, KL: 0.96, REG:0.00 | LM NLL: 3.66, KL: 22.85|DE LOSS: 310, PPL: 1289, TM: 307, LM: 2.86|BETA: 0.009065
# 082[s], 08[s], Ep: 40, Ct: 01500|TR LOSS: 318, PPL: 1422|TM NLL: 313, KL: 0.97, REG:0.00 | LM NLL: 3.65, KL: 22.82|DE LOSS: 310, PPL: 1290, TM: 307, LM: 2.87|BETA: 0.009099
# 083[s], 08[s], Ep: 40, Ct: 02000|TR LOSS: 318, PPL: 1422|TM NLL: 313, KL: 0.97, REG:0.00 | LM NLL: 3.65, KL: 22.78|DE LOSS: 310, PPL: 1291, TM: 307, LM: 2.86|BETA: 0.009134
# 082[s], 08[s], Ep: 40, Ct: 02500|TR LOSS: 318, PPL: 1421|TM NLL: 313, KL: 0.97, REG:0.00 | LM NLL: 3.64, KL: 22.75|DE LOSS: 310, PPL: 1291, TM: 307, LM: 3.03|BETA: 0.009168
# 066[s], 08[s], Ep: 41, Ct: 00000|TR LOSS: 318, PPL: 1421|TM NLL: 313, KL: 0.97, REG:0.00 | LM NLL: 3.64, KL: 22.72|DE LOSS: 310, PPL: 1293, TM: 307, LM: 2.87|BETA: 0.009195
# 083[s], 08[s], Ep: 41, Ct: 00500|TR LOSS: 318, PPL: 1420|TM NLL: 313, KL: 0.98, REG:0.00 | LM NLL: 3.64, KL: 22.69|DE LOSS: 310, PPL: 1290, TM: 307, LM: 2.85|BETA: 0.009229
# 083[s], 08[s], Ep: 41, Ct: 01000|TR LOSS: 318, PPL: 1420|TM NLL: 313, KL: 0.98, REG:0.00 | LM NLL: 3.63, KL: 22.67|DE LOSS: 310, PPL: 1289, TM: 307, LM: 2.91|BETA: 0.009264
# 083[s], 08[s], Ep: 41, Ct: 01500|TR LOSS: 318, PPL: 1419|TM NLL: 313, KL: 0.98, REG:0.00 | LM NLL: 3.63, KL: 22.65|DE LOSS: 310, PPL: 1291, TM: 307, LM: 2.89|BETA: 0.009298
# 083[s], 08[s], Ep: 41, Ct: 02000|TR LOSS: 318, PPL: 1419|TM NLL: 313, KL: 0.98, REG:0.00 | LM NLL: 3.62, KL: 22.62|DE LOSS: 310, PPL: 1291, TM: 307, LM: 2.88|BETA: 0.009333
# 083[s], 08[s], Ep: 41, Ct: 02500|TR LOSS: 318, PPL: 1418|TM NLL: 313, KL: 0.99, REG:0.00 | LM NLL: 3.62, KL: 22.60|DE LOSS: 310, PPL: 1290, TM: 307, LM: 2.86|BETA: 0.009367
# 089[s], 31[s], Ep: 42, Ct: 00000|TR LOSS: 318, PPL: 1418|TM NLL: 313, KL: 0.99, REG:0.00 | LM NLL: 3.62, KL: 22.58|DE LOSS: 310, PPL: 1288, TM: 307, LM: 2.88|BETA: 0.009394
# 104[s], 30[s], Ep: 42, Ct: 00500|TR LOSS: 318, PPL: 1417|TM NLL: 313, KL: 0.99, REG:0.00 | LM NLL: 3.61, KL: 22.55|DE LOSS: 310, PPL: 1288, TM: 307, LM: 2.86|BETA: 0.009428
# 083[s], 08[s], Ep: 42, Ct: 01000|TR LOSS: 318, PPL: 1416|TM NLL: 313, KL: 0.99, REG:0.00 | LM NLL: 3.61, KL: 22.52|DE LOSS: 310, PPL: 1291, TM: 307, LM: 2.90|BETA: 0.009463
# 083[s], 08[s], Ep: 42, Ct: 01500|TR LOSS: 318, PPL: 1416|TM NLL: 313, KL: 1.00, REG:0.00 | LM NLL: 3.60, KL: 22.49|DE LOSS: 310, PPL: 1287, TM: 307, LM: 2.85|BETA: 0.009497
# 083[s], 08[s], Ep: 42, Ct: 02000|TR LOSS: 318, PPL: 1415|TM NLL: 313, KL: 1.00, REG:0.00 | LM NLL: 3.60, KL: 22.46|DE LOSS: 310, PPL: 1288, TM: 307, LM: 2.85|BETA: 0.009531
# 082[s], 08[s], Ep: 42, Ct: 02500|TR LOSS: 318, PPL: 1415|TM NLL: 313, KL: 1.00, REG:0.00 | LM NLL: 3.60, KL: 22.43|DE LOSS: 310, PPL: 1289, TM: 307, LM: 2.89|BETA: 0.009566
# 089[s], 30[s], Ep: 43, Ct: 00000|TR LOSS: 318, PPL: 1414|TM NLL: 313, KL: 1.00, REG:0.00 | LM NLL: 3.59, KL: 22.40|DE LOSS: 310, PPL: 1287, TM: 307, LM: 2.82|BETA: 0.009592
# 083[s], 08[s], Ep: 43, Ct: 00500|TR LOSS: 318, PPL: 1414|TM NLL: 313, KL: 1.00, REG:0.00 | LM NLL: 3.59, KL: 22.37|DE LOSS: 310, PPL: 1289, TM: 307, LM: 2.85|BETA: 0.009627
# 105[s], 30[s], Ep: 43, Ct: 01000|TR LOSS: 318, PPL: 1413|TM NLL: 313, KL: 1.01, REG:0.00 | LM NLL: 3.59, KL: 22.34|DE LOSS: 310, PPL: 1286, TM: 307, LM: 2.81|BETA: 0.009661
# 083[s], 08[s], Ep: 43, Ct: 01500|TR LOSS: 318, PPL: 1413|TM NLL: 313, KL: 1.01, REG:0.00 | LM NLL: 3.58, KL: 22.30|DE LOSS: 310, PPL: 1290, TM: 307, LM: 2.82|BETA: 0.009696
# 083[s], 08[s], Ep: 43, Ct: 02000|TR LOSS: 318, PPL: 1412|TM NLL: 313, KL: 1.01, REG:0.00 | LM NLL: 3.58, KL: 22.27|DE LOSS: 310, PPL: 1287, TM: 307, LM: 2.85|BETA: 0.009730
# 083[s], 08[s], Ep: 43, Ct: 02500|TR LOSS: 318, PPL: 1412|TM NLL: 313, KL: 1.01, REG:0.00 | LM NLL: 3.57, KL: 22.24|DE LOSS: 310, PPL: 1287, TM: 307, LM: 2.83|BETA: 0.009765
# 065[s], 08[s], Ep: 44, Ct: 00000|TR LOSS: 318, PPL: 1411|TM NLL: 313, KL: 1.02, REG:0.00 | LM NLL: 3.57, KL: 22.21|DE LOSS: 310, PPL: 1290, TM: 307, LM: 2.81|BETA: 0.009791
# 083[s], 08[s], Ep: 44, Ct: 00500|TR LOSS: 318, PPL: 1411|TM NLL: 313, KL: 1.02, REG:0.00 | LM NLL: 3.57, KL: 22.18|DE LOSS: 310, PPL: 1286, TM: 307, LM: 2.84|BETA: 0.009826
# 083[s], 08[s], Ep: 44, Ct: 01000|TR LOSS: 318, PPL: 1410|TM NLL: 313, KL: 1.02, REG:0.00 | LM NLL: 3.56, KL: 22.15|DE LOSS: 310, PPL: 1287, TM: 307, LM: 2.82|BETA: 0.009860
# 083[s], 08[s], Ep: 44, Ct: 01500|TR LOSS: 318, PPL: 1410|TM NLL: 313, KL: 1.02, REG:0.00 | LM NLL: 3.56, KL: 22.12|DE LOSS: 310, PPL: 1288, TM: 307, LM: 2.86|BETA: 0.009895
# 083[s], 08[s], Ep: 44, Ct: 02000|TR LOSS: 318, PPL: 1409|TM NLL: 313, KL: 1.02, REG:0.00 | LM NLL: 3.56, KL: 22.09|DE LOSS: 310, PPL: 1286, TM: 307, LM: 2.86|BETA: 0.009929
# 083[s], 08[s], Ep: 44, Ct: 02500|TR LOSS: 318, PPL: 1409|TM NLL: 313, KL: 1.03, REG:0.00 | LM NLL: 3.55, KL: 22.05|DE LOSS: 310, PPL: 1284, TM: 307, LM: 2.81|BETA: 0.009963
# 089[s], 31[s], Ep: 45, Ct: 00000|TR LOSS: 318, PPL: 1409|TM NLL: 313, KL: 1.03, REG:0.00 | LM NLL: 3.55, KL: 22.03|DE LOSS: 310, PPL: 1284, TM: 307, LM: 2.83|BETA: 0.009990
# 083[s], 08[s], Ep: 45, Ct: 00500|TR LOSS: 318, PPL: 1408|TM NLL: 313, KL: 1.03, REG:0.00 | LM NLL: 3.54, KL: 22.00|DE LOSS: 310, PPL: 1289, TM: 307, LM: 2.81|BETA: 0.010024
# 083[s], 08[s], Ep: 45, Ct: 01000|TR LOSS: 318, PPL: 1408|TM NLL: 313, KL: 1.03, REG:0.00 | LM NLL: 3.54, KL: 21.97|DE LOSS: 310, PPL: 1288, TM: 307, LM: 2.80|BETA: 0.010059
# 083[s], 08[s], Ep: 45, Ct: 01500|TR LOSS: 318, PPL: 1407|TM NLL: 313, KL: 1.03, REG:0.00 | LM NLL: 3.54, KL: 21.93|DE LOSS: 310, PPL: 1283, TM: 307, LM: 2.83|BETA: 0.010093
# 083[s], 08[s], Ep: 45, Ct: 02000|TR LOSS: 318, PPL: 1407|TM NLL: 313, KL: 1.04, REG:0.00 | LM NLL: 3.53, KL: 21.90|DE LOSS: 310, PPL: 1283, TM: 307, LM: 2.90|BETA: 0.010128
# 121[s], 46[s], Ep: 45, Ct: 02500|TR LOSS: 318, PPL: 1406|TM NLL: 313, KL: 1.04, REG:0.00 | LM NLL: 3.53, KL: 21.87|DE LOSS: 310, PPL: 1286, TM: 307, LM: 2.81|BETA: 0.010162
# 066[s], 08[s], Ep: 46, Ct: 00000|TR LOSS: 318, PPL: 1406|TM NLL: 313, KL: 1.04, REG:0.00 | LM NLL: 3.53, KL: 21.85|DE LOSS: 310, PPL: 1286, TM: 307, LM: 2.81|BETA: 0.010189
# ...
# 084[s], 08[s], Ep: 154, Ct: 02000|TR LOSS: nan, PPL: 1326|TM NLL: 310, KL: 1.41, REG:0.38 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1286, TM: 308, LM: nan|BETA: 0.031301
# 084[s], 08[s], Ep: 154, Ct: 02500|TR LOSS: nan, PPL: 1326|TM NLL: 310, KL: 1.41, REG:0.38 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1289, TM: 308, LM: nan|BETA: 0.031336
# 067[s], 09[s], Ep: 155, Ct: 00000|TR LOSS: nan, PPL: 1326|TM NLL: 310, KL: 1.41, REG:0.38 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1287, TM: 308, LM: nan|BETA: 0.031364
# 084[s], 09[s], Ep: 155, Ct: 00500|TR LOSS: nan, PPL: 1326|TM NLL: 310, KL: 1.41, REG:0.39 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1288, TM: 308, LM: nan|BETA: 0.031399
# 083[s], 09[s], Ep: 155, Ct: 01000|TR LOSS: nan, PPL: 1326|TM NLL: 310, KL: 1.41, REG:0.39 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1289, TM: 308, LM: nan|BETA: 0.031434
# 084[s], 09[s], Ep: 155, Ct: 01500|TR LOSS: nan, PPL: 1326|TM NLL: 310, KL: 1.41, REG:0.39 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1289, TM: 308, LM: nan|BETA: 0.031470
# 084[s], 09[s], Ep: 155, Ct: 02000|TR LOSS: nan, PPL: 1326|TM NLL: 310, KL: 1.41, REG:0.39 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1287, TM: 308, LM: nan|BETA: 0.031505
# 084[s], 09[s], Ep: 155, Ct: 02500|TR LOSS: nan, PPL: 1326|TM NLL: 310, KL: 1.41, REG:0.39 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1288, TM: 308, LM: nan|BETA: 0.031540
# 066[s], 08[s], Ep: 156, Ct: 00000|TR LOSS: nan, PPL: 1326|TM NLL: 310, KL: 1.41, REG:0.39 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1287, TM: 308, LM: nan|BETA: 0.031568
# 083[s], 08[s], Ep: 156, Ct: 00500|TR LOSS: nan, PPL: 1326|TM NLL: 310, KL: 1.41, REG:0.39 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1289, TM: 308, LM: nan|BETA: 0.031603
# 083[s], 09[s], Ep: 156, Ct: 01000|TR LOSS: nan, PPL: 1326|TM NLL: 310, KL: 1.41, REG:0.39 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1284, TM: 308, LM: nan|BETA: 0.031638
# 083[s], 09[s], Ep: 156, Ct: 01500|TR LOSS: nan, PPL: 1326|TM NLL: 310, KL: 1.41, REG:0.39 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1286, TM: 308, LM: nan|BETA: 0.031674
# 083[s], 08[s], Ep: 156, Ct: 02000|TR LOSS: nan, PPL: 1325|TM NLL: 310, KL: 1.41, REG:0.39 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1288, TM: 308, LM: nan|BETA: 0.031709
# 083[s], 09[s], Ep: 156, Ct: 02500|TR LOSS: nan, PPL: 1325|TM NLL: 310, KL: 1.41, REG:0.39 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1287, TM: 308, LM: nan|BETA: 0.031745
# 066[s], 09[s], Ep: 157, Ct: 00000|TR LOSS: nan, PPL: 1325|TM NLL: 310, KL: 1.41, REG:0.39 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1287, TM: 308, LM: nan|BETA: 0.031772
# 083[s], 09[s], Ep: 157, Ct: 00500|TR LOSS: nan, PPL: 1325|TM NLL: 310, KL: 1.41, REG:0.39 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1286, TM: 308, LM: nan|BETA: 0.031807
# 084[s], 09[s], Ep: 157, Ct: 01000|TR LOSS: nan, PPL: 1325|TM NLL: 310, KL: 1.41, REG:0.39 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1290, TM: 308, LM: nan|BETA: 0.031843
# 084[s], 09[s], Ep: 157, Ct: 01500|TR LOSS: nan, PPL: 1325|TM NLL: 310, KL: 1.41, REG:0.39 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1288, TM: 308, LM: nan|BETA: 0.031878
# 083[s], 09[s], Ep: 157, Ct: 02000|TR LOSS: nan, PPL: 1325|TM NLL: 310, KL: 1.41, REG:0.39 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1288, TM: 308, LM: nan|BETA: 0.031913
# 083[s], 08[s], Ep: 157, Ct: 02500|TR LOSS: nan, PPL: 1325|TM NLL: 310, KL: 1.41, REG:0.39 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1288, TM: 308, LM: nan|BETA: 0.031949
# 066[s], 08[s], Ep: 158, Ct: 00000|TR LOSS: nan, PPL: 1325|TM NLL: 310, KL: 1.41, REG:0.39 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1286, TM: 308, LM: nan|BETA: 0.031976
# 084[s], 09[s], Ep: 158, Ct: 00500|TR LOSS: nan, PPL: 1325|TM NLL: 310, KL: 1.41, REG:0.39 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1286, TM: 308, LM: nan|BETA: 0.032011
# 084[s], 09[s], Ep: 158, Ct: 01000|TR LOSS: nan, PPL: 1325|TM NLL: 310, KL: 1.41, REG:0.39 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1286, TM: 308, LM: nan|BETA: 0.032047
# 084[s], 09[s], Ep: 158, Ct: 01500|TR LOSS: nan, PPL: 1325|TM NLL: 310, KL: 1.41, REG:0.39 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1287, TM: 308, LM: nan|BETA: 0.032082
# 083[s], 09[s], Ep: 158, Ct: 02000|TR LOSS: nan, PPL: 1325|TM NLL: 310, KL: 1.41, REG:0.39 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1287, TM: 308, LM: nan|BETA: 0.032118
# 083[s], 08[s], Ep: 158, Ct: 02500|TR LOSS: nan, PPL: 1325|TM NLL: 310, KL: 1.41, REG:0.39 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1285, TM: 308, LM: nan|BETA: 0.032153
# 066[s], 08[s], Ep: 159, Ct: 00000|TR LOSS: nan, PPL: 1325|TM NLL: 310, KL: 1.41, REG:0.39 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1290, TM: 308, LM: nan|BETA: 0.032180
# 083[s], 08[s], Ep: 159, Ct: 00500|TR LOSS: nan, PPL: 1325|TM NLL: 310, KL: 1.41, REG:0.39 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1288, TM: 308, LM: nan|BETA: 0.032215
# 084[s], 09[s], Ep: 159, Ct: 01000|TR LOSS: nan, PPL: 1325|TM NLL: 310, KL: 1.41, REG:0.39 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1285, TM: 308, LM: nan|BETA: 0.032251
# 083[s], 08[s], Ep: 159, Ct: 01500|TR LOSS: nan, PPL: 1325|TM NLL: 310, KL: 1.41, REG:0.39 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1286, TM: 308, LM: nan|BETA: 0.032286
# 083[s], 09[s], Ep: 159, Ct: 02000|TR LOSS: nan, PPL: 1325|TM NLL: 310, KL: 1.41, REG:0.39 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1286, TM: 308, LM: nan|BETA: 0.032322
# 083[s], 08[s], Ep: 159, Ct: 02500|TR LOSS: nan, PPL: 1325|TM NLL: 310, KL: 1.41, REG:0.39 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1287, TM: 308, LM: nan|BETA: 0.032357
# 066[s], 08[s], Ep: 160, Ct: 00000|TR LOSS: nan, PPL: 1325|TM NLL: 310, KL: 1.41, REG:0.40 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1287, TM: 308, LM: nan|BETA: 0.032384
# 083[s], 08[s], Ep: 160, Ct: 00500|TR LOSS: nan, PPL: 1325|TM NLL: 310, KL: 1.41, REG:0.40 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1288, TM: 308, LM: nan|BETA: 0.032420
# 084[s], 09[s], Ep: 160, Ct: 01000|TR LOSS: nan, PPL: 1325|TM NLL: 310, KL: 1.41, REG:0.40 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1288, TM: 308, LM: nan|BETA: 0.032455
# 083[s], 09[s], Ep: 160, Ct: 01500|TR LOSS: nan, PPL: 1325|TM NLL: 310, KL: 1.41, REG:0.40 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1288, TM: 308, LM: nan|BETA: 0.032490
# 083[s], 08[s], Ep: 160, Ct: 02000|TR LOSS: nan, PPL: 1324|TM NLL: 310, KL: 1.41, REG:0.40 | LM NLL: nan, KL: nan|DE LOSS: nan, PPL: 1292, TM: 308, LM: nan|BETA: 0.032526
# 0 True: elmer lower , a former abc news president who tripled the size of that network 's news division during the # s and # s , has died in florida
# 0 Pred: of
# 1 True: he was #
# 1 Pred: to
# 2 True: abc news president ben sherwood released a statement saying lower died tuesday morning in vero beach
# 2 Pred:
# 3 True: lower served as president of abc news from # to #
# 3 Pred: the
# 4 True: in that time , the news division grew from # to # employees , and the evening news expanded from # minutes to # minutes
# 4 Pred: the
# 5 True: lower also was behind the network 's hiring of broadcasting stars such as peter jennings , ted <unk> and sam donaldson
# 5 Pred: <unk> of to have is the and in
# 6 True: lower was honored with a lifetime achievement emmy award in #
# 6 Pred: of the
# 7 True: lower retired from news in #
# 7 Pred: and of the
# 8 True: he then went on to educate young journalists for more than two decades
# 8 Pred:
# 9 True: a new mexico man accused of beating a woman to death in front of a child and forcing someone to record the beating with a cell phone is set to stand trial
# 9 Pred: the , the the
# 10 True: the hobbs news sun reports ( http : //bit.ly/ # <unk> ) that <unk> stover is scheduled to face a jury next month in lovington district court
# 10 Pred: , the a the the state a of the that
# 11 True: authorities say the # year old hobbs resident beat to death his # year old live girlfriend <unk> boone in march and forced two others to bind her with duct tape while he beat her
# 11 Pred: ,
# 12 True: officials say the child saw most of the beating
# 12 Pred:
# 13 True: the lea county sheriff 's office said stover also admitted injecting boone with methamphetamine prior to an argument
# 13 Pred:
# 14 True: stover faces a number of charges including second degree murder
# 14 Pred: old
# 15 True: he has pleaded not guilty
# 15 Pred: the of
# 16 True: the trial is slated to begin feb. #
# 16 Pred: $ to and the the the not in not the to the
# 17 True: a woman says a # year old girl watched as a man fatally shot her mother and two other people to death at a house on detroit 's northwest side
# 17 Pred: # the
# 18 True: officer cassandra lewis says police found the bodies of two women and a man in the vacant house thursday morning
# 18 Pred: been to the
# 19 True: they appeared to be in their early # s and had been shot
# 19 Pred:
# 20 True: a relative of the male victim tells the detroit news ( http : <unk> ) that she spoke with a # year old girl who watched her mother being shot
# 20 Pred: # to in the the # the old
# 21 True: <unk> hunt says the girl `` is going to need a lot of family around her .
# 21 Pred: the the the the a the
# 22 True: hunt says the girl identified the shooter as her mother 's ex boyfriend
# 22 Pred: the the the say # the year # the in
# 23 True: police did n't immediately release the victim 's names
# 23 Pred: the and the on
# 24 True: authorities searching part of lake michigan and a shoreline in southwestern michigan for a missing woman have found her body
# 24 Pred: the the and two a he of and
# 25 True: the grand rapids press reports ( http : <unk> ) the body of the # year old <unk> hall of ottawa county 's park township was found thursday morning along the water in holland state park
# 25 Pred: said
# 26 True: authorities say her death does n't appear to be suspicious
# 26 Pred:
# 27 True: an autopsy was planned
# 27 Pred:
# 28 True: the search began late wednesday
# 28 Pred: of to the to and
# 29 True: authorities say the woman was reported missing by her husband and her shoes were found at a beach in park township
# 29 Pred: to a his to the the
# 30 True: u.s. coast guard crews and ottawa county sheriff 's deputies were involved in the search using boats and a coast guard helicopter
# 30 Pred:
# 31 True: authorities have identified the # year old boy killed in an apartment fire in south salt lake
# 31 Pred: been a and
# 32 True: the south salt lake fire department says jackson avery died of a combination of burns and smoke inhalation on monday
# 32 Pred: the the
# 33 True: avery 's mother and older brother were treated at the scene for smoke inhalation and the boy 's mother was later taken to a hospital with difficulty breathing
# 33 Pred:
# 34 True: authorities say it took # minutes to get the blaze under control to a point where firefighters could enter the downstairs apartment where avery 's body was found by a couch
# 34 Pred:
# 35 True: one other apartment complex resident suffered from smoke inhalation
# 35 Pred: the the to the about the the
# 36 True: fire officials are investigating the cause of the fire , but it appears to be accidental
# 36 Pred: # year the the the the
# 37 True: there will soon be a new member of the d.c. council to replace harry thomas jr. , who stepped down from his ward # seat after pleading guilty to embezzling more than $ # from the city
# 37 Pred:
# 38 True: voters in ward # cast their ballots in a special election tuesday
# 38 Pred:
# 39 True: the winner will serve the rest of thomas ' term , which runs through #
# 39 Pred: the the the
# 40 True: unofficial results as of # p.m. tuesday had <unk> mcduffie in the lead with # votes ; delano hunter , also a democrat , was second with # votes
# 40 Pred: , the
# 41 True: registered voters from any party were eligible to participate in the special election
# 41 Pred: the can the the
# 42 True: ten democrats , one republican and one independent were on the ballot barring a recount , the election results will be certified and the winner will be sworn in on may #
# 42 Pred: the <unk>
# 43 True: a london based sports wagering firm is betting on nevada and the u.s. with the purchase of a las vegas based bookmaking company
# 43 Pred: the has
# 44 True: william hill plc announced plans to purchase brandywine bookmaking llc , pending regulatory approval
# 44 Pred: the will the not to
# 45 True: spokesman david rodriguez in san francisco said tuesday the deal involves $ # million in cash before adjustments and working capital , and a $ # million convertible loan
# 45 Pred: the the will of the the
# 46 True: william hill has # outlets in the united kingdom , and handles about # percent of the uk market
# 46 Pred: the both the to the the a the the are of the
# 47 True: brandywine operates # sports book outlets in the las vegas area and sets odds for the delaware state sports lottery
# 47 Pred: the the to
# 48 True: on april # , william hill acquired las vegas based american wagering , with # leroy 's brand sports books and kiosks , and the reno based cal neva satellite race and sports book division with # outlets
# 48 Pred:
# 49 True: ( ap )
# 49 Pred: the say at the two <unk>
# 50 True: a portion of a road near the west virginia turnpike is open again after being temporarily closed because dynamite was found
# 50 Pred: agency the the the the the # the to
# 51 True: state police had closed a portion of cabin creek road on monday afternoon after discovering a stick of dynamite beneath the underpass along w.va
# 51 Pred:
# 52 True: #
# 52 Pred:
# 53 True: police dispatchers told the charleston gazette ( http : <unk> # ) that a state police bomb squad inspected the area and removed the dynamite
# 53 Pred: a
# 54 True: authorities are trying to determine how the explosive ended up along the roadway
# 54 Pred:
# 55 True: the indiana department of natural resources says # year old eugene schneider of fort branch was pulled from the water shortly before # p.m. sunday and pronounced dead at a hospital in evansville
# 55 Pred: # the the at : the
# 56 True: schneider left his home to go fishing around # p.m. sunday at a private pond near <unk>
# 56 Pred: the the old , to the
# 57 True: his son found him face down and unresponsive in the pond after schneider failed to return
# 57 Pred:
# 58 True: conservation officers with the state department of natural resources are investigating the incident
# 58 Pred: the he is
# 59 True: an autopsy is scheduled for monday afternoon at the vanderburgh county coroner 's office
# 59 Pred: house a about the
# 60 True: south dakota 's top leaders are touring two towns hit by natural disasters
# 60 Pred: the of #
# 61 True: gov . dennis daugaard will visit <unk> springs thursday morning to see the recovery progress from a tornado that hit the town last week and hold a briefing with reporters
# 61 Pred: the
# 62 True: lt. gov . matt <unk> will tour flooded areas of canton on thursday morning , meet with local officials and brief the media
# 62 Pred:
# 63 True: flooding began early last week when the town received more than # inches of rain in one day
# 63 Pred: the and
# -----------Topic Samples-----------
# 0  bow: fire water family firefighters pilot students director tv environmental department
# 0  sent:
# 1  bow: service represented world agreement reports director land winning military trail
# 1  sent:
# 2  bow: system snow american security feet storm times day counties guard
# 2  sent:
# 3  bow: federal department council authorities species damages service ban chairman communications
# 3  sent:
# 4  bow: service water law national president board u.s. weather river university
# 4  sent:
# 5  bow: project general department weather market snow rights total planned number
# 5  sent:
# 6  bow: pronounced happened spokeswoman investigating tells press arrest identified comment late
# 6  sent: <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# 7  bow: service family area lawsuit president include water judge seeking staff
# 7  sent:
# 8  bow: fire found authorities court woman home death charged car arrested
# 8  sent:
# 9  bow: percent million company bill senate republican tax house billion budget
# 9  sent:

# %% [markdown]
# # confirm variables

# %%
_prob_topic, _prob_topic_sents, _prob_topic_infer, _means_topic_infer = debug_value([prob_topic, prob_topic_sents, prob_topic_infer, means_topic_infer], return_value=True)

# %%
batch_i = 4
_prob_topic_sents[batch_i], _prob_topic_infer[batch_i]
# Out:
# (array([1.2281889e-02, 6.7835855e-03, 2.0132679e-01, 1.1674699e-02,
#         6.5264981e-03, 1.1411838e-02, 6.9189700e-03, 2.8612482e-04,
#         7.4042326e-01, 2.3663496e-03], dtype=float32),
#  array([0.09889801, 0.11335436, 0.12141278, 0.10027827, 0.13508864,
#         0.09455997, 0.0860846 , 0.08042429, 0.09635323, 0.07354581],
#        dtype=float32))

# %%
_means_topic_infer[0][:, :4]
# Out:
# array([[-0.02824139, -0.22793637,  0.3788033 , -0.02814816],
#        [ 0.06249218, -0.08085692,  0.06756439,  0.2259818 ],
#        [-0.1377574 ,  0.28185233,  0.23656711, -0.3201025 ],
#        [-0.03711405,  0.16953555,  0.16389738, -0.16461828],
#        [ 0.27302447, -0.22462857,  0.37200606, -0.00549014],
#        [-0.16755986,  0.11964113,  0.17052333,  0.18083367],
#        [ 0.26351342, -0.33828875,  0.3920058 , -0.17029142],
#        [ 0.21033517, -0.1955087 ,  0.20963705, -0.24809986],
#        [ 0.01922028, -0.03185754,  0.28022933, -0.13928899],
#        [-0.26817918, -0.3364467 ,  0.36924574,  0.15818927]],
#       dtype=float32)

# %%
w_means_topic, b_means_topic = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, "topic/dec/mean_topic")

pred_topic_embeddings, pred_topic_bow, pred_means_topic, pred_logvars_topic, pred_token_idxs, _w_means_topic, _b_means_topic, _w_mean_topic_infer = \
                                sess.run([topic_embeddings, topic_bow, means_topic, logvars_topic, topic_beam_output_token_idxs, w_means_topic, b_means_topic, w_mean_topic_infer], 
                                         feed_dict={t_variables['batch_l']: config.n_topic, t_variables['keep_prob']: 1.,})

pred_sents = idxs_to_sents(pred_token_idxs, config, idx_to_word)

pred_topics_freq_bow_indices = np.argsort(pred_topic_bow, 1)[:, ::-1][:, :10]
pred_topics_freq_bow_idxs = bow_idxs[pred_topics_freq_bow_indices]

# %%
for idxs in pred_topics_freq_bow_idxs:
    print([idx_to_word[idx] for idx in idxs])
# Out:
# ['million', 'http', 'years', 'tuesday', 'federal', 'u.s.', 'month', 'office', 'people', 'monday']
# ['reports', 'department', 'thursday', 'court', 'time', 'u.s.', 'years', 'monday', 'tuesday', "'"]
# ['school', 'public', 'u.s.', 'board', 'university', 'federal', 'president', 'program', 'health', 'students']
# ['fire', 'found', 'authorities', 'hospital', 'home', 'a.m.', 'dead', 'investigation', 'chief', 'morning']
# ['service', 'national', 'department', 'http', 'water', 'park', 'area', 'center', 'wednesday', 'weather']
# ['percent', 'company', 'million', 'billion', 'shares', 'inc.', 'revenue', 'average', 'cents', 'price']
# ['design', 'researchers', 'donations', 'prize', 'encourage', 'peak', 'awards', 'feature', 'chapter', 'affect']
# ['court', 'arrested', 'charged', 'attorney', 'death', 'authorities', 'found', 'prison', 'shooting', 'woman']
# ['bill', 'senate', 'house', 'republican', 'committee', 'public', 'board', 'approved', 'u.s.', 'law']
# ['todd', 'rear', 'drowned', 'confronted', 'foul', 'transported', 'assaulted', 'loaded', 'defender', 'unidentified']

# %%
pred_topic_embeddings[:, :10]
# Out:
# array([[ 0.09207956,  0.09077395,  0.06120839, -0.22176096,  0.19921999,
#         -0.05485373, -0.23069587,  0.05650459,  0.142239  , -0.17410392],
#        [ 0.29974467, -0.03281972,  0.25064805, -0.2893645 , -0.1312135 ,
#         -0.11136644,  0.02060958, -0.13598587,  0.24592783, -0.18463418],
#        [ 0.22819577,  0.14566512,  0.05597903, -0.1109414 , -0.00879419,
#         -0.1605561 ,  0.11445126,  0.00916692, -0.04847115, -0.0603605 ],
#        [ 0.3365141 , -0.06439152,  0.3631938 ,  0.14203475,  0.10052318,
#         -0.09119357, -0.08768138, -0.28562906,  0.3186355 , -0.08452626],
#        [ 0.26727033,  0.03540339,  0.28315246, -0.1286456 , -0.02444943,
#         -0.163507  , -0.02146725, -0.21729966,  0.26542294, -0.1589102 ],
#        [ 0.28826687, -0.18438952,  0.2760168 , -0.12692557,  0.05485712,
#          0.17983724,  0.14970489, -0.36168167,  0.30563408, -0.13128197],
#        [-0.32988435, -0.11005852, -0.27013943,  0.26166642, -0.3013388 ,
#         -0.2234488 ,  0.02287463,  0.20320751, -0.10510623,  0.28636736],
#        [ 0.37211177, -0.00585993,  0.2853141 , -0.05771174,  0.15170154,
#          0.05411884, -0.24091715, -0.01475959, -0.0408047 , -0.17167823],
#        [ 0.20512433,  0.18697639, -0.08326819,  0.03792854,  0.03214281,
#          0.05618311,  0.09544107,  0.03913466, -0.06514693, -0.04000437],
#        [-0.3745221 , -0.06385167, -0.29924905,  0.08158813, -0.28344202,
#         -0.01799835,  0.02471407,  0.408938  , -0.169172  ,  0.37273586]],
#       dtype=float32)

# %%
pred_topic_bow
# Out:
# array([[1.0327697e-03, 4.6811462e-03, 1.7024261e-04, ..., 3.3795869e-04,
#         1.5871278e-04, 6.6570101e-05],
#        [5.9443718e-04, 7.4376534e-03, 2.0111131e-04, ..., 7.4048399e-04,
#         1.5028552e-04, 8.9953668e-05],
#        [8.5580017e-04, 2.8901210e-03, 1.6464434e-04, ..., 3.1770146e-04,
#         1.9349743e-04, 3.0012103e-04],
#        ...,
#        [1.3188391e-04, 2.6697975e-03, 2.3009101e-04, ..., 8.1575691e-04,
#         1.5104198e-04, 3.2140684e-05],
#        [3.8558390e-04, 4.0810513e-03, 1.4347673e-04, ..., 1.4157601e-04,
#         1.8342295e-04, 4.7484271e-05],
#        [7.1679087e-06, 2.9757638e-07, 1.8662996e-04, ..., 5.9841594e-05,
#         1.7972868e-04, 5.0798093e-04]], dtype=float32)

# %%
_w_means_topic
# Out:
# array([[ 0.09637171, -0.09069463,  0.09532599, ..., -0.02989542,
#         -0.02514938,  0.01415634],
#        [-0.02764424,  0.01254364,  0.03703775, ..., -0.01512817,
#          0.02590305,  0.01404281],
#        [-0.08408152, -0.00924051, -0.08365072, ...,  0.05623364,
#         -0.05008389,  0.0209127 ],
#        ...,
#        [-0.00629492, -0.05131948, -0.05206006, ..., -0.0955721 ,
#         -0.01980347, -0.02646225],
#        [-0.00839109, -0.05062511, -0.05731497, ...,  0.07618995,
#          0.03893617,  0.06835916],
#        [ 0.07883421, -0.02804748,  0.09326512, ..., -0.0734218 ,
#          0.0045918 , -0.10043538]], dtype=float32)

# %%
_b_means_topic
# Out:
# array([ 0.03207342, -0.08436021,  0.36105958, -0.02925379, -0.26779142,
#        -0.4809294 , -0.04713235, -0.6384421 ,  0.49655244, -0.18943405,
#         0.32139724,  0.00376519, -0.02733823,  0.06968141,  0.12723993,
#         0.17086434,  0.4321125 ,  0.2930171 ,  0.43750855, -0.32728267,
#        -0.29320472,  0.46633536,  0.03467208, -0.11661331,  0.02106199,
#         0.10828511,  0.14413024,  0.00801178, -0.16259423,  0.31461757,
#        -0.25328413,  0.11320477], dtype=float32)

# %%
pred_means_topic
# Out:
# array([[ 0.03563995, -0.3379975 ,  1.6953684 , -0.3394102 , -1.3313038 ,
#         -1.9561913 , -0.34439525, -3.1041431 ,  2.302101  , -0.80340064,
#          1.374892  ,  0.10505254,  0.13142577,  0.36230466,  0.5036737 ,
#          0.6154421 ,  1.8879794 ,  1.263777  ,  2.0281937 , -1.4289141 ,
#         -1.3110695 ,  2.0390706 ,  0.32288784, -0.39520237,  0.10320839,
#          0.35608286,  0.61754334, -0.1438482 , -0.74413097,  1.4731948 ,
#         -1.1249324 ,  0.33894244],
#        [ 0.03510073, -0.3374708 ,  1.6888778 , -0.3363807 , -1.3308815 ,
#         -1.9608293 , -0.34732953, -3.1081154 ,  2.3005512 , -0.80602133,
#          1.3695524 ,  0.10256523,  0.13283278,  0.36182955,  0.49822897,
#          0.6213894 ,  1.8883276 ,  1.266403  ,  2.023539  , -1.426166  ,
#         -1.3108103 ,  2.0448976 ,  0.32430837, -0.38903922,  0.10560946,
#          0.3596735 ,  0.6160856 , -0.14840832, -0.74532497,  1.4738762 ,
#         -1.1249926 ,  0.33331037],
#        [ 0.03490497, -0.33676392,  1.6840277 , -0.335459  , -1.3295547 ,
#         -1.95664   , -0.3462094 , -3.1003447 ,  2.296549  , -0.80408335,
#          1.367739  ,  0.10281808,  0.13425133,  0.36240244,  0.4972452 ,
#          0.6206323 ,  1.885982  ,  1.2645416 ,  2.0215812 , -1.4212072 ,
#         -1.3081043 ,  2.0386996 ,  0.32136053, -0.39039296,  0.1050597 ,
#          0.36023104,  0.6137113 , -0.15039542, -0.7433981 ,  1.4694595 ,
#         -1.1245916 ,  0.3360805 ],
#        [ 0.03728028, -0.33768234,  1.6832604 , -0.3353232 , -1.325423  ,
#         -1.9593027 , -0.34599763, -3.1006794 ,  2.2962196 , -0.80693865,
#          1.3678529 ,  0.10114851,  0.13371727,  0.36420822,  0.49783063,
#          0.62049437,  1.8832903 ,  1.2625886 ,  2.0200832 , -1.421174  ,
#         -1.3108637 ,  2.0388248 ,  0.32396334, -0.38813725,  0.10552703,
#          0.3586173 ,  0.6122677 , -0.15264365, -0.74335086,  1.468328  ,
#         -1.1214948 ,  0.337562  ],
#        [ 0.0355639 , -0.33673748,  1.6850188 , -0.334822  , -1.3297123 ,
#         -1.9579692 , -0.34517902, -3.0999303 ,  2.296747  , -0.8048171 ,
#          1.3683693 ,  0.10311563,  0.13507861,  0.36239594,  0.4968614 ,
#          0.61993766,  1.8848993 ,  1.2634866 ,  2.0213115 , -1.4220002 ,
#         -1.3081868 ,  2.0382977 ,  0.32180363, -0.39071375,  0.10513556,
#          0.35903966,  0.6132862 , -0.15032193, -0.74355686,  1.4703372 ,
#         -1.1240762 ,  0.3361809 ],
#        [ 0.03776056, -0.33906677,  1.6886759 , -0.33578348, -1.3277831 ,
#         -1.9574624 , -0.3511446 , -3.1008887 ,  2.298576  , -0.80058026,
#          1.3695161 ,  0.10116885,  0.13310117,  0.36374724,  0.49994904,
#          0.62002206,  1.8863395 ,  1.2639412 ,  2.0218256 , -1.4257591 ,
#         -1.3068638 ,  2.038707  ,  0.3251842 , -0.38946715,  0.10602362,
#          0.3615039 ,  0.6127277 , -0.15162012, -0.739843  ,  1.4696462 ,
#         -1.1235677 ,  0.34125343],
#        [ 0.03675649, -0.33748797,  1.6818695 , -0.3343631 , -1.3270382 ,
#         -1.9566132 , -0.34484407, -3.0962553 ,  2.2958052 , -0.8025343 ,
#          1.365838  ,  0.10129849,  0.13410446,  0.36187994,  0.49527365,
#          0.62073433,  1.8827194 ,  1.264018  ,  2.019868  , -1.4191431 ,
#         -1.3083122 ,  2.036423  ,  0.32277   , -0.38972613,  0.10532874,
#          0.36029965,  0.6137044 , -0.14923215, -0.7424054 ,  1.4679198 ,
#         -1.1228634 ,  0.33640632],
#        [ 0.03632384, -0.33631054,  1.6842166 , -0.33446336, -1.3275865 ,
#         -1.959459  , -0.34500512, -3.1014085 ,  2.2958436 , -0.804686  ,
#          1.3688817 ,  0.10245646,  0.13472772,  0.3634492 ,  0.49877107,
#          0.61891234,  1.8855013 ,  1.263787  ,  2.0223496 , -1.4211094 ,
#         -1.309351  ,  2.0364125 ,  0.32266062, -0.3891954 ,  0.10458721,
#          0.35922444,  0.61319816, -0.14912874, -0.7429457 ,  1.469351  ,
#         -1.1232082 ,  0.3378038 ],
#        [ 0.03574873, -0.3368752 ,  1.6819855 , -0.33521634, -1.3290966 ,
#         -1.9556532 , -0.34607896, -3.0987115 ,  2.2963123 , -0.80486095,
#          1.3669474 ,  0.10132913,  0.13473387,  0.36283588,  0.49758494,
#          0.6216788 ,  1.8858868 ,  1.2627757 ,  2.0219636 , -1.4208897 ,
#         -1.3082187 ,  2.0389626 ,  0.32159996, -0.39116064,  0.1062526 ,
#          0.35957128,  0.6122661 , -0.14942539, -0.74453473,  1.468337  ,
#         -1.123489  ,  0.33671775],
#        [ 0.03600421, -0.33810538,  1.6826388 , -0.33433414, -1.3267329 ,
#         -1.9560882 , -0.34396413, -3.096003  ,  2.2952938 , -0.8032101 ,
#          1.366725  ,  0.10274363,  0.13443008,  0.36315334,  0.4956261 ,
#          0.6213716 ,  1.882305  ,  1.2623034 ,  2.0204127 , -1.4200761 ,
#         -1.3082595 ,  2.034914  ,  0.32189733, -0.38998067,  0.10444504,
#          0.35928738,  0.6142209 , -0.1489011 , -0.74237704,  1.4684169 ,
#         -1.1216142 ,  0.3379858 ]], dtype=float32)

# %%
_w_mean_topic_infer[:, :10, 0]
# Out:
# array([[ 0.02438005, -0.02036242, -0.01039507,  0.00277665,  0.02350294,
#          0.01473409, -0.02157389,  0.02251465,  0.00814133,  0.01785252],
#        [ 0.00074128, -0.001453  , -0.01162554, -0.0014644 , -0.02097618,
#          0.00570552,  0.00674119, -0.01879225,  0.02161046,  0.01941887],
#        [ 0.01402811, -0.00613734, -0.0027943 , -0.01052572, -0.00041091,
#          0.0045091 , -0.01547336,  0.0194314 ,  0.00784631,  0.00505763],
#        [ 0.01655601, -0.02403533,  0.01607199, -0.01643238,  0.00686195,
#         -0.01788632,  0.01109112,  0.00087933,  0.00448566, -0.00823843],
#        [-0.00695892,  0.01631877,  0.01657149,  0.01772625,  0.02026216,
#          0.01811663,  0.02153757, -0.00020743, -0.02066918, -0.00025119],
#        [ 0.02195978,  0.00867016, -0.02278856,  0.0122384 , -0.02183604,
#          0.00798479,  0.00545774,  0.00923075,  0.01814621,  0.02018008],
#        [ 0.02242495, -0.00673729,  0.01447002,  0.02163557,  0.02312511,
#         -0.00920323, -0.01116639,  0.01708085, -0.01181559, -0.00763743],
#        [-0.01978129,  0.00916991, -0.00304236,  0.00106503,  0.00690803,
#         -0.01416942,  0.0063372 ,  0.00018093,  0.00393429, -0.00307162],
#        [-0.01821756,  0.01890057,  0.00228031, -0.01240117, -0.01108933,
#         -0.01674686, -0.01161283, -0.01693372,  0.00370204, -0.00271433],
#        [-0.0158878 ,  0.01951969, -0.01606018, -0.00457847,  0.00044555,
#         -0.0050344 , -0.0013686 ,  0.00539651,  0.02015766, -0.00510509]],
#       dtype=float32)

# %%
_b_means_topic
# Out:
# array([ 0.03922943,  0.46112132, -0.08166478, -0.06917454, -0.01617851,
#         0.18225916, -0.28025913, -0.06620797,  0.03231472, -0.02211766,
#        -0.38082743,  0.11382294,  0.39363608, -0.4168986 ,  1.1677127 ,
#         0.08979508,  0.03593519, -0.07863234,  0.12493958,  0.03175303,
#         0.13351525,  0.8176425 , -0.28750482,  0.37927672, -0.01720515,
#        -0.21228473, -0.05377329, -0.10451841, -0.24399954, -0.25936088,
#         0.0845396 ,  0.33591354], dtype=float32)

# %%
_enc_state_infer, _means_topic_infer = debug_value([enc_state_infer, means_topic_infer], return_value=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-ee7c3cd147b5> in <module>
# ----> 1 _enc_state_infer, _means_topic_infer = debug_value([enc_state_infer, means_topic_infer], return_value=True)
#
# NameError: name 'enc_state_infer' is not defined

# %%
_enc_state_infer.shape
# Out:
# (67, 10, 1024)

# %%
_means_topic_infer[0]
# Out:
# array([[-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00],
#        [-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00],
#        [-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00],
#        [-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00],
#        [-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00],
#        [-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00],
#        [-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00],
#        [-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00],
#        [-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00],
#        [-4.4230181e-01, -8.2235533e-01, -3.9928532e-01,  3.3004081e-01,
#          1.2879696e+00,  2.5491878e-01,  5.9280634e+00,  1.8478313e-01,
#          1.1477946e-01,  1.1729380e+00, -3.8528564e+00, -1.1789608e+00,
#          9.1431034e-01, -1.7245387e+00, -2.9743382e-01,  1.0960317e+00,
#          5.1114732e-01,  8.8052756e-01,  5.0135303e-01,  8.0816686e-01,
#         -2.1616230e+00, -1.2552780e+00, -8.6165917e-01, -1.0416836e+00,
#          2.4590290e+00, -5.1620197e+00,  1.5814751e-03,  1.3141291e+00,
#         -6.7580324e-01,  2.8643382e+00, -2.3818936e+00, -2.5698123e+00]],
#       dtype=float32)
