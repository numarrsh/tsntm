# %%
# %load_ext autoreload
# %autoreload

import os
import re
import _pickle as cPickle
from collections import OrderedDict, defaultdict, Counter
import argparse

import numpy as np
import pandas as pd

from data_structure import Instance

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # configure

# %%
parser = argparse.ArgumentParser()
parser.add_argument('-data_path', type=str, default='data/ti/df_pair_label_6F.pickle')
parser.add_argument('-output_path', type=str, default='data/ti/instances.pkl')
parser.add_argument('-large_output_path', type=str, default='data/ti/instances_large.pkl')

config = parser.parse_args('')

# %% [markdown]
# # load source

# %%
def prepare_instances(bows):
    instances = []
    for idx_bow, bow in enumerate(bows):
        instance = Instance()
        instance.idx = idx_bow
        instance.bow = bow
        instances.append(instance)
    return instances

# %% [markdown]
# # group by category

# %%
data_df = pd.read_pickle(config.data_path)

# %%
data_df
# Out:
#                                                 material  \
# 0                     poly(tetrafluoroethylene)_membrane
# 1                              poly(vinylidene_fluoride)
# 2      porous_poly-(tetrafluoroethylene)_diaphragm_me...
# 3                                perfluoropolyalkylether
# 4                                perfluoropolyalkylether
# ...                                                  ...
# 86740                                              eptfe
# 86741                                              eptfe
# 86742                                      eptfe_samples
# 86743                                              eptfe
# 86744                                              eptfe
#
#                                                 use category  \
# 0                         selective_phase_separator     ptfe
# 1                           pyroelectric_transducer     pvdf
# 2                                            sensor     ptfe
# 3      potential_high_temperature_liquid_lubricants     pfpe
# 4                               gas_turbine_engines     pfpe
# ...                                             ...      ...
# 86740           endovascular_stent-graft_technology     ptfe
# 86741           endovascular_stent-graft_technology     ptfe
# 86742           endovascular_stent-graft_technology     ptfe
# 86743           endovascular_stent-graft_technology     ptfe
# 86744           endovascular_stent-graft_technology     ptfe
#
#                                                   vector
# 0      [-0.18909302, -0.4380685, -0.23772866, 0.15662...
# 1      [-0.49744186, 0.58450216, -0.67864054, 0.09927...
# 2      [0.349454, 0.5534546, -1.4320804, -0.24467996,...
# 3      [-0.81132436, 0.39675534, -0.5084254, 0.105702...
# 4      [-0.8650705, -0.27476096, -0.2663428, 0.243225...
# ...                                                  ...
# 86740  [0.27829906, -1.0336405, -0.56483704, 0.352723...
# 86741  [0.27829906, -1.0336405, -0.56483704, 0.352723...
# 86742  [0.27829906, -1.0336405, -0.56483704, 0.352723...
# 86743  [0.27829906, -1.0336405, -0.56483704, 0.352723...
# 86744  [0.27829906, -1.0336405, -0.56483704, 0.352723...
#
# [86745 rows x 4 columns]

# %%
use_df = data_df[~data_df.duplicated(subset='use')]
# filtered_uses = [use for use, cnt in data_df.use.value_counts().items() if cnt > 300]
# use_df = use_df[use_df['use'].apply(lambda use: use not in filtered_uses)]
word_to_idx = {use: idx for idx, use in enumerate(use_df.use)}
idx_to_word = {idx: use for use, idx in word_to_idx.items()}
embeddings = np.array(use_df.vector.values.tolist())
assert len(word_to_idx) == len(idx_to_word) == len(embeddings)

# %%
category_df = data_df.groupby('category').agg({
    'use': lambda use_series: Counter(use_series)
})
instances_df = category_df.use.apply(lambda use_cnt: np.array([use_cnt[use] if use in use_cnt else 0 for _, use in idx_to_word.items()]))
bows = np.array(instances_df.values.tolist())
categories = instances_df.index
instances = prepare_instances(bows)

# %%
print('saving preprocessed instances...')
cPickle.dump((instances, categories, word_to_idx, idx_to_word, embeddings), open(config.output_path, 'wb'))
# Out:
# saving preprocessed instances...

# %%
category_df['use_set'] = category_df['use'].apply(lambda use_cnts: set(use_cnts.keys()))
for category in categories:
    category_df[category] = category_df['use_set'].apply(lambda use_set: len(use_set & category_df['use_set'][category]))
category_df
# Out:
#                                                         use  \
# category
# etfe      {'navigation_instrument_backplane': 1, 'applic...
# fep       {'glass_battery_jar': 1, 'pipe': 1, 'flexible_...
# pctfe     {'molecular_sensing_probes': 1, 'polymer_trans...
# pfa       {'transformer_oil': 1, 'ftfe_diaphragms': 2, '...
# pfpe      {'potential_high_temperature_liquid_lubricants...
# ptfe      {'selective_phase_separator': 1, 'sensor': 52,...
# pvdf      {'pyroelectric_transducer': 3, 'hydrophones': ...
#
#                                                     use_set  etfe  fep  pctfe  \
# category
# etfe      {high-temperature_service_conductors, commerci...   313   23      4
# fep       {organic_white_paint_whereas_optical_solar_ref...    23  252      2
# pctfe     {"_at-risk_"_systems, coated_fabrics, molecula...     4    2     78
# pfa       {cation_exchange_membranes, light_reflector, a...     6    4      0
# pfpe      {top_mobile_lubricant_layer, excellent_lubrica...    10   13      3
# ptfe      {gtr_treatment, permanent_vascular_accesses, a...    79  124     28
# pvdf      {stirred_flat_membrane_cell, superhydrophobic_...    55   47     11
#
#           pfa  pfpe  ptfe  pvdf
# category
# etfe        6    10    79    55
# fep         4    13   124    47
# pctfe       0     3    28    11
# pfa        21     0    13     4
# pfpe        0   592    95    40
# ptfe       13    95  8075   555
# pvdf        4    40   555  6430

# %%
data_df[data_df['category'] == 'pvdf'].use.value_counts()[:30]
# Out:
# binder                                  610
# sensor                                  577
# sensors                                 462
# electrodes                              393
# hollow_fiber_membranes                  323
# actuators                               302
# electrode                               248
# lithium-ion_batteries                   225
# ultrafiltration                         218
# ultrafiltration_membranes               211
# separator                               189
# membrane_distillation                   185
# hollow_fiber_membrane                   178
# pvdf_sensor                             150
# pvdf_sensors                            149
# electrolyte                             149
# cathode                                 144
# actuator                                138
# microfiltration                         137
# ferro-actuator                          125
# direct_contact_membrane_distillation    124
# cell                                    123
# mf                                      122
# ultrafiltration_membrane                111
# transducers                             111
# energy_harvesting                       110
# wastewater_treatment                    110
# lithium_ion_batteries                   107
# water_treatment                         105
# microfiltration_membrane                104
# Name: use, dtype: int64

# %% [markdown]
# # group by material

# %%
materials = [material for material, cnt in data_df.material.value_counts().items() if cnt > 100]
filtered_data_df = data_df[data_df['material'].apply(lambda material: material in materials)]
len(materials)
# Out:
# 43

# %%
use_df = filtered_data_df[~filtered_data_df.duplicated(subset='use')]

word_to_idx = {use: idx for idx, use in enumerate(use_df.use)}
idx_to_word = {idx: use for use, idx in word_to_idx.items()}
embeddings = np.array(use_df.vector.values.tolist())
assert len(word_to_idx) == len(idx_to_word) == len(embeddings)

# %%
material_df = filtered_data_df.groupby('material').agg({
    'use': lambda use_series: Counter(use_series)
})
large_instances_df = material_df.use.apply(lambda use_cnt: np.array([use_cnt[use] if use in use_cnt else 0 for _, use in idx_to_word.items()]))
large_bows = np.array(large_instances_df.values.tolist())
materials = large_instances_df.index
large_instances = prepare_instances(large_bows)

# %%
material_df['use_set'] = material_df['use'].apply(lambda use_cnts: set(use_cnts.keys()))
for material in materials:
    material_df[material] = material_df['use_set'].apply(lambda use_set: len(use_set & material_df['use_set'][material]))
material_df
# Out:
#                                                                                      use  \
# material
# eptfe                                  {'transcatheter_closure': 1, 'autogenous_vein_...
# eptfe_graft                            {'vascular_graft': 5, 'palliative_treatment': ...
# eptfe_grafts                           {'artifical_heart_structures': 1, 'eptfe_vascu...
# eptfe_group                            {'prosthetic_substitutes': 1, 'svc_substitute'...
# eptfe_membrane                         {'gingival_flap_surgery': 1, 'regenerative_pro...
# etfe                                   {'applications': 1, 'wiring': 1, 'insulation_m...
# expanded_polytetrafluoroethylene       {'vascular_grafts': 31, 'femoropopliteal_posit...
# fluorinated_ethylene_propylene         {'pipe': 1, 'thickeners': 2, 'target_grease': ...
# pctfe                                  {'polymer_transfer_film': 3, 'hplc_supports': ...
# perfluoropolyether                     {'acrylic_uv-curable_systems': 1, 'conventiona...
# pfpe                                   {'data_storage_media': 2, 'thin_film_magnetic_...
# pfpes                                  {'magnetic_recording_files': 1, 'ep_gear_lubri...
# piezoelectric_polyvinylidene_fluoride  {'transduction_material': 1, 'practical_hydrop...
# poly(tetrafluoroethylene)              {'hydrophobic_electrodes': 1, 'different_spray...
# poly(vinylidene_fluoride)              {'pyroelectric_transducer': 1, 'electrode': 10...
# poly_(vinylidene_fluoride)             {'device_applications': 2, 'distributed-parame...
# polytetrafluoroethylene                {'glass_battery_jar': 1, 'burn_depth_detection...
# polytetrafluoroethylene_graft          {'vascular_conduit': 1, 'vascular_accesses': 2...
# polytetrafluoroethylene_grafts         {'ptfe_vascular_prosthesis': 1, 'vascular_subs...
# polyvinylidene_difluoride              {'piezoelectric_detectors': 1, 'important_tran...
# polyvinylidene_fluoride                {'electromagnetic_acoustic_transducers': 1, 'p...
# polyvinylidenefluoride                 {'pressure_sensors': 1, 'microphones': 1, 'aud...
# porous_pvdf_membrane                   {'bipolar_membrane': 1, 'pvdf-gma-ida_bipolar_...
# ptfe                                   {'glass_battery_jar': 3, 'burn_depth_detection...
# ptfe_graft                             {'new_arterial_prosthesis': 1, 'arterial_graft...
# ptfe_grafts                            {'stent_deployment': 1, 'fistula_construction'...
# ptfe_group                             {'chronic_hemodialysis_access': 1, 'graft_fist...
# ptfe_membrane                          {'gas-diffusion_unit': 1, 'titanium_dental_imp...
# ptfe_membranes                         {'titanium_dental_implants': 3, 'biosensor_uti...
# ptfe_particles                         {'lubricants': 1, 'gore-_tex_ptfe_acl_prosthes...
# pvdf                                   {'piezoelectric_detectors': 1, 'proton_conduct...
# pvdf-hfp                               {'polymer_electrolyte_membranes': 6, 'electric...
# pvdf_/                                 {'polymer_electrolyte_membranes': 5, 'coupled_...
# pvdf_binder                            {'electrode': 15, 'electric_double-layer_capac...
# pvdf_fibers                            {'active_textiles': 1, 'nanostructured_active_...
# pvdf_film                              {'model_transducer': 1, 'pvdf_sensor': 6, 'act...
# pvdf_films                             {'finger_pulse': 1, 'wave_sensor': 1, 'pyroele...
# pvdf_matrix                            {'working_electrode': 1, 'proton_exchange_memb...
# pvdf_membrane                          {'direct_contact_membrane_distillation_type_ex...
# pvdf_membranes                         {'continuous_flow_reactor': 5, 'transfer_membr...
# pvdf_nanofibers                        {'active_textiles': 1, 'nanostructured_active_...
# pvdf_sensor                            {'model_transducer': 1, 'pvdf_sensor': 43, 'ac...
# pvdf_sensors                           {'sensors': 15, 'narrow_strip_pvdf_sensors': 2...
#
#                                                                                  use_set  \
# material
# eptfe                                  {small_nerve_defects, interposition_prostheses...
# eptfe_graft                            {vascular_access, ideal_venous_graft, femoral_...
# eptfe_grafts                           {bilateral_renal_artery_circulation, vascular_...
# eptfe_group                            {exclusion_barrier, limb_bypass_surgery, lumba...
# eptfe_membrane                         {gynecologic_surgery, molded_eptfe_valve, bone...
# etfe                                   {high-temperature_service_conductors, canine_c...
# expanded_polytetrafluoroethylene       {vascular_access, frontalis_suspension_surgery...
# fluorinated_ethylene_propylene         {spacecraft, high-temperature_service_conducto...
# pctfe                                  {"_at-risk_"_systems, optical_viewports, valve...
# perfluoropolyether                     {top_mobile_lubricant_layer, liquid_lubricant,...
# pfpe                                   {top_mobile_lubricant_layer, liquid_lubricant,...
# pfpes                                  {excellent_lubricant, disk_lubricants, biotin_...
# piezoelectric_polyvinylidene_fluoride  {fingerprint_sensor_applications, sensor_patch...
# poly(tetrafluoroethylene)              {carbon_adsorbent, different_spray_chambers, b...
# poly(vinylidene_fluoride)              {pore-former, coagulation_bath, building_exter...
# poly_(vinylidene_fluoride)             {electric_power_generation, acoustic_actuator_...
# polytetrafluoroethylene                {pulmonary_valve, heparin-bonded_eptfe_grafts,...
# polytetrafluoroethylene_graft          {vascular_access, aortic_arch, ivc_replacement...
# polytetrafluoroethylene_grafts         {novel_slow_release_antibiotic_coatings, limb_...
# polyvinylidene_difluoride              {stirred-cell_system, high-temperatureproton-e...
# polyvinylidene_fluoride                {stirred_flat_membrane_cell, exhaled_air_energ...
# polyvinylidenefluoride                 {probe_transducer, battery_performance, mf, nu...
# porous_pvdf_membrane                   {cell, diaphragms, air-cathode_mfc, cantilever...
# ptfe                                   {high_sulfide_copper_ores, ra_repair, pulmonar...
# ptfe_graft                             {limb_salvage, vascular_access, open_aaa_repai...
# ptfe_grafts                            {canine_iliac_replacement, composite_graft, su...
# ptfe_group                             {above-knee_femoropopliteal_bypass, femoropopl...
# ptfe_membrane                          {standard_membrane_contactor_materials, filter...
# ptfe_membranes                         {flat_panel_displays, coupling_agent, uf_treat...
# ptfe_particles                         {electroless_nickel_coatings, nanofiber_separa...
# pvdf                                   {stirred_flat_membrane_cell, high-temperaturep...
# pvdf-hfp                               {gel_electrolyte_membranes, coronary_stents, l...
# pvdf_/                                 {efficient_sound_absorber, planner_nanofillers...
# pvdf_binder                            {battery, lifepo_/_c_electrode, lithium-sulfur...
# pvdf_fibers                            {power_scavenger, nonwoven_fiber_fabric, biome...
# pvdf_film                              {fingerprint_sensor_applications, exhaled_air_...
# pvdf_films                             {asymmetric_membranes, pvdf-based_functional_m...
# pvdf_matrix                            {energy_supply_systems, modifier, nanogenerato...
# pvdf_membrane                          {stirred_flat_membrane_cell, modifier, functio...
# pvdf_membranes                         {modifier, dcmd_applications, microfiltration_...
# pvdf_nanofibers                        {nanogenerators, dynamic_tactile_sensing, mf, ...
# pvdf_sensor                            {hmi, special_circuit_interface, volume_displa...
# pvdf_sensors                           {hmi, foil_sensors, volume_displacement_sensor...
#
#                                        eptfe  eptfe_graft  eptfe_grafts  \
# material
# eptfe                                   1108           93           147
# eptfe_graft                               93          102            29
# eptfe_grafts                             147           29           167
# eptfe_group                               37            0            10
# eptfe_membrane                            65            0             0
# etfe                                       6            0             0
# expanded_polytetrafluoroethylene         210           20            30
# fluorinated_ethylene_propylene             6            0             0
# pctfe                                      0            0             0
# perfluoropolyether                         5            0             1
# pfpe                                       5            0             1
# pfpes                                      1            0             0
# piezoelectric_polyvinylidene_fluoride      2            0             0
# poly(tetrafluoroethylene)                 38            6             8
# poly(vinylidene_fluoride)                 18            0             0
# poly_(vinylidene_fluoride)                 6            0             0
# polytetrafluoroethylene                  813           77           130
# polytetrafluoroethylene_graft             21            8             4
# polytetrafluoroethylene_grafts            24           10             8
# polyvinylidene_difluoride                  5            0             0
# polyvinylidene_fluoride                   31            2             2
# polyvinylidenefluoride                     4            0             0
# porous_pvdf_membrane                       1            0             0
# ptfe                                     218           21            40
# ptfe_graft                                28           10            11
# ptfe_grafts                               65           15            22
# ptfe_group                                17            4             7
# ptfe_membrane                             11            0             0
# ptfe_membranes                             8            1             1
# ptfe_particles                             3            0             0
# pvdf                                      40            1             3
# pvdf-hfp                                   3            0             0
# pvdf_/                                     6            0             0
# pvdf_binder                                3            0             0
# pvdf_fibers                                2            0             0
# pvdf_film                                  5            0             0
# pvdf_films                                 7            0             0
# pvdf_matrix                                6            0             0
# pvdf_membrane                              8            0             0
# pvdf_membranes                             7            0             0
# pvdf_nanofibers                            3            0             0
# pvdf_sensor                                3            0             0
# pvdf_sensors                               2            0             0
#
#                                        eptfe_group  eptfe_membrane  etfe  \
# material
# eptfe                                           37              65     6
# eptfe_graft                                      0               0     0
# eptfe_grafts                                    10               0     0
# eptfe_group                                     42               7     0
# eptfe_membrane                                   7              70     0
# etfe                                             0               0   234
# expanded_polytetrafluoroethylene                15              20     0
# fluorinated_ethylene_propylene                   0               0    11
# pctfe                                            0               0     2
# perfluoropolyether                               0               0     6
# pfpe                                             0               0     3
# pfpes                                            0               0     2
# piezoelectric_polyvinylidene_fluoride            0               1     2
# poly(tetrafluoroethylene)                        1               1     3
# poly(vinylidene_fluoride)                        0               3    20
# poly_(vinylidene_fluoride)                       0               1     6
# polytetrafluoroethylene                         32              48    46
# polytetrafluoroethylene_graft                    0               0     0
# polytetrafluoroethylene_grafts                   1               0     0
# polyvinylidene_difluoride                        0               1     6
# polyvinylidene_fluoride                          1               3    25
# polyvinylidenefluoride                           0               1     4
# porous_pvdf_membrane                             0               0     0
# ptfe                                            11              13    56
# ptfe_graft                                       1               0     0
# ptfe_grafts                                      4               0     0
# ptfe_group                                       1               0     0
# ptfe_membrane                                    2               5     2
# ptfe_membranes                                   1               4     0
# ptfe_particles                                   0               1     4
# pvdf                                             1               6    41
# pvdf-hfp                                         0               1     5
# pvdf_/                                           0               1     5
# pvdf_binder                                      0               1     2
# pvdf_fibers                                      0               0     1
# pvdf_film                                        0               2     6
# pvdf_films                                       0               1     8
# pvdf_matrix                                      0               1     1
# pvdf_membrane                                    0               2     6
# pvdf_membranes                                   0               1     4
# pvdf_nanofibers                                  0               1     4
# pvdf_sensor                                      0               1     1
# pvdf_sensors                                     0               0     0
#
#                                        expanded_polytetrafluoroethylene  \
# material
# eptfe                                                               210
# eptfe_graft                                                          20
# eptfe_grafts                                                         30
# eptfe_group                                                          15
# eptfe_membrane                                                       20
# etfe                                                                  0
# expanded_polytetrafluoroethylene                                    339
# fluorinated_ethylene_propylene                                        0
# pctfe                                                                 0
# perfluoropolyether                                                    0
# pfpe                                                                  0
# pfpes                                                                 0
# piezoelectric_polyvinylidene_fluoride                                 0
# poly(tetrafluoroethylene)                                             7
# poly(vinylidene_fluoride)                                             2
# poly_(vinylidene_fluoride)                                            1
# polytetrafluoroethylene                                             111
# polytetrafluoroethylene_graft                                         8
# polytetrafluoroethylene_grafts                                       17
# polyvinylidene_difluoride                                             1
# polyvinylidene_fluoride                                              10
# polyvinylidenefluoride                                                0
# porous_pvdf_membrane                                                  1
# ptfe                                                                 90
# ptfe_graft                                                            8
# ptfe_grafts                                                          28
# ptfe_group                                                            7
# ptfe_membrane                                                         5
# ptfe_membranes                                                        3
# ptfe_particles                                                        0
# pvdf                                                                 15
# pvdf-hfp                                                              0
# pvdf_/                                                                0
# pvdf_binder                                                           0
# pvdf_fibers                                                           0
# pvdf_film                                                             0
# pvdf_films                                                            0
# pvdf_matrix                                                           0
# pvdf_membrane                                                         1
# pvdf_membranes                                                        1
# pvdf_nanofibers                                                       0
# pvdf_sensor                                                           0
# pvdf_sensors                                                          0
#
#                                        fluorinated_ethylene_propylene  ...  \
# material                                                               ...
# eptfe                                                               6  ...
# eptfe_graft                                                         0  ...
# eptfe_grafts                                                        0  ...
# eptfe_group                                                         0  ...
# eptfe_membrane                                                      0  ...
# etfe                                                               11  ...
# expanded_polytetrafluoroethylene                                    0  ...
# fluorinated_ethylene_propylene                                    116  ...
# pctfe                                                               2  ...
# perfluoropolyether                                                  4  ...
# pfpe                                                                4  ...
# pfpes                                                               3  ...
# piezoelectric_polyvinylidene_fluoride                               1  ...
# poly(tetrafluoroethylene)                                           4  ...
# poly(vinylidene_fluoride)                                           8  ...
# poly_(vinylidene_fluoride)                                          1  ...
# polytetrafluoroethylene                                            45  ...
# polytetrafluoroethylene_graft                                       0  ...
# polytetrafluoroethylene_grafts                                      0  ...
# polyvinylidene_difluoride                                           3  ...
# polyvinylidene_fluoride                                            13  ...
# polyvinylidenefluoride                                              0  ...
# porous_pvdf_membrane                                                0  ...
# ptfe                                                               45  ...
# ptfe_graft                                                          0  ...
# ptfe_grafts                                                         0  ...
# ptfe_group                                                          0  ...
# ptfe_membrane                                                       0  ...
# ptfe_membranes                                                      0  ...
# ptfe_particles                                                      4  ...
# pvdf                                                               17  ...
# pvdf-hfp                                                            2  ...
# pvdf_/                                                              0  ...
# pvdf_binder                                                         0  ...
# pvdf_fibers                                                         0  ...
# pvdf_film                                                           0  ...
# pvdf_films                                                          1  ...
# pvdf_matrix                                                         1  ...
# pvdf_membrane                                                       1  ...
# pvdf_membranes                                                      1  ...
# pvdf_nanofibers                                                     2  ...
# pvdf_sensor                                                         0  ...
# pvdf_sensors                                                        0  ...
#
#                                        pvdf_binder  pvdf_fibers  pvdf_film  \
# material
# eptfe                                            3            2          5
# eptfe_graft                                      0            0          0
# eptfe_grafts                                     0            0          0
# eptfe_group                                      0            0          0
# eptfe_membrane                                   1            0          2
# etfe                                             2            1          6
# expanded_polytetrafluoroethylene                 0            0          0
# fluorinated_ethylene_propylene                   0            0          0
# pctfe                                            0            1          0
# perfluoropolyether                               1            0          1
# pfpe                                             3            1          3
# pfpes                                            1            0          0
# piezoelectric_polyvinylidene_fluoride            1            5         32
# poly(tetrafluoroethylene)                        8            3          5
# poly(vinylidene_fluoride)                       23           25         43
# poly_(vinylidene_fluoride)                       3            6         11
# polytetrafluoroethylene                         21            9         16
# polytetrafluoroethylene_graft                    0            0          0
# polytetrafluoroethylene_grafts                   0            0          0
# polyvinylidene_difluoride                       13            7         23
# polyvinylidene_fluoride                         36           30        179
# polyvinylidenefluoride                           4            2          7
# porous_pvdf_membrane                             0            0          2
# ptfe                                            19           10         19
# ptfe_graft                                       0            0          0
# ptfe_grafts                                      0            0          0
# ptfe_group                                       0            0          0
# ptfe_membrane                                    3            4          3
# ptfe_membranes                                   0            3          2
# ptfe_particles                                   2            1          1
# pvdf                                            66           58        272
# pvdf-hfp                                         9            3          3
# pvdf_/                                           2            6         10
# pvdf_binder                                     71            1          4
# pvdf_fibers                                      1           58          5
# pvdf_film                                        4            5        296
# pvdf_films                                       3            4         55
# pvdf_matrix                                      3            3          6
# pvdf_membrane                                    5            4          9
# pvdf_membranes                                   1            5          4
# pvdf_nanofibers                                  2           11          7
# pvdf_sensor                                      1            3         31
# pvdf_sensors                                     0            3         31
#
#                                        pvdf_films  pvdf_matrix  pvdf_membrane  \
# material
# eptfe                                           7            6              8
# eptfe_graft                                     0            0              0
# eptfe_grafts                                    0            0              0
# eptfe_group                                     0            0              0
# eptfe_membrane                                  1            1              2
# etfe                                            8            1              6
# expanded_polytetrafluoroethylene                0            0              1
# fluorinated_ethylene_propylene                  1            1              1
# pctfe                                           1            0              1
# perfluoropolyether                              0            1              2
# pfpe                                            3            3              5
# pfpes                                           0            0              1
# piezoelectric_polyvinylidene_fluoride           7            2              5
# poly(tetrafluoroethylene)                       4            4             12
# poly(vinylidene_fluoride)                      48           67            104
# poly_(vinylidene_fluoride)                     11           11             23
# polytetrafluoroethylene                        20           16             58
# polytetrafluoroethylene_graft                   0            0              1
# polytetrafluoroethylene_grafts                  0            0              0
# polyvinylidene_difluoride                      23            8             29
# polyvinylidene_fluoride                        82           59            181
# polyvinylidenefluoride                          2            2             20
# porous_pvdf_membrane                            0            1             14
# ptfe                                           22           21             72
# ptfe_graft                                      0            0              0
# ptfe_grafts                                     0            0              0
# ptfe_group                                      0            0              0
# ptfe_membrane                                   2            1             26
# ptfe_membranes                                  1            1              7
# ptfe_particles                                  3            1              7
# pvdf                                          168          133            312
# pvdf-hfp                                        3            5             14
# pvdf_/                                         12           20             26
# pvdf_binder                                     3            3              5
# pvdf_fibers                                     4            3              4
# pvdf_film                                      55            6              9
# pvdf_films                                    173           15              6
# pvdf_matrix                                    15          149             17
# pvdf_membrane                                   6           17            340
# pvdf_membranes                                  3            8             74
# pvdf_nanofibers                                 7            6             14
# pvdf_sensor                                    14            3              4
# pvdf_sensors                                   17            3              3
#
#                                        pvdf_membranes  pvdf_nanofibers  \
# material
# eptfe                                               7                3
# eptfe_graft                                         0                0
# eptfe_grafts                                        0                0
# eptfe_group                                         0                0
# eptfe_membrane                                      1                1
# etfe                                                4                4
# expanded_polytetrafluoroethylene                    1                0
# fluorinated_ethylene_propylene                      1                2
# pctfe                                               1                1
# perfluoropolyether                                  1                2
# pfpe                                                1                3
# pfpes                                               2                2
# piezoelectric_polyvinylidene_fluoride               3                4
# poly(tetrafluoroethylene)                           7                4
# poly(vinylidene_fluoride)                          96               50
# poly_(vinylidene_fluoride)                         19                7
# polytetrafluoroethylene                            47               16
# polytetrafluoroethylene_graft                       0                0
# polytetrafluoroethylene_grafts                      0                0
# polyvinylidene_difluoride                          16                7
# polyvinylidene_fluoride                           111               42
# polyvinylidenefluoride                             11                4
# porous_pvdf_membrane                                4                0
# ptfe                                               52               20
# ptfe_graft                                          0                0
# ptfe_grafts                                         0                0
# ptfe_group                                          0                0
# ptfe_membrane                                      15                1
# ptfe_membranes                                     13                1
# ptfe_particles                                      6                2
# pvdf                                              208               81
# pvdf-hfp                                            7                4
# pvdf_/                                             21               11
# pvdf_binder                                         1                2
# pvdf_fibers                                         5               11
# pvdf_film                                           4                7
# pvdf_films                                          3                7
# pvdf_matrix                                         8                6
# pvdf_membrane                                      74               14
# pvdf_membranes                                    220                6
# pvdf_nanofibers                                     6               90
# pvdf_sensor                                         0                2
# pvdf_sensors                                        0                3
#
#                                        pvdf_sensor  pvdf_sensors
# material
# eptfe                                            3             2
# eptfe_graft                                      0             0
# eptfe_grafts                                     0             0
# eptfe_group                                      0             0
# eptfe_membrane                                   1             0
# etfe                                             1             0
# expanded_polytetrafluoroethylene                 0             0
# fluorinated_ethylene_propylene                   0             0
# pctfe                                            0             0
# perfluoropolyether                               1             0
# pfpe                                             2             1
# pfpes                                            0             0
# piezoelectric_polyvinylidene_fluoride           13            15
# poly(tetrafluoroethylene)                        2             0
# poly(vinylidene_fluoride)                        8             9
# poly_(vinylidene_fluoride)                       4             4
# polytetrafluoroethylene                          7             5
# polytetrafluoroethylene_graft                    0             0
# polytetrafluoroethylene_grafts                   0             0
# polyvinylidene_difluoride                       10             8
# polyvinylidene_fluoride                        104            65
# polyvinylidenefluoride                           4             4
# porous_pvdf_membrane                             0             0
# ptfe                                             8             5
# ptfe_graft                                       0             0
# ptfe_grafts                                      0             0
# ptfe_group                                       0             0
# ptfe_membrane                                    1             1
# ptfe_membranes                                   1             1
# ptfe_particles                                   1             0
# pvdf                                           129           107
# pvdf-hfp                                         1             0
# pvdf_/                                           2             2
# pvdf_binder                                      1             0
# pvdf_fibers                                      3             3
# pvdf_film                                       31            31
# pvdf_films                                      14            17
# pvdf_matrix                                      3             3
# pvdf_membrane                                    4             3
# pvdf_membranes                                   0             0
# pvdf_nanofibers                                  2             3
# pvdf_sensor                                    150            47
# pvdf_sensors                                    47           115
#
# [43 rows x 45 columns]

# %%
print('saving preprocessed instances...')
cPickle.dump((large_instances, materials, word_to_idx, idx_to_word, embeddings), open(config.large_output_path, 'wb'))
# Out:
# saving preprocessed instances...

# %%
len(word_to_idx)
# Out:
# 11684

# %%
materials
# Out:
# ['pvdf',
#  'ptfe',
#  'polytetrafluoroethylene',
#  'polyvinylidene_fluoride',
#  'eptfe',
#  'poly(vinylidene_fluoride)',
#  'ptfe_grafts',
#  'pfpe',
#  'pvdf_membrane',
#  'pvdf_film',
#  'expanded_polytetrafluoroethylene',
#  'etfe',
#  'pvdf_membranes',
#  'perfluoropolyether',
#  'eptfe_grafts',
#  'polyvinylidene_difluoride',
#  'pvdf_sensor',
#  'pvdf_sensors',
#  'pvdf_films',
#  'ptfe_graft',
#  'poly(tetrafluoroethylene)',
#  'ptfe_membrane',
#  'pvdf_/',
#  'polytetrafluoroethylene_grafts',
#  'polytetrafluoroethylene_graft',
#  'pvdf-hfp',
#  'pvdf_matrix',
#  'eptfe_graft',
#  'poly_(vinylidene_fluoride)',
#  'ptfe_group',
#  'eptfe_membrane',
#  'pvdf_binder',
#  'polyvinylidenefluoride',
#  'fluorinated_ethylene_propylene',
#  'piezoelectric_polyvinylidene_fluoride',
#  'pctfe',
#  'pvdf_nanofibers',
#  'pfpes',
#  'ptfe_particles',
#  'ptfe_membranes',
#  'eptfe_group',
#  'porous_pvdf_membrane',
#  'pvdf_fibers']
