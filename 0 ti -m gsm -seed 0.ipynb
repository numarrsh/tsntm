# %%
# %%javascript
# IPython.notebook.kernel.execute('nb_name = "' + IPython.notebook.notebook_name + '"')

# %%
# %load_ext autoreload
# %autoreload
from IPython.display import clear_output

import os
os.environ['PYTHONHASHSEED'] = '0'
os.environ["NUMEXPR_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["OMP_NUM_THREADS"] = "1"

import sys
import argparse
import subprocess
import pdb
import time
import random
import _pickle as cPickle
import matplotlib.pyplot as plt
import glob

# %matplotlib inline

import numpy as np
import pandas as pd
import tensorflow as tf

from data_structure import get_batches
from gsm import GaussianSoftmaxModel
from rsm import RecurrentStickbreakingModel
from evaluation import validate, print_flat_topic_sample
from configure import get_config

# %% [markdown]
# # load data & set config

# %%
config = get_config(nb_name)

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = config.gpu
np.random.seed(config.seed)
random.seed(config.seed)

# %%
instances_train, categories, word_to_idx, idx_to_word, embeddings = cPickle.load(open(config.path_data, 'rb'))
config.batch_size = len(instances_train)
train_batches = get_batches(instances_train, config.batch_size, iterator=False)
config.dim_bow = len(idx_to_word)
config.dim_emb = embeddings.shape[-1]

# %%
def debug(variable, sample_batch=None, sample=False):
    if sample_batch is None: sample_batch = train_batches[0][1]
    feed_dict = model.get_feed_dict(sample_batch, mode='eval')
    _variable = sess.run(variable, feed_dict=feed_dict)
    return _variable

# %% [markdown]
# # run

# %% [markdown]
# ## initialize log

# %%
checkpoint = []
losses_train = []
ppls_train = []
ppl_min = np.inf
epoch = 0

log_df = pd.DataFrame(columns=pd.MultiIndex.from_tuples(
                    list(zip(*[['','','','TRAIN:','','','','','VALID:','','','','','TEST:',''],
                            ['Time','Ep','Ct','LOSS','PPL','NLL','KL','REG','LOSS','PPL','NLL','KL','REG','LOSS','PPL']]))))

cmd_rm = 'rm -r %s' % config.dir_model
res = subprocess.call(cmd_rm.split())
cmd_mk = 'mkdir %s' % config.dir_model
res = subprocess.call(cmd_mk.split())

def update_checkpoint(config, checkpoint, global_step):
    checkpoint.append(config.path_model + '-%i' % global_step)
    if len(checkpoint) > config.max_to_keep:
        path_model = checkpoint.pop(0) + '.*'
        for p in glob.glob(path_model):
            os.remove(p)
    cPickle.dump(checkpoint, open(config.path_checkpoint, 'wb'))

# %% [markdown]
# ## initialize model

# %%
config.n_topic = 20
config.train_emb = False

# %%
if 'sess' in globals(): sess.close()
if config.model == 'gsm':
    Model = GaussianSoftmaxModel
elif config.model == 'rsm':
    Model = RecurrentStickbreakingModel
model = Model(config)    
sess = tf.Session(config=tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1))
sess.run(tf.global_variables_initializer())
sess.run(model.bow_embeddings.assign(embeddings))
saver = tf.train.Saver(max_to_keep=config.max_to_keep)
update_tree_flg = False

# %% [markdown]
# ## train & validate model

# %%
config.n_epochs = 10000
config.log_period = 500

# %%
time_start = time.time()
while epoch < config.n_epochs:
    ct, batch = train_batches[0]
    
    feed_dict = model.get_feed_dict(batch)
    _, loss_batch, topic_loss_recon_batch, topic_loss_kl_batch, topic_loss_reg_batch, ppls_batch, global_step_log = \
    sess.run([model.opt, model.loss, model.topic_loss_recon, model.topic_loss_kl, model.topic_loss_reg, model.topic_ppls, tf.train.get_global_step()], feed_dict = feed_dict)

    losses_train += [[loss_batch, topic_loss_recon_batch, topic_loss_kl_batch, topic_loss_reg_batch]]
    ppls_train += list(ppls_batch)

    if global_step_log % config.log_period == 0:
        # validate
        loss_train, topic_loss_recon_train, topic_loss_kl_train, topic_loss_reg_train = np.mean(losses_train, 0)
        ppl_train = np.exp(np.mean(ppls_train))
        loss_dev, topic_loss_recon_dev, topic_loss_kl_dev, topic_loss_reg_dev, ppl_dev, probs_topic_dev = 0, 0, 0, 0, 0, 0

        # test
        if ppl_train < ppl_min:
            ppl_min = ppl_dev
            loss_test, _, _, _, ppl_test, _ = 0, 0, 0, 0, 0, 0
            saver.save(sess, config.path_model, global_step=global_step_log)
            cPickle.dump(config, open(config.path_config % global_step_log, 'wb'))
            update_checkpoint(config, checkpoint, global_step_log)

        # visualize topic
        topics_freq_indices = np.argsort(sess.run(model.topic_bow), 1)[:, ::-1][:, :config.n_freq]
        topics_freq_idxs = topics_freq_indices
        topics_freq_tokens = [[idx_to_word[idx] for idx in topic_freq_idxs] for topic_freq_idxs in topics_freq_idxs]

        # log
        clear_output()
        time_log = int(time.time() - time_start)
        log_series = pd.Series([time_log, epoch, ct, \
                '%.2f'%loss_train, '%.0f'%ppl_train, '%.2f'%topic_loss_recon_train, '%.2f'%topic_loss_kl_train, '%.2f'%topic_loss_reg_train, \
                '%.2f'%loss_dev, '%.0f'%ppl_dev, '%.2f'%topic_loss_recon_dev, '%.2f'%topic_loss_kl_dev, '%.2f'%topic_loss_reg_dev, \
                '%.2f'%loss_test, '%.0f'%ppl_test],
                index=log_df.columns)
        log_df.loc[global_step_log] = log_series
        display(log_df)
        cPickle.dump(log_df, open(os.path.join(config.path_log), 'wb'))
        print_flat_topic_sample(sess, model, topics_freq_tokens=topics_freq_tokens)

#         # update tree
#         if not config.static:

#             if update_sequence_flg:
#                 print(config.tree_idxs)
#                 name_variables = {tensor.name: variable for tensor, variable in zip(tf.global_variables(), sess.run(tf.global_variables()))} # store paremeters
#                 if 'sess' in globals(): sess.close()
#                 model = Model(config)
#                 sess = tf.Session(config=tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1))
#                 name_tensors = {tensor.name: tensor for tensor in tf.global_variables()}
#                 sess.run([name_tensors[name].assign(variable) for name, variable in name_variables.items()]) # restore parameters
#                 saver = tf.train.Saver(max_to_keep=1)

        time_start = time.time()

    epoch += 1
# Out:
#                         TRAIN:                               VALID:            \
#       Time    Ep Ct       LOSS   PPL        NLL     KL   REG   LOSS PPL   NLL
# 500      3   499  0  110359.08  6178  110280.55  78.53  0.01   0.00   0  0.00
# 1000     2   999  0  109386.16  5498  109309.41  76.76  0.01   0.00   0  0.00
# 1500     2  1499  0  108921.20  5044  108846.84  74.46  0.01   0.00   0  0.00
# 2000     2  1999  0  108628.47  4768  108556.37  72.11  0.01   0.00   0  0.00
# 2500     2  2499  0  108421.54  4567  108351.52  70.04  0.01   0.00   0  0.00
# 3000     2  2999  0  108263.84  4415  108195.50  68.30  0.01   0.00   0  0.00
# 3500     2  3499  0  108136.66  4295  108069.90  66.76  0.01   0.00   0  0.00
# 4000     2  3999  0  108030.84  4196  107965.30  65.46  0.01   0.00   0  0.00
# 4500     2  4499  0  107939.57  4115  107875.29  64.34  0.01   0.00   0  0.00
# 5000     2  4999  0  107859.81  4044  107796.43  63.30  0.01   0.00   0  0.00
# 5500     2  5499  0  107788.66  3983  107726.43  62.41  0.01   0.00   0  0.00
# 6000     2  5999  0  107724.91  3932  107663.73  61.61  0.01   0.00   0  0.00
# 6500     2  6499  0  107668.29  3887  107608.16  60.92  0.01   0.00   0  0.00
# 7000     2  6999  0  107616.55  3851  107556.30  60.28  0.01   0.00   0  0.00
# 7500     2  7499  0  107568.77  3823  107509.62  59.70  0.01   0.00   0  0.00
# 8000     2  7999  0  107525.54  3804  107466.27  59.19  0.01   0.00   0  0.00
# 8500     2  8499  0  107484.10  3789  107425.86  58.72  0.01   0.00   0  0.00
# 9000     2  8999  0  107446.98  3776  107388.42  58.28  0.01   0.00   0  0.00
# 9500     2  9499  0  107411.60  3764  107354.45  57.88  0.01   0.00   0  0.00
# 10000    2  9999  0  107378.62  3752  107321.31  57.51  0.01   0.00   0  0.00
#
#                   TEST:
#          KL   REG  LOSS PPL
# 500    0.00  0.00  0.00   0
# 1000   0.00  0.00  0.00   0
# 1500   0.00  0.00  0.00   0
# 2000   0.00  0.00  0.00   0
# 2500   0.00  0.00  0.00   0
# 3000   0.00  0.00  0.00   0
# 3500   0.00  0.00  0.00   0
# 4000   0.00  0.00  0.00   0
# 4500   0.00  0.00  0.00   0
# 5000   0.00  0.00  0.00   0
# 5500   0.00  0.00  0.00   0
# 6000   0.00  0.00  0.00   0
# 6500   0.00  0.00  0.00   0
# 7000   0.00  0.00  0.00   0
# 7500   0.00  0.00  0.00   0
# 8000   0.00  0.00  0.00   0
# 8500   0.00  0.00  0.00   0
# 9000   0.00  0.00  0.00   0
# 9500   0.00  0.00  0.00   0
# 10000  0.00  0.00  0.00   0
# 0 vascular_grafts vascular_access vascular_graft hemodialysis_access vascular_prostheses vascular_prosthesis bone_regeneration stent-grafts coatings guided_tissue_regeneration
# 1 gtr gbr lumbar_discectomy tract_reconstruction ptfe_/_vein_cuff tract_reconstructions infected_eptfe_mesh haemodialysis adherent ptfe_graft_reconstruction
# 2 femoropopliteal_bypass femoropopliteal_bypasses valves femoropopliteal_bypass_grafts femoropopliteal_bypass_graft bypasses seals bypass femoropopliteal_bypass_grafting valve
# 3 bearings mitral_valve_repair greases chordal_replacement gaskets tips solid_lubricant solid_lubricants repair vesicoureteral_reflux
# 4 electrodes electrode binder cathode cell electrolyte anode cathodes cells devices
# 5 fuel_cell ptfe_transfer_film fuel_cell_performance pemfc ptfe_grafts gas_diffusion_layer pemfcs gas_diffusion_layers mfc catalyst_ink
# 6 hollow_fiber_membranes hollow_fiber_membrane ptfe_hollow_fiber_membranes hollow_fibre_membranes pvdf_hollow_fiber_membranes ptfe_hollow_fiber_membrane hollow_fibre_membrane fibrous_membranes pvdf_hollow_fiber_membrane hollow-fiber_membranes
# 7 ultrafiltration membrane_distillation direct_contact_membrane_distillation microfiltration water_treatment ultrafiltration_membranes wastewater_treatment ultrafiltration_membrane membrane_distillation_membranes direct_methanol_fuel_cell
# 8 transducers transducer dssc pvdf_transducers pvdf-transducers dsscs pvdf_nanoweb_fibers pvdf_transducer ultrasonic_transducers acoustic_nanogenerator
# 9 fuel_cells filters proton_exchange_membrane_fuel_cells venous_system proton_exchange_membrane_fuel_cell system polymer_electrolyte_membrane_fuel_cells polymer_electrolyte_membrane_fuel_cell membrane_filters fuel_cell
# 10 building_sector building_façade building_applications building_roofs building_materials building_envelopes insulation fuel_cells buildings flexible_photovoltaics
# 11 binder sensor separator composite_membrane binders separators membrane_material actuators membrane actuator
# 12 mf ferro-actuator md dmfc dmfcs mfcs lib mfc vanadium_redox_flow_battery mbr
# 13 implants graft_material hepatic_tissue stent_graft remarkable_membrane_material implant endoscopic_treatment carrier graft biosensor
# 14 greases lubricants magnetic_disk_drives hard_disk_lubricants magnetic_disks pfpe_lubricants lubricant hard_disk_drive pfpe_greases disk_lubricants
# 15 sensors sensor actuators pvdf_sensors pvdf_sensor actuator piezoelectric_sensors piezoelectric_sensor tactile_sensors pvdf_nasal_sensors
# 16 electric_wire pumps diodes aerospace_applications spacecraft outer_skins laser_welding spacecrafts greases wire
# 17 energy_harvesting energy_harvester energy_harvesters co_capture energy microbial_fuel_cells energy_storage detectors dust_detectors photocatalytic_membrane_reactor
# 18 leads etfe_cushion_roof etfe_foils etfe_cushion_models pv-etfe_cushion etfe_cushion_model air_systems etfe_foil_cushions conventional_etfe_cushion_structures etfe_foil_spring_cushion
# 19 lithium-ion_batteries lithium_ion_batteries applications polymer_electrolytes lithium-ion_battery lithium_batteries electrolytes li-ion_batteries polymer_electrolyte electronic_applications

# %% [markdown]
# # visualize topics

# %%
def print_freq_uses(category_index, n_topics=10, n_freq=100, n_known=10, n_unknown=10):
    topics_use_indices = np.argsort(sess.run(model.topic_bow), 1)[:, ::-1][:n_freq]
    
    instance = train_batches[0][1][category_index]
    known_use_indices = np.where(instance.bow>0)[0]
    category = categories[category_index]

    prob_topics = sess.run(model.prob_topic, feed_dict=model.get_feed_dict(batch=[instance], mode='infer'))[0]
    sorted_topic_indices = np.argsort(prob_topics)[::-1]
    
    print('-------------------------------------------------')
    print('category: %s' % category)
    for topic_index in sorted_topic_indices[:n_topics]:
        prob_topic = prob_topics[topic_index]
        if prob_topic < 0.01: break
        
        topic_use_indices = topics_use_indices[topic_index]
        unknown_topic_use_indices = [index for index in topic_use_indices if index not in known_use_indices]
        print(topic_index, '%.3f'%prob_topic, \
                  ' '.join([idx_to_word[index] for index in topic_use_indices[:n_known]]), \
                  ' '.join(['<%s>'%idx_to_word[index] for index in unknown_topic_use_indices[:n_unknown]]))

# %%
for i in range(len(categories)):
    print_freq_uses(category_index=i)
# Out:
# -------------------------------------------------
# category: etfe
# 10 0.630 building_sector building_façade building_applications building_roofs building_materials building_envelopes insulation fuel_cells buildings flexible_photovoltaics <photovoltaics> <smart_structure> <photovoltaic_cell> <smart_structures> <insulation_equipment> <c-block_architectures> <solar_panels> <cation_exchange_membranes> <photovoltaic_cells> <cation-exchange_membranes>
# 18 0.268 leads etfe_cushion_roof etfe_foils etfe_cushion_models pv-etfe_cushion etfe_cushion_model air_systems etfe_foil_cushions conventional_etfe_cushion_structures etfe_foil_spring_cushion <air_systems> <"_at-risk_"_systems> <hydraulic_fluid> <pipe_systems> <guide_systems> <"_at-risk_"_high-pressure_oxygen> <high-pressure_oxygen_systems> <jackets> <ppts> <waterborne_resins>
# 16 0.085 electric_wire pumps diodes aerospace_applications spacecraft outer_skins laser_welding spacecrafts greases wire <diodes> <spacecraft> <spacecrafts> <greases> <wire> <bags> <thermal_blankets> <paper_coatings> <space_reflectors> <reactors>
# -------------------------------------------------
# category: fep
# 16 0.553 electric_wire pumps diodes aerospace_applications spacecraft outer_skins laser_welding spacecrafts greases wire <electric_wire> <diodes> <aerospace_applications> <outer_skins> <laser_welding> <spacecrafts> <wire> <thermal_isolation> <multilayer_coatings> <paper_coatings>
# 13 0.093 implants graft_material hepatic_tissue stent_graft remarkable_membrane_material implant endoscopic_treatment carrier graft biosensor <implants> <graft_material> <hepatic_tissue> <stent_graft> <remarkable_membrane_material> <implant> <endoscopic_treatment> <carrier> <graft> <biosensor>
# 14 0.080 greases lubricants magnetic_disk_drives hard_disk_lubricants magnetic_disks pfpe_lubricants lubricant hard_disk_drive pfpe_greases disk_lubricants <magnetic_disk_drives> <hard_disk_lubricants> <magnetic_disks> <pfpe_lubricants> <lubricant> <hard_disk_drive> <pfpe_greases> <disk_lubricants> <magnetic_disk> <hard_disk_drives>
# 9 0.073 fuel_cells filters proton_exchange_membrane_fuel_cells venous_system proton_exchange_membrane_fuel_cell system polymer_electrolyte_membrane_fuel_cells polymer_electrolyte_membrane_fuel_cell membrane_filters fuel_cell <filters> <venous_system> <system> <polymer_electrolyte_membrane_fuel_cell> <membrane_filters> <fuel_cell> <polymer_electrolyte_fuel_cells> <clinical_medicine> <proton_exchange_membrane> <water_system>
# 10 0.049 building_sector building_façade building_applications building_roofs building_materials building_envelopes insulation fuel_cells buildings flexible_photovoltaics <building_sector> <building_façade> <building_applications> <building_roofs> <building_materials> <building_envelopes> <insulation> <buildings> <flexible_photovoltaics> <intelligent_building_skins>
# 5 0.045 fuel_cell ptfe_transfer_film fuel_cell_performance pemfc ptfe_grafts gas_diffusion_layer pemfcs gas_diffusion_layers mfc catalyst_ink <fuel_cell> <ptfe_transfer_film> <pemfc> <ptfe_grafts> <gas_diffusion_layer> <pemfcs> <gas_diffusion_layers> <mfc> <catalyst_ink> <fuel_cell_gas_diffusion_layers>
# 18 0.039 leads etfe_cushion_roof etfe_foils etfe_cushion_models pv-etfe_cushion etfe_cushion_model air_systems etfe_foil_cushions conventional_etfe_cushion_structures etfe_foil_spring_cushion <leads> <etfe_cushion_roof> <etfe_foils> <etfe_cushion_models> <pv-etfe_cushion> <etfe_cushion_model> <air_systems> <etfe_foil_cushions> <conventional_etfe_cushion_structures> <etfe_foil_spring_cushion>
# 6 0.016 hollow_fiber_membranes hollow_fiber_membrane ptfe_hollow_fiber_membranes hollow_fibre_membranes pvdf_hollow_fiber_membranes ptfe_hollow_fiber_membrane hollow_fibre_membrane fibrous_membranes pvdf_hollow_fiber_membrane hollow-fiber_membranes <ptfe_hollow_fiber_membranes> <hollow_fibre_membranes> <pvdf_hollow_fiber_membranes> <ptfe_hollow_fiber_membrane> <hollow_fibre_membrane> <fibrous_membranes> <pvdf_hollow_fiber_membrane> <hollow-fiber_membranes> <nanofibrous_membranes> <flat_membranes>
# -------------------------------------------------
# category: pctfe
# 18 0.745 leads etfe_cushion_roof etfe_foils etfe_cushion_models pv-etfe_cushion etfe_cushion_model air_systems etfe_foil_cushions conventional_etfe_cushion_structures etfe_foil_spring_cushion <leads> <etfe_cushion_roof> <etfe_foils> <etfe_cushion_models> <pv-etfe_cushion> <etfe_cushion_model> <etfe_foil_cushions> <conventional_etfe_cushion_structures> <etfe_foil_spring_cushion> <etfe_foil_systems>
# 16 0.174 electric_wire pumps diodes aerospace_applications spacecraft outer_skins laser_welding spacecrafts greases wire <electric_wire> <pumps> <spacecraft> <outer_skins> <laser_welding> <spacecrafts> <wire> <thermal_isolation> <wires> <bags>
# 9 0.044 fuel_cells filters proton_exchange_membrane_fuel_cells venous_system proton_exchange_membrane_fuel_cell system polymer_electrolyte_membrane_fuel_cells polymer_electrolyte_membrane_fuel_cell membrane_filters fuel_cell <fuel_cells> <filters> <proton_exchange_membrane_fuel_cells> <venous_system> <proton_exchange_membrane_fuel_cell> <system> <polymer_electrolyte_membrane_fuel_cells> <polymer_electrolyte_membrane_fuel_cell> <membrane_filters> <fuel_cell>
# 10 0.020 building_sector building_façade building_applications building_roofs building_materials building_envelopes insulation fuel_cells buildings flexible_photovoltaics <building_sector> <building_façade> <building_applications> <building_roofs> <building_materials> <building_envelopes> <insulation> <fuel_cells> <buildings> <flexible_photovoltaics>
# -------------------------------------------------
# category: pfa
# 18 0.439 leads etfe_cushion_roof etfe_foils etfe_cushion_models pv-etfe_cushion etfe_cushion_model air_systems etfe_foil_cushions conventional_etfe_cushion_structures etfe_foil_spring_cushion <leads> <etfe_cushion_roof> <etfe_foils> <etfe_cushion_models> <pv-etfe_cushion> <etfe_cushion_model> <air_systems> <etfe_foil_cushions> <conventional_etfe_cushion_structures> <etfe_foil_spring_cushion>
# 10 0.357 building_sector building_façade building_applications building_roofs building_materials building_envelopes insulation fuel_cells buildings flexible_photovoltaics <building_sector> <building_façade> <building_applications> <building_roofs> <building_materials> <building_envelopes> <insulation> <fuel_cells> <buildings> <flexible_photovoltaics>
# 16 0.074 electric_wire pumps diodes aerospace_applications spacecraft outer_skins laser_welding spacecrafts greases wire <electric_wire> <pumps> <diodes> <aerospace_applications> <spacecraft> <outer_skins> <laser_welding> <spacecrafts> <greases> <wire>
# 2 0.068 femoropopliteal_bypass femoropopliteal_bypasses valves femoropopliteal_bypass_grafts femoropopliteal_bypass_graft bypasses seals bypass femoropopliteal_bypass_grafting valve <femoropopliteal_bypass> <femoropopliteal_bypasses> <valves> <femoropopliteal_bypass_grafts> <femoropopliteal_bypass_graft> <bypasses> <seals> <bypass> <femoropopliteal_bypass_grafting> <valve>
# 9 0.019 fuel_cells filters proton_exchange_membrane_fuel_cells venous_system proton_exchange_membrane_fuel_cell system polymer_electrolyte_membrane_fuel_cells polymer_electrolyte_membrane_fuel_cell membrane_filters fuel_cell <fuel_cells> <filters> <proton_exchange_membrane_fuel_cells> <venous_system> <proton_exchange_membrane_fuel_cell> <system> <polymer_electrolyte_membrane_fuel_cells> <polymer_electrolyte_membrane_fuel_cell> <membrane_filters> <fuel_cell>
# -------------------------------------------------
# category: pfpe
# 14 0.942 greases lubricants magnetic_disk_drives hard_disk_lubricants magnetic_disks pfpe_lubricants lubricant hard_disk_drive pfpe_greases disk_lubricants <nanoimprint_lithography> <lubrications> <lubricomp> <protective_lubricant> <nanoimprint_stamps> <vivo_delivery> <disk_bearing> <arm_lubricants> <surface_lubricity> <disk_bearings>
# 19 0.021 lithium-ion_batteries lithium_ion_batteries applications polymer_electrolytes lithium-ion_battery lithium_batteries electrolytes li-ion_batteries polymer_electrolyte electronic_applications <lithium_ion_batteries> <applications> <polymer_electrolytes> <lithium-ion_battery> <li-ion_batteries> <polymer_electrolyte> <electronic_applications> <lithium_ion_battery> <libs> <support>
# 4 0.014 electrodes electrode binder cathode cell electrolyte anode cathodes cells devices <electrodes> <electrode> <cathode> <cell> <electrolyte> <anode> <cathodes> <devices> <battery> <solar_cells>
# 5 0.012 fuel_cell ptfe_transfer_film fuel_cell_performance pemfc ptfe_grafts gas_diffusion_layer pemfcs gas_diffusion_layers mfc catalyst_ink <fuel_cell> <ptfe_transfer_film> <fuel_cell_performance> <pemfc> <ptfe_grafts> <gas_diffusion_layers> <mfc> <catalyst_ink> <proton_exchange_membrane_fuel_cell> <fuel_cell_gas_diffusion_layers>
# -------------------------------------------------
# category: ptfe
# 1 0.397 gtr gbr lumbar_discectomy tract_reconstruction ptfe_/_vein_cuff tract_reconstructions infected_eptfe_mesh haemodialysis adherent ptfe_graft_reconstruction <asc> <repair_patch> <scpcs> <pd> <fibrin-based_vascular_graft> <hard_disk_media> <dvs> <antibiotic_surface_modification> <spinal_cord_repair> <small_flows>
# 2 0.136 femoropopliteal_bypass femoropopliteal_bypasses valves femoropopliteal_bypass_grafts femoropopliteal_bypass_graft bypasses seals bypass femoropopliteal_bypass_grafting valve <bioreactors> <triboelectric_devices> <paper_industry> <field_coil_insulation_material> <fluorination_agent> <printer_paper> <modifier> <oilfield> <configuration-printed_circuit_board> <glow_discharge_polymerization_method>
# 3 0.114 bearings mitral_valve_repair greases chordal_replacement gaskets tips solid_lubricant solid_lubricants repair vesicoureteral_reflux <gas_industry> <liquid_lubricant> <bone_restoration> <replacement_lubricants> <mixed_lubricants> <dental_units> <bars> <abdominal_wall_replacement> <vapor_lubrication> <vapor_phase_condensation_reflow>
# 5 0.108 fuel_cell ptfe_transfer_film fuel_cell_performance pemfc ptfe_grafts gas_diffusion_layer pemfcs gas_diffusion_layers mfc catalyst_ink <pem_fuel_cell> <improved_fuel_cell_performance> <half-membrane_electrode_assembly> <intermediate_temperature_proton_exchange_membrane_fuel_cells> <pefc> <membrane_/_electrode_assemblies> <composite_cathode_coatings> <fuel_cell_electrodes> <cathode_film> <composite_electrode_coatings>
# 13 0.093 implants graft_material hepatic_tissue stent_graft remarkable_membrane_material implant endoscopic_treatment carrier graft biosensor <corneal_implants> <implantable_biosensors> <wound_treatment> <chemical_treatment> <carbon_dioxide_carrier> <brine_treatment> <bilateral_abdominal_sacrocolpopexy> <support_substrates> <medical_implant_device> <peripheral_intravenous_catheters>
# 0 0.079 vascular_grafts vascular_access vascular_graft hemodialysis_access vascular_prostheses vascular_prosthesis bone_regeneration stent-grafts coatings guided_tissue_regeneration <prosthetic_vascular_grafts> <biomedical_devices> <wear_applications> <many_coatings_applications> <bone_tissue_engineering> <bone_tissue_engineering_applications> <vascular_prothesis> <biomaterial_applications> <sensing_applications> <stent_applications>
# 4 0.026 electrodes electrode binder cathode cell electrolyte anode cathodes cells devices <solar_cells> <solar_cell> <dye-sensitized_solar_cell> <polymeric_binder> <cathode_binder> <sensitizer> <electrochromic_devices> <polymer_binder> <li_/_lifepo_cells> <battery_cells>
# 9 0.019 fuel_cells filters proton_exchange_membrane_fuel_cells venous_system proton_exchange_membrane_fuel_cell system polymer_electrolyte_membrane_fuel_cells polymer_electrolyte_membrane_fuel_cell membrane_filters fuel_cell <polymer_electrolyte_fuel_cell_membranes> <polymer_electrolytes> <ion_exchange_membrane> <membrane_systems> <filter_monitor_membranes> <anion-exchange_membrane_fuel_cells> <electrolyte_membranes> <radiation_dosimeters> <new_ion_exchange_membrane> <dust_detectors>
# 7 0.011 ultrafiltration membrane_distillation direct_contact_membrane_distillation microfiltration water_treatment ultrafiltration_membranes wastewater_treatment ultrafiltration_membrane membrane_distillation_membranes direct_methanol_fuel_cell <ion_exchange_membrane> <water_purification_membranes> <filtration_membrane> <vacuum_membrane> <flat_membrane_distillation_membranes> <membrane_fabrication> <separation_membranes> <pervaporation_membranes> <wastewater_separation> <pervaporation_membrane>
# -------------------------------------------------
# category: pvdf
# 8 0.431 transducers transducer dssc pvdf_transducers pvdf-transducers dsscs pvdf_nanoweb_fibers pvdf_transducer ultrasonic_transducers acoustic_nanogenerator <power> <bio-_/_nano-_sensors> <dcs> <nir_dye> <nanofiber_separator> <films> <sensing_membranes> <ultrasonic_motors> <ultrasonic_motor> <concentrator>
# 12 0.149 mf ferro-actuator md dmfc dmfcs mfcs lib mfc vanadium_redox_flow_battery mbr <mfs> <alkaline_anion_exchange_membrane_water_electrolysis> <oilfield_water> <available_bench_model> <cathode_fouling> <solid-state_supercapacitor> <af> <ferroelectric_liquid_crystals_displays> <lithium_/_sulfur_battery> <high_sulfide_copper_ores>
# 19 0.116 lithium-ion_batteries lithium_ion_batteries applications polymer_electrolytes lithium-ion_battery lithium_batteries electrolytes li-ion_batteries polymer_electrolyte electronic_applications <lithium-> <biomedical_materials> <lithium_/> <tissue_engineering> <biomaterial_applications> <vivo_applications> <biomedical_material> <polymer_electrolyte_fuel_cells> <architectural_applications> <many_engineering_applications>
# 7 0.070 ultrafiltration membrane_distillation direct_contact_membrane_distillation microfiltration water_treatment ultrafiltration_membranes wastewater_treatment ultrafiltration_membrane membrane_distillation_membranes direct_methanol_fuel_cell <membrane_distillation_membranes> <separation_membrane> <nanofiltration_membrane> <exchange_membranes> <ion-exchange_membrane_fabrication> <micropore_membranes> <filter_membranes> <micro-porous_membranes> <md_membranes> <flat_membrane_contactors>
# 15 0.056 sensors sensor actuators pvdf_sensors pvdf_sensor actuator piezoelectric_sensors piezoelectric_sensor tactile_sensors pvdf_nasal_sensors <moisture_sensor> <ph_sensor> <piezoelectrets> <catheters> <pipe> <prosthesis> <sealing> <piezo-sensor> <dose_inhalers> <flexible_pressure_sensor>
# 4 0.054 electrodes electrode binder cathode cell electrolyte anode cathodes cells devices <propellant> <electroless_plating> <pt_binder> <conventional_fuel_cell> <test_cells> <unisolar_cells> <medical_polymer> <li_/_licoo_cell> <electrolyte_fuel_cells> <electrochemical_performance>
# 17 0.053 energy_harvesting energy_harvester energy_harvesters co_capture energy microbial_fuel_cells energy_storage detectors dust_detectors photocatalytic_membrane_reactor <photocatalysis> <spacecraft> <nerve_cells> <membrane_pump> <piezoelectrets> <toxin_detection> <enzyme-linked_immunosorbent_assay> <nerve_healing> <tendon_repair> <spermatoceles>
# 11 0.047 binder sensor separator composite_membrane binders separators membrane_material actuators membrane actuator <filter_material> <separation_membrane> <composite_anion-exchange_membrane> <electrode_membrane> <suture_materials> <composite_core_material> <membrane_electrode> <hydrophobic_materials> <porous_electrode> <sorbent>
# 6 0.022 hollow_fiber_membranes hollow_fiber_membrane ptfe_hollow_fiber_membranes hollow_fibre_membranes pvdf_hollow_fiber_membranes ptfe_hollow_fiber_membrane hollow_fibre_membrane fibrous_membranes pvdf_hollow_fiber_membrane hollow-fiber_membranes <ptfe_hollow_fiber_membranes> <ptfe_hollow_fiber_membrane> <ptfe_nanofibrous_membrane> <hydrophobic_ptfe_hollow_fiber_membranes> <hollow_fiber_mc> <fabric_membrane> <filter_membranes> <ptfe_hollow_fiber_membrane_module> <ptfe_flat_membrane> <md_membranes>
